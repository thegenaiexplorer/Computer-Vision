# %% [markdown]
# # Hyperparameter Optimization with Optuna
#
# Welcome to the Optuna-based hyperparameter optimization tutorial! In this interactive notebook, you will explore world of hyperparameter tuning for a Convolutional Neural Network (CNN) specifically aimed at image classification using the CIFAR-10 dataset. Hyperparameter optimization is pivotal in enhancing model performance, making your models more accurate and efficient.
#
# Optuna, a robust and versatile library, plays a central role in automating and streamlining this process. It empowers you to navigate through complex hyperparameter spaces with ease. In this tutorial, you will engage with Optuna's core functionalities, and you'll also have the opportunity to construct a flexible CNN architecture. This adaptable design is essential for understanding how models can be fine-tuned effortlessly to suit various hyperparameter configurations.
#
# Throughout this session, you will:
# - Learn how to set up and execute an Optuna study, incorporating all essential elements required for effective hyperparameter optimization.
# - Perform a thorough analysis of the results to evaluate how different hyperparameters influence model performance, gaining insights into their practical impact.
#
# Additionally, this tutorial includes an optional section where you will compare two prevalent methods of hyperparameter optimization: Optuna's default sampling method (Tree-structured Parzen Estimator, or TPE) and the traditional Grid Search method. This comparison will not only highlight the strengths of Optuna but also provide a clearer perspective on how it can outperform conventional optimization techniques.

# %% [markdown]
# ## Import Libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import optuna
import matplotlib.pyplot as plt
import helper_utils
import torch.nn.functional as F
from pprint import pprint

helper_utils.set_seed(15)

# %%
# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ## Hyperparameter Optimization for CNNs on CIFAR-10
#
# In this section, you explore the vital task of finding the optimal hyperparameters for a Convolutional Neural Network (CNN) tailored to the CIFAR-10 dataset.
# Utilizing Optuna, a sophisticated framework for hyperparameter optimization, your goal is to streamline and automate the process, ensuring efficiency and effectiveness.
# The selection of hyperparameters is notably intensive computationally and depends on various factors including the architecture of the model, the dataset characteristics, and the specific training processes involved. These elements, collectively and individually, have significant impacts on the performance outcomes of the model.
#
# ### Defining a Flexible CNN Architecture
#
# The model architecture here is deliberately designed to be flexible, accommodating variability in its layers which is pivotal for adapting to different hyperparameter configurations suggested by Optuna during optimization trials.
# The architecture is defined in a modular manner, allowing for easy adjustments and experimentation with different layer configurations, activation functions, and other hyperparameters.
#
# `FlexibleCNN` is a class that encapsulates the architecture of the CNN model:
#
# * **`__init__`**: The constructor initializes the model's feature extraction layers.
# >    * It constructs a series of convolutional blocks based on the `n_layers` parameter. Each block is a sequence of `nn.Conv2d`, `nn.ReLU`, and `nn.MaxPool2d`.
# >    * The `in_channels` for each block is set to the `out_channels` of the preceding block to ensure a seamless data flow.
# >    * All blocks are combined into a single `nn.Sequential` module assigned to the `.features` attribute, which handles feature extraction.
# >    * The classifier, `.classifier`, is initially set to `None` and will be constructed dynamically later.
#  * **`_create_classifier`**: This helper method dynamically builds the classifier part of the network.
# >    * It's called during the first forward pass once the input size for the linear layers is known.
#  * **`forward`**: This method defines the forward pass of the model.
# >    * The input `x` first passes through the `.features` layers.
# >    * The output from the feature extractor is flattened to determine the input size for the classifier.
# >    * If the `.classifier` has not been created yet, it calls `_create_classifier` to build it on the fly.
# >    * Finally, the flattened data is passed through the `.classifier` to produce the final output.

# %%
class FlexibleCNN(nn.Module):
    """
    A flexible Convolutional Neural Network with a dynamically created classifier.

    This CNN's architecture is defined by the provided hyperparameters,
    allowing for a variable number of convolutional layers. The classifier
    (fully connected layers) is constructed during the first forward pass
    to adapt to the output size of the convolutional feature extractor.
    """
    def __init__(self, n_layers, n_filters, kernel_sizes, dropout_rate, fc_size):
        """
        Initializes the feature extraction part of the CNN.

        Args:
            n_layers: The number of convolutional blocks to create.
            n_filters: A list of integers specifying the number of output
                       filters for each convolutional block.
            kernel_sizes: A list of integers specifying the kernel size for
                          each convolutional layer.
            dropout_rate: The dropout probability to be used in the classifier.
            fc_size: The number of neurons in the hidden fully connected layer.
        """
        super(FlexibleCNN, self).__init__()

        # Initialize an empty list to hold the convolutional blocks
        blocks = []
        # Set the initial number of input channels for RGB images
        in_channels = 3

        # Loop to construct each convolutional block
        for i in range(n_layers):

            # Get the parameters for the current convolutional layer
            out_channels = n_filters[i]
            kernel_size = kernel_sizes[i]
            # Calculate padding to maintain the input spatial dimensions ('same' padding)
            padding = (kernel_size - 1) // 2

            # Define a block as a sequence of Conv, ReLU, and MaxPool layers
            block = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size, padding=padding),
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)
            )
            
            # Add the newly created block to the list
            blocks.append(block)

            # Update the number of input channels for the next block
            in_channels = out_channels

        # Combine all blocks into a single feature extractor module
        self.features = nn.Sequential(*blocks)

        # Store hyperparameters needed for building the classifier later
        self.dropout_rate = dropout_rate
        self.fc_size = fc_size

        # The classifier will be initialized dynamically in the forward pass
        self.classifier = None

    def _create_classifier(self, flattened_size, device):
        """
        Dynamically creates and initializes the classifier part of the network.

        This helper method is called during the first forward pass to build the
        fully connected layers based on the feature map size from the
        convolutional base.

        Args:
            flattened_size: The number of input features for the first linear
                            layer, determined from the flattened feature map.
            device: The device to which the new classifier layers should be moved.
        """
        # Define the classifier's architecture
        self.classifier = nn.Sequential(
            nn.Dropout(self.dropout_rate),
            nn.Linear(flattened_size, self.fc_size),
            nn.ReLU(inplace=True),
            nn.Dropout(self.dropout_rate),
            nn.Linear(self.fc_size, 10)  # Assumes 10 output classes (e.g., CIFAR-10)
        ).to(device)

    def forward(self, x):
        """
        Defines the forward pass of the model.

        Args:
            x: The input tensor of shape (batch_size, channels, height, width).

        Returns:
            The output logits from the classifier.
        """
        # Get the device of the input tensor to ensure consistency
        device = x.device

        # Pass the input through the feature extraction layers
        x = self.features(x)

        # Flatten the feature map to prepare it for the fully connected layers
        flattened = torch.flatten(x, 1)
        flattened_size = flattened.size(1)

        # If the classifier has not been created yet, initialize it
        if self.classifier is None:
            self._create_classifier(flattened_size, device)

        # Pass the flattened features through the classifier to get the final output
        return self.classifier(flattened)

# %% [markdown]
# ## Defining the Optuna Objective Function
#
# The objective function is the core of the hyperparameter optimization process, being the function that Optuna will repeatedly call to evaluate different hyperparameter configurations.
# This function encapsulates the entire training and evaluation process, including the definition of the CNN model architecture, the optimizer, the data loaders, the training loop, and the evaluation metrics.
# Within this function, you define the search space for hyperparameters using `trial.suggest_*` methods, which allow Optuna to sample hyperparameters from a defined range or set of values.
# For a full list of available `suggest_*` methods, you can refer to the [Optuna documentation](https://optuna.readthedocs.io/en/stable/reference/generated/optuna.trial.Trial.html).
#
# *The objective function is designed to return a single scalar value, which represents the performance of the model for the given hyperparameters*.
# In your case, the aim to maximize the accuracy of the model on the validation set, which is computed using the `evaluate_accuracy` function.
#
# **Dynamic Layer Initialization**: A noteworthy addition to this objective function is the initialization step involving a dummy input. Because the `FlexibleCNN` creates its classifier layers dynamically during the first forward pass, these parameters do not exist immediately after the model is instantiated.
# - **Why use a dummy input?** Passing data through the model forces it to calculate the flattened feature size and build the classifier layers. You must do this *before* defining the optimizer so that `model.parameters()` includes the classifier weights. Otherwise, the optimizer would only track the feature extractor, leaving the classifier untrained.
# >
# - **Why these dimensions?** The tensor `torch.randn(1, 3, 32, 32)` is used to mimic the structure of the CIFAR-10 dataset. It represents a single image (batch size of 1) with 3 color channels (RGB) and a resolution of `32x32` pixels.
#
# Observe that some hyperparameters are defined as fixed values, such as the number of epochs, the batch size, and the learning rate.

# %%
def objective(trial, device):
    """
    Defines the objective function for hyperparameter optimization using Optuna.

    For each trial, this function samples a set of hyperparameters,
    constructs a model, trains it for a fixed number of epochs, evaluates
    its performance on a validation set, and returns the accuracy. Optuna
    uses the returned accuracy to guide its search for the best
    hyperparameter combination.

    Args:
        trial: An Optuna `Trial` object, used to sample hyperparameters.
        device: The device ('cpu' or 'cuda') for model training and evaluation.

    Returns:
        The validation accuracy of the trained model as a float.
    """
    # Sample hyperparameters for the feature extractor using the Optuna trial
    n_layers = trial.suggest_int("n_layers", 1, 3)
    n_filters = [trial.suggest_int(f"n_filters_{i}", 16, 128) for i in range(n_layers)]
    kernel_sizes = [trial.suggest_categorical(f"kernel_size_{i}", [3, 5]) for i in range(n_layers)]

    # Sample hyperparameters for the classifier
    dropout_rate = trial.suggest_float("dropout_rate", 0.1, 0.5)
    fc_size = trial.suggest_int("fc_size", 64, 256)

    # Instantiate the model with the sampled hyperparameters
    model = FlexibleCNN(n_layers, n_filters, kernel_sizes, dropout_rate, fc_size).to(device)

    # Initialize the dynamic classifier layer by passing a dummy input through the model
    # This ensures all parameters are instantiated before the optimizer is defined
    dummy_input = torch.randn(1, 3, 32, 32).to(device)
    model(dummy_input)

    # Define fixed training parameters: learning rate, loss function, and optimizer
    learning_rate = 0.001
    loss_fcn = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Define fixed data loading parameters and create data loaders
    batch_size = 128
    train_loader, val_loader = helper_utils.get_dataset_dataloaders(batch_size=batch_size)

    # Define the fixed number of epochs for training
    n_epochs = 10
    # Train the model using a helper function
    helper_utils.train_model(
        model=model,
        optimizer=optimizer,
        train_dataloader=train_loader,
        n_epochs=n_epochs,
        loss_fcn=loss_fcn,
        device=device
    )

    # Evaluate the trained model's accuracy on the validation set
    accuracy = helper_utils.evaluate_accuracy(model, val_loader, device)
    
    # Return the final accuracy for this trial
    return accuracy

# %% [markdown]
# ## Running the Optuna Study
#
# Once that the objective function is defined, an Optuna study is created to manage the hyperparameter optimization process.
# The study is responsible for running the objective function multiple times with different hyperparameter configurations, allowing Optuna to explore the search space and find the best hyperparameters.
# In this case, your goal is to **maximize the accuracy** of the CNN model on the CIFAR-10 dataset, this is why we use `direction='maximize'` when creating the study.
# The `optimize` method of the study is called to start the optimization process, which will run the objective function for a defined number of trials.
#
# A lambda function is used to pass the device to the objective function, allowing the model to be trained on the specified device
# *Note*: you can also pass other parameters to the objective function using the lambda function, if needed.
#
# **NOTE:** the code below will take about 8 minutes to run.

# %%
# Create a study object and optimize the objective function
study = optuna.create_study(direction='maximize') # The goal in this case is to maximize accuracy

# Start the optimization process (it takes about 8 minutes for 20 trials)
n_trials = 20
study.optimize(lambda trial: objective(trial, device), n_trials=n_trials) # use more trials in practice
# Out:
# [I 2026-07-12 12:55:07,753] A new study created in memory with name: no-name-1fc5e8cb-47b5-4c79-aec9-e15a3ab3dd7b
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.2627
# Epoch 10 - Train Loss: 0.8955
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 12:55:29,891] Trial 0 finished with value: 0.5865 and parameters: {'n_layers': 2, 'n_filters_0': 36, 'n_filters_1': 71, 'kernel_size_0': 3, 'kernel_size_1': 5, 'dropout_rate': 0.10741854510176521, 'fc_size': 69}. Best is trial 0 with value: 0.5865.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.4397
# Epoch 10 - Train Loss: 1.1830
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 12:55:56,591] Trial 1 finished with value: 0.571 and parameters: {'n_layers': 3, 'n_filters_0': 113, 'n_filters_1': 109, 'n_filters_2': 16, 'kernel_size_0': 3, 'kernel_size_1': 5, 'kernel_size_2': 5, 'dropout_rate': 0.3534872543038806, 'fc_size': 151}. Best is trial 0 with value: 0.5865.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.1260
# Epoch 10 - Train Loss: 0.6917
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 12:56:20,862] Trial 2 finished with value: 0.6055 and parameters: {'n_layers': 2, 'n_filters_0': 90, 'n_filters_1': 43, 'kernel_size_0': 5, 'kernel_size_1': 3, 'dropout_rate': 0.2229676025781645, 'fc_size': 256}. Best is trial 2 with value: 0.6055.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.2750
# Epoch 10 - Train Loss: 1.0023
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 12:56:46,643] Trial 3 finished with value: 0.5805 and parameters: {'n_layers': 2, 'n_filters_0': 109, 'n_filters_1': 67, 'kernel_size_0': 5, 'kernel_size_1': 3, 'dropout_rate': 0.3963342516585848, 'fc_size': 115}. Best is trial 2 with value: 0.6055.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.3120
# Epoch 10 - Train Loss: 0.9121
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 12:57:10,275] Trial 4 finished with value: 0.5985 and parameters: {'n_layers': 3, 'n_filters_0': 64, 'n_filters_1': 18, 'n_filters_2': 66, 'kernel_size_0': 5, 'kernel_size_1': 3, 'kernel_size_2': 5, 'dropout_rate': 0.18208984543545026, 'fc_size': 207}. Best is trial 2 with value: 0.6055.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.1616
# Epoch 10 - Train Loss: 0.7773
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 12:57:32,554] Trial 5 finished with value: 0.601 and parameters: {'n_layers': 2, 'n_filters_0': 64, 'n_filters_1': 73, 'kernel_size_0': 3, 'kernel_size_1': 5, 'dropout_rate': 0.22213810836868153, 'fc_size': 126}. Best is trial 2 with value: 0.6055.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.0609
# Epoch 10 - Train Loss: 0.6847
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 12:57:53,477] Trial 6 finished with value: 0.5745 and parameters: {'n_layers': 1, 'n_filters_0': 47, 'kernel_size_0': 3, 'dropout_rate': 0.16954318200944313, 'fc_size': 112}. Best is trial 2 with value: 0.6055.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.5231
# Epoch 10 - Train Loss: 1.2842
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 12:58:16,522] Trial 7 finished with value: 0.549 and parameters: {'n_layers': 3, 'n_filters_0': 66, 'n_filters_1': 47, 'n_filters_2': 123, 'kernel_size_0': 5, 'kernel_size_1': 3, 'kernel_size_2': 3, 'dropout_rate': 0.4529686298213117, 'fc_size': 68}. Best is trial 2 with value: 0.6055.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.1391
# Epoch 10 - Train Loss: 0.7689
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 12:58:37,774] Trial 8 finished with value: 0.5925 and parameters: {'n_layers': 1, 'n_filters_0': 71, 'kernel_size_0': 3, 'dropout_rate': 0.18105246591933738, 'fc_size': 94}. Best is trial 2 with value: 0.6055.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.4595
# Epoch 10 - Train Loss: 1.1868
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 12:59:02,297] Trial 9 finished with value: 0.544 and parameters: {'n_layers': 3, 'n_filters_0': 89, 'n_filters_1': 80, 'n_filters_2': 101, 'kernel_size_0': 5, 'kernel_size_1': 3, 'kernel_size_2': 3, 'dropout_rate': 0.4010811623971313, 'fc_size': 102}. Best is trial 2 with value: 0.6055.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.0941
# Epoch 10 - Train Loss: 0.6847
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 12:59:26,274] Trial 10 finished with value: 0.5765 and parameters: {'n_layers': 1, 'n_filters_0': 95, 'kernel_size_0': 5, 'dropout_rate': 0.3028200411252907, 'fc_size': 243}. Best is trial 2 with value: 0.6055.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.2917
# Epoch 10 - Train Loss: 1.0151
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 12:59:47,315] Trial 11 finished with value: 0.582 and parameters: {'n_layers': 2, 'n_filters_0': 17, 'n_filters_1': 34, 'kernel_size_0': 3, 'kernel_size_1': 5, 'dropout_rate': 0.2568212792341262, 'fc_size': 167}. Best is trial 2 with value: 0.6055.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.0836
# Epoch 10 - Train Loss: 0.6143
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 13:00:12,955] Trial 12 finished with value: 0.5935 and parameters: {'n_layers': 2, 'n_filters_0': 88, 'n_filters_1': 105, 'kernel_size_0': 5, 'kernel_size_1': 5, 'dropout_rate': 0.25412490416382727, 'fc_size': 255}. Best is trial 2 with value: 0.6055.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.2087
# Epoch 10 - Train Loss: 0.8327
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 13:00:36,830] Trial 13 finished with value: 0.613 and parameters: {'n_layers': 2, 'n_filters_0': 127, 'n_filters_1': 52, 'kernel_size_0': 3, 'kernel_size_1': 3, 'dropout_rate': 0.24818954617527839, 'fc_size': 155}. Best is trial 13 with value: 0.613.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.1983
# Epoch 10 - Train Loss: 0.8836
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 13:01:00,119] Trial 14 finished with value: 0.5785 and parameters: {'n_layers': 2, 'n_filters_0': 128, 'n_filters_1': 47, 'kernel_size_0': 3, 'kernel_size_1': 3, 'dropout_rate': 0.3157226906397165, 'fc_size': 186}. Best is trial 13 with value: 0.613.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.0419
# Epoch 10 - Train Loss: 0.4893
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 13:01:25,628] Trial 15 finished with value: 0.619 and parameters: {'n_layers': 2, 'n_filters_0': 127, 'n_filters_1': 49, 'kernel_size_0': 5, 'kernel_size_1': 3, 'dropout_rate': 0.11082716729358844, 'fc_size': 211}. Best is trial 15 with value: 0.619.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.9323
# Epoch 10 - Train Loss: 0.4622
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 13:01:51,604] Trial 16 finished with value: 0.6035 and parameters: {'n_layers': 1, 'n_filters_0': 126, 'kernel_size_0': 5, 'dropout_rate': 0.101704845087188, 'fc_size': 217}. Best is trial 15 with value: 0.619.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.1538
# Epoch 10 - Train Loss: 0.7233
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 13:02:15,648] Trial 17 finished with value: 0.607 and parameters: {'n_layers': 2, 'n_filters_0': 109, 'n_filters_1': 59, 'kernel_size_0': 3, 'kernel_size_1': 3, 'dropout_rate': 0.13906239210051835, 'fc_size': 148}. Best is trial 15 with value: 0.619.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.3649
# Epoch 10 - Train Loss: 1.0644
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 13:02:41,287] Trial 18 finished with value: 0.5615 and parameters: {'n_layers': 1, 'n_filters_0': 119, 'kernel_size_0': 5, 'dropout_rate': 0.48238040167449125, 'fc_size': 185}. Best is trial 15 with value: 0.619.
# Evaluation complete.
# Current Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/63 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 1.4727
# Epoch 10 - Train Loss: 1.2812
# Training complete!
# Evaluating:   0%|          | 0/16 [00:00<?, ?it/s]
# [I 2026-07-12 13:03:05,945] Trial 19 finished with value: 0.5365 and parameters: {'n_layers': 3, 'n_filters_0': 103, 'n_filters_1': 26, 'n_filters_2': 16, 'kernel_size_0': 3, 'kernel_size_1': 3, 'kernel_size_2': 3, 'dropout_rate': 0.259326059602424, 'fc_size': 218}. Best is trial 15 with value: 0.619.
# Evaluation complete.

# %% [markdown]
# ### Analyzing the Results
# After the optimization process is complete, you can analyze the results to understand which hyperparameters yielded the best performance.
# The `study` object contains a wealth of information about the trials, including the hyperparameters sampled, the corresponding performance metrics, and the best trial.
#
# You can access the full DataFrame of trials using the `trials_dataframe()` method, which provides a comprehensive overview of all the trials conducted during the optimization process.
# This DataFrame includes columns for the trial number, hyperparameters, and the objective value (in our case, the accuracy).
#
# To access the best hyperparameters and the best trial, you can use the `best_trial` attributes of the study object.
#
# **Note:** these results may change every time you re-run the training study.

# %%
# Extract the dataframe with the results
df = study.trials_dataframe()

df
# Out:
#     number   value             datetime_start          datetime_complete  \
# 0        0  0.5865 2026-07-12 12:55:07.755083 2026-07-12 12:55:29.890776
# 1        1  0.5710 2026-07-12 12:55:29.891594 2026-07-12 12:55:56.591505
# 2        2  0.6055 2026-07-12 12:55:56.592323 2026-07-12 12:56:20.862348
# 3        3  0.5805 2026-07-12 12:56:20.863119 2026-07-12 12:56:46.643692
# 4        4  0.5985 2026-07-12 12:56:46.644515 2026-07-12 12:57:10.275027
# 5        5  0.6010 2026-07-12 12:57:10.275844 2026-07-12 12:57:32.554210
# 6        6  0.5745 2026-07-12 12:57:32.555055 2026-07-12 12:57:53.477732
# 7        7  0.5490 2026-07-12 12:57:53.478529 2026-07-12 12:58:16.521844
# 8        8  0.5925 2026-07-12 12:58:16.522656 2026-07-12 12:58:37.773897
# 9        9  0.5440 2026-07-12 12:58:37.774686 2026-07-12 12:59:02.296892
# 10      10  0.5765 2026-07-12 12:59:02.297667 2026-07-12 12:59:26.274284
# 11      11  0.5820 2026-07-12 12:59:26.275056 2026-07-12 12:59:47.315357
# 12      12  0.5935 2026-07-12 12:59:47.316165 2026-07-12 13:00:12.955308
# 13      13  0.6130 2026-07-12 13:00:12.956094 2026-07-12 13:00:36.830064
# 14      14  0.5785 2026-07-12 13:00:36.830838 2026-07-12 13:01:00.119005
# 15      15  0.6190 2026-07-12 13:01:00.119765 2026-07-12 13:01:25.628681
# 16      16  0.6035 2026-07-12 13:01:25.629422 2026-07-12 13:01:51.604181
# 17      17  0.6070 2026-07-12 13:01:51.604999 2026-07-12 13:02:15.648318
# 18      18  0.5615 2026-07-12 13:02:15.649124 2026-07-12 13:02:41.287335
# 19      19  0.5365 2026-07-12 13:02:41.288179 2026-07-12 13:03:05.945027
#
#                  duration  params_dropout_rate  params_fc_size  \
# 0  0 days 00:00:22.135693             0.107419              69
# 1  0 days 00:00:26.699911             0.353487             151
# 2  0 days 00:00:24.270025             0.222968             256
# 3  0 days 00:00:25.780573             0.396334             115
# 4  0 days 00:00:23.630512             0.182090             207
# 5  0 days 00:00:22.278366             0.222138             126
# 6  0 days 00:00:20.922677             0.169543             112
# 7  0 days 00:00:23.043315             0.452969              68
# 8  0 days 00:00:21.251241             0.181052              94
# 9  0 days 00:00:24.522206             0.401081             102
# 10 0 days 00:00:23.976617             0.302820             243
# 11 0 days 00:00:21.040301             0.256821             167
# 12 0 days 00:00:25.639143             0.254125             255
# 13 0 days 00:00:23.873970             0.248190             155
# 14 0 days 00:00:23.288167             0.315723             186
# 15 0 days 00:00:25.508916             0.110827             211
# 16 0 days 00:00:25.974759             0.101705             217
# 17 0 days 00:00:24.043319             0.139062             148
# 18 0 days 00:00:25.638211             0.482380             185
# 19 0 days 00:00:24.656848             0.259326             218
#
#     params_kernel_size_0  params_kernel_size_1  params_kernel_size_2  \
# 0                      3                   5.0                   NaN
# 1                      3                   5.0                   5.0
# 2                      5                   3.0                   NaN
# 3                      5                   3.0                   NaN
# 4                      5                   3.0                   5.0
# 5                      3                   5.0                   NaN
# 6                      3                   NaN                   NaN
# 7                      5                   3.0                   3.0
# 8                      3                   NaN                   NaN
# 9                      5                   3.0                   3.0
# 10                     5                   NaN                   NaN
# 11                     3                   5.0                   NaN
# 12                     5                   5.0                   NaN
# 13                     3                   3.0                   NaN
# 14                     3                   3.0                   NaN
# 15                     5                   3.0                   NaN
# 16                     5                   NaN                   NaN
# 17                     3                   3.0                   NaN
# 18                     5                   NaN                   NaN
# 19                     3                   3.0                   3.0
#
#     params_n_filters_0  params_n_filters_1  params_n_filters_2  \
# 0                   36                71.0                 NaN
# 1                  113               109.0                16.0
# 2                   90                43.0                 NaN
# 3                  109                67.0                 NaN
# 4                   64                18.0                66.0
# 5                   64                73.0                 NaN
# 6                   47                 NaN                 NaN
# 7                   66                47.0               123.0
# 8                   71                 NaN                 NaN
# 9                   89                80.0               101.0
# 10                  95                 NaN                 NaN
# 11                  17                34.0                 NaN
# 12                  88               105.0                 NaN
# 13                 127                52.0                 NaN
# 14                 128                47.0                 NaN
# 15                 127                49.0                 NaN
# 16                 126                 NaN                 NaN
# 17                 109                59.0                 NaN
# 18                 119                 NaN                 NaN
# 19                 103                26.0                16.0
#
#     params_n_layers     state
# 0                 2  COMPLETE
# 1                 3  COMPLETE
# 2                 2  COMPLETE
# 3                 2  COMPLETE
# 4                 3  COMPLETE
# 5                 2  COMPLETE
# 6                 1  COMPLETE
# 7                 3  COMPLETE
# 8                 1  COMPLETE
# 9                 3  COMPLETE
# 10                1  COMPLETE
# 11                2  COMPLETE
# 12                2  COMPLETE
# 13                2  COMPLETE
# 14                2  COMPLETE
# 15                2  COMPLETE
# 16                1  COMPLETE
# 17                2  COMPLETE
# 18                1  COMPLETE
# 19                3  COMPLETE

# %%
# Extract and print the best trial
best_trial = study.best_trial

print("Best trial:")
print(f"  Value (Accuracy): {best_trial.value:.4f}")

print("  Hyperparameters:")
pprint(best_trial.params)
# Out:
# Best trial:
#   Value (Accuracy): 0.6190
#   Hyperparameters:
# {'dropout_rate': 0.11082716729358844,
#  'fc_size': 211,
#  'kernel_size_0': 5,
#  'kernel_size_1': 3,
#  'n_filters_0': 127,
#  'n_filters_1': 49,
#  'n_layers': 2}

# %% [markdown]
# ## Visualizing the Results
#
# Optuna provides several built-in visualization functions to help analyze the results of the hyperparameter optimization process.
# These visualizations can provide valuable insights into the optimization process and the impact of different hyperparameters on the model's performance:
# - `plot_optimization_history`: This plot shows the optimization history of the objective function, allowing you to see how the performance of the model improved over time. It provides a visual representation of the objective values (in this case, accuracy) across different trials.
#
# - `plot_param_importances`: This plot shows the importance of each hyperparameter in the optimization process. It helps identify which hyperparameters had the most significant impact on the model's performance, allowing you to focus on the most influential hyperparameters in future experiments.
#
# - `plot_parallel_coordinate`: This plot visualizes the relationship between different hyperparameters and the objective function. It allows you to see how different hyperparameter configurations affected the model's performance, providing insights into the interactions between hyperparameters and their impact on the objective value.

# %%
# Plotting the optimization history
optuna.visualization.matplotlib.plot_optimization_history(study)
plt.title('Optimization History')
plt.show()

# Importance of hyperparameters
optuna.visualization.matplotlib.plot_param_importances(study)
plt.show()

ax = optuna.visualization.matplotlib.plot_parallel_coordinate(
    study, params=['n_layers', 'n_filters_0', 'kernel_size_0', 'dropout_rate', 'fc_size']
)
fig = ax.figure
fig.set_size_inches(12, 6, forward=True)  # forward=True updates the canvas
fig.tight_layout()

# %% [markdown]
# ## (Optional) Comparing Grid Search with Optuna's Default Search
#
# In this section, you will compare the performance of Optuna's default search algorithm with a grid search approach.
# Grid search is a traditional method for hyperparameter optimization that exhaustively searches through a predefined set of hyperparameter combinations.
# While it can be effective, it is often computationally expensive and may not explore the search space as efficiently as Optuna's adaptive algorithms.
#
# To perform the comparison, a simpler example is used, such as the one from previous labs.
# The `FlexibleSimpleCNN` model is used on a smaller dataset, consisting in a subset of the [Fruit and Vegetable Disease (Healthy vs Rotten)](https://www.kaggle.com/datasets/muhammad0subhan/fruit-and-vegetable-disease-healthy-vs-rotten).
# This dataset contains images of healthy and rotten fruits and vegetables.
# You will only use a custom subset of the dataset, which contains 1200 images of apples, 1000 being healthy and 200 being rotten.

# %%
class FlexibleSimpleCNN(nn.Module):
    """
    A simple, flexible Convolutional Neural Network.

    This network consists of two convolutional layers, each followed by a
    max-pooling layer, and two fully connected layers. The number of filters
    in the convolutional layers and the size of the hidden linear layer are
    configurable, making the architecture adaptable to different requirements.
    """
    def __init__(self, conv1_out, conv2_out, fc_size, num_classes):
        """
        Initializes the layers of the CNN.

        Args:
            conv1_out: The number of output channels for the first
                       convolutional layer.
            conv2_out: The number of output channels for the second
                       convolutional layer.
            fc_size: The number of neurons in the hidden fully connected layer.
            num_classes: The number of output classes for the final layer.
        """
        super(FlexibleSimpleCNN, self).__init__()
        # Define the first convolutional layer
        self.conv1 = nn.Conv2d(3, conv1_out, kernel_size=3, padding=1)
        # Define the second convolutional layer
        self.conv2 = nn.Conv2d(conv1_out, conv2_out, kernel_size=3, padding=1)
        # Define a max pooling layer to be used after each convolution
        self.pool = nn.MaxPool2d(2, 2)
        
        # Define the first fully connected (hidden) layer
        # Assumes input images are 32x32, resulting in an 8x8 feature map after two pooling layers
        self.fc1 = nn.Linear(conv2_out * 8 * 8, fc_size)
        # Define the final fully connected (output) layer
        self.fc2 = nn.Linear(fc_size, num_classes)

    def forward(self, x):
        """
        Defines the forward pass of the network.

        Args:
            x: The input tensor of shape (batch_size, channels, height, width).

        Returns:
            The output logits from the network.
        """
        # Apply the first convolutional block: convolution, ReLU activation, and pooling
        x = self.pool(F.relu(self.conv1(x)))
        # Apply the second convolutional block
        x = self.pool(F.relu(self.conv2(x)))
        # Flatten the feature map to prepare for the fully connected layers
        x = x.view(x.size(0), -1)
        # Pass through the first fully connected layer with ReLU activation
        x = F.relu(self.fc1(x))
        # Pass through the final output layer
        x = self.fc2(x)
        # Return the resulting logits
        return x

# %% [markdown]
# The goal of the model is to classify the images into two classes: healthy and rotten.
# Note that the dataset is imbalanced, with a higher number of healthy images compared to rotten ones.
# In such cases, accuracy is not the best metric to evaluate model performance, as it can be misleading due to the class imbalance.
# Therefore, the **F1 score will be used as the evaluation metric**, as it is more suitable for imbalanced datasets.
# To ensure a fair comparison between grid search and Optuna's search, the same hyperparameter space will be used for both approaches.
#
# You will also use the `trial.set_user_attr` method, which allows you to store additional information in each trial object, such as accuracy, recall, precision, and F1 score.
# This is useful for tracking additional metrics that can be analyzed later.
#
# **Why no dummy input is needed here**: Unlike the `FlexibleCNN` used earlier, the `FlexibleSimpleCNN` used in this section does not require a dummy input to initialize its parameters.
#
# - **Static Initialization**: In `FlexibleSimpleCNN`, the classifier layers (`self.fc1` and `self.fc2`) are defined directly within the `__init__` method based on a fixed input, rather than being created dynamically during the first forward pass.
# >
# - **Optimizer Safety**: Because these layers exist immediately upon model instantiation, `model.parameters()` correctly includes the classifier weights right from the start. The optimizer will therefore track and train the classifier correctly without needing a "warm-up" pass.

# %%
def objective_apples(trial, device):
    """
    Defines the Optuna objective function for a CNN on an apple dataset.

    For each trial, this function samples hyperparameters for a CNN
    architecture, trains the model on a custom apple dataset, and evaluates
    its performance. It logs accuracy, precision, and recall, while
    returning the F1-score as the primary metric for Optuna to optimize.

    Args:
        trial: An Optuna `Trial` object used to sample hyperparameters.
        device: The device ('cpu' or 'cuda') for model training and evaluation.

    Returns:
        The F1-score of the trained model on the validation set.
    """
    # Sample a set of hyperparameters for the model architecture
    conv1_out = trial.suggest_int("conv1_out", 8, 64, step=8)
    conv2_out = trial.suggest_int("conv2_out", 16, 128, step=16)
    fc_size = trial.suggest_int("fc_size", 32, 256, step=32)

    # Define fixed parameters for the data loaders
    img_size = 32
    batch_size = 128

    # Create the training and validation data loaders for the apple dataset
    train_loader, val_loader = helper_utils.get_apples_dataset_dataloaders(
        img_size=img_size,
        batch_size=batch_size
    )

    # Specify the number of output classes for the dataset
    num_classes = 2
    # Create an instance of the model with the sampled hyperparameters
    model = FlexibleSimpleCNN(
        conv1_out=conv1_out,
        conv2_out=conv2_out,
        fc_size=fc_size,
        num_classes=num_classes
    ).to(device)
    
    # Define fixed training components: learning rate, optimizer, and loss function
    learning_rate = 0.001
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    loss_fcn = nn.CrossEntropyLoss()

    # Set the fixed number of epochs for the training loop
    n_epochs = 5
    # Train the model using a helper function
    helper_utils.train_model(
        model=model,
        optimizer=optimizer,
        train_dataloader=train_loader,
        n_epochs=n_epochs,
        loss_fcn=loss_fcn,
        device=device
    )

    # Evaluate the trained model on the validation set to get performance metrics
    accuracy, precision, recall, f1 = helper_utils.evaluate_metrics(
        model, val_loader, device, num_classes=2
    )

    # Log additional metrics to the Optuna trial for more detailed analysis
    trial.set_user_attr("accuracy", accuracy)
    trial.set_user_attr("precision", precision)
    trial.set_user_attr("recall", recall)

    # Return the F1-score as the objective value for Optuna to maximize
    return f1

# %% [markdown]
# With the objective function defined, you can now run both the default Optuna search algorithm and the grid search algorithm. Both methods will be executed for the same number of trials, and the results will be compared using the `plot_optimization_history` function.
#
# First, in this case, you will specify `sampler = optuna.samplers.TPESampler(seed=42)` (the default sampler in Optuna), which is the Tree-structured Parzen Estimator (TPE) sampler. The TPE sampler is a sophisticated algorithm that adapts the search space based on the results of previous trials, allowing for more efficient exploration of the hyperparameter space. Then, you will create a study object with the desired sampler and set `direction='maximize'` to indicate that you want to maximize the objective function (in this case, the F1 score). Note that the trials dataframe now includes additional columns for accuracy, recall, and precision, which were set using the `trial.set_user_attr` method inside the objective function.
#
# Next, run the grid search sampler (`sampler = optuna.samplers.GridSampler(param_grid)`) to explore the hyperparameter space. The grid search will iterate, until reaching the number of trials defined, over all possible combinations of hyperparameters in the grid, evaluating the objective function for each unique configuration without repeating any combination.

# %%
seed = 42
helper_utils.set_seed(seed)

sampler = optuna.samplers.TPESampler(seed=seed)  # Use TPE sampler (the default sampler in Optuna)

# Create a study object and optimize the objective function
study_apples = optuna.create_study(direction='maximize', sampler=sampler)

n_trials = 10
study_apples.optimize(lambda trial: objective_apples(trial, device), n_trials=n_trials)
# Out:
# [I 2026-07-12 13:04:29,235] A new study created in memory with name: no-name-5bf6aaa3-4bb2-43c9-97ef-d0cf423d6f5c
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.3548
# Training complete!
# [I 2026-07-12 13:05:08,515] Trial 0 finished with value: 0.6255446672439575 and parameters: {'conv1_out': 24, 'conv2_out': 128, 'fc_size': 192}. Best is trial 0 with value: 0.6255446672439575.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.4515
# Training complete!
# [I 2026-07-12 13:05:49,540] Trial 1 finished with value: 0.439461886882782 and parameters: {'conv1_out': 40, 'conv2_out': 32, 'fc_size': 64}. Best is trial 0 with value: 0.6255446672439575.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.3359
# Training complete!
# [I 2026-07-12 13:06:31,944] Trial 2 finished with value: 0.7176079750061035 and parameters: {'conv1_out': 8, 'conv2_out': 112, 'fc_size': 160}. Best is trial 2 with value: 0.7176079750061035.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.3461
# Training complete!
# [I 2026-07-12 13:07:12,624] Trial 3 finished with value: 0.6919227838516235 and parameters: {'conv1_out': 48, 'conv2_out': 16, 'fc_size': 256}. Best is trial 2 with value: 0.7176079750061035.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.3534
# Training complete!
# [I 2026-07-12 13:07:54,568] Trial 4 finished with value: 0.8412935733795166 and parameters: {'conv1_out': 56, 'conv2_out': 32, 'fc_size': 64}. Best is trial 4 with value: 0.8412935733795166.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.3716
# Training complete!
# [I 2026-07-12 13:08:36,681] Trial 5 finished with value: 0.5040310621261597 and parameters: {'conv1_out': 16, 'conv2_out': 48, 'fc_size': 160}. Best is trial 4 with value: 0.8412935733795166.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.2957
# Training complete!
# [I 2026-07-12 13:09:18,377] Trial 6 finished with value: 0.7342193126678467 and parameters: {'conv1_out': 32, 'conv2_out': 48, 'fc_size': 160}. Best is trial 4 with value: 0.8412935733795166.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.2838
# Training complete!
# [I 2026-07-12 13:09:58,016] Trial 7 finished with value: 0.858942985534668 and parameters: {'conv1_out': 16, 'conv2_out': 48, 'fc_size': 96}. Best is trial 7 with value: 0.858942985534668.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.3141
# Training complete!
# [I 2026-07-12 13:10:39,918] Trial 8 finished with value: 0.9125000238418579 and parameters: {'conv1_out': 32, 'conv2_out': 112, 'fc_size': 64}. Best is trial 8 with value: 0.9125000238418579.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.3694
# Training complete!
# [I 2026-07-12 13:11:20,553] Trial 9 finished with value: 0.677465558052063 and parameters: {'conv1_out': 40, 'conv2_out': 80, 'fc_size': 32}. Best is trial 8 with value: 0.9125000238418579.

# %%
df_apples_study = study_apples.trials_dataframe()

df_apples_study
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0       0  0.625545 2026-07-12 13:04:29.236318 2026-07-12 13:05:08.515752
# 1       1  0.439462 2026-07-12 13:05:08.516658 2026-07-12 13:05:49.539864
# 2       2  0.717608 2026-07-12 13:05:49.540733 2026-07-12 13:06:31.944524
# 3       3  0.691923 2026-07-12 13:06:31.945404 2026-07-12 13:07:12.623875
# 4       4  0.841294 2026-07-12 13:07:12.624786 2026-07-12 13:07:54.568475
# 5       5  0.504031 2026-07-12 13:07:54.569335 2026-07-12 13:08:36.681598
# 6       6  0.734219 2026-07-12 13:08:36.682465 2026-07-12 13:09:18.377252
# 7       7  0.858943 2026-07-12 13:09:18.378127 2026-07-12 13:09:58.016073
# 8       8  0.912500 2026-07-12 13:09:58.016968 2026-07-12 13:10:39.918784
# 9       9  0.677466 2026-07-12 13:10:39.919647 2026-07-12 13:11:20.553721
#
#                 duration  params_conv1_out  params_conv2_out  params_fc_size  \
# 0 0 days 00:00:39.279434                24               128             192
# 1 0 days 00:00:41.023206                40                32              64
# 2 0 days 00:00:42.403791                 8               112             160
# 3 0 days 00:00:40.678471                48                16             256
# 4 0 days 00:00:41.943689                56                32              64
# 5 0 days 00:00:42.112263                16                48             160
# 6 0 days 00:00:41.694787                32                48             160
# 7 0 days 00:00:39.637946                16                48              96
# 8 0 days 00:00:41.901816                32               112              64
# 9 0 days 00:00:40.634074                40                80              32
#
#    user_attrs_accuracy  user_attrs_precision  user_attrs_recall     state
# 0                0.824              0.839588           0.606009  COMPLETE
# 1                0.784              0.392000           0.500000  COMPLETE
# 2                0.864              0.860886           0.676211  COMPLETE
# 3                0.868              0.807815           0.654647  COMPLETE
# 4                0.932              0.925148           0.792602  COMPLETE
# 5                0.812              0.904858           0.530000  COMPLETE
# 6                0.872              0.930736           0.686275  COMPLETE
# 7                0.916              0.899405           0.830574  COMPLETE
# 8                0.944              0.912500           0.912500  COMPLETE
# 9                0.856              0.840949           0.641547  COMPLETE

# %%
# Run with Grid Search Sampler

# Define the hyperparameter grid
param_grid = {
    "conv1_out": list(range(8, 65, 8)),       # [8, 16, 24, 32, 40, 48, 56, 64]
    "conv2_out": list(range(16, 129, 16)),    # [16, 32, 48, 64, 80, 96, 112, 128]
    "fc_size":   list(range(32, 257, 32))     # [32, 64, 96, 128, 160, 192, 224, 256]
}

# Create a GridSampler with the defined grid
grid_sampler = optuna.samplers.GridSampler(param_grid, seed=seed)  # Use seed for reproducibility

# Create a study object with the GridSampler
study_grid = optuna.create_study(direction='maximize', sampler=grid_sampler)

study_grid.optimize(lambda trial: objective_apples(trial, device), n_trials=n_trials)
# Out:
# [I 2026-07-12 13:11:20,577] A new study created in memory with name: no-name-70e8141d-9c9e-4329-8f38-23fb51ce7c6e
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.3343
# Training complete!
# [I 2026-07-12 13:12:02,137] Trial 0 finished with value: 0.4343891441822052 and parameters: {'conv1_out': 40, 'conv2_out': 112, 'fc_size': 32}. Best is trial 0 with value: 0.4343891441822052.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.3425
# Training complete!
# [I 2026-07-12 13:12:41,115] Trial 1 finished with value: 0.44933921098709106 and parameters: {'conv1_out': 64, 'conv2_out': 96, 'fc_size': 256}. Best is trial 1 with value: 0.44933921098709106.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.2647
# Training complete!
# [I 2026-07-12 13:13:22,351] Trial 2 finished with value: 0.8049752712249756 and parameters: {'conv1_out': 56, 'conv2_out': 112, 'fc_size': 256}. Best is trial 2 with value: 0.8049752712249756.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.2777
# Training complete!
# [I 2026-07-12 13:14:05,480] Trial 3 finished with value: 0.8275692462921143 and parameters: {'conv1_out': 24, 'conv2_out': 64, 'fc_size': 64}. Best is trial 3 with value: 0.8275692462921143.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.3035
# Training complete!
# [I 2026-07-12 13:14:47,242] Trial 4 finished with value: 0.8207193613052368 and parameters: {'conv1_out': 64, 'conv2_out': 112, 'fc_size': 64}. Best is trial 3 with value: 0.8275692462921143.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.4426
# Training complete!
# [I 2026-07-12 13:15:28,879] Trial 5 finished with value: 0.45652174949645996 and parameters: {'conv1_out': 24, 'conv2_out': 16, 'fc_size': 128}. Best is trial 3 with value: 0.8275692462921143.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.3236
# Training complete!
# [I 2026-07-12 13:16:11,763] Trial 6 finished with value: 0.7238179445266724 and parameters: {'conv1_out': 32, 'conv2_out': 32, 'fc_size': 160}. Best is trial 3 with value: 0.8275692462921143.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.2880
# Training complete!
# [I 2026-07-12 13:16:52,656] Trial 7 finished with value: 0.7032498121261597 and parameters: {'conv1_out': 64, 'conv2_out': 128, 'fc_size': 96}. Best is trial 3 with value: 0.8275692462921143.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.3744
# Training complete!
# [I 2026-07-12 13:17:34,886] Trial 8 finished with value: 0.5978121161460876 and parameters: {'conv1_out': 48, 'conv2_out': 16, 'fc_size': 192}. Best is trial 3 with value: 0.8275692462921143.
# {'healthy': 0, 'rotten': 1}
# Current Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Current Batch:   0%|          | 0/8 [00:00<?, ?it/s]
# Epoch 5 - Train Loss: 0.2829
# Training complete!
# [I 2026-07-12 13:18:15,905] Trial 9 finished with value: 0.7767857313156128 and parameters: {'conv1_out': 32, 'conv2_out': 112, 'fc_size': 256}. Best is trial 3 with value: 0.8275692462921143.

# %%
# Plotting the optimization history
optuna.visualization.matplotlib.plot_optimization_history(study_apples)
plt.title('Optimization History')
plt.show()

# Plotting the optimization history
optuna.visualization.matplotlib.plot_optimization_history(study_grid)
plt.title('Optimization History')
plt.show()

# %% [markdown]
# Under the grid search approach, the objective values vary significantly because all possible combinations of hyperparameters in the grid are exhaustively evaluated.
# Since grid search does not take into account the performance of previous trials, it may waste resources evaluating many suboptimal configurations, especially in high-dimensional or redundant hyperparameter spaces.
#
# In contrast, Optuna's search algorithm employs a more intelligent, adaptive sampling strategy (such as TPE).
# It uses the results of previous trials to guide the search toward more promising regions of the hyperparameter space, allowing for a more efficient and focused exploration.
# As a result, Optuna is often able to identify better-performing hyperparameter configurations with fewer trials compared to grid search.
#
# The larger and more complex the search space becomes, the more pronounced the advantage of adaptive sampling methods like Optuna over exhaustive methods like grid search.

# %% [markdown]
# ## Conclusion
#
# Congratulations on completing the hyperparameter optimization tutorial with Optuna!
#
# In this notebook, you explored the key components of an Optuna-based optimization workflow: defining the objective function, setting up the study, and analyzing the results. You also built a flexible CNN architecture designed to accommodate varying hyperparameter configurations, allowing for more dynamic experimentation.
#
# Additionally, you compared Optuna’s default search algorithm (TPE) with a traditional grid search, demonstrating the efficiency and adaptability of Optuna in navigating complex hyperparameter spaces. Throughout the tutorial, you evaluated model performance using multiple metrics and learned how to interpret results through Optuna’s powerful visualization tools.
#
# By the end of this tutorial, you’ve gained a practical and conceptual understanding of how to integrate Optuna into deep learning projects, equipping you with a valuable skill for optimizing model performance efficiently and effectively.

# %%
# !ls
# Out:
# C2_M1_Lab_3_Optuna.ipynb  apple_ad_subset  helper_utils.py
# __pycache__		  cifar10

# %%
# !du -hs .
# Out:
# 348M	.

# %%
# !tar cvf pytorch_dlai_c2m1lab3.tar .
# Out:
# ./
# ./.ipynb_checkpoints/
# ./.ipynb_checkpoints/C2_M1_Lab_3_Optuna-checkpoint.ipynb
# ./__pycache__/
# ./__pycache__/helper_utils.cpython-311.pyc
# ./C2_M1_Lab_3_Optuna.ipynb
# tar: ./pytorch_dlai_c2m1lab3.tar: archive cannot contain itself; not dumped
# ./apple_ad_subset/
# ./apple_ad_subset/healthy/
# ./apple_ad_subset/healthy/FreshApple (1).jpg
# ./apple_ad_subset/healthy/FreshApple (10).jpg
# ./apple_ad_subset/healthy/FreshApple (100).jpg
# ./apple_ad_subset/healthy/FreshApple (101).jpg
# ./apple_ad_subset/healthy/FreshApple (105).jpg
# ./apple_ad_subset/healthy/FreshApple (111).jpg
# ./apple_ad_subset/healthy/FreshApple (112).jpg
# ./apple_ad_subset/healthy/FreshApple (113).jpg
# ./apple_ad_subset/healthy/FreshApple (116).jpg
# ./apple_ad_subset/healthy/FreshApple (12).jpg
# ./apple_ad_subset/healthy/FreshApple (124).jpg
# ./apple_ad_subset/healthy/FreshApple (13).jpg
# ./apple_ad_subset/healthy/FreshApple (132).jpg
# ./apple_ad_subset/healthy/FreshApple (133).jpg
# ./apple_ad_subset/healthy/FreshApple (134).jpg
# ./apple_ad_subset/healthy/FreshApple (135).jpg
# ./apple_ad_subset/healthy/FreshApple (136).jpg
# ./apple_ad_subset/healthy/FreshApple (138).jpg
# ./apple_ad_subset/healthy/FreshApple (139).jpg
# ./apple_ad_subset/healthy/FreshApple (14).jpg
# ./apple_ad_subset/healthy/FreshApple (140).jpg
# ./apple_ad_subset/healthy/FreshApple (142).jpg
# ./apple_ad_subset/healthy/FreshApple (145).jpg
# ./apple_ad_subset/healthy/FreshApple (149).jpg
# ./apple_ad_subset/healthy/FreshApple (15).jpg
# ./apple_ad_subset/healthy/FreshApple (152).jpg
# ./apple_ad_subset/healthy/FreshApple (156).jpg
# ./apple_ad_subset/healthy/FreshApple (157).jpg
# ./apple_ad_subset/healthy/FreshApple (16).jpg
# ./apple_ad_subset/healthy/FreshApple (166).jpg
# ./apple_ad_subset/healthy/FreshApple (167).jpg
# ./apple_ad_subset/healthy/FreshApple (168).jpg
# ./apple_ad_subset/healthy/FreshApple (171).jpg
# ./apple_ad_subset/healthy/FreshApple (172).jpg
# ./apple_ad_subset/healthy/FreshApple (173).jpg
# ./apple_ad_subset/healthy/FreshApple (174).jpg
# ./apple_ad_subset/healthy/FreshApple (176).jpg
# ./apple_ad_subset/healthy/FreshApple (178).jpg
# ./apple_ad_subset/healthy/FreshApple (182).jpg
# ./apple_ad_subset/healthy/FreshApple (184).jpg
# ./apple_ad_subset/healthy/FreshApple (186).jpg
# ./apple_ad_subset/healthy/FreshApple (187).jpg
# ./apple_ad_subset/healthy/FreshApple (190).jpg
# ./apple_ad_subset/healthy/FreshApple (192).jpg
# ./apple_ad_subset/healthy/FreshApple (195).jpg
# ./apple_ad_subset/healthy/FreshApple (197).jpg
# ./apple_ad_subset/healthy/FreshApple (199).jpg
# ./apple_ad_subset/healthy/FreshApple (2).jpg
# ./apple_ad_subset/healthy/FreshApple (20).jpg
# ./apple_ad_subset/healthy/FreshApple (200).jpg
# ./apple_ad_subset/healthy/FreshApple (22).jpg
# ./apple_ad_subset/healthy/FreshApple (23).jpg
# ./apple_ad_subset/healthy/FreshApple (30).jpg
# ./apple_ad_subset/healthy/FreshApple (31).jpg
# ./apple_ad_subset/healthy/FreshApple (32).jpg
# ./apple_ad_subset/healthy/FreshApple (33).jpg
# ./apple_ad_subset/healthy/FreshApple (34).jpg
# ./apple_ad_subset/healthy/FreshApple (38).jpg
# ./apple_ad_subset/healthy/FreshApple (39).jpg
# ./apple_ad_subset/healthy/FreshApple (42).jpg
# ./apple_ad_subset/healthy/FreshApple (48).jpg
# ./apple_ad_subset/healthy/FreshApple (5).jpg
# ./apple_ad_subset/healthy/FreshApple (50).jpg
# ./apple_ad_subset/healthy/FreshApple (51).jpg
# ./apple_ad_subset/healthy/FreshApple (53).jpg
# ./apple_ad_subset/healthy/FreshApple (55).jpg
# ./apple_ad_subset/healthy/FreshApple (56).jpg
# ./apple_ad_subset/healthy/FreshApple (58).jpg
# ./apple_ad_subset/healthy/FreshApple (60).jpg
# ./apple_ad_subset/healthy/FreshApple (61).jpg
# ./apple_ad_subset/healthy/FreshApple (64).jpg
# ./apple_ad_subset/healthy/FreshApple (7).jpg
# ./apple_ad_subset/healthy/FreshApple (72).jpg
# ./apple_ad_subset/healthy/FreshApple (78).jpg
# ./apple_ad_subset/healthy/FreshApple (85).jpg
# ./apple_ad_subset/healthy/FreshApple (86).jpg
# ./apple_ad_subset/healthy/FreshApple (87).jpg
# ./apple_ad_subset/healthy/FreshApple (88).jpg
# ./apple_ad_subset/healthy/FreshApple (9).jpg
# ./apple_ad_subset/healthy/FreshApple (90).jpg
# ./apple_ad_subset/healthy/FreshApple (91).jpg
# ./apple_ad_subset/healthy/FreshApple (92).jpg
# ./apple_ad_subset/healthy/FreshApple (93).jpg
# ./apple_ad_subset/healthy/FreshApple (98).jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 4.59.36 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.00.26 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.01.01 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.01.34 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.02.08 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.02.24 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.02.31 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.02.38 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.02.48 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.03.59 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.04.11 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.04.59 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.05.06 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.05.18 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.06.10 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.06.19 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.06.28 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.06.54 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.07.05 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.07.32 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.08.05 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.08.52 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.09.03 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.09.10 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.10.29 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.10.53 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.11.02 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.11.08 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.11.24 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.11.41 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.12.29 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.12.34 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.12.41 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.14.07 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.14.20 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.14.44 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.14.48 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.15.52 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.16.44 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.18.12 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.18.26 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.18.51 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.19.15 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.20.17 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.20.26 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.20.32 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.20.51 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.21.35 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.22.20 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.22.35 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.22.48 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.22.58 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.23.26 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.23.51 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.24.04 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.24.12 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.24.26 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.25.02 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.25.22 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.25.33 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.25.37 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.26.24 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.26.36 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.26.41 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.26.58 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.27.13 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.27.19 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.27.27 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.28.48 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.32.33 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.33.05 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.33.18 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.33.33 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.34.01 PM.jpg
# ./apple_ad_subset/healthy/Screen Shot 2018-06-08 at 5.34.21 PM.jpg
# ./apple_ad_subset/healthy/freshApple (202).jpg
# ./apple_ad_subset/healthy/freshApple (206).jpg
# ./apple_ad_subset/healthy/freshApple (214).jpg
# ./apple_ad_subset/healthy/freshApple (215).jpg
# ./apple_ad_subset/healthy/freshApple (217).jpg
# ./apple_ad_subset/healthy/freshApple (219).jpg
# ./apple_ad_subset/healthy/freshApple (224).jpg
# ./apple_ad_subset/healthy/freshApple (226).jpg
# ./apple_ad_subset/healthy/freshApple (227).jpg
# ./apple_ad_subset/healthy/freshApple (231).jpg
# ./apple_ad_subset/healthy/freshApple (234).jpg
# ./apple_ad_subset/healthy/freshApple (235).jpg
# ./apple_ad_subset/healthy/freshApple (237).jpg
# ./apple_ad_subset/healthy/freshApple (238).jpg
# ./apple_ad_subset/healthy/freshApple (241).jpg
# ./apple_ad_subset/healthy/freshApple (243).jpg
# ./apple_ad_subset/healthy/freshApple (244).jpg
# ./apple_ad_subset/healthy/freshApple (249).jpg
# ./apple_ad_subset/healthy/freshApple (254).jpg
# ./apple_ad_subset/healthy/freshApple (255).jpg
# ./apple_ad_subset/healthy/freshApple (257).jpg
# ./apple_ad_subset/healthy/freshApple (260).jpg
# ./apple_ad_subset/healthy/freshApple (266).jpg
# ./apple_ad_subset/healthy/freshApple (267).jpg
# ./apple_ad_subset/healthy/freshApple (270).jpg
# ./apple_ad_subset/healthy/freshApple (273).jpg
# ./apple_ad_subset/healthy/freshApple (274).jpg
# ./apple_ad_subset/healthy/freshApple (275).jpg
# ./apple_ad_subset/healthy/freshApple (276).jpg
# ./apple_ad_subset/healthy/freshApple (277).jpg
# ./apple_ad_subset/healthy/freshApple (278).jpg
# ./apple_ad_subset/healthy/freshApple (281).jpg
# ./apple_ad_subset/healthy/freshApple (282).jpg
# ./apple_ad_subset/healthy/freshApple (284).jpg
# ./apple_ad_subset/healthy/freshApple (285).jpg
# ./apple_ad_subset/healthy/freshApple (286).jpg
# ./apple_ad_subset/healthy/freshApple (287).jpg
# ./apple_ad_subset/healthy/freshApple (291).jpg
# ./apple_ad_subset/healthy/freshApple (293).jpg
# ./apple_ad_subset/healthy/freshApple (294).jpg
# ./apple_ad_subset/healthy/freshApple (296).jpg
# ./apple_ad_subset/healthy/freshApple (297).jpg
# ./apple_ad_subset/healthy/freshApple (298).jpg
# ./apple_ad_subset/healthy/freshApple (300).jpg
# ./apple_ad_subset/healthy/freshApple (304).jpg
# ./apple_ad_subset/healthy/freshApple (307).jpg
# ./apple_ad_subset/healthy/freshApple (310).jpg
# ./apple_ad_subset/healthy/freshApple (311).jpg
# ./apple_ad_subset/healthy/freshApple (312).jpg
# ./apple_ad_subset/healthy/freshApple (316).jpg
# ./apple_ad_subset/healthy/freshApple (317).jpg
# ./apple_ad_subset/healthy/freshApple (428).jpg
# ./apple_ad_subset/healthy/freshApple (430).jpg
# ./apple_ad_subset/healthy/freshApple (432).jpg
# ./apple_ad_subset/healthy/freshApple (433).jpg
# ./apple_ad_subset/healthy/freshApple (435).jpg
# ./apple_ad_subset/healthy/freshApple (436).jpg
# ./apple_ad_subset/healthy/freshApple (437).jpg
# ./apple_ad_subset/healthy/freshApple (438).jpg
# ./apple_ad_subset/healthy/freshApple (440).jpg
# ./apple_ad_subset/healthy/freshApple (442).jpg
# ./apple_ad_subset/healthy/freshApple (446).jpg
# ./apple_ad_subset/healthy/freshApple (447).jpg
# ./apple_ad_subset/healthy/freshApple (453).jpg
# ./apple_ad_subset/healthy/freshApple (455).jpg
# ./apple_ad_subset/healthy/freshApple (459).jpg
# ./apple_ad_subset/healthy/freshApple (461).jpg
# ./apple_ad_subset/healthy/freshApple (464).jpg
# ./apple_ad_subset/healthy/freshApple (466).jpg
# ./apple_ad_subset/healthy/freshApple (468).jpg
# ./apple_ad_subset/healthy/freshApple (471).jpg
# ./apple_ad_subset/healthy/freshApple (476).jpg
# ./apple_ad_subset/healthy/freshApple (477).jpg
# ./apple_ad_subset/healthy/freshApple (478).jpg
# ./apple_ad_subset/healthy/freshApple (480).jpg
# ./apple_ad_subset/healthy/freshApple (484).jpg
# ./apple_ad_subset/healthy/freshApple (491).jpg
# ./apple_ad_subset/healthy/freshApple (493).jpg
# ./apple_ad_subset/healthy/freshApple (495).jpg
# ./apple_ad_subset/healthy/freshApple (496).jpg
# ./apple_ad_subset/healthy/freshApple (498).jpg
# ./apple_ad_subset/healthy/freshApple (499).jpg
# ./apple_ad_subset/healthy/freshApple (502).jpg
# ./apple_ad_subset/healthy/freshApple (504).jpg
# ./apple_ad_subset/healthy/freshApple (508).jpg
# ./apple_ad_subset/healthy/freshApple (512).jpg
# ./apple_ad_subset/healthy/freshApple (514).jpg
# ./apple_ad_subset/healthy/freshApple (517).jpg
# ./apple_ad_subset/healthy/freshApple (521).jpg
# ./apple_ad_subset/healthy/freshApple (522).jpg
# ./apple_ad_subset/healthy/freshApple (523).jpg
# ./apple_ad_subset/healthy/freshApple (524).jpg
# ./apple_ad_subset/healthy/freshApple (528).jpg
# ./apple_ad_subset/healthy/freshApple (529).jpg
# ./apple_ad_subset/healthy/freshApple (533).jpg
# ./apple_ad_subset/healthy/freshApple (546).jpg
# ./apple_ad_subset/healthy/freshApple (547).jpg
# ./apple_ad_subset/healthy/freshApple (548).jpg
# ./apple_ad_subset/healthy/freshApple (549).jpg
# ./apple_ad_subset/healthy/freshApple (554).jpg
# ./apple_ad_subset/healthy/freshApple (555).jpg
# ./apple_ad_subset/healthy/freshApple (556).jpg
# ./apple_ad_subset/healthy/freshApple (557).jpg
# ./apple_ad_subset/healthy/freshApple (558).jpg
# ./apple_ad_subset/healthy/freshApple (561).jpg
# ./apple_ad_subset/healthy/freshApple (562).jpg
# ./apple_ad_subset/healthy/freshApple (566).jpg
# ./apple_ad_subset/healthy/freshApple (568).jpg
# ./apple_ad_subset/healthy/freshApple (569).jpg
# ./apple_ad_subset/healthy/freshApple (570).jpg
# ./apple_ad_subset/healthy/freshApple (572).jpg
# ./apple_ad_subset/healthy/freshApple (573).jpg
# ./apple_ad_subset/healthy/freshApple (574).jpg
# ./apple_ad_subset/healthy/freshApple (575).jpg
# ./apple_ad_subset/healthy/freshApple (576).jpg
# ./apple_ad_subset/healthy/freshApple (577).jpg
# ./apple_ad_subset/healthy/freshApple (580).jpg
# ./apple_ad_subset/healthy/freshApple (588).jpg
# ./apple_ad_subset/healthy/freshApple (592).jpg
# ./apple_ad_subset/healthy/freshApple (596).jpg
# ./apple_ad_subset/healthy/freshApple (600).jpg
# ./apple_ad_subset/healthy/freshApple (606).jpg
# ./apple_ad_subset/healthy/freshApple (610).jpg
# ./apple_ad_subset/healthy/freshApple (612).jpg
# ./apple_ad_subset/healthy/freshApple (613).jpg
# ./apple_ad_subset/healthy/freshApple (614).jpg
# ./apple_ad_subset/healthy/freshApple (615).jpg
# ./apple_ad_subset/healthy/freshApple (616).jpg
# ./apple_ad_subset/healthy/freshApple (620).jpg
# ./apple_ad_subset/healthy/freshApple (622).jpg
# ./apple_ad_subset/healthy/freshApple (623).jpg
# ./apple_ad_subset/healthy/freshApple (624).jpg
# ./apple_ad_subset/healthy/freshApple (625).jpg
# ./apple_ad_subset/healthy/freshApple (626).jpg
# ./apple_ad_subset/healthy/freshApple (627).jpg
# ./apple_ad_subset/healthy/freshApple (629).jpg
# ./apple_ad_subset/healthy/freshApple (638).jpg
# ./apple_ad_subset/healthy/freshApple (640).jpg
# ./apple_ad_subset/healthy/freshApple (642).jpg
# ./apple_ad_subset/healthy/freshApple (645).jpg
# ./apple_ad_subset/healthy/freshApple (646).jpg
# ./apple_ad_subset/healthy/freshApple (649).jpg
# ./apple_ad_subset/healthy/freshApple (650).jpg
# ./apple_ad_subset/healthy/freshApple (653).jpg
# ./apple_ad_subset/healthy/freshApple (654).jpg
# ./apple_ad_subset/healthy/freshApple (655).jpg
# ./apple_ad_subset/healthy/freshApple (656).jpg
# ./apple_ad_subset/healthy/freshApple (657).jpg
# ./apple_ad_subset/healthy/freshApple (662).jpg
# ./apple_ad_subset/healthy/freshApple (664).jpg
# ./apple_ad_subset/healthy/freshApple (670).jpg
# ./apple_ad_subset/healthy/freshApple (673).jpg
# ./apple_ad_subset/healthy/freshApple (674).jpg
# ./apple_ad_subset/healthy/freshApple (675).jpg
# ./apple_ad_subset/healthy/freshApple (679).jpg
# ./apple_ad_subset/healthy/freshApple (680).jpg
# ./apple_ad_subset/healthy/freshApple (684).jpg
# ./apple_ad_subset/healthy/freshApple (686).jpg
# ./apple_ad_subset/healthy/freshApple (689).jpg
# ./apple_ad_subset/healthy/freshApple (691).jpg
# ./apple_ad_subset/healthy/freshApple (692).jpg
# ./apple_ad_subset/healthy/freshApple (695).jpg
# ./apple_ad_subset/healthy/freshApple (696).jpg
# ./apple_ad_subset/healthy/freshApple (697).jpg
# ./apple_ad_subset/healthy/freshApple (698).jpg
# ./apple_ad_subset/healthy/freshApple (701).jpg
# ./apple_ad_subset/healthy/freshApple (704).jpg
# ./apple_ad_subset/healthy/freshApple (705).jpg
# ./apple_ad_subset/healthy/freshApple (707).jpg
# ./apple_ad_subset/healthy/freshApple (708).jpg
# ./apple_ad_subset/healthy/freshApple (714).jpg
# ./apple_ad_subset/healthy/freshApple (717).jpg
# ./apple_ad_subset/healthy/freshApple (721).jpg
# ./apple_ad_subset/healthy/freshApple (723).jpg
# ./apple_ad_subset/healthy/freshApple (725).jpg
# ./apple_ad_subset/healthy/freshApple (726).jpg
# ./apple_ad_subset/healthy/freshApple (728).jpg
# ./apple_ad_subset/healthy/freshApple (731).jpg
# ./apple_ad_subset/healthy/freshApple (732).jpg
# ./apple_ad_subset/healthy/freshApple (733).jpg
# ./apple_ad_subset/healthy/freshApple (741).jpg
# ./apple_ad_subset/healthy/freshApple (742).jpg
# ./apple_ad_subset/healthy/freshApple (745).jpg
# ./apple_ad_subset/healthy/freshApple (747).jpg
# ./apple_ad_subset/healthy/freshApple (751).jpg
# ./apple_ad_subset/healthy/freshApple (753).jpg
# ./apple_ad_subset/healthy/freshApple (754).jpg
# ./apple_ad_subset/healthy/freshApple (757).jpg
# ./apple_ad_subset/healthy/freshApple (760).jpg
# ./apple_ad_subset/healthy/freshApple (761).jpg
# ./apple_ad_subset/healthy/freshApple (762).jpg
# ./apple_ad_subset/healthy/freshApple (764).jpg
# ./apple_ad_subset/healthy/freshApple (767).jpg
# ./apple_ad_subset/healthy/freshApple (768).jpg
# ./apple_ad_subset/healthy/freshApple (769).jpg
# ./apple_ad_subset/healthy/freshApple (770).jpg
# ./apple_ad_subset/healthy/freshApple (771).jpg
# ./apple_ad_subset/healthy/freshApple (779).jpg
# ./apple_ad_subset/healthy/freshApple (780).jpg
# ./apple_ad_subset/healthy/freshApple (781).jpg
# ./apple_ad_subset/healthy/freshApple (784).jpg
# ./apple_ad_subset/healthy/freshApple (785).jpg
# ./apple_ad_subset/healthy/freshApple (795).jpg
# ./apple_ad_subset/healthy/freshApple (798).jpg
# ./apple_ad_subset/healthy/freshApple (800).jpg
# ./apple_ad_subset/healthy/freshApple (802).jpg
# ./apple_ad_subset/healthy/freshApple (803).jpg
# ./apple_ad_subset/healthy/freshApple (806).jpg
# ./apple_ad_subset/healthy/freshApple (809).jpg
# ./apple_ad_subset/healthy/freshApple (812).jpg
# ./apple_ad_subset/healthy/freshApple (814).jpg
# ./apple_ad_subset/healthy/freshApple (815).jpg
# ./apple_ad_subset/healthy/freshApple (816).jpg
# ./apple_ad_subset/healthy/freshApple (819).jpg
# ./apple_ad_subset/healthy/freshApple (820).jpg
# ./apple_ad_subset/healthy/freshApple (823).jpg
# ./apple_ad_subset/healthy/freshApple (826).jpg
# ./apple_ad_subset/healthy/freshApple (828).jpg
# ./apple_ad_subset/healthy/freshApple (829).jpg
# ./apple_ad_subset/healthy/freshApple (831).jpg
# ./apple_ad_subset/healthy/freshApple (833).jpg
# ./apple_ad_subset/healthy/freshApple (837).jpg
# ./apple_ad_subset/healthy/freshApple (838).jpg
# ./apple_ad_subset/healthy/freshApple (839).jpg
# ./apple_ad_subset/healthy/freshApple (843).jpg
# ./apple_ad_subset/healthy/freshApple (844).jpg
# ./apple_ad_subset/healthy/freshApple (846).jpg
# ./apple_ad_subset/healthy/freshApple (848).jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 4.59.36 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 4.59.44 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 4.59.57 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.00.03 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.00.12 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.00.18 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.00.26 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.00.50 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.02.24 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.02.38 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.02.48 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.03.17 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.03.59 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.04.31 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.05.06 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.05.41 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.06.10 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.06.33 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.07.26 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.07.32 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.09.17 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.09.47 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.10.03 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.10.11 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.11.24 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.11.41 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.11.52 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.12.20 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.12.29 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.12.34 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.12.41 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.12.56 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.13.54 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.14.01 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.15.21 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.15.34 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.15.39 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.15.45 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.16.44 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.16.49 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.16.57 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.17.34 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.17.42 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.18.12 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.18.16 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.19.15 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.19.58 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.20.08 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.21.40 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.21.44 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.22.15 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.22.20 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.22.35 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.23.23 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.23.31 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.25.02 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.25.22 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.25.28 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.26.24 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.26.29 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.26.36 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.26.41 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.26.52 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.26.58 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.27.34 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.28.04 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.28.15 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.28.24 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.28.42 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.28.48 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.29.07 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.29.18 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.32.38 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.32.50 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.33.05 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.33.18 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.34.07 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_15_Screen Shot 2018-06-08 at 5.34.14 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 4.59.44 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.00.12 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.00.18 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.00.26 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.00.50 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.01.41 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.02.24 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.02.43 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.03.05 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.03.59 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.04.05 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.04.11 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.04.16 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.04.24 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.04.31 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.05.18 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.05.27 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.05.48 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.06.28 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.06.40 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.06.54 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.08.52 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.08.58 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.09.03 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.09.17 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.10.37 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.11.08 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.11.59 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.13.02 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.13.54 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.14.01 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.15.09 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.15.14 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.16.06 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.17.42 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.17.58 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.18.12 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.18.58 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.20.08 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.20.32 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.21.51 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.22.15 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.22.58 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.23.07 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.23.14 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.23.26 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.23.31 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.24.26 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.25.22 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.25.33 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.25.37 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.25.49 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.26.05 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.26.24 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.26.36 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.27.06 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.27.13 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.27.27 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.27.34 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.28.04 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.28.10 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.28.15 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.29.07 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.29.24 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.33.05 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.33.11 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.33.18 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.33.55 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.34.01 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.34.07 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_30_Screen Shot 2018-06-08 at 5.34.14 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 4.59.44 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 4.59.49 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.00.03 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.00.18 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.00.43 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.00.50 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.01.08 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.01.29 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.02.31 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.03.05 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.03.17 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.03.59 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.05.06 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.06.10 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.06.19 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.06.54 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.07.05 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.07.32 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.08.46 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.09.17 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.10.21 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.10.37 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.10.53 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.11.08 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.11.16 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.11.52 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.11.59 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.12.14 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.12.29 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.12.47 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.12.56 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.13.10 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.13.18 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.13.45 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.13.54 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.14.20 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.14.56 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.15.09 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.15.34 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.15.52 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.16.28 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.16.33 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.16.44 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.16.49 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.16.57 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.17.04 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.17.34 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.18.16 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.19.15 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.19.28 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.19.58 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.20.08 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.20.17 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.20.56 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.21.06 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.21.31 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.21.35 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.22.15 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.22.27 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.22.48 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.23.14 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.23.26 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.23.31 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.23.51 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.24.19 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.25.22 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.25.37 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.26.24 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.26.36 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.26.58 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.27.13 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.27.19 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.27.34 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.28.24 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.28.38 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.28.42 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.28.48 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.29.13 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.29.18 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.32.33 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.32.50 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.33.05 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.33.27 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_45_Screen Shot 2018-06-08 at 5.34.07 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 4.59.44 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 4.59.49 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.00.18 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.00.26 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.00.43 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.00.50 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.01.01 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.01.08 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.01.15 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.03.05 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.03.34 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.03.40 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.03.59 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.04.11 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.04.31 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.04.59 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.05.27 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.06.19 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.06.23 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.06.28 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.06.33 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.06.47 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.07.18 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.08.37 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.09.25 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.09.40 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.09.47 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.10.11 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.10.29 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.10.43 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.11.16 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.11.24 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.11.59 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.12.20 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.12.34 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.12.47 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.12.56 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.13.10 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.13.25 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.13.45 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.14.56 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.15.34 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.15.52 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.16.33 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.16.49 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.17.04 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.17.42 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.18.26 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.18.37 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.19.15 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.19.28 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.19.47 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.19.58 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.20.08 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.20.42 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.21.31 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.21.51 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.22.15 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.22.53 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.22.58 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.24.04 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.24.19 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.24.26 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.25.37 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.26.05 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.27.19 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.27.34 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.28.04 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.28.10 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.28.15 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.28.59 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.29.13 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.29.24 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.29.31 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.32.38 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_60_Screen Shot 2018-06-08 at 5.33.55 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 4.59.44 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 4.59.49 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.00.03 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.01.15 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.01.22 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.01.29 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.02.43 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.02.48 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.02.54 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.03.34 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.03.40 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.04.05 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.04.16 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.04.24 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.05.18 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.05.48 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.07.05 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.07.18 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.07.26 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.07.52 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.08.05 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.08.52 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.09.31 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.09.47 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.10.03 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.10.21 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.10.43 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.10.53 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.11.02 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.11.16 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.11.41 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.12.20 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.12.29 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.12.34 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.13.18 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.13.25 PM.jpg
# ./apple_ad_subset/healthy/rotated_by_75_Screen Shot 2018-06-08 at 5.13.31 PM.jpg
# ...
# ./apple_ad_subset/rotten/rotated_by_15_Screen Shot 2018-06-08 at 2.49.27 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-07 at 2.22.00 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-07 at 2.38.04 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-07 at 2.43.54 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-07 at 2.45.35 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-07 at 2.51.45 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-07 at 2.54.41 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-07 at 2.59.13 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-07 at 3.02.18 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-08 at 2.24.37 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-08 at 2.28.42 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-08 at 2.39.35 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-08 at 2.41.39 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-08 at 2.42.38 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-08 at 2.44.13 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-08 at 2.50.14 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-08 at 2.51.43 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_30_Screen Shot 2018-06-08 at 2.52.05 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-07 at 2.18.57 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-07 at 2.35.38 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-07 at 2.37.32 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-07 at 2.38.13 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-07 at 2.40.00 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-07 at 2.42.58 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-07 at 2.43.48 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-07 at 2.44.26 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-07 at 2.47.35 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-07 at 2.51.16 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-07 at 2.53.33 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-07 at 3.00.46 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-07 at 3.00.56 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-07 at 3.04.10 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-08 at 2.21.33 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-08 at 2.25.24 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-08 at 2.26.34 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-08 at 2.28.12 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-08 at 2.30.03 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-08 at 2.31.33 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-08 at 2.36.01 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-08 at 2.39.51 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-08 at 2.45.05 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-08 at 2.50.38 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_45_Screen Shot 2018-06-08 at 2.51.09 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-07 at 2.15.50 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-07 at 2.24.02 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-07 at 2.33.47 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-07 at 2.35.10 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-07 at 2.35.21 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-07 at 2.42.58 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-07 at 2.44.59 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-07 at 2.46.04 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-07 at 3.00.00 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-07 at 3.03.12 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-07 at 3.03.21 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-07 at 3.03.46 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-07 at 3.04.10 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-07 at 3.04.47 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-08 at 2.24.09 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-08 at 2.26.09 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-08 at 2.28.42 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-08 at 2.29.33 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-08 at 2.30.26 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-08 at 2.31.23 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-08 at 2.34.47 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-08 at 2.35.10 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-08 at 2.36.31 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-08 at 2.37.13 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-08 at 2.42.58 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-08 at 2.46.25 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-08 at 2.46.36 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_60_Screen Shot 2018-06-08 at 2.47.03 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-07 at 2.20.56 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-07 at 2.37.32 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-07 at 2.38.28 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-07 at 2.38.49 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-07 at 2.40.55 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-07 at 2.41.14 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-07 at 2.44.51 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-07 at 2.46.32 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-07 at 2.50.43 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-07 at 2.56.09 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-07 at 2.57.13 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-07 at 2.58.04 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-07 at 3.03.58 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-07 at 3.05.38 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-08 at 2.24.15 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-08 at 2.24.37 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-08 at 2.25.17 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-08 at 2.28.12 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-08 at 2.29.55 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-08 at 2.42.30 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-08 at 2.47.30 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-08 at 2.48.15 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-08 at 2.50.14 PM.jpg
# ./apple_ad_subset/rotten/rotated_by_75_Screen Shot 2018-06-08 at 2.50.49 PM.jpg
# ./apple_ad_subset/rotten/rottenApple (1).jpg
# ./apple_ad_subset/rotten/rottenApple (103).jpg
# ./apple_ad_subset/rotten/rottenApple (118).jpg
# ./apple_ad_subset/rotten/rottenApple (152).jpg
# ./apple_ad_subset/rotten/rottenApple (154).jpg
# ./apple_ad_subset/rotten/rottenApple (164).jpg
# ./apple_ad_subset/rotten/rottenApple (166).jpg
# ./apple_ad_subset/rotten/rottenApple (18).jpg
# ./apple_ad_subset/rotten/rottenApple (180).jpg
# ./apple_ad_subset/rotten/rottenApple (2).jpg
# ./apple_ad_subset/rotten/rottenApple (214).jpg
# ./apple_ad_subset/rotten/rottenApple (227).jpg
# ./apple_ad_subset/rotten/rottenApple (228).jpg
# ./apple_ad_subset/rotten/rottenApple (25).jpg
# ./apple_ad_subset/rotten/rottenApple (255).jpg
# ./apple_ad_subset/rotten/rottenApple (265).jpg
# ./apple_ad_subset/rotten/rottenApple (3).jpg
# ./apple_ad_subset/rotten/rottenApple (305).jpg
# ./apple_ad_subset/rotten/rottenApple (316).jpg
# ./apple_ad_subset/rotten/rottenApple (320).jpg
# ./apple_ad_subset/rotten/rottenApple (336).jpg
# ./apple_ad_subset/rotten/rottenApple (344).jpg
# ./apple_ad_subset/rotten/rottenApple (345).jpg
# ./apple_ad_subset/rotten/rottenApple (365).jpg
# ./apple_ad_subset/rotten/rottenApple (371).jpg
# ./apple_ad_subset/rotten/rottenApple (399).jpg
# ./apple_ad_subset/rotten/rottenApple (429).jpg
# ./apple_ad_subset/rotten/rottenApple (434).jpg
# ./apple_ad_subset/rotten/rottenApple (439).jpg
# ./apple_ad_subset/rotten/rottenApple (455).jpg
# ./apple_ad_subset/rotten/rottenApple (478).jpg
# ./apple_ad_subset/rotten/rottenApple (491).jpg
# ./apple_ad_subset/rotten/rottenApple (504).jpg
# ./apple_ad_subset/rotten/rottenApple (510).jpg
# ./apple_ad_subset/rotten/rottenApple (512).jpg
# ./apple_ad_subset/rotten/rottenApple (519).jpg
# ./apple_ad_subset/rotten/rottenApple (522).jpg
# ./apple_ad_subset/rotten/rottenApple (524).jpg
# ./apple_ad_subset/rotten/rottenApple (546).jpg
# ./apple_ad_subset/rotten/rottenApple (557).jpg
# ./apple_ad_subset/rotten/rottenApple (57).jpg
# ./apple_ad_subset/rotten/rottenApple (573).jpg
# ./apple_ad_subset/rotten/rottenApple (578).jpg
# ./apple_ad_subset/rotten/rottenApple (74).jpg
# ./apple_ad_subset/rotten/rottenApple (83).jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-07 at 2.17.15 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-07 at 2.19.15 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-07 at 2.20.04 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-07 at 2.33.38 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-07 at 2.37.53 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-07 at 2.39.35 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-07 at 2.40.48 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-07 at 2.45.09 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-07 at 2.56.34 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-07 at 2.57.13 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-07 at 2.58.17 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-07 at 3.00.56 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-07 at 3.01.21 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-08 at 2.25.43 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-08 at 2.26.55 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-08 at 2.30.26 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-08 at 2.37.03 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-08 at 2.37.19 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-08 at 2.40.56 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-08 at 2.44.13 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-08 at 2.45.44 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-08 at 2.46.44 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-08 at 2.48.43 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-08 at 2.49.27 PM.jpg
# ./apple_ad_subset/rotten/saltandpepper_Screen Shot 2018-06-08 at 2.52.20 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-07 at 2.15.20 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-07 at 2.24.35 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-07 at 2.24.47 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-07 at 2.31.43 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-07 at 2.33.47 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-07 at 2.43.13 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-07 at 2.45.09 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-07 at 2.47.13 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-07 at 2.50.43 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-07 at 2.52.22 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-07 at 3.01.21 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-07 at 3.04.24 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-07 at 3.04.35 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-07 at 3.06.30 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-08 at 2.24.09 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-08 at 2.31.33 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-08 at 2.37.03 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-08 at 2.37.24 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-08 at 2.39.35 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-08 at 2.44.54 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-08 at 2.46.44 PM.jpg
# ./apple_ad_subset/rotten/translation_Screen Shot 2018-06-08 at 2.52.05 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.16.54 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.36.21 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.37.32 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.38.38 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.39.35 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.39.44 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.40.48 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.41.07 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.41.23 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.42.18 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.44.26 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.47.20 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.50.52 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.51.45 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 2.54.08 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 3.01.38 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 3.01.54 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 3.03.46 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 3.03.58 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-07 at 3.05.13 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-08 at 2.34.05 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-08 at 2.37.24 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-08 at 2.38.47 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-08 at 2.42.22 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-08 at 2.43.29 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-08 at 2.50.33 PM.jpg
# ./apple_ad_subset/rotten/vertical_flip_Screen Shot 2018-06-08 at 2.50.49 PM.jpg
# ./cifar10/
# ./cifar10/cifar-10-batches-py/
# ./cifar10/cifar-10-batches-py/batches.meta
# ./cifar10/cifar-10-batches-py/data_batch_1
# ./cifar10/cifar-10-batches-py/data_batch_2
# ./cifar10/cifar-10-batches-py/data_batch_3
# ./cifar10/cifar-10-batches-py/data_batch_4
# ./cifar10/cifar-10-batches-py/data_batch_5
# ./cifar10/cifar-10-batches-py/readme.html
# ./cifar10/cifar-10-batches-py/test_batch
# ./helper_utils.py
