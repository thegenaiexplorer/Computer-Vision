# %% [markdown]
# ## Milestone 1.1

# %%
# !nvidia-smi
# Out:
# Mon Apr 17 02:29:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   71C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
# Out:
# Your runtime has 13.6 gigabytes of available RAM

# %%
import requests
import pickle
import zipfile
import time
import os
#from google.colab import drive
import random
import glob
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy import asarray
from PIL.ImageStat import Stat
# !pip install pydicom
import pydicom
# Package for converting PNG Files to DICOM(.dcm ) format
# !pip install simpleitk
import SimpleITK as sitk
from sklearn.model_selection import train_test_split
from PIL import Image
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import DataFrameIterator
#from keras_preprocessing.image.dataframe_iterator import DataFrameIterator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Conv2D, AveragePooling2D, Flatten, Dense, Activation, MaxPool2D, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydicom in /usr/local/lib/python3.9/dist-packages (2.3.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: simpleitk in /usr/local/lib/python3.9/dist-packages (2.2.1)

# %%
data_path = './content'
archive_path = data_path + '/data/'
if os.path.exists(archive_path):
  print(f"{archive_path} directory exists.")
else:
  print(f"Did not find {archive_path} directory, creating one...")
  os.mkdir('./content')

  os.mkdir(archive_path)
  if os.path.exists(archive_path):
    print(f'{archive_path} created successfully')
# Out:
# ./content/data/ directory exists.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#!mv /content/gdrive/MyDrive/Manning_Projects/archive\ \(2\).zip /content/gdrive/MyDrive/Manning_Projects/covid_data.zip
# !ls /content/gdrive/MyDrive/Manning_Projects/
# Out:
#  Best_Project_XRAY_VGG16_transfer_learning_conv.ipynb
# 'Copy of Project_XRAY_Resnet50_fc_removed.ipynb'
#  covid_data.zip
#  model_best_weights.zip
#  Project_XRAY_Resnet18.ipynb
#  Project_XRAY_Resnet50.ipynb
# 'Project_XRAY_VGG16_Transfer_Learning (1).ipynb'
#  Project_XRAY_VGG16_transfer_learning_conv.ipynb
#  Project_XRAY_VGG16_Transfer_Learning.ipynb
#  Project_XRAY_ViT.ipynb
#  XRAY_NFC_resnet50_model_best_weights.zip
#  XRAY_resnet50_model_best_weights.zip

# %%
DRIVE_PATH = '/content/gdrive/MyDrive/Manning_Projects/'
ARCHIVE_ZIP_FILE = DRIVE_PATH + 'covid_data.zip'
ARCHIVE_ZIP_FILE
# Out:
# '/content/gdrive/MyDrive/Manning_Projects/covid_data.zip'

# %%
# !cp {ARCHIVE_ZIP_FILE} ./content/data/

# %%
archive_file =  archive_path + 'covid_data.zip'

size = os.path.getsize(archive_file)
  
print(f'Size of the file is {size/1024} MegaBytes.')
# Out:
# Size of the file is 796903.357421875 MegaBytes.

# %%
with zipfile.ZipFile(archive_file, "r") as zip_ref:
  print("Unzipping archive") 
  zip_ref.extractall(archive_path)
# Out:
# Unzipping archive

# %%
# !rm -rf ./content/data/COVID-19_Radiography_Dataset/Lung_Opacity

# %%
# !rm -rf ./content/data/COVID-19_Radiography_Dataset/Viral\ Pneumonia

# %%
COVID_IMAGE_PATH = './content/data/COVID-19_Radiography_Dataset/COVID/images'
NON_COVID_IMAGE_PATH = './content/data/COVID-19_Radiography_Dataset/Normal/images'

# %%
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
walk_through_dir(COVID_IMAGE_PATH)
# Out:
# There are 0 directories and 3616 images in './content/data/COVID-19_Radiography_Dataset/COVID/images'.

# %%
walk_through_dir(NON_COVID_IMAGE_PATH)
# Out:
# There are 0 directories and 10192 images in './content/data/COVID-19_Radiography_Dataset/Normal/images'.

# %%
random.seed(42)

COVID_IMAGE_PATH_LIST = glob.glob(COVID_IMAGE_PATH + "/*.png")
len(COVID_IMAGE_PATH_LIST), type(COVID_IMAGE_PATH_LIST)
# Out:
# (3616, list)

# %%
NON_COVID_IMAGE_PATH_LIST = glob.glob(NON_COVID_IMAGE_PATH + "/*.png")
len(NON_COVID_IMAGE_PATH_LIST), type(NON_COVID_IMAGE_PATH_LIST)
# Out:
# (10192, list)

# %%
random_image_cov = random.choice(COVID_IMAGE_PATH_LIST)
cov_pic = Image.open(random_image_cov) #.convert('L')
cov_pic.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=299x299 at 0x7FDCA9AFDD00>

# %%
random_image_ncov = random.choice(NON_COVID_IMAGE_PATH_LIST)
ncov_pic = Image.open(random_image_ncov) #.convert('L')
ncov_pic.show()
type(ncov_pic)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=299x299 at 0x7FDC13AFA2E0>
# PIL.PngImagePlugin.PngImageFile

# %%
def image_show(image_list, label):
  fig, subs = plt.subplots(3,3, figsize=(16,12))
  for i, sub in enumerate(subs.flatten()):
    #image_path = os.path.normpath(image[i])
    print(f'Image path is {image_list[i]} and label is {label}')
    img = Image.open(image_list[i])
    img.thumbnail((224,224))
    sub.imshow(img, cmap='gray')
    #sub.axis("off")
    print(f'Size of displayed image is {img.size}')
    sub.set_title(label)

# %%
random.seed(3)
ll_d_c =  []
for i in range(9):
  im = random.choice(COVID_IMAGE_PATH_LIST)
  ll_d_c.append(im)
print(ll_d_c, len(ll_d_c))

ll_d_nc = []
for i in range(9):
  im = random.choice(NON_COVID_IMAGE_PATH_LIST)
  ll_d_nc.append(im)

print(ll_d_nc, len(ll_d_nc))
# Out:
# ['./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-939.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1866.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-3602.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1481.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2145.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-3351.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-205.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-411.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1156.png'] 9
# ['./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-7459.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-4799.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5313.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5039.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-8739.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-7503.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6736.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-8293.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5557.png'] 9

# %%
image_show(ll_d_c, 'COVID')
# Out:
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-939.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1866.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-3602.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1481.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2145.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-3351.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-205.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-411.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1156.png and label is COVID
# Size of displayed image is (224, 224)

# %%
image_show(ll_d_nc, 'NON-COVID')
# Out:
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-7459.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-4799.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5313.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5039.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-8739.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-7503.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6736.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-8293.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5557.png and label is NON-COVID
# Size of displayed image is (224, 224)

# %%
#def img_resize_save(img_path_list):
#  for i in range(len(img_path_list)):
#    temp_img = Image.open(img_path_list[i])
#    temp_img.thumbnail((224,224))
#    temp_img.save(img_path_list[i])
#  print('All images in supplied list resized to (224,224)')

#Originally I was under impression that all files have to be resized to 224,224 and then saved to disk. This is mentioned as a separate task.
#Hence, the logical deduction

# %%
df = pd.DataFrame({'Class': [len(NON_COVID_IMAGE_PATH_LIST), len(COVID_IMAGE_PATH_LIST)]})

# %%
total_class = df.Class.sum()
total_class
# Out:
# 13808

# %%
df['per_distr'] = df['Class'].apply(lambda x: x/total_class)
df.index = ['Non_Covid', 'Covid']

# %%
df.Class.plot(kind="bar", figsize=(8,6))
plt.ylabel("Number of Images")
plt.xlabel("Image Class")
plt.title("Distribution of Covid/Non-Covid Images")
plt.show()

# %%
list_arr = []
for pic in COVID_IMAGE_PATH_LIST:
  pic_np = np.array(Image.open(pic).convert('L'))
  pic_np = pic_np.reshape(299,299,1)
  list_arr.append(pic_np)

# %%
len(list_arr)
# Out:
# 3616

# %%
covid_arr = np.array(list_arr)

# %%
covid_arr.shape
# Out:
# (3616, 299, 299, 1)

# %%
np.mean(covid_arr), np.min(covid_arr), np.max(covid_arr), np.std(covid_arr)
# Out:
# (139.52120961679765, 0, 255, 61.90712697550073)

# %%
# Flatten the image data into a 1D array
pixel_values = covid_arr.flatten()

pixel_values.shape
# Out:
# (323274016,)

# %%
# Plot a histogram of the pixel values
plt.hist(pixel_values, bins=50)
plt.suptitle("Distribution of pixel values for Covid Image Data")
plt.show()

# %%
list_arr_nc = []
for pic in NON_COVID_IMAGE_PATH_LIST:
  pic_np_nc = np.array(Image.open(pic).convert('L'))
  pic_np_nc = pic_np_nc.reshape(299,299,1)
  list_arr_nc.append(pic_np_nc)
len(list_arr_nc)
# Out:
# 10192

# %%
covid_arr_nc = np.array(list_arr_nc)
covid_arr_nc.shape
# Out:
# (10192, 299, 299, 1)

# %%
np.min(covid_arr_nc), np.max(covid_arr_nc), np.mean(covid_arr_nc), np.std(covid_arr_nc)
# Out:
# (0, 255, 129.38979982014257, 66.21686464627402)

# %%
# Flatten the image data into a 1D array
pixel_values_nc = covid_arr_nc.flatten()
pixel_values_nc.shape
# Out:
# (911174992,)

# %%
# Plot a histogram of the pixel values
fig, subs = plt.subplots(1,2, figsize=(24,6))
for i, sub in enumerate(subs.flatten()):
  if i==0:
    sub.hist(pixel_values_nc, bins=50)
    sub.set_title("Distribution of pixel values for Non-Covid Image Data")
  else:
    sub.hist(pixel_values, bins=50)
    sub.set_title("Distribution of pixel values for Covid Image Data")

# %% [markdown]
# ## Observation
#
# It can be seen from above two histograms that pixel intensity for covid data is more peaked(kurtosis is high) than for non-covid images.
#
# This confirms with fact that X-Ray images for covid infected patients show white patches in chest X-Ray Images.

# %%
from torchvision import transforms
grayscale_3D = transforms.Grayscale(num_output_channels=3)

# %%
#Lets do simple check on whether the pixel data that we get from converted .dcm files is same what we get from original png image
image = COVID_IMAGE_PATH_LIST[0]
im1 = Image.open(image).convert('L')
######
#newcode for 3D conversion
print("mean for 1D" , np.mean(np.array(im1)))
output_3D = grayscale_3D(im1)
im1 = np.array(output_3D)
print(im1.shape, type(im1), np.mean(im1))
#######
#im1= np.array(im1)
img= sitk.GetImageFromArray(im1)
sitk.WriteImage(img,'./template.dcm')
# Out:
# mean for 1D 169.9040279191508
# (299, 299, 3) <class 'numpy.ndarray'> 169.9040279191508

# %%
fig, subs = plt.subplots(1,2, figsize=(12,6))
for i, sub in enumerate(subs.flatten()):
  if i==0:
    #ds = pydicom.dcmread('template.dcm')
    # Load the DICOM file
    ds = pydicom.dcmread('./template.dcm')
    # Access the image data
    image_d = ds.pixel_array
    print(type(image_d),image_d.shape, np.mean(image_d))
    sub.imshow(image_d, cmap='gray')
    sub.set_title("Image data from .dcm file")
  else:
    sub.imshow(im1, cmap='gray')
    sub.set_title("Image data from original png file")
# Out:
# <class 'numpy.ndarray'> (299, 299, 3) 169.9040279191508

# %% [markdown]
# ## It does looks like the data from both sources are one and same.
# ## STATUS : VERIFIED

# %% [markdown]
# ## Convert all the PNG Files to DICOM (.dcm) Format

# %%
DCM_FILE_PATH = './content/data/DCM/'
COVID_DCM_FILE_PATH = './content/data/DCM/COVID/'
NON_COVID_DCM_FILE_PATH = './content/data/DCM/NON_COVID/'
if os.path.exists(DCM_FILE_PATH):
  print(f"{DCM_FILE_PATH} directory exists.")
  if os.path.exists(COVID_DCM_FILE_PATH):
    print(f'{COVID_DCM_FILE_PATH} directory exists')
  else:
    print(f'Ok... looks like {COVID_DCM_FILE_PATH} does not exists. Let us make one')
    os.mkdir(COVID_DCM_FILE_PATH)
    print(f'{COVID_DCM_FILE_PATH} directory created successfully')
  if os.path.exists(NON_COVID_DCM_FILE_PATH):
    print(f'{NON_COVID_DCM_FILE_PATH} directory exists')
  else:
    print(f'Ok... looks like {NON_COVID_DCM_FILE_PATH} does not exists. Let us make one')
    os.mkdir(NON_COVID_DCM_FILE_PATH)
    print(f'{NON_COVID_DCM_FILE_PATH} directory created successfully')
else:
  print(f'Looks like there is no directory structure below /content/data.. Lets create required directory structures')
  print(f'Creating {DCM_FILE_PATH} directory path first')
  os.mkdir(DCM_FILE_PATH)
  print(f'{DCM_FILE_PATH} directory created successfully')

  print(f'Creating {COVID_DCM_FILE_PATH} directory path')
  os.mkdir(COVID_DCM_FILE_PATH)
  print(f'{COVID_DCM_FILE_PATH} directory created successfully')

  print(f'Creating {NON_COVID_DCM_FILE_PATH} directory path')
  os.mkdir(NON_COVID_DCM_FILE_PATH)
  print(f'{NON_COVID_DCM_FILE_PATH} directory created successfully')
# Out:
# ./content/data/DCM/ directory exists.
# ./content/data/DCM/COVID/ directory exists
# ./content/data/DCM/NON_COVID/ directory exists

# %%
#output_image = grayscale_3D(img_pil)
def pngtodcm(image_list, COVID, l_i):
  print(f'COVID variable is set to {COVID}')
  list_im = []
  list_im = l_i

  for png_image in image_list:
    #png_im_arr = np.array(Image.open(png_image).convert('L'))
    image_1D = Image.open(png_image).convert('L')
    #newcode for 3D conversion
    output_3D = grayscale_3D(image_1D)
    png_im_arr = np.array(output_3D)
    ##end newcode
    dcm_im_arr = sitk.GetImageFromArray(png_im_arr)
    if COVID:
      SAVE_PATH = COVID_DCM_FILE_PATH
      list_im = list_im_c
    else:
      SAVE_PATH = NON_COVID_DCM_FILE_PATH
      list_im = list_im_nc
    FILENAME = png_image.split("/")[-1].split(".")[0]
    DCM_FILENAME = SAVE_PATH + FILENAME + '.dcm'
    sitk.WriteImage(dcm_im_arr, DCM_FILENAME)
    print(f'Successfully converted and saved {DCM_FILENAME}')
    list_im.append(DCM_FILENAME)

# %%
list_im_c = []
pngtodcm(COVID_IMAGE_PATH_LIST, True, list_im_c)
# Out:
# COVID variable is set to True
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1727.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2823.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2563.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1896.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-892.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3337.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2647.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2037.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2457.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1451.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1871.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1654.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1319.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2411.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3188.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2418.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2376.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-715.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1580.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-428.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-883.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-324.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-216.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1001.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3368.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3267.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2213.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2022.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-557.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2256.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-948.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2038.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2883.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2632.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3440.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-875.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2230.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3219.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1206.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3438.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2172.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2210.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2972.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1298.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-666.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2845.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-541.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3417.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1441.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1747.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1848.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3077.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3609.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-833.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1929.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-297.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1269.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1644.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1104.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-879.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1014.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2075.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2090.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3372.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-937.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3153.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2770.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2483.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-138.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1625.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1961.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2035.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1447.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-643.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-282.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1328.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3420.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-706.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3386.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-476.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1653.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1997.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-269.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3356.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2508.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3441.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2010.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-380.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-436.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-591.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3068.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-308.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2945.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-139.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1537.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-928.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2750.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3241.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2335.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2438.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3510.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-487.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-403.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1829.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1604.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-382.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1384.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-683.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3044.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1111.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-424.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-667.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3021.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-429.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-384.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2807.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-888.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-991.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1372.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-481.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2107.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1120.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1923.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-30.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-826.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2653.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-162.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3014.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1273.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1311.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2822.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-42.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2948.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2214.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2643.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1978.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-168.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3268.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-973.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-244.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-77.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-893.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2674.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3437.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1490.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1430.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-414.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1295.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1184.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1468.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2887.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1415.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2940.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1636.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1684.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2777.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2221.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-111.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2612.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2524.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-498.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-769.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2917.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1115.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3152.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2189.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1029.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-71.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1421.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3555.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2834.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3090.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1955.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1307.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2442.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-956.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1629.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1254.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2097.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2154.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-339.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-453.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1113.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2615.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2424.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-239.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1946.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2395.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1039.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2133.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2051.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-108.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2583.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-228.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2607.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-685.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1804.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-929.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1708.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-661.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-663.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3198.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1769.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2728.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2837.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2876.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2364.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3598.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2867.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1203.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2257.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2378.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-754.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3579.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1554.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1647.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-602.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1453.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-671.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2024.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-461.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2585.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2401.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-558.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1460.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2673.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3583.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-63.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1563.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-351.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3224.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1544.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2849.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1347.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-353.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-460.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-50.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1061.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-217.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-465.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-39.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3150.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1363.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2435.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2562.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1191.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2447.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-606.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1035.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1541.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1576.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-167.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3164.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2543.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1990.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2190.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-234.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1239.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2225.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1894.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-285.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1521.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2298.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-961.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-575.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1141.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3313.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1638.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3097.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3108.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1321.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1207.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3503.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2506.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-121.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1610.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-853.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2116.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2928.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3458.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-767.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-439.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2410.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1504.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-912.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3004.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2900.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1176.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-445.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1398.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1758.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2134.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2882.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-624.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2367.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2290.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2722.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-688.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2234.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2061.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1286.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-191.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2970.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3289.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2730.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1672.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2389.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2589.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1837.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1548.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2386.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-851.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1049.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1759.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-408.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-214.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1983.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1976.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2101.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3532.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1312.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1911.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2207.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3494.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-539.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3411.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-572.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3480.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2192.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3379.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2875.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-571.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1117.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2368.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3410.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1790.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3215.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-981.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1594.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1788.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3124.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3398.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1379.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3352.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3523.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1939.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2796.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2650.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-689.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3230.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-915.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2475.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-70.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3522.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-705.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-737.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2409.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2002.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1836.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-570.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2866.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-147.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-74.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1267.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2165.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-811.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3498.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-997.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2870.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1581.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1122.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-935.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1395.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-376.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2178.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1802.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3460.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2765.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-9.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2520.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-433.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2676.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1028.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1463.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-28.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-744.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-320.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1020.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1702.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-569.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-250.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-477.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2216.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1313.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-251.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1750.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2681.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2608.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3314.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2995.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1511.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1169.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1130.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3576.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1454.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-806.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-857.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3476.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-140.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1056.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1276.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2269.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-316.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2538.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-566.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-516.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-844.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1650.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3526.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1331.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1067.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1950.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2151.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-723.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3509.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-484.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3002.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2428.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-698.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3520.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3317.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-383.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3278.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1752.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-760.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1694.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1844.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3242.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3113.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1841.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-304.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-115.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1833.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3055.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-839.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1465.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-531.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2593.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-813.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2577.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2792.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1590.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3530.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2719.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-544.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3171.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1005.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2873.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2311.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3207.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2721.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2231.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1143.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2535.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2203.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-650.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-331.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3444.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-374.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3081.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1051.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-556.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1512.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1247.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2088.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1626.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-444.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-936.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2964.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-845.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1356.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-149.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-858.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2623.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-696.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-46.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2412.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1066.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-215.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-463.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2745.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2284.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-471.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3538.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1550.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1252.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2786.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1810.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2471.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-781.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2631.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1106.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2148.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1341.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1096.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1877.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-310.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2550.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-57.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2635.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2949.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2295.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1030.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1013.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2031.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1370.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2299.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1719.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-356.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1098.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-302.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2579.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2762.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1210.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-542.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-61.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2383.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1643.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2455.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3362.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3451.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1660.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2329.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1481.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1787.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1198.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1471.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2705.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1155.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1021.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1734.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-626.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-116.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-823.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1516.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-925.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2398.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3285.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2292.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2844.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1116.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3302.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2933.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1915.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2669.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-340.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1739.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-950.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3167.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3298.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2058.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-44.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1517.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2742.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1492.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2096.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-120.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2253.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-298.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2162.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3156.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-83.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-874.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1697.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2938.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3550.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-435.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3306.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3117.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3570.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3256.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1525.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2316.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2086.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1387.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1973.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2922.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3385.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3205.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2453.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-164.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2678.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3400.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1418.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3214.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1045.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-413.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3363.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-451.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-202.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1213.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3465.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-401.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3505.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2297.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-209.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1086.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2636.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-564.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1551.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-728.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-186.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-94.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1163.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1383.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1706.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2557.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1077.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-6.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-468.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-246.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3132.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2011.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1221.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-89.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3220.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2222.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2158.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-36.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-131.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-212.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1473.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1938.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1351.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2716.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2137.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1996.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1807.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2894.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2402.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1217.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-404.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-118.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1965.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1406.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-470.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-955.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2790.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3371.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-709.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-701.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2710.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1054.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1918.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1345.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1242.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3254.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-703.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2177.dcm
# ...
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3026.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1065.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2164.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1695.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2965.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1646.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2032.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2487.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-482.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1984.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2310.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2392.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1386.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-765.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2465.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2440.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-524.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3158.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2812.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3547.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-856.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3383.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-738.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1083.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-827.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1133.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-577.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3250.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-546.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2224.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3455.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-207.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2571.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1726.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3122.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1880.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1600.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3174.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-596.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-921.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1856.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-54.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1998.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-362.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3011.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3396.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1583.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1003.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-641.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-716.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3479.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3424.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2899.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1325.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3019.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-204.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-638.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3287.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2779.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-627.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3588.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1315.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-863.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-588.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1153.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-170.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1794.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3236.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-553.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2273.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2375.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-780.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-646.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2312.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-364.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-166.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-265.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-267.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-992.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-4.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1779.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-92.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-840.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3327.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2325.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1927.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1472.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2782.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3027.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1655.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2087.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2503.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-586.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2597.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1546.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3238.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3453.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1072.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-897.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3551.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2961.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1102.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2554.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3364.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3350.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1199.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1558.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-196.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-45.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-600.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2430.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3102.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-37.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1619.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2799.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-506.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3258.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2509.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1811.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2784.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-372.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1507.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-658.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3390.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1681.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-334.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2703.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3419.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2321.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1601.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1533.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1882.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3434.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2462.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3477.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2454.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-622.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-876.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-473.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2828.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-261.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2169.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2480.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2444.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-294.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-579.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2361.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2843.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1885.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1074.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1063.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2317.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3408.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3199.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3425.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3565.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-496.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-230.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-158.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-292.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2237.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1380.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3519.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1703.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2848.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3013.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1046.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-66.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-555.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1335.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-824.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-832.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2783.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-766.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1070.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2971.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3054.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1797.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1314.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1330.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2016.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-873.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1002.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-127.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1969.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-125.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1502.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-538.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2507.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2630.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2106.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-325.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1427.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2217.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2385.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1201.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-438.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-759.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1444.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2619.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1435.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3592.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3601.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2726.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-132.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-872.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-678.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3426.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-895.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1129.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3361.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-255.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-274.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-26.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1564.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-817.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1508.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3292.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2159.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2089.dcm

# %%
len(list_im_c)
# Out:
# 3616

# %%
list_im_nc = []
pngtodcm(NON_COVID_IMAGE_PATH_LIST, False, list_im_nc)
# Out:
# Streaming output truncated to the last 5000 lines.
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4432.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1122.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1352.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-14.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2254.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6038.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9372.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1073.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7619.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5518.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5501.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7202.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1310.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9151.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1408.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8196.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2703.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6891.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7369.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-418.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5410.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7557.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4665.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9962.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1383.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5270.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5926.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9190.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1885.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5260.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8007.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3173.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4259.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4708.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9458.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2349.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7257.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1109.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3529.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8132.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2612.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5699.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5416.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9365.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2986.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-602.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-752.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5402.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3432.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8041.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2768.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6432.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1651.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2065.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4643.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5383.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2043.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7078.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7414.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7830.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5784.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1009.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6947.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1805.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1720.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7466.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9980.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1393.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5315.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9839.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-123.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6535.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3986.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6467.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9997.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7711.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9730.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-69.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1148.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5863.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9773.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-152.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6242.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8753.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9226.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6989.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-649.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6826.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5981.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1746.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1736.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-100.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9361.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7228.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2434.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8379.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6710.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8845.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10032.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4848.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3613.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4192.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1743.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9249.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5426.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6340.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9666.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2710.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6133.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2268.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9003.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-354.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3402.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8183.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8667.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5182.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4875.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1766.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2061.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7738.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1849.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2923.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9658.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7723.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-215.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5566.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9667.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1589.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2315.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7355.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5464.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8226.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-948.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8165.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6588.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-900.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7192.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8178.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2395.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5451.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4576.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-337.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7004.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3642.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10185.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4333.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8366.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8180.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1422.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4365.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4389.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-918.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4053.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7461.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-660.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8640.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-819.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1200.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8428.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9320.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9402.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1050.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3533.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5804.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8087.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8733.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2823.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2629.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5152.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3217.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9765.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9985.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9589.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7229.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2948.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4340.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2818.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6884.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2368.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-407.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-824.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5255.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9687.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7499.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9825.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7046.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6001.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5232.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9915.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9828.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1107.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3983.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7984.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8470.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7515.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4083.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1695.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3360.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1795.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6980.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3672.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-369.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8808.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6047.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3575.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6439.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4433.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3881.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-375.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2184.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1832.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8859.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2867.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7850.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9692.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-836.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7175.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2928.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-696.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9326.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7297.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7728.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8655.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5906.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6199.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-793.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8353.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5367.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-578.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7934.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9873.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5832.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8715.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3547.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10021.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2378.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4329.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8301.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5901.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3556.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1121.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-98.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3790.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5587.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-119.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5280.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-582.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7045.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2064.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5203.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-153.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4266.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2099.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10138.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5626.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-594.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8169.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6936.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3410.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9862.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5292.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7349.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6492.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3149.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9193.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-768.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6101.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8462.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7032.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6004.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5085.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1678.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4511.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8241.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1379.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8793.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1856.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2286.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3710.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5077.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9549.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7432.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5934.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-974.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4378.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2199.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2079.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9846.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3210.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1558.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1046.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1315.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8348.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6907.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2989.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-313.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6739.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6678.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6006.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4578.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6478.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9619.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7322.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9005.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4322.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9411.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3292.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7529.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7405.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1852.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2866.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9058.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8440.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-841.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1511.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-94.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2716.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3687.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2561.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2376.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4067.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3404.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5915.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1516.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2437.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6369.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-675.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8903.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9885.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9710.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8906.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7382.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4481.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1580.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-489.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6093.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5205.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9469.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2429.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5882.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4444.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5215.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1740.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9745.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-591.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5612.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1072.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10005.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5629.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5053.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1915.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5544.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5314.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3675.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2048.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4579.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6743.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7173.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4998.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8221.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5539.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2499.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9714.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1344.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8883.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4214.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3811.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3246.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8557.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-383.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3711.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-504.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10148.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7448.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9049.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8142.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9857.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-55.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8972.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-691.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9353.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6895.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4384.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3097.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1527.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5946.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6608.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9500.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5633.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7824.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1214.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-920.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5972.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2623.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4530.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7195.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9883.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8861.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5737.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7285.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-321.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1820.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2508.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-237.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1963.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9218.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-269.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2566.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3403.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1768.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2166.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7570.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1562.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9936.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9263.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4070.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8904.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1434.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2976.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8027.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5274.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5300.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4595.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8162.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4694.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7732.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9837.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8896.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3029.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5241.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6822.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8284.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6547.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9013.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1830.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9974.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5701.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2141.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8783.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9223.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5513.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9270.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8101.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10090.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4923.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8554.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5436.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2833.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-349.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7852.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5909.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8004.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9618.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1936.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-74.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8048.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7494.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1834.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2423.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-473.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9042.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1178.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1047.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3677.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6851.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2133.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6734.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3530.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4951.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2534.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9339.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4633.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1533.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-753.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6582.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10186.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2030.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5172.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6274.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2574.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8875.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8787.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2294.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8380.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7094.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3704.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8313.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6155.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3435.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2010.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9859.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4504.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3417.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1630.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3809.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10081.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1699.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5846.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-966.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6750.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1224.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2824.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8490.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9170.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6520.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6132.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3709.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4622.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2398.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4908.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2941.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8224.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4170.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7972.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8602.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1243.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6840.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4960.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5571.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10128.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7880.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4232.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4135.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4871.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4798.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5107.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9780.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2502.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2372.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5124.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6832.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4522.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9116.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5382.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4689.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4045.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8765.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7737.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7282.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-393.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4452.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3357.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-48.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6617.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-711.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1103.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1345.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9660.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3896.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6095.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8066.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6049.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-690.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5866.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1602.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5927.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4920.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8663.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10190.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1297.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9061.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4974.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3602.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2838.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-800.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7427.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5769.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8801.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6173.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3190.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6860.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5603.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2999.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6949.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9597.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2927.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8782.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6512.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2530.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7658.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9079.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7746.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4564.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5323.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9653.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7949.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6310.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4858.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3412.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8668.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3787.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3715.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4712.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4968.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5933.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1169.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5714.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7564.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4477.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4779.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7321.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1342.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4773.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5644.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9852.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3359.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9066.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-484.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4146.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4187.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7789.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6343.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-816.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9808.dcm
# ...
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3112.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8769.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5467.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6127.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10102.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1076.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7033.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4800.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1255.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5802.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1006.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1584.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9310.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4289.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2821.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2046.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1586.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7794.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3559.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8233.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2091.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3968.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1877.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-633.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6431.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6971.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5254.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9293.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5188.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3298.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-382.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4025.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8619.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1326.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1199.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9009.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8939.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8113.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3763.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9799.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5877.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2400.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3399.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8460.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6843.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3786.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2904.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7303.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8558.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-159.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9205.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7199.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6577.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7067.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2342.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9608.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4253.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6491.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4972.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2969.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4040.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8609.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7074.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1001.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1248.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5887.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2234.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6613.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3243.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1240.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6080.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3252.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6690.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3453.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8647.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3664.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5030.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1360.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9289.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1916.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2835.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3639.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8676.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5952.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9699.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-622.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5820.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6644.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4520.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8146.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6390.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5691.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5462.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3326.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8645.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8474.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8703.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6787.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9137.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2610.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5138.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5311.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6030.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3847.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9340.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2451.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1033.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6456.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2243.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2828.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9613.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1960.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7329.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9485.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-142.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-792.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5783.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2344.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1967.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6441.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4838.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5097.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6104.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6450.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1613.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2536.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5975.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3853.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-870.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5226.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-233.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5610.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-222.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3476.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9176.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1711.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3142.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9831.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7317.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-415.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6035.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-765.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7005.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-941.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9187.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8467.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6835.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1525.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6453.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10126.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4427.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6059.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4913.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6576.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3568.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7249.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4623.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6475.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4087.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5477.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2755.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9719.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5295.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6968.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6179.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8306.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8096.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8788.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6174.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-70.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8737.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1895.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6873.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2810.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4567.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8394.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6457.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1207.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9078.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9960.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2169.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1312.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1597.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1872.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3151.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1987.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9281.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1380.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3282.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7247.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8982.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-216.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7001.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1198.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10057.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2415.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9076.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8545.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-429.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7155.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3729.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2865.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4231.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1020.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1937.dcm

# %%
len(list_im_nc), len(list_im_c)
# Out:
# (10192, 3616)

# %%
len(NON_COVID_IMAGE_PATH_LIST), len(COVID_IMAGE_PATH_LIST)
# Out:
# (10192, 3616)

# %%
list_im_nc[0], list_im_c[0]
# Out:
# ('./content/data/DCM/NON_COVID/Normal-1089.dcm',
#  './content/data/DCM/COVID/COVID-1727.dcm')

# %%
def extract_fnames(file_list):
  temp_ll = []
  for i in file_list:
    fname = i.split("/")[-1].split(".")[0]
    temp_ll.append(fname)
    return sorted(temp_ll)

# %%
ll_dc_fname = extract_fnames(list_im_c)
ll_dnc_fname = extract_fnames(list_im_nc)
ll_pc_fname = extract_fnames(COVID_IMAGE_PATH_LIST)
ll_pnc_fname = extract_fnames(NON_COVID_IMAGE_PATH_LIST)

# %%
ll_dc_fname == ll_pc_fname
# Out:
# True

# %%
ll_dnc_fname == ll_pnc_fname
# Out:
# True

# %%
df_nc = pd.DataFrame()

# %%
df_nc['filename'] = list_im_nc

# %%
df_nc['class'] = 0

# %%
df_nc
# Out:
#                                            filename  class
# 0      ./content/data/DCM/NON_COVID/Normal-1089.dcm      0
# 1      ./content/data/DCM/NON_COVID/Normal-5957.dcm      0
# 2      ./content/data/DCM/NON_COVID/Normal-1316.dcm      0
# 3      ./content/data/DCM/NON_COVID/Normal-5054.dcm      0
# 4      ./content/data/DCM/NON_COVID/Normal-4166.dcm      0
# ...                                             ...    ...
# 10187  ./content/data/DCM/NON_COVID/Normal-3729.dcm      0
# 10188  ./content/data/DCM/NON_COVID/Normal-2865.dcm      0
# 10189  ./content/data/DCM/NON_COVID/Normal-4231.dcm      0
# 10190  ./content/data/DCM/NON_COVID/Normal-1020.dcm      0
# 10191  ./content/data/DCM/NON_COVID/Normal-1937.dcm      0
#
# [10192 rows x 2 columns]

# %%
label_1 = list(np.ones(len(list_im_c), dtype=int))
len(label_1), len(list_im_c)
# Out:
# (3616, 3616)

# %%
dict_c = {'filename': list_im_c, 'class': label_1}

# %%
df_c = pd.DataFrame(data=dict_c)

# %%
df_c
# Out:
#                                      filename  class
# 0     ./content/data/DCM/COVID/COVID-1727.dcm      1
# 1     ./content/data/DCM/COVID/COVID-2823.dcm      1
# 2     ./content/data/DCM/COVID/COVID-2563.dcm      1
# 3     ./content/data/DCM/COVID/COVID-1896.dcm      1
# 4      ./content/data/DCM/COVID/COVID-892.dcm      1
# ...                                       ...    ...
# 3611   ./content/data/DCM/COVID/COVID-817.dcm      1
# 3612  ./content/data/DCM/COVID/COVID-1508.dcm      1
# 3613  ./content/data/DCM/COVID/COVID-3292.dcm      1
# 3614  ./content/data/DCM/COVID/COVID-2159.dcm      1
# 3615  ./content/data/DCM/COVID/COVID-2089.dcm      1
#
# [3616 rows x 2 columns]

# %%
df = pd.concat([df_nc, df_c])

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns=['index'], inplace=True)

# %%
df
# Out:
#                                            filename  class
# 0      ./content/data/DCM/NON_COVID/Normal-1089.dcm      0
# 1      ./content/data/DCM/NON_COVID/Normal-5957.dcm      0
# 2      ./content/data/DCM/NON_COVID/Normal-1316.dcm      0
# 3      ./content/data/DCM/NON_COVID/Normal-5054.dcm      0
# 4      ./content/data/DCM/NON_COVID/Normal-4166.dcm      0
# ...                                             ...    ...
# 13803        ./content/data/DCM/COVID/COVID-817.dcm      1
# 13804       ./content/data/DCM/COVID/COVID-1508.dcm      1
# 13805       ./content/data/DCM/COVID/COVID-3292.dcm      1
# 13806       ./content/data/DCM/COVID/COVID-2159.dcm      1
# 13807       ./content/data/DCM/COVID/COVID-2089.dcm      1
#
# [13808 rows x 2 columns]

# %%
df['class'].value_counts()
# Out:
# 0    10192
# 1     3616
# Name: class, dtype: int64

# %%
df.to_csv('./content/data/DCM/dcm_files_list_labels.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13808 entries, 0 to 13807
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  13808 non-null  object
#  1   class     13808 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 215.9+ KB

# %% [markdown]
# ## Milestone 1.2

# %%
df_loaddata = pd.read_csv('./content/data/DCM/dcm_files_list_labels.csv')

# %%
df_loaddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13808 entries, 0 to 13807
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  13808 non-null  object
#  1   class     13808 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 215.9+ KB

# %%
len(df_loaddata.filename.unique())
# Out:
# 13808

# %%
df_loaddata['class'].value_counts()
# Out:
# 0    10192
# 1     3616
# Name: class, dtype: int64

# %%
df_X = df_loaddata.drop(columns=['class'])
df_y = df_loaddata['class']

# %%
df_y.head(), df_X.head()
# Out:
# (0    0
#  1    0
#  2    0
#  3    0
#  4    0
#  Name: class, dtype: int64,
#                                         filename
#  0  ./content/data/DCM/NON_COVID/Normal-1089.dcm
#  1  ./content/data/DCM/NON_COVID/Normal-5957.dcm
#  2  ./content/data/DCM/NON_COVID/Normal-1316.dcm
#  3  ./content/data/DCM/NON_COVID/Normal-5054.dcm
#  4  ./content/data/DCM/NON_COVID/Normal-4166.dcm)

# %%
train_df, test_df = train_test_split(df_loaddata, test_size=0.2, random_state=42, stratify=df['class'])

len(train_df), len(test_df)
# Out:
# (11046, 2762)

# %%
# we need to further reserve 20% data in training for validation
train_df, valid_df = train_test_split(train_df, test_size=0.2, random_state=42, stratify=train_df['class'])

len(train_df), len(valid_df)
# Out:
# (8836, 2210)

# %%
train_df['class'].sum(), valid_df['class'].sum(), test_df['class'].sum()
# Out:
# (2314, 579, 723)

# %%
train_df['class'].sum() + valid_df['class'].sum() + test_df['class'].sum()
# Out:
# 3616

# %%
train_aug_params = dict(
    #rescale=1./255,
    rotation_range=10,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    brightness_range = [0.8, 1.2],
    #preprocessing_function = preprocess_input
)

valid_aug_params = dict(
    #rescale=1./255
    #preprocessing_function = preprocess_input
    )

test_aug_params = dict(
    #rescale=1./255
    #preprocessing_function = preprocess_input
)

# %%
#Creating augmenters

train_augmenter = ImageDataGenerator(**train_aug_params)
valid_augmenter = ImageDataGenerator(**valid_aug_params)
test_augmenter = ImageDataGenerator(**test_aug_params)

# %%
type(train_augmenter), type(valid_augmenter), type(test_augmenter)
# Out:
# (keras.preprocessing.image.ImageDataGenerator,
#  keras.preprocessing.image.ImageDataGenerator,
#  keras.preprocessing.image.ImageDataGenerator)

# %%
# training parameters
BATCH_SIZE = 32
COLOR_MODE = 'rgb'
TARGET_SIZE = (224, 224)
EPOCHS = 10

train_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE,  
}

valid_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE, 
    'shuffle': False
}

test_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE,  # resize input images
    'shuffle': False
}

# %%
ds = pydicom.dcmread('./content/data/DCM/NON_COVID/Normal-5054.dcm')
# Access the image data
image_d = ds.pixel_array
print(type(image_d),image_d.shape)
img_pil = Image.fromarray(image_d)

#fig, subs = plt.subplots(1,2, figsize=(12,6))

#for i, sub in enumerate(subs.flatten()):
#  if i==0:
plt.imshow(img_pil, cmap='gray')
plt.title("Image data from .dcm file before converting to RGB")
plt.show()
img_pil.mode
#print("Mean for 1D", np.mean(np.array(img_pil)))
#output_image = grayscale_3D(img_pil)
#print(output_image.size, type(output_image), output_image.mode, output_image.getbands())
#print("Mean for 3D", np.mean(np.array(output_image)))
#print(np.array(output_image).shape)
#plt.imshow(output_image, cmap='gray')
#plt.title("Image data from .dcm file after converting to RGB")
#plt.show()
#output_image = grayscale_3D('./content/data/DCM/NON_COVID/Normal-5054.dcm')
#output_image.size, type(output_image)
# Out:
# <class 'numpy.ndarray'> (299, 299, 3)
# 'RGB'

# %%
#png_im_arr = np.array(output_image) #.convert('L'))
#dcm_im_arr = sitk.GetImageFromArray(png_im_arr)
#print(type(dcm_im_arr))
#FILENAME = './dcm_3CH.dcm' #png_image.split("/")[-1].split(".")[0]
#DCM_FILENAME = SAVE_PATH + FILENAME + '.dcm'
#sitk.WriteImage(dcm_im_arr, FILENAME)
#print(f'Successfully converted and saved {FILENAME}')

#ds = pydicom.dcmread('./dcm_3CH.dcm')
# Access the image data
#image_d = ds.pixel_array
#print(type(image_d),image_d.shape)
#img_pil = Image.fromarray(image_d)
#plt.imshow(image_d, cmap='gray')
#plt.show()
#print("Mean of all channels", np.mean(image_d))

# %%
class DCMDataFrameIterator(DataFrameIterator):
    def __init__(self, *arg, **kwargs):
        self.white_list_formats = ('dcm')
        super(DCMDataFrameIterator, self).__init__(*arg, **kwargs)
        self.dataframe = kwargs['dataframe']
        self.x = self.dataframe[kwargs['x_col']]
        self.y = self.dataframe[kwargs['y_col']]
        self.color_mode = kwargs['color_mode']
        self.target_size = kwargs['target_size']

    def _get_batches_of_transformed_samples(self, indices_array):
        # get batch of images
        batch_x = np.array([self.read_dcm_as_array(dcm_path, self.target_size, color_mode=self.color_mode)
                            for dcm_path in self.x.iloc[indices_array]])

        batch_y = np.array(self.y.iloc[indices_array].astype(np.uint8))  # astype because y was passed as str

        # transform images
        if self.image_data_generator is not None:
            for i, (x, y) in enumerate(zip(batch_x, batch_y)):
                transform_params = self.image_data_generator.get_random_transform(x.shape)
                batch_x[i] = self.image_data_generator.apply_transform(x, transform_params)
                
                # you can change y here as well, eg: in semantic segmentation you want to transform masks as well 
                # using the same image_data_generator transformations.

        return batch_x, batch_y

    @staticmethod
    def read_dcm_as_array(dcm_path, target_size=(256, 256), color_mode='rgb'):
        #image_array = pydicom.dcmread(dcm_path).pixel_array
       # image = Image.fromarray(image_array) #converts from array to PIL
        #image = Image.open(image).convert('L')
        #image.thumbnail((224,224)) #resize image to 224,224
        #image_array = cv2.resize(image_array, target_size, interpolation=cv2.INTER_NEAREST)  #this returns a 2d array
        #image_array = np.expand_dims(image, -1)
        image_array = pydicom.dcmread(dcm_path).pixel_array
        image = Image.fromarray(image_array) #converts from array to PIL
        image.thumbnail((224,224)) #resize image to 224,224
        image_array = np.array(image)
        return image_array.astype(np.float32)

# %%
dcm_path  = './content/data/DCM/NON_COVID/Normal-5054.dcm'
image_array = pydicom.dcmread(dcm_path).pixel_array
image = Image.fromarray(image_array) #converts from array to PIL
image.thumbnail((224,224)) #resize image to 224,224
print("After image thumbnail size is", np.array(image).shape)
image_array = np.expand_dims(image, 0)
print(image_array.shape)
# Out:
# After image thumbnail size is (224, 224, 3)
# (1, 224, 224, 3)

# %%
train_df['class'] = train_df['class'].astype('str')
valid_df['class'] = valid_df['class'].astype('str')
test_df['class'] = test_df['class'].astype('str')

# %%
train_df.info(), valid_df.info(),  test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8836 entries, 13528 to 8134
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  8836 non-null   object
#  1   class     8836 non-null   object
# dtypes: object(2)
# memory usage: 207.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2210 entries, 6681 to 12452
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  2210 non-null   object
#  1   class     2210 non-null   object
# dtypes: object(2)
# memory usage: 51.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2762 entries, 1939 to 8436
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  2762 non-null   object
#  1   class     2762 non-null   object
# dtypes: object(2)
# memory usage: 64.7+ KB
# (None, None, None)

# %%
train_generator = DCMDataFrameIterator(dataframe=train_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=train_augmenter,
                             **train_consts)

valid_generator = DCMDataFrameIterator(dataframe=valid_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=valid_augmenter,
                             **valid_consts)

test_generator = DCMDataFrameIterator(dataframe=test_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=test_augmenter,
                             **test_consts)
# Out:
# Found 8836 validated image filenames belonging to 2 classes.
# Found 2210 validated image filenames belonging to 2 classes.
# Found 2762 validated image filenames belonging to 2 classes.

# %%
#train_augmenter.fit(train_generator)

# %%
classes = ['NON-COVID', 'COVID']

# %%
for i in train_generator:
  x = i
  break

# %%
im, lab = x
im.shape, lab.shape
# Out:
# ((32, 224, 224, 3), (32,))

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(train_generator))

imgs.shape, labels.shape, type(imgs), type(labels)
# Out:
# ((32, 224, 224, 3), (32,), numpy.ndarray, numpy.ndarray)

# %%
imgs[0].mean(), imgs[0].max(), imgs[0].min()
# Out:
# (139.35083, 177.0, 18.0)

# %%
imgs[0].shape, type(imgs[0])
# Out:
# ((224, 224, 3), numpy.ndarray)

# %%
imgs[0]
# Out:
# array([[[ 77.,  77.,  77.],
#         [ 78.,  78.,  78.],
#         [ 78.,  78.,  78.],
#         ...,
#         [ 47.,  47.,  47.],
#         [ 47.,  47.,  47.],
#         [ 49.,  49.,  49.]],
#
#        [[ 76.,  76.,  76.],
#         [ 77.,  77.,  77.],
#         [ 77.,  77.,  77.],
#         ...,
#         [ 47.,  47.,  47.],
#         [ 47.,  47.,  47.],
#         [ 49.,  49.,  49.]],
#
#        [[ 74.,  74.,  74.],
#         [ 76.,  76.,  76.],
#         [ 76.,  76.,  76.],
#         ...,
#         [ 47.,  47.,  47.],
#         [ 47.,  47.,  47.],
#         [ 49.,  49.,  49.]],
#
#        ...,
#
#        [[127., 127., 127.],
#         [131., 131., 131.],
#         [133., 133., 133.],
#         ...,
#         [ 56.,  56.,  56.],
#         [ 31.,  31.,  31.],
#         [ 28.,  28.,  28.]],
#
#        [[127., 127., 127.],
#         [131., 131., 131.],
#         [133., 133., 133.],
#         ...,
#         [ 44.,  44.,  44.],
#         [ 24.,  24.,  24.],
#         [ 25.,  25.,  25.]],
#
#        [[127., 127., 127.],
#         [132., 132., 132.],
#         [133., 133., 133.],
#         ...,
#         [ 37.,  37.,  37.],
#         [ 18.,  18.,  18.],
#         [ 23.,  23.,  23.]]], dtype=float32)

# %%
#im_rgb = imgs[0][:, :, [2, 1, 0]]
#img_arr_rgb = Image.fromarray(im_rgb)
#img_arr_bgr.mode
#img_arr_bgr = Image.fromarray(imgs[0])
#img_arr_bgr.mode
plt.imshow(imgs[0][:,:,0], cmap='gray')
#plt.title(classes[labels[0]])
#plt.show()

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(valid_generator))
print(imgs.shape, labels.shape, type(imgs), type(labels))
plt.imshow(imgs[0][:,:,0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()
# Out:
# (32, 224, 224, 3) (32,) <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(test_generator))
print(imgs.shape, labels.shape, type(imgs), type(labels))
plt.imshow(imgs[0][:,:,0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()
# Out:
# (32, 224, 224, 3) (32,) <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
imgs[0].dtype
# Out:
# dtype('float32')

# %%
#imgs[0]

# %%
#help(train_generator)

# %%
import tensorflow
from tensorflow.keras.layers import ZeroPadding2D, Add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.applications import  VGG16
l2_reg = l2(0.001)

# %%
basemodel = VGG16(weights='imagenet', include_top=False, input_tensor=Input(shape=(224,224,3)), pooling='avg')
basemodel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
basemodel.output, basemodel.layers, basemodel
# Out:
# (<KerasTensor: shape=(None, 512) dtype=float32 (created by layer 'global_average_pooling2d')>,
#  [<keras.engine.input_layer.InputLayer at 0x7fdc117e08e0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fdc116019a0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fdc11878970>,
#   <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x7fdadaa136a0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fdc11878f70>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fdc11771430>,
#   <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x7fdc117787f0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fdadae69a90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fdc1161ef70>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fdc1187e580>,
#   <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x7fdc117c4130>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fdc1187e760>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fdc115039d0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fdc11437070>,
#   <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x7fdc11740a90>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fdc11437cd0>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fdc267ed640>,
#   <keras.layers.convolutional.conv2d.Conv2D at 0x7fdc13bc3ca0>,
#   <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x7fdc11638b20>,
#   <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D at 0x7fdc116386a0>],
#  <keras.engine.functional.Functional at 0x7fdc11638490>)

# %%
class VGG16_TL(tensorflow.keras.Model):
  def __init__(self):
    super().__init__()

    self.basemodel = VGG16(weights='imagenet', include_top=False, input_tensor=Input(shape=(224,224,3)))
    for layer in self.basemodel.layers:
      layer.trainable=False
    self.classifier = Sequential([
        Flatten(),
        Dense(4096, use_bias=False),
        BatchNormalization(),
        Activation('relu'),
        Dropout(0.3),
        Dense(4096, use_bias=False),
        BatchNormalization(),
        Activation('relu'),
        Dropout(0.3),
        Dense(2)
    ])

  def call(self,x):
    #for layer in self.basemodel.layers:
     # layer.trainable=False
    x = preprocess_input(x)
    x = self.basemodel(x)
    x = self.classifier(x)
    return x

# %%
model = VGG16_TL()

# %%
#VGG16_custom(224).build([None, 224,244,1,])
X_input = Input(shape=(224,224,3,))
out = VGG16_TL()(X_input)
temp_model = Model(inputs=X_input, outputs=out)
temp_model.summary(expand_nested=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg16_tl_1 (VGG16_TL)       (None, 2)                 134293314
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | vgg16 (Functional)        (None, 7, 7, 512)         14714688  |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_4 (InputLayer)    [(None, 224, 224, 3)]     0         ||
# ||                                                             ||
# || block1_conv1 (Conv2D)   (None, 224, 224, 64)      1792      ||
# ||                                                             ||
# || block1_conv2 (Conv2D)   (None, 224, 224, 64)      36928     ||
# ||                                                             ||
# || block1_pool (MaxPooling2D)  (None, 112, 112, 64)  0         ||
# ||                                                             ||
# || block2_conv1 (Conv2D)   (None, 112, 112, 128)     73856     ||
# ||                                                             ||
# || block2_conv2 (Conv2D)   (None, 112, 112, 128)     147584    ||
# ||                                                             ||
# || block2_pool (MaxPooling2D)  (None, 56, 56, 128)   0         ||
# ||                                                             ||
# || block3_conv1 (Conv2D)   (None, 56, 56, 256)       295168    ||
# ||                                                             ||
# || block3_conv2 (Conv2D)   (None, 56, 56, 256)       590080    ||
# ||                                                             ||
# || block3_conv3 (Conv2D)   (None, 56, 56, 256)       590080    ||
# ||                                                             ||
# || block3_pool (MaxPooling2D)  (None, 28, 28, 256)   0         ||
# ||                                                             ||
# || block4_conv1 (Conv2D)   (None, 28, 28, 512)       1180160   ||
# ||                                                             ||
# || block4_conv2 (Conv2D)   (None, 28, 28, 512)       2359808   ||
# ||                                                             ||
# || block4_conv3 (Conv2D)   (None, 28, 28, 512)       2359808   ||
# ||                                                             ||
# || block4_pool (MaxPooling2D)  (None, 14, 14, 512)   0         ||
# ||                                                             ||
# || block5_conv1 (Conv2D)   (None, 14, 14, 512)       2359808   ||
# ||                                                             ||
# || block5_conv2 (Conv2D)   (None, 14, 14, 512)       2359808   ||
# ||                                                             ||
# || block5_conv3 (Conv2D)   (None, 14, 14, 512)       2359808   ||
# ||                                                             ||
# || block5_pool (MaxPooling2D)  (None, 7, 7, 512)     0         ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_1 (Sequential)  (None, 2)                119578626 |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || flatten_1 (Flatten)     (None, 25088)             0         ||
# ||                                                             ||
# || dense_3 (Dense)         (None, 4096)              102760448 ||
# ||                                                             ||
# || batch_normalization_2 (Batc  (None, 4096)         16384     ||
# || hNormalization)                                             ||
# ||                                                             ||
# || activation_2 (Activation)  (None, 4096)           0         ||
# ||                                                             ||
# || dropout_2 (Dropout)     (None, 4096)              0         ||
# ||                                                             ||
# || dense_4 (Dense)         (None, 4096)              16777216  ||
# ||                                                             ||
# || batch_normalization_3 (Batc  (None, 4096)         16384     ||
# || hNormalization)                                             ||
# ||                                                             ||
# || activation_3 (Activation)  (None, 4096)           0         ||
# ||                                                             ||
# || dropout_3 (Dropout)     (None, 4096)              0         ||
# ||                                                             ||
# || dense_5 (Dense)         (None, 2)                 8194      ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 134,293,314
# Trainable params: 119,562,242
# Non-trainable params: 14,731,072
# _________________________________________________________________

# %%
model = VGG16_TL()

# %%
#help(tensorflow.python.keras.layers.convolutional.Conv2D)

# %%
opt = Adam(learning_rate=0.0001)
loss_fn = tensorflow.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
train_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()
val_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()
test_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()

# %%
from sklearn.metrics import confusion_matrix

# %%
if os.path.exists('./content/data/ckpt'):
    print(f'Weight Checkpoint directory already exists')
    # !ls -ld ./content/data/ckpt
else:
    print(f'Weight Checkpooint directory doesnt exists.. Creating it now..')
    os.mkdir('./content/data/ckpt')
    print(f'Weight Checkpoint directory successfully created')
    # !ls -ld ./content/data/ckpt

    
if os.path.exists('./content/data/saved_model'):
    print(f'Protobuf Checkpoint directory already exists')
    # !ls -ld ./content/data/saved_model
else:
    print(f'Protobuf Checkpoint directory doesnt exists.. Creating it now..')
    os.mkdir('./content/data/saved_model')
    print(f'Weight Checkpoint directory successfully created')
    # !ls -ld ./content/data/saved_model
# Out:
# Weight Checkpoint directory already exists
# drwxr-xr-x 2 root root 4096 Apr 17 02:27 ./content/data/ckpt
# Protobuf Checkpoint directory already exists
# drwxr-xr-x 3 root root 4096 Apr 17 02:27 ./content/data/saved_model

# %%
class Model_Train():
  def __init__(self, model, optimizer, loss_fn, epochs, batch_size, train_gen, valid_gen, test_gen, train_acc_metric, val_acc_metric, test_acc_metric):
    super().__init__()

    self.model = model
    self.optimizer = optimizer
    self.loss_fn = loss_fn
    self.epochs = epochs
    self.batch_size = batch_size
    self.train_generator = train_gen
    self.valid_generator = valid_gen
    self.test_generator = test_gen
    self.steps_train = len(train_gen)
    self.steps_valid = len(valid_gen)
    self.steps_test = len(test_gen)
    self.train_acc_metric = train_acc_metric
    self.val_acc_metric = val_acc_metric
    self.test_acc_metric = test_acc_metric
    self.train_history = {'loss': [], 'accuracy': [], 'f1': [], 'precision': [], 'recall': []}
    self.valid_history = {'loss': [], 'accuracy': [], 'f1': [], 'precision': [], 'recall': [], 'ckpt_name': []}


   

  @tensorflow.function
  def train_step(self, train_data, train_label):
    with tensorflow.GradientTape() as tape:
      output = self.model(train_data, training=True)
      loss_value = self.loss_fn(train_label, output)
    grads = tape.gradient(loss_value, self.model.trainable_weights)
    self.optimizer.apply_gradients(zip(grads, self.model.trainable_weights))
    self.train_acc_metric.update_state(train_label, output)
    return output, loss_value

  @tensorflow.function
  def test_step(self, validation_data, validation_label):
    val_output = self.model(validation_data, training=False)
    loss_value = self.loss_fn(validation_label, val_output)
    self.val_acc_metric.update_state(validation_label, val_output)
    return val_output, loss_value

  def getloss_accuracy(self, gen, batch_size, steps_per_epoch, df, train=False, valid=False):
    loss_epoch = 0
    n=0
    for step, (x_batch, y_batch) in enumerate(gen):
      if train:
        output, loss_value = self.train_step(x_batch, y_batch)
        ###new code below
        
        pred_labls = list(np.argmax(output.numpy(), axis=1))
        temp_df = pd.DataFrame({'orig_label': list(y_batch), 'pred_label': pred_labls})
        df = pd.concat([df, temp_df])
            

        ## newcode above
        
      else:
        output, loss_value = self.test_step(x_batch, y_batch)
        pred_labls = list(np.argmax(output.numpy(), axis=1))
        temp_df = pd.DataFrame({'orig_label': list(y_batch), 'pred_label': pred_labls})
        df = pd.concat([df, temp_df])
            
      loss_epoch += loss_value*x_batch.shape[0]
      #n = n+1
      #print("Training step ", n )
      if step >= (steps_per_epoch-1):
        if train:
          avg_epoch_loss = (loss_epoch/(len(train_df))).numpy()
          accuracy = self.train_acc_metric.result().numpy()
          self.train_acc_metric.reset_states()
          gen.on_epoch_end()
        else:
          if valid:
            avg_epoch_loss = (loss_epoch/(len(valid_df))).numpy()
            accuracy = self.val_acc_metric.result().numpy()
            self.val_acc_metric.reset_states()
          else:
            avg_epoch_loss = (loss_epoch/(len(test_df))).numpy()
            accuracy = self.val_acc_metric.result().numpy()
            self.val_acc_metric.reset_states()


        return df, avg_epoch_loss, accuracy

  def train_validate_loop(self):
    for epoch in range(self.epochs):
      start_time = time.time()
      histdf_train = pd.DataFrame({'orig_label': [], 'pred_label': []})
      histdf_val   = pd.DataFrame({'orig_label': [], 'pred_label': []})  

      df_train_cm, avg_epoch_train_loss, train_accuracy = self.getloss_accuracy(self.train_generator, self.batch_size, self.steps_train, histdf_train, train=True)
      df_val_cm, avg_epoch_val_loss, val_accuracy = self.getloss_accuracy(self.valid_generator, self.batch_size, self.steps_valid, histdf_val, train=False, valid=True)

    
      f1, precision, recall             = self.calc_rec_prec_f1(df_train_cm, train=True)
      f1_val, precision_val, recall_val = self.calc_rec_prec_f1(df_val_cm, train=False)


      print(f'Epoch : {epoch}, Train Loss: {avg_epoch_train_loss}, Train Accuracy: {train_accuracy}, Validation Loss: {avg_epoch_val_loss}, Validation Accuracy: {val_accuracy}')
      
      self.train_history['loss'].append(avg_epoch_train_loss)
      self.train_history['accuracy'].append(train_accuracy)
      self.train_history['f1'].append(f1)
      self.train_history['precision'].append(precision)
      self.train_history['recall'].append(recall)

      self.valid_history['loss'].append(avg_epoch_val_loss)
      self.valid_history['accuracy'].append(val_accuracy)
      self.valid_history['f1'].append(f1_val)
      self.valid_history['precision'].append(precision_val)
      self.valid_history['recall'].append(recall_val)

      ###New Code for early stopping#####
      la = self.valid_history['accuracy']
      if (len(la) > 4):
        if (((la[-1] <= la[-2]) and (la[-2] <= la[-3])) and ((la[-3] <= la[-4]) and (la[-4] <= la[-5]))):
          print("Validation accuracy has not improved over last 4 epochs, hence invoking early stopping and exiting training process")
          if len(self.valid_history['ckpt_name']) > 0:
            print('Loading Best weights..')
            self.model.load_weights(self.valid_history['ckpt_name'][-1])
            break
          else:
            print("Ouch !! seems like you dont have any checkpoints saved matching criteria specified in logic. Please excuse !")
            break
                        
      if ((la[-1] > 0.9) and (len(la) > 1)):
        if(la[-1] > max(la[0:-1])):
          self.save_checkpoint(la[-1])
      elif ((la[-1] > 0.9) and (len(la) == 1)):
        self.save_checkpoint(la[-1])





      #####New Cod for early stopping


    
      print(f'Time taken: {np.round((time.time() - start_time), 4)}')
    print(f'Training completed successfully. Loading best checkpoint weights ...')
    if len(self.valid_history['ckpt_name']) > 0:
      self.model.load_weights(self.valid_history['ckpt_name'][-1])
      print(f'Best checkpoint weights loaded : {self.valid_history["ckpt_name"][-1]}')
    else:
      print("Ouch !! seems like you dont have any checkpoints saved matching criteria specified in logic. Please excuse !")

      #draw graph depicting train and validation losses and accuracy + recall, f1
    return self.train_history, self.valid_history

  def save_checkpoint(self, acc):
    ckpt_name = './content/data/ckpt/' + 'ckpt' + '_' + str(acc) + '_acc.pt'
    pb_name = './content/data/saved_model/' + 'ckpt' + '_' + str(acc) + '_acc'
    self.model.save_weights(ckpt_name)
    self.valid_history['ckpt_name'].append(ckpt_name)
    print(f'Saved Checkpoint : {ckpt_name}')
    self.model.save(pb_name)
    print(f'Saved model in protobuf format : {pb_name}')


  def get_test_accuracy(self):
    df = pd.DataFrame({'orig_label': [], 'pred_label': []})
    df_test, avg_test_loss, test_accuracy = self.getloss_accuracy(self.test_generator, self.batch_size, self.steps_test, df)
    return df_test, avg_test_loss, test_accuracy

  def calc_rec_prec_f1(self, df, train):
    print_string = "Training Confusion Matrix" if train else "Validation Confusion Matrix"
    print(print_string, "\n", confusion_matrix(df['orig_label'], df['pred_label']))
    tn, fp, fn, tp = confusion_matrix(df['orig_label'], df['pred_label']).ravel()
    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    f1 = 2*precision*recall/(precision+recall)
    return f1, precision, recall

  def predict_single(self,dcm_path, target_size=(224,224)):
    image_array = pydicom.dcmread(dcm_path).pixel_array
    image = Image.fromarray(image_array) #converts from array to PIL
    #image.thumbnail((224,224)) #resize image to 224,224
    image = image.resize((224,224))
    image_array = np.expand_dims(image, 0)
    image_array = image_array.astype(np.float32) # * (1.0/255.0)
    #image_array = np.expand_dims(image_array, 0)
    output = self.model(image_array, training=False)
    pred_label = np.argmax(output.numpy())
    print(f'Predicted label for image supplied is : {classes[pred_label]}')
    return classes[pred_label]
    
  def pred_image_show(self,image_list):
    fig, subs = plt.subplots(3,3, figsize=(14,12))
    for i, sub in enumerate(subs.flatten()):
      print(f'Image path is {image_list[i][0]} and Original label is {classes[int(image_list[i][1])]}')
      pred_class = self.predict_single(image_list[i][0])
      image_array = pydicom.dcmread(image_list[i][0]).pixel_array
      sub.imshow(image_array, cmap='gray')
      sub.set_title(f'{pred_class}(Pred) : {classes[int(image_list[i][1])]}(Orig)')
            
  def plot_metrics(self):
    list = ['accuracy', 'loss', 'f1', 'recall', 'precision']
    for metrics in list:
      x = [i for i in range(len(self.train_history[metrics]))]
      y1 = self.train_history[metrics]
      y2 = self.valid_history[metrics]
      fig, ax = plt.subplots()
      ax.plot(x, y1, label="train_"+metrics)
      ax.plot(x, y2, label="valid_"+metrics)
      plt.suptitle(f'Plot showing {metrics} for Different Epoch Runs')
      ax.legend()
      plt.show()
## Save weights
## if current accuracy > 90 and current accuracy > max(list_accuracy) then create checkpoint and save weights. Also do a protobuf saved model
## store the saved checkpoint name in a list. This will make sure than checkpoints are stored in asecnding order.
## at the end of training , take the last element in checkpoint list and load and restore it. test accuracy should be checked using this chkpoint.

# %%
EPOCHS = 5
train_object = Model_Train(model, opt, loss_fn, EPOCHS, BATCH_SIZE, train_generator, valid_generator, test_generator,
             train_acc_metric, val_acc_metric, test_acc_metric
             )

# %%
train_object.__dict__
# Out:
# {'model': <__main__.VGG16_TL at 0x7fdad74b7130>,
#  'optimizer': <keras.optimizers.adam.Adam at 0x7fdad73bbc70>,
#  'loss_fn': <keras.losses.SparseCategoricalCrossentropy at 0x7fdad73bbaf0>,
#  'epochs': 5,
#  'batch_size': 32,
#  'train_generator': <__main__.DCMDataFrameIterator at 0x7fdadaa02f10>,
#  'valid_generator': <__main__.DCMDataFrameIterator at 0x7fdadaa02490>,
#  'test_generator': <__main__.DCMDataFrameIterator at 0x7fdadaa02400>,
#  'steps_train': 277,
#  'steps_valid': 70,
#  'steps_test': 87,
#  'train_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7fdad73aac40>,
#  'val_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7fdad73a7160>,
#  'test_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7fdad739b550>,
#  'train_history': {'loss': [],
#   'accuracy': [],
#   'f1': [],
#   'precision': [],
#   'recall': []},
#  'valid_history': {'loss': [],
#   'accuracy': [],
#   'f1': [],
#   'precision': [],
#   'recall': [],
#   'ckpt_name': []}}

# %%
train_dict, val_dict = train_object.train_validate_loop()
# Out:
# Training Confusion Matrix
#  [[6090  434]
#  [ 468 1844]]
# Validation Confusion Matrix
#  [[1592   39]
#  [  96  483]]
# Epoch : 0, Train Loss: 0.31396910548210144, Train Accuracy: 0.897917628288269, Validation Loss: 0.1923869103193283, Validation Accuracy: 0.9389140009880066
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.938914_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.938914_acc
# Time taken: 786.603
# Training Confusion Matrix
#  [[6259  262]
#  [ 306 2009]]
# Validation Confusion Matrix
#  [[1627    4]
#  [ 158  421]]
# Epoch : 1, Train Loss: 0.19553685188293457, Train Accuracy: 0.9357175230979919, Validation Loss: 0.29619377851486206, Validation Accuracy: 0.9266968369483948
# Time taken: 762.814
# Training Confusion Matrix
#  [[6283  238]
#  [ 262 2053]]
# Validation Confusion Matrix
#  [[1585   46]
#  [  23  556]]
# Epoch : 2, Train Loss: 0.15703850984573364, Train Accuracy: 0.9434133172035217, Validation Loss: 0.09228070080280304, Validation Accuracy: 0.9687782526016235
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.96877825_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.96877825_acc
# Time taken: 768.6799
# Training Confusion Matrix
#  [[6344  187]
#  [ 214 2091]]
# Validation Confusion Matrix
#  [[1593   38]
#  [  24  555]]
# Epoch : 3, Train Loss: 0.12181875109672546, Train Accuracy: 0.9546175003051758, Validation Loss: 0.08294060826301575, Validation Accuracy: 0.9719457030296326
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9719457_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.9719457_acc
# Time taken: 760.4806
# Training Confusion Matrix
#  [[6355  165]
#  [ 199 2117]]
# Validation Confusion Matrix
#  [[1586   45]
#  [  27  552]]
# Epoch : 4, Train Loss: 0.10770618915557861, Train Accuracy: 0.9588049054145813, Validation Loss: 0.08902736753225327, Validation Accuracy: 0.9674208164215088
# Time taken: 757.9891
# Training completed successfully. Loading best checkpoint weights ...
# Best checkpoint weights loaded : ./content/data/ckpt/ckpt_0.9719457_acc.pt

# %%
df, loss, accuracy = train_object.get_test_accuracy() #from df returned by function you can check which image has lables incorrectly predicted

# %%
accuracy
# Out:
# 0.9659667

# %%
confusion_matrix(df['orig_label'], df['pred_label'])
# Out:
# array([[1976,   63],
#        [  31,  692]])

# %%
train_object.predict_single(test_df.iloc[-2,0])
# Out:
# Predicted label for image supplied is : COVID
# 'COVID'

# %%
train_object.model.save_weights('./content/data/ckpt/model_best_weights')

# %%
with zipfile.ZipFile('./XRAY_resnet50_model_best_weights.zip', 'w') as myzip:
    myzip.write('./content/data/ckpt/checkpoint')
    myzip.write('./content/data/ckpt/model_best_weights.data-00000-of-00001')
    #myzip.write('./content/data/ckpt/model_best_weights.data-00001-of-00002')
    myzip.write('./content/data/ckpt/model_best_weights.index')

# %%
random_9_test = random.sample(list(test_df.values), 9)
random_9_test, len(random_9_test)
# Out:
# ([array(['./content/data/DCM/COVID/COVID-3019.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-4698.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-472.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-9249.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-4099.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-5085.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-5304.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-6733.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-2237.dcm', '0'], dtype=object)],
#  9)

# %%
random_9_test[0][0], random_9_test[0][1]
# Out:
# ('./content/data/DCM/COVID/COVID-3019.dcm', '1')

# %%
train_object.pred_image_show(random_9_test)
# Out:
# Image path is ./content/data/DCM/COVID/COVID-3019.dcm and Original label is COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-4698.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-472.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-9249.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-4099.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-5085.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-5304.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-6733.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-2237.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID

# %%
train_object.plot_metrics()

# %%
# !cp ./*model_best_weights.zip ./gdrive/MyDrive/Manning_Projects/

# %%
train_dict
# Out:
# {'loss': [0.3139691, 0.19553685, 0.15703851, 0.12181875, 0.10770619],
#  'accuracy': [0.8979176, 0.9357175, 0.9434133, 0.9546175, 0.9588049],
#  'f1': [0.8034858387799564,
#   0.8761447884866986,
#   0.891445940078159,
#   0.9125027274710888,
#   0.9208351457155285],
#  'precision': [0.8094820017559262,
#   0.8846323205636284,
#   0.8961152335224792,
#   0.917910447761194,
#   0.9276950043821209],
#  'recall': [0.7975778546712803,
#   0.8678185745140389,
#   0.8868250539956803,
#   0.9071583514099784,
#   0.9140759930915371]}

# %%
val_dict
# Out:
# {'loss': [0.19238691, 0.29619378, 0.0922807, 0.08294061, 0.08902737],
#  'accuracy': [0.938914, 0.92669684, 0.96877825, 0.9719457, 0.9674208],
#  'f1': [0.8773841961852862,
#   0.8386454183266934,
#   0.9415749364944962,
#   0.9470989761092149,
#   0.9387755102040817],
#  'precision': [0.9252873563218391,
#   0.9905882352941177,
#   0.9235880398671097,
#   0.9359190556492412,
#   0.9246231155778895],
#  'recall': [0.8341968911917098,
#   0.7271157167530224,
#   0.9602763385146805,
#   0.9585492227979274,
#   0.9533678756476683],
#  'ckpt_name': ['./content/data/ckpt/ckpt_0.938914_acc.pt',
#   './content/data/ckpt/ckpt_0.96877825_acc.pt',
#   './content/data/ckpt/ckpt_0.9719457_acc.pt']}

# %% [markdown]
# ## Next . Instead of converting grayscale to 3D, use a conv2D on top of basemodel to convert single channel to 3 channel and use that as an input to basemodel.
# Take input 1D image; convert into 3D using conv--> on the output of conv layer apply pre_process function and then feed it into basemodel and follow usual next process steps..
