# %% [markdown]
# ## Milestone 1.1

# %%
# !nvidia-smi
# Out:
# Tue Apr 18 07:43:45 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
# Out:
# Your runtime has 13.6 gigabytes of available RAM

# %%
import requests
import pickle
import zipfile
import time
import os
#from google.colab import drive
import random
import glob
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy import asarray
from PIL.ImageStat import Stat
# !pip install pydicom
import pydicom
# Package for converting PNG Files to DICOM(.dcm ) format
# !pip install simpleitk
import SimpleITK as sitk
from sklearn.model_selection import train_test_split
from PIL import Image
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import DataFrameIterator
#from keras_preprocessing.image.dataframe_iterator import DataFrameIterator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Conv2D, AveragePooling2D, Flatten, Dense, Activation, MaxPool2D, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import sparse_categorical_crossentropy
try:
  import transformers
  from transformers import AutoFeatureExtractor,ViTFeatureExtractor, TFViTModel
except:
  print("Looks like transformers package is not installed.. Initiating install")
  # !pip install transformers
  print("Transformers package installation complete")
  import transformers
  from transformers import AutoFeatureExtractor, ViTFeatureExtractor, TFViTModel
from tensorflow.keras.layers import Resizing, Rescaling, Normalization
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydicom in /usr/local/lib/python3.9/dist-packages (2.3.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: simpleitk in /usr/local/lib/python3.9/dist-packages (2.2.1)

# %%
data_path = './content'
archive_path = data_path + '/data/'
if os.path.exists(archive_path):
  print(f"{archive_path} directory exists.")
else:
  print(f"Did not find {archive_path} directory, creating one...")
  os.mkdir('./content')

  os.mkdir(archive_path)
  if os.path.exists(archive_path):
    print(f'{archive_path} created successfully')
# Out:
# Did not find ./content/data/ directory, creating one...
# ./content/data/ created successfully

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !mv /content/gdrive/MyDrive/Manning_Projects/archive\ \(2\).zip /content/gdrive/MyDrive/Manning_Projects/covid_data.zip
# !ls /content/gdrive/MyDrive/Manning_Projects/
# Out:
# mv: cannot stat '/content/gdrive/MyDrive/Manning_Projects/archive (2).zip': No such file or directory
#  Best_Project_XRAY_VGG16_transfer_learning_conv.ipynb
# 'Copy of Project_XRAY_Resnet50_fc_removed.ipynb'
#  covid_data.zip
#  model_best_weights.zip
#  Project_XRAY_Resnet18.ipynb
#  Project_XRAY_Resnet50.ipynb
#  Project_XRAY_RESNET50_transfer_learning_conv.ipynb
#  Project_XRAY_VGG16_Transfer_Learning_3D.ipynb
#  Project_XRAY_VGG16_transfer_learning_conv.ipynb
#  Project_XRAY_VGG16_Transfer_Learning.ipynb
#  Project_XRAY_ViT.ipynb
#  Project_XRAY_ViT_transfer_learning_conv.ipynb
#  XRAY_NFC_resnet50_model_best_weights.zip
#  XRAY_resnet50_model_best_weights.zip

# %%
DRIVE_PATH = '/content/gdrive/MyDrive/Manning_Projects/'
ARCHIVE_ZIP_FILE = DRIVE_PATH + 'covid_data.zip'
ARCHIVE_ZIP_FILE
# Out:
# '/content/gdrive/MyDrive/Manning_Projects/covid_data.zip'

# %%
# !cp {ARCHIVE_ZIP_FILE} ./content/data/

# %%
archive_file =  archive_path + 'covid_data.zip'

size = os.path.getsize(archive_file)
  
print(f'Size of the file is {size/1024} MegaBytes.')
# Out:
# Size of the file is 796903.357421875 MegaBytes.

# %%
with zipfile.ZipFile(archive_file, "r") as zip_ref:
  print("Unzipping archive") 
  zip_ref.extractall(archive_path)
# Out:
# Unzipping archive

# %%
# !rm -rf ./content/data/COVID-19_Radiography_Dataset/Lung_Opacity

# %%
# !rm -rf ./content/data/COVID-19_Radiography_Dataset/Viral\ Pneumonia

# %%
COVID_IMAGE_PATH = './content/data/COVID-19_Radiography_Dataset/COVID/images'
NON_COVID_IMAGE_PATH = './content/data/COVID-19_Radiography_Dataset/Normal/images'

# %%
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
walk_through_dir(COVID_IMAGE_PATH)
# Out:
# There are 0 directories and 3616 images in './content/data/COVID-19_Radiography_Dataset/COVID/images'.

# %%
walk_through_dir(NON_COVID_IMAGE_PATH)
# Out:
# There are 0 directories and 10192 images in './content/data/COVID-19_Radiography_Dataset/Normal/images'.

# %%
random.seed(42)

COVID_IMAGE_PATH_LIST = glob.glob(COVID_IMAGE_PATH + "/*.png")
len(COVID_IMAGE_PATH_LIST), type(COVID_IMAGE_PATH_LIST)
# Out:
# (3616, list)

# %%
NON_COVID_IMAGE_PATH_LIST = glob.glob(NON_COVID_IMAGE_PATH + "/*.png")
len(NON_COVID_IMAGE_PATH_LIST), type(NON_COVID_IMAGE_PATH_LIST)
# Out:
# (10192, list)

# %%
random_image_cov = random.choice(COVID_IMAGE_PATH_LIST)
cov_pic = Image.open(random_image_cov).convert('L')
cov_pic.show()
# Out:
# <PIL.Image.Image image mode=L size=299x299 at 0x7FF6EC64B1F0>

# %%
random_image_ncov = random.choice(NON_COVID_IMAGE_PATH_LIST)
ncov_pic = Image.open(random_image_ncov).convert('L')
ncov_pic.show()
type(ncov_pic)
# Out:
# <PIL.Image.Image image mode=L size=299x299 at 0x7FF6EA64E3D0>
# PIL.Image.Image

# %%
def image_show(image_list, label):
  fig, subs = plt.subplots(3,3, figsize=(16,12))
  for i, sub in enumerate(subs.flatten()):
    #image_path = os.path.normpath(image[i])
    print(f'Image path is {image_list[i]} and label is {label}')
    img = Image.open(image_list[i])
    img.thumbnail((224,224))
    sub.imshow(img, cmap='gray')
    #sub.axis("off")
    print(f'Size of displayed image is {img.size}')
    sub.set_title(label)

# %%
random.seed(3)
ll_d_c =  []
for i in range(9):
  im = random.choice(COVID_IMAGE_PATH_LIST)
  ll_d_c.append(im)
print(ll_d_c, len(ll_d_c))

ll_d_nc = []
for i in range(9):
  im = random.choice(NON_COVID_IMAGE_PATH_LIST)
  ll_d_nc.append(im)

print(ll_d_nc, len(ll_d_nc))
# Out:
# ['./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-668.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1215.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-58.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-226.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1326.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1389.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1763.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-392.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-565.png'] 9
# ['./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2928.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-1515.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-8911.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5263.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5712.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6746.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5172.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2796.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-835.png'] 9

# %%
image_show(ll_d_c, 'COVID')
# Out:
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-668.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1215.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-58.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-226.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1326.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1389.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1763.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-392.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-565.png and label is COVID
# Size of displayed image is (224, 224)

# %%
image_show(ll_d_nc, 'NON-COVID')
# Out:
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2928.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-1515.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-8911.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5263.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5712.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6746.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5172.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2796.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-835.png and label is NON-COVID
# Size of displayed image is (224, 224)

# %%
random_image = random.choice(COVID_IMAGE_PATH_LIST)
random_image_gs = Image.open(random_image).convert('L')
shape= random_image_gs.size
img= np.reshape(random_image_gs, (-1, *shape, 1))
img.shape
# Out:
# (1, 299, 299, 1)

# %%
#def img_resize_save(img_path_list):
#  for i in range(len(img_path_list)):
#    temp_img = Image.open(img_path_list[i])
#    temp_img.thumbnail((224,224))
#    temp_img.save(img_path_list[i])
#  print('All images in supplied list resized to (224,224)')

#Originally I was under impression that all files have to be resized to 224,224 and then saved to disk. This is mentioned as a separate task.
#Hence, the logical deduction

# %%
df = pd.DataFrame({'Class': [len(NON_COVID_IMAGE_PATH_LIST), len(COVID_IMAGE_PATH_LIST)]})

# %%
total_class = df.Class.sum()
total_class
# Out:
# 13808

# %%
df['per_distr'] = df['Class'].apply(lambda x: x/total_class)
df.index = ['Non_Covid', 'Covid']

# %%
df.Class.plot(kind="bar", figsize=(8,6))
plt.ylabel("Number of Images")
plt.xlabel("Image Class")
plt.title("Distribution of Covid/Non-Covid Images")
plt.show()

# %%
list_arr = []
for pic in COVID_IMAGE_PATH_LIST:
  pic_np = np.array(Image.open(pic).convert('L'))
  pic_np = pic_np.reshape(299,299,1)
  list_arr.append(pic_np)

# %%
len(list_arr)
# Out:
# 3616

# %%
covid_arr = np.array(list_arr)

# %%
covid_arr.shape
# Out:
# (3616, 299, 299, 1)

# %%
np.mean(covid_arr), np.min(covid_arr), np.max(covid_arr), np.std(covid_arr)
# Out:
# (139.52120961679765, 0, 255, 61.907126975500574)

# %%
# Flatten the image data into a 1D array
pixel_values = covid_arr.flatten()

pixel_values.shape
# Out:
# (323274016,)

# %%
# Plot a histogram of the pixel values
plt.hist(pixel_values, bins=50)
plt.suptitle("Distribution of pixel values for Covid Image Data")
plt.show()

# %%
list_arr_nc = []
for pic in NON_COVID_IMAGE_PATH_LIST:
  pic_np_nc = np.array(Image.open(pic).convert('L'))
  pic_np_nc = pic_np_nc.reshape(299,299,1)
  list_arr_nc.append(pic_np_nc)
len(list_arr_nc)
# Out:
# 10192

# %%
covid_arr_nc = np.array(list_arr_nc)
covid_arr_nc.shape
# Out:
# (10192, 299, 299, 1)

# %%
np.mean(covid_arr_nc), np.max(covid_arr_nc), np.mean(covid_arr_nc), np.std(covid_arr_nc)
# Out:
# (129.38979982014257, 255, 129.38979982014257, 66.21686464627398)

# %%
# Flatten the image data into a 1D array
pixel_values_nc = covid_arr_nc.flatten()
pixel_values_nc.shape
# Out:
# (911174992,)

# %%
# Plot a histogram of the pixel values
fig, subs = plt.subplots(1,2, figsize=(24,6))
for i, sub in enumerate(subs.flatten()):
  if i==0:
    sub.hist(pixel_values_nc, bins=50)
    sub.set_title("Distribution of pixel values for Non-Covid Image Data")
  else:
    sub.hist(pixel_values, bins=50)
    sub.set_title("Distribution of pixel values for Covid Image Data")

# %% [markdown]
# ## Observation
#
# It can be seen from above two histograms that pixel intensity for covid data is more peaked(kurtosis is high) than for non-covid images.
#
# This confirms with fact that X-Ray images for covid infected patients show white patches in chest X-Ray Images.

# %%
#Lets do simple check on whether the pixel data that we get from converted .dcm files is same what we get from original png image
image = COVID_IMAGE_PATH_LIST[0]
im1 = Image.open(image).convert('L')
im1= np.array(im1)
img= sitk.GetImageFromArray(im1)
sitk.WriteImage(img,'template.dcm')

# %%
fig, subs = plt.subplots(1,2, figsize=(12,6))
for i, sub in enumerate(subs.flatten()):
  if i==0:
    #ds = pydicom.dcmread('template.dcm')
    # Load the DICOM file
    ds = pydicom.dcmread('template.dcm')
    # Access the image data
    image_d = ds.pixel_array
    print(type(image_d))
    sub.imshow(image_d, cmap='gray')
    sub.set_title("Image data from .dcm file")
  else:
    sub.imshow(im1, cmap='gray')
    sub.set_title("Image data from original png file")
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## It does looks like the data from both sources are one and same.
# ## STATUS : VERIFIED

# %% [markdown]
# ## Convert all the PNG Files to DICOM (.dcm) Format

# %%
DCM_FILE_PATH = './content/data/DCM/'
COVID_DCM_FILE_PATH = './content/data/DCM/COVID/'
NON_COVID_DCM_FILE_PATH = './content/data/DCM/NON_COVID/'
if os.path.exists(DCM_FILE_PATH):
  print(f"{DCM_FILE_PATH} directory exists.")
  if os.path.exists(COVID_DCM_FILE_PATH):
    print(f'{COVID_DCM_FILE_PATH} directory exists')
  else:
    print(f'Ok... looks like {COVID_DCM_FILE_PATH} does not exists. Let us make one')
    os.mkdir(COVID_DCM_FILE_PATH)
    print(f'{COVID_DCM_FILE_PATH} directory created successfully')
  if os.path.exists(NON_COVID_DCM_FILE_PATH):
    print(f'{NON_COVID_DCM_FILE_PATH} directory exists')
  else:
    print(f'Ok... looks like {NON_COVID_DCM_FILE_PATH} does not exists. Let us make one')
    os.mkdir(NON_COVID_DCM_FILE_PATH)
    print(f'{NON_COVID_DCM_FILE_PATH} directory created successfully')
else:
  print(f'Looks like there is no directory structure below /content/data.. Lets create required directory structures')
  print(f'Creating {DCM_FILE_PATH} directory path first')
  os.mkdir(DCM_FILE_PATH)
  print(f'{DCM_FILE_PATH} directory created successfully')

  print(f'Creating {COVID_DCM_FILE_PATH} directory path')
  os.mkdir(COVID_DCM_FILE_PATH)
  print(f'{COVID_DCM_FILE_PATH} directory created successfully')

  print(f'Creating {NON_COVID_DCM_FILE_PATH} directory path')
  os.mkdir(NON_COVID_DCM_FILE_PATH)
  print(f'{NON_COVID_DCM_FILE_PATH} directory created successfully')
# Out:
# Looks like there is no directory structure below /content/data.. Lets create required directory structures
# Creating ./content/data/DCM/ directory path first
# ./content/data/DCM/ directory created successfully
# Creating ./content/data/DCM/COVID/ directory path
# ./content/data/DCM/COVID/ directory created successfully
# Creating ./content/data/DCM/NON_COVID/ directory path
# ./content/data/DCM/NON_COVID/ directory created successfully

# %%
def pngtodcm(image_list, COVID, l_i):
  print(f'COVID variable is set to {COVID}')
  list_im = []
  list_im = l_i

  for png_image in image_list:
    png_im_arr = np.array(Image.open(png_image).convert('L'))
    dcm_im_arr = sitk.GetImageFromArray(png_im_arr)
    if COVID:
      SAVE_PATH = COVID_DCM_FILE_PATH
      list_im = list_im_c
    else:
      SAVE_PATH = NON_COVID_DCM_FILE_PATH
      list_im = list_im_nc
    FILENAME = png_image.split("/")[-1].split(".")[0]
    DCM_FILENAME = SAVE_PATH + FILENAME + '.dcm'
    sitk.WriteImage(dcm_im_arr, DCM_FILENAME)
    print(f'Successfully converted and saved {DCM_FILENAME}')
    list_im.append(DCM_FILENAME)

# %%
list_im_c = []
pngtodcm(COVID_IMAGE_PATH_LIST, True, list_im_c)
# Out:
# COVID variable is set to True
# Successfully converted and saved ./content/data/DCM/COVID/COVID-185.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-115.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-522.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2050.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1177.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3495.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-650.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3166.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2379.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3151.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2702.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3094.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-932.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2837.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3205.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1822.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1882.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3590.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1484.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2572.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2586.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-359.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-701.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3379.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3193.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2203.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-949.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2029.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2331.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-206.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1968.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-195.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2135.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2528.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-773.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1737.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3569.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1489.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2941.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3022.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-602.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1010.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1325.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-983.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3511.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2974.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-379.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3276.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1001.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1590.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-776.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1706.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3124.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-878.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2442.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3334.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-550.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2268.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-355.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1283.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2277.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2229.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3253.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2614.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2325.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3493.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2423.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-618.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1127.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3275.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1080.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3028.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3428.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2221.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3561.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-47.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3199.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-835.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2795.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2525.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1857.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2382.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3478.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1651.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-288.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3563.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2960.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-508.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-407.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3389.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2095.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1366.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-240.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-637.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2005.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2648.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1657.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2451.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1477.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1059.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-838.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-629.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1720.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3585.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3609.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3215.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3024.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3562.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3555.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-255.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2431.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1587.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2373.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-183.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1171.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-955.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3138.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1409.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2545.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-283.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1951.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-490.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1956.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1470.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1213.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-533.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1699.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3383.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2285.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-471.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1150.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1973.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2979.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3191.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2804.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1928.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-623.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1185.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-414.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1957.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2714.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3200.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1025.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1360.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2037.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1106.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1694.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-960.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3574.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2445.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2549.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1454.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-787.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3526.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1645.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1448.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2056.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2238.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-373.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-23.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1072.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3239.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1317.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3490.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2409.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1603.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3398.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1493.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-323.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2874.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-626.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2189.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3319.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1429.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-595.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2326.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1755.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-559.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1219.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-739.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3061.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2959.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3531.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3556.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2688.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1090.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3522.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3207.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2464.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2042.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3293.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-478.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2992.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1049.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2471.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2845.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1963.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2337.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-64.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2197.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1321.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3343.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1379.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2764.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1949.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3458.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2212.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1296.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3386.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-731.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-462.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1363.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3182.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2099.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1328.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-499.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-486.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-81.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3439.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1139.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-564.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2245.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3219.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2933.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2427.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3489.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2457.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-128.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1069.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1345.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1595.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1305.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1633.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1849.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2800.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-140.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3610.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1466.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-314.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2539.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2685.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1549.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-748.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1515.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-43.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2513.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1088.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-63.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2905.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3409.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1686.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-401.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1994.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-873.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1804.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3403.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2070.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1503.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1176.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1154.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2893.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1024.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3294.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1794.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3472.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3156.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-438.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1140.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2798.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1577.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3479.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1773.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2157.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1594.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2613.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1455.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1576.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-772.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1449.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2757.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3523.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3537.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1028.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1872.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-450.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-348.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1496.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2061.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2103.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1192.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3351.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1147.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1426.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2751.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2117.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2740.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3305.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3582.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2503.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1889.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2064.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-441.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1292.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3171.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-829.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2207.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3558.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1128.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1033.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-875.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1780.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2502.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1568.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3358.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2787.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1669.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1226.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2823.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2327.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-882.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3077.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1421.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-968.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-410.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2122.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3053.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-696.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2756.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3165.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-248.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2650.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1265.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-491.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3159.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1159.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-541.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3608.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1946.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3050.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-141.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2590.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-492.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3332.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-433.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2178.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1929.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2213.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2535.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-25.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3314.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3616.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1859.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2954.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3441.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1289.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3135.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2546.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3448.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2888.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3285.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-152.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2270.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2306.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2592.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2334.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-61.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2211.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-501.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3168.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1452.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2677.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-726.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3482.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-899.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2014.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2644.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3202.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1750.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-622.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-68.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2387.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-775.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2043.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-573.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-504.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2067.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-851.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1241.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1382.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2045.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-234.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1070.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1105.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1175.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1769.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2880.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1178.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-380.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3066.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2470.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-100.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3357.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2139.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3560.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3006.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-581.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2202.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-885.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-470.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1997.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2078.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2822.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3103.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1705.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3040.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2850.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2429.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2998.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1336.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3036.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1479.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1021.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-352.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1065.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1323.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2608.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1972.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-153.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1771.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2587.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2731.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2839.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3306.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1307.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1131.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1277.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-131.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-678.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1772.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2143.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1248.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1155.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2485.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2840.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1135.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2651.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2519.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2097.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2629.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1832.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2338.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-135.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2254.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-908.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-316.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-563.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3355.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2801.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2351.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1516.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1596.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-350.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3423.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-142.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-291.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-228.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3134.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2399.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2694.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3356.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1582.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-716.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3570.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3381.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1569.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1614.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1492.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1146.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-865.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3370.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-936.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2258.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2660.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1712.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2950.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2601.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2768.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1232.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3089.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2929.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2749.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2416.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2239.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3488.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2292.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-400.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2397.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2884.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2022.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2458.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1252.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-143.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2900.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3477.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-510.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2489.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3172.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2193.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1524.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1355.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3580.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2595.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1536.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1817.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2204.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2461.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-830.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2186.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3320.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-300.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3550.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-129.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3361.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-544.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-473.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1617.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-680.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-62.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1907.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2508.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2872.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1157.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-493.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1556.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-226.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2887.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1704.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1257.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3397.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2003.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-710.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-610.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-801.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1709.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1546.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2925.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-825.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1417.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3248.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3127.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2243.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-764.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1169.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-876.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1679.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1724.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3140.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3139.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2228.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-598.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-368.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-341.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1714.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3230.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1381.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2152.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-895.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3255.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1458.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-201.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2653.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3400.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-976.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2089.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2190.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1631.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2013.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1742.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-813.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3246.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-343.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1894.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-24.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-96.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2040.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1606.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1970.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1201.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-165.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3244.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2904.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1108.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-78.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1121.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1985.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1578.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2039.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3502.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1600.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2488.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-658.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2626.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-569.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1862.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3145.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1564.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-703.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1831.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-597.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1273.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1392.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-681.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-831.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1839.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1559.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-942.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1736.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2817.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3474.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-326.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1091.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2236.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1910.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-398.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2188.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1523.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-653.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2016.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2944.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-360.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2096.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-304.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1601.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2606.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-365.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1659.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2481.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-121.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2596.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1671.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-465.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2173.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-76.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3589.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1904.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1330.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-494.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1413.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3237.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2241.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3283.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3520.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-795.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2851.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1895.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1327.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1927.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2290.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2852.dcm
# ...
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1101.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1439.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-502.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2755.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3304.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-34.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-330.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-596.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-961.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2296.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3565.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1397.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1828.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1191.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2753.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3496.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1915.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-820.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1891.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1414.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2162.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2428.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2051.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1030.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3514.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2405.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1095.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2035.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1639.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2443.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3548.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1930.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2137.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3206.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2330.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-594.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1227.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2018.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2632.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2882.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3212.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1676.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2027.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3360.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3060.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2322.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1952.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-808.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-840.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-582.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2530.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1851.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3446.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2993.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1662.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2180.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2522.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3301.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3468.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1836.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1667.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3279.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-797.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-461.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3106.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1228.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-460.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1102.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1672.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2744.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1880.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2517.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3419.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1211.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3376.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-832.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3122.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1149.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-440.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2384.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2899.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-858.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1236.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2109.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1129.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3375.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3547.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-918.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-358.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2242.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-107.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2129.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2918.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-535.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1380.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1609.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1026.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-803.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2536.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2803.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-552.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-19.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3181.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3354.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-554.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2663.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2912.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3259.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2557.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3593.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2393.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1221.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1781.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2286.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1117.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-36.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1370.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-766.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3311.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-902.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1518.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-55.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-705.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-157.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-301.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2655.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1497.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2728.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-467.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3010.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3046.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2949.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3069.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-880.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-233.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3222.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2215.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2769.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3035.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2455.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-178.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3003.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2469.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-53.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1608.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1767.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1130.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2226.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1302.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3133.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-855.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2259.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3063.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-661.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1186.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2805.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2446.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1710.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2721.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-646.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1352.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1749.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1902.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-264.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2917.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-353.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2112.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2066.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1378.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2540.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-704.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3251.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2943.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2742.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-711.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2578.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2818.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-282.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2582.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-664.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-804.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3264.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2195.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1684.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1054.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2414.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2077.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3572.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3586.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3309.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2059.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3121.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3322.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1620.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2350.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-219.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1655.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-421.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-500.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-868.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1098.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2781.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-84.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2299.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1261.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2719.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-591.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-385.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2381.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3224.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2052.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-489.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-768.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1589.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2848.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2689.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-175.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2450.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1625.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1220.dcm

# %%
len(list_im_c)
# Out:
# 3616

# %%
list_im_nc = []
pngtodcm(NON_COVID_IMAGE_PATH_LIST, False, list_im_nc)
# Out:
# Streaming output truncated to the last 5000 lines.
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4555.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7757.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-636.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9332.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3185.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-841.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2633.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3240.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7561.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2384.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3619.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-322.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7165.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5139.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-806.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1510.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9697.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-104.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7479.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6192.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10124.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9119.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6023.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3719.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-716.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1451.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7460.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2824.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7462.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2550.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-419.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1411.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9481.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7624.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3038.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6704.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4790.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2624.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1966.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5619.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-175.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6055.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3575.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8604.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-153.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2579.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9848.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8034.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7183.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7960.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9063.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5242.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4477.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6488.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10087.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10168.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2368.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9300.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7814.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-100.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6661.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-95.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4463.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6636.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7908.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4721.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5281.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9084.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9746.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6393.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5799.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5533.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9854.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2825.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6502.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-538.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4468.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4132.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5951.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1735.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2631.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1242.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2004.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5000.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9656.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5161.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3568.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2114.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10073.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-120.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9555.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8066.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4159.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8122.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5363.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9207.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-915.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7859.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2768.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6793.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4961.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1946.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3980.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-942.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6195.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2127.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-629.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6845.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1526.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9948.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9691.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9826.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6629.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2940.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4764.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8617.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4536.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7837.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6675.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3399.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3133.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5401.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1609.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9454.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3011.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3222.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9878.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3516.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7491.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2112.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7715.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9404.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8861.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4092.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7740.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9999.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6739.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6866.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8869.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1898.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4692.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10100.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4688.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4090.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7441.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5944.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8346.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6054.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6187.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6630.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5782.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-235.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1237.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2889.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3545.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7091.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-945.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1205.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8009.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7670.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8025.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9134.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4803.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7443.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5509.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4936.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2764.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9255.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7529.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-171.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9912.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2931.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-82.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2506.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7933.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4587.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6300.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2887.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1551.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1427.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9233.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6371.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5448.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-745.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3623.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5971.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4227.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7703.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4040.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1629.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6990.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1060.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6947.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10083.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7731.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7061.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4832.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2724.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3528.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6218.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1341.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3720.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9785.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3265.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7401.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2294.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6795.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6650.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2185.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4929.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-321.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2471.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1152.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7096.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4107.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5031.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1352.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8994.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10132.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2041.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8699.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1618.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8021.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2243.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8003.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5378.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3052.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2167.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4874.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3355.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4292.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4439.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5546.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8657.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6331.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3671.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4789.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2542.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4720.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4156.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6900.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1807.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6595.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9654.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3174.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9638.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8759.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6074.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3071.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-19.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8690.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4530.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9745.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3857.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-496.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3886.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5959.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7123.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7103.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-48.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3325.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1586.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2835.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8852.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9517.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7144.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7496.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5431.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5141.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1481.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8372.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1311.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3696.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4953.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2346.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-359.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4080.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2327.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6528.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-411.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6216.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-368.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3217.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4078.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4091.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4021.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3093.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-875.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3718.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1685.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9012.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8218.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2709.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3985.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-279.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6052.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1984.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8306.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-973.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7373.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4599.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5649.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9566.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5229.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2424.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4135.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8588.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4331.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8541.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1786.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2379.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4154.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6069.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8929.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3230.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7230.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6811.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4663.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5879.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3453.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-748.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9570.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1221.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5389.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2606.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9263.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7360.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5856.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7145.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5522.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2288.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9615.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7363.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4763.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4830.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9241.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4461.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2971.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8600.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6919.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8669.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3508.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3570.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1533.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5882.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1608.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3663.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4560.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2237.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3210.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7817.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6205.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7192.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3424.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2594.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-422.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-223.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3648.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4414.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3923.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7828.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8241.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-734.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8633.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7458.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8013.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1036.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2690.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6140.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6075.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2320.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4723.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8495.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9611.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1906.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8580.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-930.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-680.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5148.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9920.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9825.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9633.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3983.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1977.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10049.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8213.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1620.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4843.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1156.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7806.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7040.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3280.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7967.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4158.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1919.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2717.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1856.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7674.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8502.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5508.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5819.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2535.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1265.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5402.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9118.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6355.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1359.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3742.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1232.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9804.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1349.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9498.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8116.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7216.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3758.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7891.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-688.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5304.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8789.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2791.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8649.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6434.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7873.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6773.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2458.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5872.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2363.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6272.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-600.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3478.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6585.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-828.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7277.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5886.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8903.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10119.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8058.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7531.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2469.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3773.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4048.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2628.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4543.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9266.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2193.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3419.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1888.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4731.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5579.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2646.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5976.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10131.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9345.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8110.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6599.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5860.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1332.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6755.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4910.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8226.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1226.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-983.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-611.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2996.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1150.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4117.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4670.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5922.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1942.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1819.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3927.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8343.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7687.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4127.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4269.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8791.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1444.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5050.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-776.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-36.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2340.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2729.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3246.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-472.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-599.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6821.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4730.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8494.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2240.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7118.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5962.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5742.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6715.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9314.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5002.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2770.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5984.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-917.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3537.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1902.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3606.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9501.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7280.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1843.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6492.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8081.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6126.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8221.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5354.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1348.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1498.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1995.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-260.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1811.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7010.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6267.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8044.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5687.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8802.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4067.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8983.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3131.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3442.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-730.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7578.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10007.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10093.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5167.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2351.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7392.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7311.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7735.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4685.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-598.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1590.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8893.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8336.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5365.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4943.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6344.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9105.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5838.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8102.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1758.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4647.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4177.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1485.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1460.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2571.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-569.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2246.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8349.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8315.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1313.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6895.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9247.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5507.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-20.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10101.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6548.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9325.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1096.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4215.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3512.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5717.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4809.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6499.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5060.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-873.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6450.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4133.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8314.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-250.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-791.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3121.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6957.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7509.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8615.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4365.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6215.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6908.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-340.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7117.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6417.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8493.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6723.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7939.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3206.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3915.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8098.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1777.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1640.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9508.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-659.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7489.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7774.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8108.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1881.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-209.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3550.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8506.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7228.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2460.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6299.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-23.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1238.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10002.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-879.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2141.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3048.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7276.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5908.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8740.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-905.dcm
# ...
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9767.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9003.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3935.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9367.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-339.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3385.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9961.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4774.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4716.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-405.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3881.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5808.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4705.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9422.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1250.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3140.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2997.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9979.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6294.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4844.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7902.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3943.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3268.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6838.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6269.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8076.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1342.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6710.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-672.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2838.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-555.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-268.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6473.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7770.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-750.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6280.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2993.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5135.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5602.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4689.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8330.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1855.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6246.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1285.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4137.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1540.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2104.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3233.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5627.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2217.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3175.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1115.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-988.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6881.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8879.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7437.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7085.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1504.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-192.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6472.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4270.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7237.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3202.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6689.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3964.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5040.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1097.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3366.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8285.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2329.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-253.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4791.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7180.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6191.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2175.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3746.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4362.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9832.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6744.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-114.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8239.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8656.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2915.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5534.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1619.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1219.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8726.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7312.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2488.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2297.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9971.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1657.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2076.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8884.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1664.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3876.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1783.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6572.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1745.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3805.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7287.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2963.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6929.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2111.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1790.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8223.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6020.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-543.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5441.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5147.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1896.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4459.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9569.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9363.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-704.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10091.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2194.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6836.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6209.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6346.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7109.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3338.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-894.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5071.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-226.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5647.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3661.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-779.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9059.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4690.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8912.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8409.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-379.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9733.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2400.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2057.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1314.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6805.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-146.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3803.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8555.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8936.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1581.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1981.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1600.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3392.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3656.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8307.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8962.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-286.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6697.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-911.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1368.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3501.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7063.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8401.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1028.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8286.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2268.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5329.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6663.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7427.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1741.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3921.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9906.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5652.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7508.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3070.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5336.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-13.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4766.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6998.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-868.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9677.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4633.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9097.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4003.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7710.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3260.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2333.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8611.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7177.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9169.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-714.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5341.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6767.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-697.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4841.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6727.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3714.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2023.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2703.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6082.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2920.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8914.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6422.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2128.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6597.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1853.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3511.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4970.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9943.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2615.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2024.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8634.dcm

# %%
len(list_im_nc), len(list_im_c)
# Out:
# (10192, 3616)

# %%
len(NON_COVID_IMAGE_PATH_LIST), len(COVID_IMAGE_PATH_LIST)
# Out:
# (10192, 3616)

# %%
list_im_nc[0], list_im_c[0]
# Out:
# ('./content/data/DCM/NON_COVID/Normal-6589.dcm',
#  './content/data/DCM/COVID/COVID-185.dcm')

# %%
def extract_fnames(file_list):
  temp_ll = []
  for i in file_list:
    fname = i.split("/")[-1].split(".")[0]
    temp_ll.append(fname)
    return sorted(temp_ll)

# %%
ll_dc_fname = extract_fnames(list_im_c)
ll_dnc_fname = extract_fnames(list_im_nc)
ll_pc_fname = extract_fnames(COVID_IMAGE_PATH_LIST)
ll_pnc_fname = extract_fnames(NON_COVID_IMAGE_PATH_LIST)

# %%
ll_dc_fname == ll_pc_fname
# Out:
# True

# %%
ll_dnc_fname == ll_pnc_fname
# Out:
# True

# %%
df_nc = pd.DataFrame()

# %%
df_nc['filename'] = list_im_nc

# %%
df_nc['class'] = 0

# %%
df_nc
# Out:
#                                            filename  class
# 0      ./content/data/DCM/NON_COVID/Normal-6589.dcm      0
# 1      ./content/data/DCM/NON_COVID/Normal-7120.dcm      0
# 2       ./content/data/DCM/NON_COVID/Normal-739.dcm      0
# 3      ./content/data/DCM/NON_COVID/Normal-1194.dcm      0
# 4      ./content/data/DCM/NON_COVID/Normal-8906.dcm      0
# ...                                             ...    ...
# 10187  ./content/data/DCM/NON_COVID/Normal-4970.dcm      0
# 10188  ./content/data/DCM/NON_COVID/Normal-9943.dcm      0
# 10189  ./content/data/DCM/NON_COVID/Normal-2615.dcm      0
# 10190  ./content/data/DCM/NON_COVID/Normal-2024.dcm      0
# 10191  ./content/data/DCM/NON_COVID/Normal-8634.dcm      0
#
# [10192 rows x 2 columns]

# %%
label_1 = list(np.ones(len(list_im_c), dtype=int))
len(label_1), len(list_im_c)
# Out:
# (3616, 3616)

# %%
dict_c = {'filename': list_im_c, 'class': label_1}

# %%
df_c = pd.DataFrame(data=dict_c)

# %%
df_c
# Out:
#                                      filename  class
# 0      ./content/data/DCM/COVID/COVID-185.dcm      1
# 1      ./content/data/DCM/COVID/COVID-115.dcm      1
# 2      ./content/data/DCM/COVID/COVID-522.dcm      1
# 3     ./content/data/DCM/COVID/COVID-2050.dcm      1
# 4     ./content/data/DCM/COVID/COVID-1177.dcm      1
# ...                                       ...    ...
# 3611  ./content/data/DCM/COVID/COVID-2689.dcm      1
# 3612   ./content/data/DCM/COVID/COVID-175.dcm      1
# 3613  ./content/data/DCM/COVID/COVID-2450.dcm      1
# 3614  ./content/data/DCM/COVID/COVID-1625.dcm      1
# 3615  ./content/data/DCM/COVID/COVID-1220.dcm      1
#
# [3616 rows x 2 columns]

# %%
df = pd.concat([df_nc, df_c])

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns=['index'], inplace=True)

# %%
df
# Out:
#                                            filename  class
# 0      ./content/data/DCM/NON_COVID/Normal-6589.dcm      0
# 1      ./content/data/DCM/NON_COVID/Normal-7120.dcm      0
# 2       ./content/data/DCM/NON_COVID/Normal-739.dcm      0
# 3      ./content/data/DCM/NON_COVID/Normal-1194.dcm      0
# 4      ./content/data/DCM/NON_COVID/Normal-8906.dcm      0
# ...                                             ...    ...
# 13803       ./content/data/DCM/COVID/COVID-2689.dcm      1
# 13804        ./content/data/DCM/COVID/COVID-175.dcm      1
# 13805       ./content/data/DCM/COVID/COVID-2450.dcm      1
# 13806       ./content/data/DCM/COVID/COVID-1625.dcm      1
# 13807       ./content/data/DCM/COVID/COVID-1220.dcm      1
#
# [13808 rows x 2 columns]

# %%
df['class'].value_counts()
# Out:
# 0    10192
# 1     3616
# Name: class, dtype: int64

# %%
df.to_csv('./content/data/DCM/dcm_files_list_labels.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13808 entries, 0 to 13807
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  13808 non-null  object
#  1   class     13808 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 215.9+ KB

# %% [markdown]
# ## Milestone 1.2

# %%
df_loaddata = pd.read_csv('./content/data/DCM/dcm_files_list_labels.csv')

# %%
df_loaddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13808 entries, 0 to 13807
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  13808 non-null  object
#  1   class     13808 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 215.9+ KB

# %%
len(df_loaddata.filename.unique())
# Out:
# 13808

# %%
df_loaddata['class'].value_counts()
# Out:
# 0    10192
# 1     3616
# Name: class, dtype: int64

# %%
df_X = df_loaddata.drop(columns=['class'])
df_y = df_loaddata['class']

# %%
df_y.head(), df_X.head()
# Out:
# (0    0
#  1    0
#  2    0
#  3    0
#  4    0
#  Name: class, dtype: int64,
#                                         filename
#  0  ./content/data/DCM/NON_COVID/Normal-6589.dcm
#  1  ./content/data/DCM/NON_COVID/Normal-7120.dcm
#  2   ./content/data/DCM/NON_COVID/Normal-739.dcm
#  3  ./content/data/DCM/NON_COVID/Normal-1194.dcm
#  4  ./content/data/DCM/NON_COVID/Normal-8906.dcm)

# %%
train_df, test_df = train_test_split(df_loaddata, test_size=0.2, random_state=42, stratify=df['class'])

len(train_df), len(test_df)
# Out:
# (11046, 2762)

# %%
# we need to further reserve 20% data in training for validation
train_df, valid_df = train_test_split(train_df, test_size=0.2, random_state=42, stratify=train_df['class'])

len(train_df), len(valid_df)
# Out:
# (8836, 2210)

# %%
train_df['class'].sum(), valid_df['class'].sum(), test_df['class'].sum()
# Out:
# (2314, 579, 723)

# %%
train_df['class'].sum() + valid_df['class'].sum() + test_df['class'].sum()
# Out:
# 3616

# %%
train_aug_params = dict(
    #rescale=1./255,
    rotation_range=10,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    brightness_range = [0.8, 1.2]
)

valid_aug_params = dict(
    #rescale=1./255
    )

test_aug_params = dict(
    #rescale=1./255
)

# %%
#Creating augmenters

train_augmenter = ImageDataGenerator(**train_aug_params)
valid_augmenter = ImageDataGenerator(**valid_aug_params)
test_augmenter = ImageDataGenerator(**test_aug_params)

# %%
type(train_augmenter), type(valid_augmenter), type(test_augmenter)
# Out:
# (keras.preprocessing.image.ImageDataGenerator,
#  keras.preprocessing.image.ImageDataGenerator,
#  keras.preprocessing.image.ImageDataGenerator)

# %%
# training parameters
BATCH_SIZE = 32
COLOR_MODE = 'grayscale'
TARGET_SIZE = (224, 224)
EPOCHS = 10

train_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE,  
}

valid_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE, 
    'shuffle': False
}

test_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE,  # resize input images
    'shuffle': False
}

# %%
class DCMDataFrameIterator(DataFrameIterator):
    def __init__(self, *arg, **kwargs):
        self.white_list_formats = ('dcm')
        super(DCMDataFrameIterator, self).__init__(*arg, **kwargs)
        self.dataframe = kwargs['dataframe']
        self.x = self.dataframe[kwargs['x_col']]
        self.y = self.dataframe[kwargs['y_col']]
        self.color_mode = kwargs['color_mode']
        self.target_size = kwargs['target_size']

    def _get_batches_of_transformed_samples(self, indices_array):
        # get batch of images
        batch_x = np.array([self.read_dcm_as_array(dcm_path, self.target_size, color_mode=self.color_mode)
                            for dcm_path in self.x.iloc[indices_array]])

        batch_y = np.array(self.y.iloc[indices_array].astype(np.uint8))  # astype because y was passed as str

        # transform images
        if self.image_data_generator is not None:
            for i, (x, y) in enumerate(zip(batch_x, batch_y)):
                transform_params = self.image_data_generator.get_random_transform(x.shape)
                batch_x[i] = self.image_data_generator.apply_transform(x, transform_params)
                
                # you can change y here as well, eg: in semantic segmentation you want to transform masks as well 
                # using the same image_data_generator transformations.

        return batch_x, batch_y

    @staticmethod
    def read_dcm_as_array(dcm_path, target_size=(256, 256), color_mode='rgb'):
        image_array = pydicom.dcmread(dcm_path).pixel_array
        image = Image.fromarray(image_array) #converts from array to PIL
        #image = Image.open(image).convert('L')
        image.thumbnail((224,224)) #resize image to 224,224
        #image_array = cv2.resize(image_array, target_size, interpolation=cv2.INTER_NEAREST)  #this returns a 2d array
        image_array = np.expand_dims(image, -1)
        return image_array.astype(np.float32)

# %%
train_df['class'] = train_df['class'].astype('str')
valid_df['class'] = valid_df['class'].astype('str')
test_df['class'] = test_df['class'].astype('str')

# %%
train_df.info(), valid_df.info(),  test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8836 entries, 13528 to 8134
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  8836 non-null   object
#  1   class     8836 non-null   object
# dtypes: object(2)
# memory usage: 207.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2210 entries, 6681 to 12452
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  2210 non-null   object
#  1   class     2210 non-null   object
# dtypes: object(2)
# memory usage: 51.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2762 entries, 1939 to 8436
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  2762 non-null   object
#  1   class     2762 non-null   object
# dtypes: object(2)
# memory usage: 64.7+ KB
# (None, None, None)

# %%
train_generator = DCMDataFrameIterator(dataframe=train_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=train_augmenter,
                             **train_consts)

valid_generator = DCMDataFrameIterator(dataframe=valid_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=valid_augmenter,
                             **valid_consts)

test_generator = DCMDataFrameIterator(dataframe=test_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=test_augmenter,
                             **test_consts)
# Out:
# Found 8836 validated image filenames belonging to 2 classes.
# Found 2210 validated image filenames belonging to 2 classes.
# Found 2762 validated image filenames belonging to 2 classes.

# %%
#train_augmenter.fit(train_generator)

# %%
classes = ['NON-COVID', 'COVID']

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(train_generator))

imgs.shape, labels.shape, type(imgs), type(labels)
# Out:
# ((32, 224, 224, 1), (32,), numpy.ndarray, numpy.ndarray)

# %%
imgs[0].mean(), imgs[0].max(), imgs[0].min()
# Out:
# (128.77989, 244.0, 0.0)

# %%
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(valid_generator))
print(imgs.shape, labels.shape, type(imgs), type(labels))
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()
# Out:
# (32, 224, 224, 1) (32,) <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(test_generator))
print(imgs.shape, labels.shape, type(imgs), type(labels))
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()
# Out:
# (32, 224, 224, 1) (32,) <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
imgs[0].dtype
# Out:
# dtype('float32')

# %%
#imgs[0]

# %%
#help(train_generator)

# %%
#help(tensorflow.python.keras.layers.convolutional.Conv2D)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Add, Flatten, LayerNormalization, Activation, Input
from tensorflow.keras import Sequential
try:
    from einops import rearrange, repeat
    from einops.layers.tensorflow import Rearrange
except:
    print("Einops not installed, Initiating install")
    # !pip install einops
    from einops import rearrange, repeat
    from einops.layers.tensorflow import Rearrange
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
# Out:
# Einops not installed, Initiating install
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting einops
#   Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.6.0

# %%
from transformers import TFAutoImageProcessor
basemodel = TFViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
inputs = Input(shape=(3,224,224,))
outputs = basemodel(inputs)
model = Model(inputs=inputs, outputs=outputs)
basemodel.summary(expand_nested=True)
ckpt_name = 'google/vit-base-patch16-224-in21k'
feature_extractor = AutoImageProcessor.from_pretrained(ckpt_name)
feature_extractor
# Out:
# All model checkpoint layers were used when initializing TFViTModel.
#
# All the layers of TFViTModel were initialized from the model checkpoint at google/vit-base-patch16-224-in21k.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFViTModel for predictions without further training.
# Model: "tf_vi_t_model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  86389248
#
# =================================================================
# Total params: 86,389,248
# Trainable params: 86,389,248
# Non-trainable params: 0
# _________________________________________________________________
# ViTImageProcessor {
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "image_processor_type": "ViTImageProcessor",
#   "image_std": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "resample": 2,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "height": 224,
#     "width": 224
#   }
# }

# %%
basemodel.summary()
# Out:
# Model: "tf_vi_t_model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vit (TFViTMainLayer)        multiple                  86389248
#
# =================================================================
# Total params: 86,389,248
# Trainable params: 86,389,248
# Non-trainable params: 0
# _________________________________________________________________

# %%
ds = pydicom.dcmread('./content/data/DCM/NON_COVID/Normal-3090.dcm')
image_d = ds.pixel_array
image = Image.fromarray(image_d)
image.thumbnail((224,224)) #resize image to 224,224
image_d = np.expand_dims(image,-1)
#image_d = Image.fromarray(image)
image.mode
#image_d = np.expand_dims(image_d, 0)
#image_d = image_d.astype(np.float32)
#l_c = Conv2D(3, (3,3), padding='same')
#out_3D = l_c(image_d)
#out_3D = tf.transpose(out_3D, perm=[0, 3,1,2])
#out_3D = np.squeeze(out_3D,0)
#out_3D.shape, type(out_3D)
#out_3D_PIL = Image.fromarray(out_3D)
#inp = feature_extractor(images=image)
#inp.shape
#out = model(out_3D)
#out['pooler_output'].shape
# Out:
# 'L'

# %%
ckpt_name = 'google/vit-base-patch16-224-in21k'
labels = ['NON-COVID', 'COVID']
id2label = {key: value for key, value in enumerate(labels)}
print(id2label)
label2id = {value: key for key, value in enumerate(labels)}
print(label2id)
# Out:
# {0: 'NON-COVID', 1: 'COVID'}
# {'NON-COVID': 0, 'COVID': 1}

# %%
from transformers import TFAutoModelForImageClassification
model = TFAutoModelForImageClassification.from_pretrained(ckpt_name, num_labels=len(labels), id2label=id2label, label2id=label2id, ignore_mismatched_sizes=True)
model
# Out:
# Some layers from the model checkpoint at google/vit-base-patch16-224-in21k were not used when initializing TFViTForImageClassification: ['vit/pooler/dense/kernel:0', 'vit/pooler/dense/bias:0']
# - This IS expected if you are initializing TFViTForImageClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTForImageClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import AutoImageProcessor
feature_extractor = AutoImageProcessor.from_pretrained(ckpt_name)
feature_extractor.size
# Out:
# {'height': 224, 'width': 224}

# %%
from tensorflow.keras.layers import Resizing, Rescaling, Normalization

# %%
data_augmentation = Sequential([
    #Resizing(224, 224),
    Rescaling(0.00392156862745098),
    Normalization(mean=0.5, variance=0.5)
    ])

# %%
ds = pydicom.dcmread('./content/data/DCM/NON_COVID/Normal-3090.dcm')
image_d = ds.pixel_array
image = Image.fromarray(image_d)
image.thumbnail((224,224)) #resize image to 224,224
image_d = np.expand_dims(image,-1)
#image_d = Image.fromarray(image)
#image.mode
image_d = np.expand_dims(image_d, 0)
image_d = image_d.astype(np.float32)
l_c = Conv2D(3, (3,3), padding='same')
out_3D = l_c(image_d)
out_3D = tf.transpose(out_3D, perm=[0, 3,1,2])
out_3D.shape
out_3D = data_augmentation(out_3D)
base_model = TFViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
#pixel_values = tf.keras.layers.Input(shape=(3,224,224), name='pixel_values', dtype='float32')
outputs = base_model(out_3D)
last_hidden_states = outputs.last_hidden_state
print(last_hidden_states.shape)
last_hidden_states_CLS = last_hidden_states[:, 0, :]
last_hidden_states_CLS.shape
#print(type(pixel_values), pixel_values.shape)
#vit = base_model.vit(pixel_values)[0]
#print(type(vit), vit.shape)
classifier = tf.keras.layers.Dense(10, activation='softmax', name='outputs')(last_hidden_states_CLS)
print(classifier.shape, type(classifier))
# Out:
# All model checkpoint layers were used when initializing TFViTModel.
#
# All the layers of TFViTModel were initialized from the model checkpoint at google/vit-base-patch16-224-in21k.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFViTModel for predictions without further training.
# (1, 197, 768)
# (1, 10) <class 'tensorflow.python.framework.ops.EagerTensor'>

# %%
base_model.trainable=False
base_model.layers

# %%
class VIT_TL(tensorflow.keras.Model):
  def __init__(self):
    super().__init__()

    self.conv_layer = Conv2D(3, (3,3), padding='same')
    self.preprocess_input = Sequential([
        Rescaling(0.00392156862745098),
        Normalization(mean=0.5, variance=0.5)
        ])

    self.basemodel = TFViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
    self.basemodel.trainable=False
   
    self.classifier = Sequential([
        #Flatten(),
        Dense(256, use_bias=False),
        BatchNormalization(),
        Activation('relu'),
        Dropout(0.25),
        Dense(128, use_bias=False),
        BatchNormalization(),
        Activation('relu'),
        Dropout(0.25),
        Dense(2)
    ])

  def call(self,x):
    #for layer in self.basemodel.layers:
     # layer.trainable=False
    x = self.conv_layer(x)
    x = tensorflow.transpose(x, perm=[0, 3,1,2])
    x = self.preprocess_input(x)
    x = self.basemodel(x)
    last_hidden_states = x.last_hidden_state
    last_hidden_states_CLS = last_hidden_states[:, 0, :]
    x = self.classifier(last_hidden_states_CLS)
    return x

# %%
model = VIT_TL()
# Out:
# All model checkpoint layers were used when initializing TFViTModel.
#
# All the layers of TFViTModel were initialized from the model checkpoint at google/vit-base-patch16-224-in21k.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFViTModel for predictions without further training.

# %%
X_input = Input(shape=(224,224,1,))
out = VIT_TL()(X_input)
temp_model = Model(inputs=X_input, outputs=out)
temp_model.summary(expand_nested=True)
# Out:
# All model checkpoint layers were used when initializing TFViTModel.
#
# All the layers of TFViTModel were initialized from the model checkpoint at google/vit-base-patch16-224-in21k.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFViTModel for predictions without further training.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 1)]     0
#
#  vit_tl_4 (VIT_TL)           (None, 2)                 86620448
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | conv2d_4 (Conv2D)         multiple                  30        |
# |                                                               |
# | sequential_6 (Sequential)  (None, 3, 224, 224)      0         |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || rescaling_3 (Rescaling)  (None, 3, 224, 224)      0         ||
# ||                                                             ||
# || normalization_3 (Normalizat  (None, 3, 224, 224)  0         ||
# || ion)                                                        ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | tf_vi_t_model_3 (TFViTModel  multiple               86389248  |
# | )                                                             |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || vit (TFViTMainLayer)    multiple                  86389248  ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_7 (Sequential)  (None, 2)                231170    |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || dense_9 (Dense)         (None, 256)               196608    ||
# ||                                                             ||
# || batch_normalization_6 (Batc  (None, 256)          1024      ||
# || hNormalization)                                             ||
# ||                                                             ||
# || activation_6 (Activation)  (None, 256)            0         ||
# ||                                                             ||
# || dropout_154 (Dropout)   (None, 256)               0         ||
# ||                                                             ||
# || dense_10 (Dense)        (None, 128)               32768     ||
# ||                                                             ||
# || batch_normalization_7 (Batc  (None, 128)          512       ||
# || hNormalization)                                             ||
# ||                                                             ||
# || activation_7 (Activation)  (None, 128)            0         ||
# ||                                                             ||
# || dropout_155 (Dropout)   (None, 128)               0         ||
# ||                                                             ||
# || dense_11 (Dense)        (None, 2)                 258       ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 86,620,448
# Trainable params: 230,432
# Non-trainable params: 86,390,016
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
from tensorflow import data, train, math, reduce_sum, cast, equal, argmax, \
float32, GradientTape, TensorSpec, function, int64

# %%
opt = Adam(learning_rate=0.0001)
loss_fn = tensorflow.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
train_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()
val_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()
test_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()

# %%
from sklearn.metrics import confusion_matrix

# %%
if os.path.exists('./content/data/ckpt'):
    print(f'Weight Checkpoint directory already exists')
    # !ls -ld ./content/data/ckpt
else:
    print(f'Weight Checkpooint directory doesnt exists.. Creating it now..')
    os.mkdir('./content/data/ckpt')
    print(f'Weight Checkpoint directory successfully created')
    # !ls -ld ./content/data/ckpt

    
if os.path.exists('./content/data/saved_model'):
    print(f'Protobuf Checkpoint directory already exists')
    # !ls -ld ./content/data/saved_model
else:
    print(f'Protobuf Checkpoint directory doesnt exists.. Creating it now..')
    os.mkdir('./content/data/saved_model')
    print(f'Weight Checkpoint directory successfully created')
    # !ls -ld ./content/data/saved_model
# Out:
# Weight Checkpooint directory doesnt exists.. Creating it now..
# Weight Checkpoint directory successfully created
# drwxr-xr-x 2 root root 4096 Apr 18 07:59 ./content/data/ckpt
# Protobuf Checkpoint directory doesnt exists.. Creating it now..
# Weight Checkpoint directory successfully created
# drwxr-xr-x 2 root root 4096 Apr 18 07:59 ./content/data/saved_model

# %%
class Model_Train():
  def __init__(self, model, optimizer, loss_fn, epochs, batch_size, train_gen, valid_gen, test_gen, train_acc_metric, val_acc_metric, test_acc_metric):
    super().__init__()

    self.model = model
    self.optimizer = optimizer
    self.loss_fn = loss_fn
    self.epochs = epochs
    self.batch_size = batch_size
    self.train_generator = train_gen
    self.valid_generator = valid_gen
    self.test_generator = test_gen
    self.steps_train = len(train_gen)
    self.steps_valid = len(valid_gen)
    self.steps_test = len(test_gen)
    self.train_acc_metric = train_acc_metric
    self.val_acc_metric = val_acc_metric
    self.test_acc_metric = test_acc_metric
    self.train_history = {'loss': [], 'accuracy': [], 'f1': [], 'precision': [], 'recall': []}
    self.valid_history = {'loss': [], 'accuracy': [], 'f1': [], 'precision': [], 'recall': [], 'ckpt_name': []}


   

  @tensorflow.function
  def train_step(self, train_data, train_label):
    with tensorflow.GradientTape() as tape:
      output = self.model(train_data, training=True)
      loss_value = self.loss_fn(train_label, output)
    grads = tape.gradient(loss_value, self.model.trainable_weights)
    self.optimizer.apply_gradients(zip(grads, self.model.trainable_weights))
    self.train_acc_metric.update_state(train_label, output)
    return output, loss_value

  @tensorflow.function
  def test_step(self, validation_data, validation_label):
    val_output = self.model(validation_data, training=False)
    loss_value = self.loss_fn(validation_label, val_output)
    self.val_acc_metric.update_state(validation_label, val_output)
    return val_output, loss_value

  def getloss_accuracy(self, gen, batch_size, steps_per_epoch, df, train=False, valid=False):
    loss_epoch = 0
    n=0
    for step, (x_batch, y_batch) in enumerate(gen):
      if train:
        output, loss_value = self.train_step(x_batch, y_batch)
        ###new code below
        
        pred_labls = list(np.argmax(output.numpy(), axis=1))
        temp_df = pd.DataFrame({'orig_label': list(y_batch), 'pred_label': pred_labls})
        df = pd.concat([df, temp_df])
            

        ## newcode above
        
      else:
        output, loss_value = self.test_step(x_batch, y_batch)
        pred_labls = list(np.argmax(output.numpy(), axis=1))
        temp_df = pd.DataFrame({'orig_label': list(y_batch), 'pred_label': pred_labls})
        df = pd.concat([df, temp_df])
            
      loss_epoch += loss_value*x_batch.shape[0]
      #n = n+1
      #print("Training step ", n )
      if step >= (steps_per_epoch-1):
        if train:
          avg_epoch_loss = (loss_epoch/(len(train_df))).numpy()
          accuracy = self.train_acc_metric.result().numpy()
          self.train_acc_metric.reset_states()
          gen.on_epoch_end()
        else:
          if valid:
            avg_epoch_loss = (loss_epoch/(len(valid_df))).numpy()
            accuracy = self.val_acc_metric.result().numpy()
            self.val_acc_metric.reset_states()
          else:
            avg_epoch_loss = (loss_epoch/(len(test_df))).numpy()
            accuracy = self.val_acc_metric.result().numpy()
            self.val_acc_metric.reset_states()


        return df, avg_epoch_loss, accuracy

  def train_validate_loop(self):
    for epoch in range(self.epochs):
      start_time = time.time()
      histdf_train = pd.DataFrame({'orig_label': [], 'pred_label': []})
      histdf_val   = pd.DataFrame({'orig_label': [], 'pred_label': []})  

      df_train_cm, avg_epoch_train_loss, train_accuracy = self.getloss_accuracy(self.train_generator, self.batch_size, self.steps_train, histdf_train, train=True)
      df_val_cm, avg_epoch_val_loss, val_accuracy = self.getloss_accuracy(self.valid_generator, self.batch_size, self.steps_valid, histdf_val, train=False, valid=True)

    
      f1, precision, recall             = self.calc_rec_prec_f1(df_train_cm, train=True)
      f1_val, precision_val, recall_val = self.calc_rec_prec_f1(df_val_cm, train=False)


      print(f'Epoch : {epoch}, Train Loss: {avg_epoch_train_loss}, Train Accuracy: {train_accuracy}, Validation Loss: {avg_epoch_val_loss}, Validation Accuracy: {val_accuracy}')
      
      self.train_history['loss'].append(avg_epoch_train_loss)
      self.train_history['accuracy'].append(train_accuracy)
      self.train_history['f1'].append(f1)
      self.train_history['precision'].append(precision)
      self.train_history['recall'].append(recall)

      self.valid_history['loss'].append(avg_epoch_val_loss)
      self.valid_history['accuracy'].append(val_accuracy)
      self.valid_history['f1'].append(f1_val)
      self.valid_history['precision'].append(precision_val)
      self.valid_history['recall'].append(recall_val)

      ###New Code for early stopping#####
      la = self.valid_history['accuracy']
      if (len(la) > 4):
        if (((la[-1] <= la[-2]) and (la[-2] <= la[-3])) and ((la[-3] <= la[-4]) and (la[-4] <= la[-5]))):
          print("Validation accuracy has not improved over last 4 epochs, hence invoking early stopping and exiting training process")
          if len(self.valid_history['ckpt_name']) > 0:
            print('Loading Best weights..')
            self.model.load_weights(self.valid_history['ckpt_name'][-1])
            break
          else:
            print("Ouch !! seems like you dont have any checkpoints saved matching criteria specified in logic. Please excuse !")
            break
                        
      if ((la[-1] > 0.9) and (len(la) > 1)):
        if(la[-1] > max(la[0:-1])):
          self.save_checkpoint(la[-1])
      elif ((la[-1] > 0.9) and (len(la) == 1)):
        self.save_checkpoint(la[-1])





      #####New Cod for early stopping


    
      print(f'Time taken: {np.round((time.time() - start_time), 4)}')
    print(f'Training completed successfully. Loading best checkpoint weights ...')
    if len(self.valid_history['ckpt_name']) > 0:
      self.model.load_weights(self.valid_history['ckpt_name'][-1])
      print(f'Best checkpoint weights loaded : {self.valid_history["ckpt_name"][-1]}')
    else:
      print("Ouch !! seems like you dont have any checkpoints saved matching criteria specified in logic. Please excuse !")

      #draw graph depicting train and validation losses and accuracy + recall, f1
    return self.train_history, self.valid_history

  def save_checkpoint(self, acc):
    ckpt_name = './content/data/ckpt/' + 'ckpt' + '_' + str(acc) + '_acc.pt'
    pb_name = './content/data/saved_model/' + 'ckpt' + '_' + str(acc) + '_acc'
    self.model.save_weights(ckpt_name)
    self.valid_history['ckpt_name'].append(ckpt_name)
    print(f'Saved Checkpoint : {ckpt_name}')
    self.model.save(pb_name)
    print(f'Saved model in protobuf format : {pb_name}')


  def get_test_accuracy(self):
    df = pd.DataFrame({'orig_label': [], 'pred_label': []})
    df_test, avg_test_loss, test_accuracy = self.getloss_accuracy(self.test_generator, self.batch_size, self.steps_test, df)
    return df_test, avg_test_loss, test_accuracy

  def calc_rec_prec_f1(self, df, train):
    print_string = "Training Confusion Matrix" if train else "Validation Confusion Matrix"
    print(print_string, "\n", confusion_matrix(df['orig_label'], df['pred_label']))
    tn, fp, fn, tp = confusion_matrix(df['orig_label'], df['pred_label']).ravel()
    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    f1 = 2*precision*recall/(precision+recall)
    return f1, precision, recall

  def predict_single(self,dcm_path, target_size=(224,224)):
    image_array = pydicom.dcmread(dcm_path).pixel_array
    image = Image.fromarray(image_array) #converts from array to PIL
    #image.thumbnail((224,224)) #resize image to 224,224
    image = image.resize((224,224))
    image_array = np.expand_dims(image, 0)
    image_array = image_array.astype(np.float32) # * (1.0/255.0)
    image_array = np.expand_dims(image_array, -1)
    output = self.model(image_array, training=False)
    pred_label = np.argmax(output.numpy())
    print(f'Predicted label for image supplied is : {classes[pred_label]}')
    return classes[pred_label]
    
  def pred_image_show(self,image_list):
    fig, subs = plt.subplots(3,3, figsize=(14,12))
    for i, sub in enumerate(subs.flatten()):
      print(f'Image path is {image_list[i][0]} and Original label is {classes[int(image_list[i][1])]}')
      pred_class = self.predict_single(image_list[i][0])
      image_array = pydicom.dcmread(image_list[i][0]).pixel_array
      sub.imshow(image_array, cmap='gray')
      sub.set_title(f'{pred_class}(Pred) : {classes[int(image_list[i][1])]}(Orig)')
            
  def plot_metrics(self):
    list = ['accuracy', 'loss', 'f1', 'recall', 'precision']
    for metrics in list:
      x = [i for i in range(len(self.train_history[metrics]))]
      y1 = self.train_history[metrics]
      y2 = self.valid_history[metrics]
      fig, ax = plt.subplots()
      ax.plot(x, y1, label="train_"+metrics)
      ax.plot(x, y2, label="valid_"+metrics)
      plt.suptitle(f'Plot showing {metrics} for Different Epoch Runs')
      ax.legend()
      plt.show()
## Save weights
## if current accuracy > 90 and current accuracy > max(list_accuracy) then create checkpoint and save weights. Also do a protobuf saved model
## store the saved checkpoint name in a list. This will make sure than checkpoints are stored in asecnding order.
## at the end of training , take the last element in checkpoint list and load and restore it. test accuracy should be checked using this chkpoint.

# %%
EPOCHS = 15
train_object = Model_Train(model, opt, loss_fn, EPOCHS, BATCH_SIZE, train_generator, valid_generator, test_generator,
             train_acc_metric, val_acc_metric, test_acc_metric
             )

# %%
train_object.__dict__
# Out:
# {'model': <__main__.VIT_TL at 0x7ff6e40c4b80>,
#  'optimizer': <keras.optimizers.adam.Adam at 0x7ff62c0ba0a0>,
#  'loss_fn': <keras.losses.SparseCategoricalCrossentropy at 0x7ff62c0ba6a0>,
#  'epochs': 15,
#  'batch_size': 32,
#  'train_generator': <__main__.DCMDataFrameIterator at 0x7ff6ea4107c0>,
#  'valid_generator': <__main__.DCMDataFrameIterator at 0x7ff6ea410b20>,
#  'test_generator': <__main__.DCMDataFrameIterator at 0x7ff6ea410fd0>,
#  'steps_train': 277,
#  'steps_valid': 70,
#  'steps_test': 87,
#  'train_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7ff62c0d9520>,
#  'val_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7ff62c0dd880>,
#  'test_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7ff62c0dd220>,
#  'train_history': {'loss': [],
#   'accuracy': [],
#   'f1': [],
#   'precision': [],
#   'recall': []},
#  'valid_history': {'loss': [],
#   'accuracy': [],
#   'f1': [],
#   'precision': [],
#   'recall': [],
#   'ckpt_name': []}}

# %%
train_dict, val_dict = train_object.train_validate_loop()
# Out:
# Training Confusion Matrix
#  [[5721  802]
#  [1015 1298]]
# Validation Confusion Matrix
#  [[1616   15]
#  [ 400  179]]
# Epoch : 0, Train Loss: 0.4683731198310852, Train Accuracy: 0.7943639755249023, Validation Loss: 0.394328773021698, Validation Accuracy: 0.8122171759605408
# Time taken: 391.0481
# Training Confusion Matrix
#  [[6051  473]
#  [ 851 1461]]
# Validation Confusion Matrix
#  [[1594   37]
#  [ 211  368]]
# Epoch : 1, Train Loss: 0.3591648042201996, Train Accuracy: 0.8501584529876709, Validation Loss: 0.2755023241043091, Validation Accuracy: 0.8877828121185303
# Time taken: 349.1277
# Training Confusion Matrix
#  [[6097  429]
#  [ 754 1556]]
# Validation Confusion Matrix
#  [[1581   50]
#  [ 154  425]]
# Epoch : 2, Train Loss: 0.32498037815093994, Train Accuracy: 0.8661158680915833, Validation Loss: 0.2338927984237671, Validation Accuracy: 0.9076923131942749
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9076923_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, embeddings_layer_call_fn, embeddings_layer_call_and_return_conditional_losses, encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses while saving (showing 5 of 426). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.9076923_acc
# Time taken: 399.5428
# Training Confusion Matrix
#  [[6120  406]
#  [ 708 1602]]
# Validation Confusion Matrix
#  [[1591   40]
#  [ 161  418]]
# Epoch : 3, Train Loss: 0.2986741065979004, Train Accuracy: 0.8739248514175415, Validation Loss: 0.22537417709827423, Validation Accuracy: 0.9090497493743896
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.90904975_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, embeddings_layer_call_fn, embeddings_layer_call_and_return_conditional_losses, encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses while saving (showing 5 of 426). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.90904975_acc
# Time taken: 411.838
# Training Confusion Matrix
#  [[6135  384]
#  [ 618 1699]]
# Validation Confusion Matrix
#  [[1593   38]
#  [ 136  443]]
# Epoch : 4, Train Loss: 0.28011712431907654, Train Accuracy: 0.8866002559661865, Validation Loss: 0.20756599307060242, Validation Accuracy: 0.9212669730186462
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.921267_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, embeddings_layer_call_fn, embeddings_layer_call_and_return_conditional_losses, encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses while saving (showing 5 of 426). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.921267_acc
# Time taken: 417.9154
# Training Confusion Matrix
#  [[6175  347]
#  [ 600 1714]]
# Validation Confusion Matrix
#  [[1574   57]
#  [ 104  475]]
# Epoch : 5, Train Loss: 0.2641954720020294, Train Accuracy: 0.8928248286247253, Validation Loss: 0.1946600079536438, Validation Accuracy: 0.9271492958068848
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9271493_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, embeddings_layer_call_fn, embeddings_layer_call_and_return_conditional_losses, encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses while saving (showing 5 of 426). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.9271493_acc
# Time taken: 421.3116
# Training Confusion Matrix
#  [[6151  370]
#  [ 564 1751]]
# Validation Confusion Matrix
#  [[1589   42]
#  [ 116  463]]
# Epoch : 6, Train Loss: 0.25386738777160645, Train Accuracy: 0.8942960500717163, Validation Loss: 0.18660475313663483, Validation Accuracy: 0.9285067915916443
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9285068_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, embeddings_layer_call_fn, embeddings_layer_call_and_return_conditional_losses, encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses while saving (showing 5 of 426). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.9285068_acc
# Time taken: 418.9855
# Training Confusion Matrix
#  [[6230  296]
#  [ 598 1712]]
# Validation Confusion Matrix
#  [[1601   30]
#  [ 116  463]]
# Epoch : 7, Train Loss: 0.24188125133514404, Train Accuracy: 0.8988230228424072, Validation Loss: 0.18033787608146667, Validation Accuracy: 0.9339366555213928
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.93393666_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, embeddings_layer_call_fn, embeddings_layer_call_and_return_conditional_losses, encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses while saving (showing 5 of 426). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.93393666_acc
# Time taken: 419.8549
# Training Confusion Matrix
#  [[6196  329]
#  [ 507 1804]]
# Validation Confusion Matrix
#  [[1589   42]
#  [  99  480]]
# Epoch : 8, Train Loss: 0.23172485828399658, Train Accuracy: 0.9053870439529419, Validation Loss: 0.17748750746250153, Validation Accuracy: 0.9361990690231323
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.93619907_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, embeddings_layer_call_fn, embeddings_layer_call_and_return_conditional_losses, encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses while saving (showing 5 of 426). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.93619907_acc
# Time taken: 415.6928
# Training Confusion Matrix
#  [[6227  289]
#  [ 497 1823]]
# Validation Confusion Matrix
#  [[1601   30]
#  [ 113  466]]
# Epoch : 9, Train Loss: 0.22671149671077728, Train Accuracy: 0.9110457301139832, Validation Loss: 0.16744664311408997, Validation Accuracy: 0.9352940917015076
# Time taken: 367.5779
# Training Confusion Matrix
#  [[6216  307]
#  [ 450 1863]]
# Validation Confusion Matrix
#  [[1560   71]
#  [  69  510]]
# Epoch : 10, Train Loss: 0.21257372200489044, Train Accuracy: 0.9143277406692505, Validation Loss: 0.1711335927248001, Validation Accuracy: 0.9366515874862671
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9366516_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, embeddings_layer_call_fn, embeddings_layer_call_and_return_conditional_losses, encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses while saving (showing 5 of 426). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.9366516_acc
# Time taken: 406.184
# Training Confusion Matrix
#  [[6228  293]
#  [ 488 1827]]
# Validation Confusion Matrix
#  [[1571   60]
#  [  73  506]]
# Epoch : 11, Train Loss: 0.22066311538219452, Train Accuracy: 0.9116116166114807, Validation Loss: 0.16482576727867126, Validation Accuracy: 0.9398189783096313
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.939819_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, embeddings_layer_call_fn, embeddings_layer_call_and_return_conditional_losses, encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses while saving (showing 5 of 426). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.939819_acc
# Time taken: 412.7569
# Training Confusion Matrix
#  [[6245  280]
#  [ 432 1879]]
# Validation Confusion Matrix
#  [[1591   40]
#  [  85  494]]
# Epoch : 12, Train Loss: 0.19804111123085022, Train Accuracy: 0.9194205403327942, Validation Loss: 0.15531958639621735, Validation Accuracy: 0.9434388875961304
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9434389_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, embeddings_layer_call_fn, embeddings_layer_call_and_return_conditional_losses, encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses while saving (showing 5 of 426). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.9434389_acc
# Time taken: 415.635
# Training Confusion Matrix
#  [[6228  296]
#  [ 411 1901]]
# Validation Confusion Matrix
#  [[1597   34]
#  [  82  497]]
# Epoch : 13, Train Loss: 0.19999197125434875, Train Accuracy: 0.9199864268302917, Validation Loss: 0.15510116517543793, Validation Accuracy: 0.9475113153457642
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9475113_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, embeddings_layer_call_fn, embeddings_layer_call_and_return_conditional_losses, encoder_layer_call_fn, encoder_layer_call_and_return_conditional_losses while saving (showing 5 of 426). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.9475113_acc
# Time taken: 415.4241
# Training Confusion Matrix
#  [[6265  256]
#  [ 396 1919]]
# Validation Confusion Matrix
#  [[1588   43]
#  [  81  498]]
# Epoch : 14, Train Loss: 0.18543250858783722, Train Accuracy: 0.9262109398841858, Validation Loss: 0.1530519276857376, Validation Accuracy: 0.9438914060592651
# Time taken: 362.9161
# Training completed successfully. Loading best checkpoint weights ...
# Best checkpoint weights loaded : ./content/data/ckpt/ckpt_0.9475113_acc.pt

# %%
df, loss, accuracy = train_object.get_test_accuracy() #from df returned by function you can check which image has lables incorrectly predicted

# %%
accuracy
# Out:
# 0.9438813

# %%
confusion_matrix(df['orig_label'], df['pred_label'])
# Out:
# array([[1990,   49],
#        [ 106,  617]])

# %%
train_object.predict_single(test_df.iloc[-2,0])
# Out:
# Predicted label for image supplied is : COVID
# 'COVID'

# %%
train_object.model.save_weights('./content/data/ckpt/model_best_weights')

# %%
with zipfile.ZipFile('./XRAY_resnet50_model_best_weights.zip', 'w') as myzip:
    myzip.write('./content/data/ckpt/checkpoint')
    myzip.write('./content/data/ckpt/model_best_weights.data-00000-of-00001')
    #myzip.write('./content/data/ckpt/model_best_weights.data-00001-of-00002')
    myzip.write('./content/data/ckpt/model_best_weights.index')

# %%
random_9_test = random.sample(list(test_df.values), 9)
random_9_test, len(random_9_test)
# Out:
# ([array(['./content/data/DCM/NON_COVID/Normal-6010.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-181.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-8395.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-5757.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-1143.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-5430.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-678.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-5206.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-2488.dcm', '1'], dtype=object)],
#  9)

# %%
random_9_test[0][0], random_9_test[0][1]
# Out:
# ('./content/data/DCM/NON_COVID/Normal-6010.dcm', '0')

# %%
train_object.pred_image_show(random_9_test)
# Out:
# Image path is ./content/data/DCM/NON_COVID/Normal-6010.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-181.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-8395.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-5757.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-1143.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-5430.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/COVID/COVID-678.dcm and Original label is COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-5206.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/COVID/COVID-2488.dcm and Original label is COVID
# Predicted label for image supplied is : COVID

# %%
train_object.plot_metrics()

# %%
# !cp ./*model_best_weights.zip ./gdrive/MyDrive/Manning_Projects/
