# %% [markdown]
# ## Milestone 1.1

# %%
# !nvidia-smi
# Out:
# Sun Apr 23 02:50:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   63C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
# Out:
# Your runtime has 13.6 gigabytes of available RAM

# %%
import requests
import pickle
import zipfile
import time
import os
#from google.colab import drive
import random
import glob
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy import asarray
from PIL.ImageStat import Stat
# !pip install pydicom
import pydicom
# Package for converting PNG Files to DICOM(.dcm ) format
# !pip install simpleitk
import SimpleITK as sitk
from sklearn.model_selection import train_test_split
from PIL import Image
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import DataFrameIterator
#from keras_preprocessing.image.dataframe_iterator import DataFrameIterator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Conv2D, AveragePooling2D, Flatten, Dense, Activation, MaxPool2D, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.applications import EfficientNetV2B0
#tf.keras.applications.efficientnet.EfficientNetB4
#tf.keras.applications.efficientnet.preprocess_input (not required for efficientnets)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydicom in /usr/local/lib/python3.9/dist-packages (2.3.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: simpleitk in /usr/local/lib/python3.9/dist-packages (2.2.1)

# %%
data_path = './content'
archive_path = data_path + '/data/'
if os.path.exists(archive_path):
  print(f"{archive_path} directory exists.")
else:
  print(f"Did not find {archive_path} directory, creating one...")
  os.mkdir('./content')

  os.mkdir(archive_path)
  if os.path.exists(archive_path):
    print(f'{archive_path} created successfully')
# Out:
# Did not find ./content/data/ directory, creating one...
# ./content/data/ created successfully

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#!mv /content/gdrive/MyDrive/Manning_Projects/archive\ \(2\).zip /content/gdrive/MyDrive/Manning_Projects/covid_data.zip
# !ls /content/gdrive/MyDrive/Manning_Projects/
# Out:
# 'Best Project_XRAY_EfficientnetB0_transfer_learning_conv.ipynb'
#  Best_Project_XRAY_VGG16_transfer_learning_conv.ipynb
# 'Copy of Project_XRAY_Resnet50_fc_removed.ipynb'
#  covid_data.zip
#  model_best_weights.zip
#  Project_CTSCAN_EfficientNetB0_Transfer_transfer.ipynb
#  Project_CTSCAN_ViT_Transfer_transfer_all_outs_conv.ipynb
#  Project_XRAY_EfficientnetB0_transfer_learning_conv.ipynb
#  Project_XRAY_EfficientNetV2B0_transfer_learning_conv.ipynb
#  Project_XRAY_Resnet18.ipynb
#  Project_XRAY_Resnet50.ipynb
#  Project_XRAY_RESNET50_transfer_learning_conv.ipynb
#  Project_XRAY_VGG16_Transfer_Learning_3D.ipynb
#  Project_XRAY_VGG16_transfer_learning_conv.ipynb
#  Project_XRAY_VGG16_Transfer_Learning.ipynb
#  Project_XRAY_ViT_1.ipynb
#  Project_XRAY_ViT.ipynb
#  Project_XRAY_ViT_transfer_learning_conv.ipynb
#  XRAY_NFC_resnet50_model_best_weights.zip
#  XRAY_resnet50_model_best_weights.zip

# %%
DRIVE_PATH = '/content/gdrive/MyDrive/Manning_Projects/'
ARCHIVE_ZIP_FILE = DRIVE_PATH + 'covid_data.zip'
ARCHIVE_ZIP_FILE
# Out:
# '/content/gdrive/MyDrive/Manning_Projects/covid_data.zip'

# %%
# !cp {ARCHIVE_ZIP_FILE} ./content/data/

# %%
archive_file =  archive_path + 'covid_data.zip'

size = os.path.getsize(archive_file)
  
print(f'Size of the file is {size/1024} MegaBytes.')
# Out:
# Size of the file is 796903.357421875 MegaBytes.

# %%
with zipfile.ZipFile(archive_file, "r") as zip_ref:
  print("Unzipping archive") 
  zip_ref.extractall(archive_path)
# Out:
# Unzipping archive

# %%
# !rm -rf ./content/data/COVID-19_Radiography_Dataset/Lung_Opacity

# %%
# !rm -rf ./content/data/COVID-19_Radiography_Dataset/Viral\ Pneumonia

# %%
COVID_IMAGE_PATH = './content/data/COVID-19_Radiography_Dataset/COVID/images'
NON_COVID_IMAGE_PATH = './content/data/COVID-19_Radiography_Dataset/Normal/images'

# %%
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
walk_through_dir(COVID_IMAGE_PATH)
# Out:
# There are 0 directories and 3616 images in './content/data/COVID-19_Radiography_Dataset/COVID/images'.

# %%
walk_through_dir(NON_COVID_IMAGE_PATH)
# Out:
# There are 0 directories and 10192 images in './content/data/COVID-19_Radiography_Dataset/Normal/images'.

# %%
random.seed(42)

COVID_IMAGE_PATH_LIST = glob.glob(COVID_IMAGE_PATH + "/*.png")
len(COVID_IMAGE_PATH_LIST), type(COVID_IMAGE_PATH_LIST)
# Out:
# (3616, list)

# %%
NON_COVID_IMAGE_PATH_LIST = glob.glob(NON_COVID_IMAGE_PATH + "/*.png")
len(NON_COVID_IMAGE_PATH_LIST), type(NON_COVID_IMAGE_PATH_LIST)
# Out:
# (10192, list)

# %%
random_image_cov = random.choice(COVID_IMAGE_PATH_LIST)
cov_pic = Image.open(random_image_cov).convert('L')
cov_pic.show()
# Out:
# <PIL.Image.Image image mode=L size=299x299 at 0x7F349BDB5D00>

# %%
random_image_ncov = random.choice(NON_COVID_IMAGE_PATH_LIST)
ncov_pic = Image.open(random_image_ncov).convert('L')
ncov_pic.show()
type(ncov_pic)
# Out:
# <PIL.Image.Image image mode=L size=299x299 at 0x7F349BC699A0>
# PIL.Image.Image

# %%
def image_show(image_list, label):
  fig, subs = plt.subplots(3,3, figsize=(16,12))
  for i, sub in enumerate(subs.flatten()):
    #image_path = os.path.normpath(image[i])
    print(f'Image path is {image_list[i]} and label is {label}')
    img = Image.open(image_list[i])
    img.thumbnail((224,224))
    sub.imshow(img, cmap='gray')
    #sub.axis("off")
    print(f'Size of displayed image is {img.size}')
    sub.set_title(label)

# %%
random.seed(3)
ll_d_c =  []
for i in range(9):
  im = random.choice(COVID_IMAGE_PATH_LIST)
  ll_d_c.append(im)
print(ll_d_c, len(ll_d_c))

ll_d_nc = []
for i in range(9):
  im = random.choice(NON_COVID_IMAGE_PATH_LIST)
  ll_d_nc.append(im)

print(ll_d_nc, len(ll_d_nc))
# Out:
# ['./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2121.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-991.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-3292.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1386.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1054.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1091.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2067.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1727.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1569.png'] 9
# ['./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6687.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-4632.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-3784.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-8287.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-7156.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-3783.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-8963.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5030.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5899.png'] 9

# %%
image_show(ll_d_c, 'COVID')
# Out:
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2121.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-991.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-3292.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1386.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1054.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1091.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2067.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1727.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1569.png and label is COVID
# Size of displayed image is (224, 224)

# %%
image_show(ll_d_nc, 'NON-COVID')
# Out:
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6687.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-4632.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-3784.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-8287.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-7156.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-3783.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-8963.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5030.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5899.png and label is NON-COVID
# Size of displayed image is (224, 224)

# %%
random_image = random.choice(COVID_IMAGE_PATH_LIST)
random_image_gs = Image.open(random_image).convert('L')
shape= random_image_gs.size
img= np.reshape(random_image_gs, (-1, *shape, 1))
img.shape
# Out:
# (1, 299, 299, 1)

# %%
#def img_resize_save(img_path_list):
#  for i in range(len(img_path_list)):
#    temp_img = Image.open(img_path_list[i])
#    temp_img.thumbnail((224,224))
#    temp_img.save(img_path_list[i])
#  print('All images in supplied list resized to (224,224)')

#Originally I was under impression that all files have to be resized to 224,224 and then saved to disk. This is mentioned as a separate task.
#Hence, the logical deduction

# %%
df = pd.DataFrame({'Class': [len(NON_COVID_IMAGE_PATH_LIST), len(COVID_IMAGE_PATH_LIST)]})

# %%
total_class = df.Class.sum()
total_class
# Out:
# 13808

# %%
df['per_distr'] = df['Class'].apply(lambda x: x/total_class)
df.index = ['Non_Covid', 'Covid']

# %%
df.Class.plot(kind="bar", figsize=(8,6))
plt.ylabel("Number of Images")
plt.xlabel("Image Class")
plt.title("Distribution of Covid/Non-Covid Images")
plt.show()

# %%
list_arr = []
for pic in COVID_IMAGE_PATH_LIST:
  pic_np = np.array(Image.open(pic).convert('L'))
  pic_np = pic_np.reshape(299,299,1)
  list_arr.append(pic_np)

# %%
len(list_arr)
# Out:
# 3616

# %%
covid_arr = np.array(list_arr)

# %%
covid_arr.shape
# Out:
# (3616, 299, 299, 1)

# %%
np.mean(covid_arr), np.min(covid_arr), np.max(covid_arr), np.std(covid_arr)
# Out:
# (139.52120961679765, 0, 255, 61.90712697550053)

# %%
# Flatten the image data into a 1D array
pixel_values = covid_arr.flatten()

pixel_values.shape
# Out:
# (323274016,)

# %%
# Plot a histogram of the pixel values
plt.hist(pixel_values, bins=50)
plt.suptitle("Distribution of pixel values for Covid Image Data")
plt.show()

# %%
list_arr_nc = []
for pic in NON_COVID_IMAGE_PATH_LIST:
  pic_np_nc = np.array(Image.open(pic).convert('L'))
  pic_np_nc = pic_np_nc.reshape(299,299,1)
  list_arr_nc.append(pic_np_nc)
len(list_arr_nc)
# Out:
# 10192

# %%
covid_arr_nc = np.array(list_arr_nc)
covid_arr_nc.shape
# Out:
# (10192, 299, 299, 1)

# %%
np.mean(covid_arr_nc), np.max(covid_arr_nc), np.mean(covid_arr_nc), np.std(covid_arr_nc)
# Out:
# (129.38979982014257, 255, 129.38979982014257, 66.21686464627422)

# %%
# Flatten the image data into a 1D array
pixel_values_nc = covid_arr_nc.flatten()
pixel_values_nc.shape
# Out:
# (911174992,)

# %%
# Plot a histogram of the pixel values
fig, subs = plt.subplots(1,2, figsize=(24,6))
for i, sub in enumerate(subs.flatten()):
  if i==0:
    sub.hist(pixel_values_nc, bins=50)
    sub.set_title("Distribution of pixel values for Non-Covid Image Data")
  else:
    sub.hist(pixel_values, bins=50)
    sub.set_title("Distribution of pixel values for Covid Image Data")

# %% [markdown]
# ## Observation
#
# It can be seen from above two histograms that pixel intensity for covid data is more peaked(kurtosis is high) than for non-covid images.
#
# This confirms with fact that X-Ray images for covid infected patients show white patches in chest X-Ray Images.

# %%
#Lets do simple check on whether the pixel data that we get from converted .dcm files is same what we get from original png image
image = COVID_IMAGE_PATH_LIST[0]
im1 = Image.open(image).convert('L')
im1= np.array(im1)
img= sitk.GetImageFromArray(im1)
sitk.WriteImage(img,'template.dcm')

# %%
fig, subs = plt.subplots(1,2, figsize=(12,6))
for i, sub in enumerate(subs.flatten()):
  if i==0:
    #ds = pydicom.dcmread('template.dcm')
    # Load the DICOM file
    ds = pydicom.dcmread('template.dcm')
    # Access the image data
    image_d = ds.pixel_array
    print(type(image_d))
    sub.imshow(image_d, cmap='gray')
    sub.set_title("Image data from .dcm file")
  else:
    sub.imshow(im1, cmap='gray')
    sub.set_title("Image data from original png file")
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## It does looks like the data from both sources are one and same.
# ## STATUS : VERIFIED

# %% [markdown]
# ## Convert all the PNG Files to DICOM (.dcm) Format

# %%
DCM_FILE_PATH = './content/data/DCM/'
COVID_DCM_FILE_PATH = './content/data/DCM/COVID/'
NON_COVID_DCM_FILE_PATH = './content/data/DCM/NON_COVID/'
if os.path.exists(DCM_FILE_PATH):
  print(f"{DCM_FILE_PATH} directory exists.")
  if os.path.exists(COVID_DCM_FILE_PATH):
    print(f'{COVID_DCM_FILE_PATH} directory exists')
  else:
    print(f'Ok... looks like {COVID_DCM_FILE_PATH} does not exists. Let us make one')
    os.mkdir(COVID_DCM_FILE_PATH)
    print(f'{COVID_DCM_FILE_PATH} directory created successfully')
  if os.path.exists(NON_COVID_DCM_FILE_PATH):
    print(f'{NON_COVID_DCM_FILE_PATH} directory exists')
  else:
    print(f'Ok... looks like {NON_COVID_DCM_FILE_PATH} does not exists. Let us make one')
    os.mkdir(NON_COVID_DCM_FILE_PATH)
    print(f'{NON_COVID_DCM_FILE_PATH} directory created successfully')
else:
  print(f'Looks like there is no directory structure below /content/data.. Lets create required directory structures')
  print(f'Creating {DCM_FILE_PATH} directory path first')
  os.mkdir(DCM_FILE_PATH)
  print(f'{DCM_FILE_PATH} directory created successfully')

  print(f'Creating {COVID_DCM_FILE_PATH} directory path')
  os.mkdir(COVID_DCM_FILE_PATH)
  print(f'{COVID_DCM_FILE_PATH} directory created successfully')

  print(f'Creating {NON_COVID_DCM_FILE_PATH} directory path')
  os.mkdir(NON_COVID_DCM_FILE_PATH)
  print(f'{NON_COVID_DCM_FILE_PATH} directory created successfully')
# Out:
# Looks like there is no directory structure below /content/data.. Lets create required directory structures
# Creating ./content/data/DCM/ directory path first
# ./content/data/DCM/ directory created successfully
# Creating ./content/data/DCM/COVID/ directory path
# ./content/data/DCM/COVID/ directory created successfully
# Creating ./content/data/DCM/NON_COVID/ directory path
# ./content/data/DCM/NON_COVID/ directory created successfully

# %%
def pngtodcm(image_list, COVID, l_i):
  print(f'COVID variable is set to {COVID}')
  list_im = []
  list_im = l_i

  for png_image in image_list:
    png_im_arr = np.array(Image.open(png_image).convert('L'))
    dcm_im_arr = sitk.GetImageFromArray(png_im_arr)
    if COVID:
      SAVE_PATH = COVID_DCM_FILE_PATH
      list_im = list_im_c
    else:
      SAVE_PATH = NON_COVID_DCM_FILE_PATH
      list_im = list_im_nc
    FILENAME = png_image.split("/")[-1].split(".")[0]
    DCM_FILENAME = SAVE_PATH + FILENAME + '.dcm'
    sitk.WriteImage(dcm_im_arr, DCM_FILENAME)
    print(f'Successfully converted and saved {DCM_FILENAME}')
    list_im.append(DCM_FILENAME)

# %%
list_im_c = []
pngtodcm(COVID_IMAGE_PATH_LIST, True, list_im_c)
# Out:
# COVID variable is set to True
# Successfully converted and saved ./content/data/DCM/COVID/COVID-215.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1264.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2130.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-861.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3149.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2966.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-585.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1351.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3400.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-330.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2889.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-842.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-4.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-537.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-196.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1472.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-374.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1997.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3491.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2297.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-699.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2486.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-438.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2213.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1082.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3478.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-894.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-985.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3104.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1430.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1123.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-104.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-382.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1756.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-557.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1076.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1805.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2259.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3221.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-28.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-158.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1442.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-49.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2852.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3473.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2973.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-465.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1447.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-186.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3338.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-446.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2276.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3116.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1860.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3542.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-299.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1421.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2762.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2414.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1944.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3596.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1896.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-742.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2476.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1758.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2236.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2463.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-475.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2785.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-688.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1928.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3501.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3159.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-589.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1093.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2705.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1067.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2469.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-105.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-728.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-993.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2430.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2841.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1536.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1910.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2774.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1754.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-134.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2981.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2393.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-875.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-203.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-830.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1348.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-570.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3285.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2920.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-649.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3072.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-535.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3270.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-283.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1212.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-626.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-797.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1590.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2696.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-786.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1779.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1987.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-334.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2126.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1187.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3023.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2499.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3543.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2115.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1622.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2233.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3610.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3000.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2069.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1103.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2833.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-71.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1209.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-927.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1263.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2697.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2462.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2814.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3378.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2128.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1416.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-60.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1654.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1249.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2661.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-914.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-47.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2248.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1995.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1108.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2694.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-61.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1192.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3085.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-97.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2797.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-764.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-421.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2960.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1161.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1253.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-210.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3272.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3038.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1715.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1379.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-602.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-613.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2519.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1722.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2945.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-327.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3544.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2501.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1539.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1219.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2314.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1080.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-737.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1157.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3411.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1956.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-206.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-317.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2085.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3363.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3280.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2265.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2677.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1369.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-470.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2667.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1115.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3598.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1073.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-63.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1417.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2017.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2240.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1196.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2573.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-780.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2068.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1429.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2585.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2425.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-220.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-547.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1843.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1909.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2188.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-906.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2706.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-135.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1455.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2197.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3560.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3279.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2811.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3017.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1079.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2095.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3515.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2662.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-611.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2521.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-761.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2360.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1660.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3510.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2511.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2947.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2061.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1556.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-422.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2725.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2358.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1684.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-840.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-8.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3397.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3013.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3276.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3240.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2353.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1312.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3212.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1523.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-175.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1796.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-489.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1671.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-292.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-569.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2625.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-491.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3489.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3550.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1820.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2359.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3184.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3110.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-383.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3065.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3136.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-637.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-308.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-787.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-274.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-466.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2437.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-971.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2849.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3448.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1968.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3284.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1025.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3591.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1931.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-877.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1153.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1881.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3189.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2066.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1300.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1047.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2543.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1349.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-262.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2053.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1634.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-986.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3361.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1113.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2326.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1182.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-783.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1398.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2723.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3375.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2925.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-697.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3247.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2081.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-844.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1645.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3592.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2030.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-395.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-18.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2403.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1537.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2783.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3257.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-364.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1906.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2548.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2072.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2728.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-551.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1731.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-79.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-990.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2764.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1558.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-936.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2557.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-350.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1226.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3195.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2504.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-242.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1388.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1697.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1243.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-915.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1831.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2969.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1063.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-34.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2753.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-62.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1876.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2442.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1777.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2286.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2563.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-517.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2769.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2980.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2158.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-81.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3420.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-119.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-640.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1555.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-300.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1028.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1046.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2713.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-68.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1461.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-179.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2527.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1942.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1105.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1862.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1148.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2062.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-804.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-468.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1908.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-481.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3480.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3565.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3218.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-992.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-576.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1029.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-428.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1507.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3049.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2050.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3078.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-730.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1870.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2687.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2447.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-116.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-872.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-607.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-810.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2721.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2944.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3452.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-632.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-314.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-476.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-650.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1252.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1589.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1246.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1914.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-188.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2755.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1661.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1707.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-268.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1164.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1630.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2198.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1269.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2572.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-58.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3235.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1313.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1919.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3220.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-83.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1801.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3446.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3407.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1354.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1703.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2028.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3548.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-600.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2984.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-829.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-803.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2954.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3348.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-525.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3047.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3304.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3135.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-507.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2087.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2730.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3181.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-720.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2992.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2460.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3611.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2631.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-165.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1845.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2836.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-935.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-483.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2789.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3127.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1229.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3243.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2230.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1040.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2523.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2406.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-654.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3427.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3395.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2765.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2093.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1248.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3150.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2232.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2246.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2666.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2347.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2171.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-209.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2187.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-50.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1766.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2786.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3035.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-967.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-410.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-973.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1675.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-302.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1538.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3253.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2714.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2336.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1917.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1812.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-181.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1647.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1309.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1827.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2612.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2150.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2064.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-128.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-520.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2070.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3232.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-560.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-789.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2823.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1920.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3425.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1090.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2535.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-388.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3087.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1975.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-426.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-515.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2307.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1913.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1657.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3034.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-477.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-469.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3586.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-114.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2580.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1780.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-13.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-568.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-562.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2195.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-777.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3160.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2481.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-734.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1147.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2726.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-448.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-675.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2228.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-918.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-424.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-620.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2251.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-687.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2776.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1963.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1386.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2610.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-267.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2910.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3223.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-661.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2508.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1641.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2037.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1293.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1659.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3390.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-950.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-11.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1408.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-924.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2371.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3154.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2664.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2245.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1244.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-747.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2653.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3573.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-272.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2124.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1904.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-559.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1492.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1576.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-172.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-832.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3075.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-377.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2865.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3430.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3341.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1687.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2672.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3311.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3539.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1285.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2239.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3224.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1402.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-902.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-763.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1043.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-818.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1767.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2860.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2926.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-595.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1420.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-957.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-944.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1493.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3155.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-427.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-770.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-700.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3587.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1880.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3456.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2296.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1735.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1986.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-93.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1495.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-594.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1627.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3316.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1778.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1274.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1973.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1008.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2340.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-200.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1414.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-295.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2756.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-456.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2383.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2844.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1566.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-471.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-312.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1112.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3335.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-590.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1966.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3217.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2154.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2082.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-934.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-642.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3450.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2934.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-955.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-983.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-516.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2167.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-96.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3057.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1058.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2218.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1877.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1144.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3152.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1431.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2537.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3487.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1141.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2387.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2513.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1460.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1800.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3414.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1850.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1842.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-482.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3465.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3428.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3313.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1791.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-367.dcm
# ...
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3260.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3458.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2279.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3401.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3469.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-182.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2938.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3521.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2482.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3419.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2870.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3238.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1445.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1706.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1464.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-72.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1403.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2344.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2861.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2794.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3139.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2959.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1002.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-225.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2202.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2331.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-911.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2237.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3589.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-558.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-885.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1268.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3239.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-681.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3488.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-643.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2898.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-29.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2192.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3581.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2552.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2574.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2758.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2355.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-315.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1257.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-380.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-702.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1158.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2946.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3108.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3385.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3436.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2748.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-192.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-53.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3453.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1712.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1149.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1303.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2449.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-523.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2388.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3242.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-659.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3531.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2750.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2227.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1440.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1724.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3549.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2931.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-381.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1050.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3438.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3140.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1109.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2250.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3603.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-86.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1680.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1648.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-653.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3426.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3475.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-46.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1071.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-358.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2843.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-344.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-281.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2168.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2916.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-273.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-6.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1923.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-845.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-868.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2306.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3254.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2703.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3261.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3355.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-160.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1346.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-255.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-336.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-677.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2681.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2342.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2071.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3118.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1383.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-641.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-193.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1725.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1694.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2941.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2056.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1145.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3123.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2305.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-194.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2341.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1912.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1574.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1024.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2164.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1409.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2330.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3091.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2832.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-494.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2398.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1049.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-766.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1984.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2857.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2162.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2842.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1169.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2003.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1567.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-21.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3121.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-14.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1718.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-884.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-256.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-820.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2534.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1872.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1343.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3093.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1437.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1425.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3434.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1084.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1915.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-324.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1592.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2468.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1502.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2982.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-487.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1220.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1068.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2716.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-280.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-736.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3173.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-852.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1359.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1639.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1672.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-565.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2456.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2688.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2901.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3429.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-259.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1834.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1453.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1602.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1998.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-758.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1578.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-445.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-54.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-942.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3096.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3345.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2255.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3408.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1463.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-550.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1528.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-140.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1549.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-509.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3373.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1594.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1465.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-157.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-821.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-107.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1774.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-261.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1172.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2397.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-15.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3191.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2224.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2183.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1329.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-774.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-739.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1787.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-888.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1247.dcm

# %%
len(list_im_c)
# Out:
# 3616

# %%
list_im_nc = []
pngtodcm(NON_COVID_IMAGE_PATH_LIST, False, list_im_nc)
# Out:
# Streaming output truncated to the last 5000 lines.
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6660.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6345.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2968.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9611.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3971.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7791.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-390.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10042.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8214.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1126.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4484.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1351.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2392.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2524.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6199.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8836.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4699.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7042.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10067.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3492.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-373.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4686.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7362.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1616.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7314.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1393.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6212.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7365.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6571.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4768.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5729.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5484.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8212.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4122.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-929.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9179.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9473.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4662.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-93.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8986.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5868.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-20.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6725.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1587.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3283.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3412.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6361.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3477.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2619.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2803.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6177.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9997.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9890.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-909.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3657.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3538.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6531.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1893.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4226.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6031.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2622.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1015.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6368.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5585.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4001.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8420.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6329.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9064.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5027.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-48.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4218.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6051.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4687.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8511.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4789.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4544.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7143.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-134.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7919.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3330.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6247.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4194.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6268.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9352.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5052.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4168.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6919.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1564.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9677.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-375.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6206.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1956.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5171.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2406.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7184.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4960.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8007.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8150.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2334.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9633.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6484.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9581.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5205.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8320.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3773.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5969.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4231.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5985.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2318.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1777.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1142.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7000.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3997.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1626.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8677.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9167.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8239.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7434.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4257.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4854.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6006.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-377.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8881.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8890.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-334.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5259.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8261.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-157.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1690.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5104.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2856.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7470.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2447.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9968.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8139.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2113.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3436.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-859.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5064.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3316.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5389.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9941.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3822.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-29.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6995.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1819.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9371.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4318.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4637.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8448.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4983.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7963.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6054.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2829.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4300.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-113.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3881.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1116.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5771.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1481.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3300.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8518.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3257.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7774.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-509.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-913.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-971.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-408.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-274.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9432.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9720.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7818.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-374.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4536.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7252.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3556.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3173.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4219.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4653.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-462.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6325.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-957.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-344.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8557.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5474.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6424.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6131.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7812.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8802.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9190.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4548.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2149.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4207.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2743.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8074.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3980.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6273.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4843.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9281.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6981.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9531.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9819.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5693.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8639.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6311.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1891.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8215.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3679.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5240.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5944.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2557.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8787.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2635.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9431.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9803.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9871.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5237.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7529.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6593.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1792.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1894.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1422.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3272.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6968.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6002.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9494.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1117.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9685.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1396.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8427.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3281.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4362.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2404.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6410.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4304.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5706.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-115.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5984.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8593.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5672.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7368.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4285.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8256.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8451.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7006.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9272.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6950.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3641.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9170.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9711.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1573.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1540.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2513.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9822.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9204.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2864.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4683.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3720.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3459.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1515.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7295.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3293.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9388.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7638.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5152.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1321.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3634.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-210.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10058.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6817.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4338.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-148.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1380.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3793.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8552.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8056.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3332.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8375.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8783.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9857.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1710.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-863.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6815.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3320.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8049.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10071.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1082.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9323.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8755.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9128.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9294.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2262.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8203.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2225.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1712.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2143.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-360.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8597.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3102.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4179.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5450.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1766.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8722.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9230.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4244.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-212.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1450.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8172.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9101.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5943.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7320.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6112.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3649.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2585.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7425.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2186.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-448.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4987.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10065.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7088.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5095.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5359.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9656.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6774.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1578.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6516.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8213.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3437.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1707.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9628.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3018.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8325.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7200.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9933.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4601.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-278.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9254.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2105.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6386.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3357.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3583.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8059.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-221.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8441.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7744.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4447.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9944.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-155.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8804.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4738.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3450.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10177.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3522.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4066.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1250.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1580.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2975.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-307.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5226.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4614.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4875.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5749.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3484.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4477.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7535.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3249.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1709.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3774.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-526.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2973.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8892.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-676.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8662.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9321.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6030.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8194.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5358.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-702.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9055.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9312.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3764.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5357.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-31.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9831.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7914.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6663.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8607.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4436.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3734.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6639.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2163.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2593.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2240.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6037.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5181.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3288.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10154.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8251.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5909.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-74.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1688.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6966.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-388.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4951.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2512.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7715.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9765.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10022.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8609.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2889.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7670.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5652.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5888.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9498.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1330.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1695.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8211.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9598.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7875.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5875.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2559.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-41.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4333.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5334.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9807.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9195.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9468.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4909.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4337.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3006.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9072.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3650.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3289.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3365.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1475.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6994.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5251.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7737.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6077.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7666.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3785.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2626.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1470.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6292.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7305.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9188.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-700.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1297.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9623.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1009.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4077.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7337.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1433.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1397.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-57.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6338.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6367.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10115.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6010.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2838.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2999.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6230.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2277.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1171.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8465.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8838.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4590.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5222.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7157.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5738.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2757.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3598.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5399.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8231.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4600.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5722.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8621.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-337.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2202.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2691.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7533.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5118.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6963.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6109.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5762.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3143.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6671.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3526.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9671.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5886.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10081.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2858.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7041.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6870.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9443.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4115.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6772.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5235.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6929.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8835.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2851.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4592.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8932.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5429.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8990.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1023.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2066.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6754.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2485.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2121.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6629.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4534.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1448.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-887.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6332.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6791.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10099.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1785.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8422.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1642.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5756.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4293.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8716.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6874.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2103.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8432.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3865.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10108.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1169.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3433.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2279.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1650.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9644.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3580.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1921.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7881.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6872.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1807.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4823.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7802.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8259.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9250.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5526.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-875.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4322.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6444.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10130.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1183.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1591.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1449.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9816.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8288.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5740.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7966.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9053.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7114.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4769.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7828.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3384.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6175.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-366.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1068.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1908.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6188.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9777.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3391.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3837.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5924.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6707.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7230.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7648.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1360.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2937.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8715.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-280.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7213.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9766.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1900.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9212.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2450.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1256.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6047.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2024.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6993.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3390.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7051.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5926.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8577.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3584.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6275.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7695.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6634.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3019.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4361.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4209.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9906.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1871.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8285.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10043.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5921.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5114.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2215.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7804.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6573.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4064.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9021.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8688.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9242.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1189.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3322.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3256.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6812.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6544.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9476.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8235.dcm
# ...
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9176.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-179.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2869.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1677.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3136.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-713.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3672.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6592.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-588.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9776.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3654.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7647.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7831.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4464.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7029.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3443.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5468.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-51.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3767.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2797.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6661.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9552.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9683.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2306.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4889.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2221.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-330.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8883.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2401.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3915.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4633.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6906.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9632.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9689.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6140.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9995.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8821.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4747.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3336.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-331.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5459.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6293.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3309.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9705.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1191.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-793.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4537.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9257.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1108.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3415.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4432.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4685.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4728.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6370.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-183.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9996.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8207.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3142.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2686.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4072.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3669.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3554.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3955.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2516.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5148.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4696.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4451.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-821.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9485.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6667.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6029.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-627.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5093.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-576.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7275.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7518.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3176.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7611.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8700.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-488.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5014.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1727.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9059.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8851.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1644.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8507.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-655.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3722.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8336.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-66.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7014.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7873.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3488.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10120.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3371.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8140.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7456.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5330.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6714.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6672.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7607.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2438.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2096.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2934.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6762.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2261.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4474.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9517.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9351.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2165.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3302.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-930.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3195.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7755.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-889.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5942.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-998.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7182.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4416.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-764.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4152.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2866.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8368.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9658.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3625.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6482.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3851.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-514.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2236.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5514.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2278.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5200.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2174.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9447.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-760.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7700.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6057.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2131.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9157.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4163.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4565.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7123.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7551.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-90.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5091.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2510.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3610.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6943.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-229.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5845.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3953.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6576.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1868.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3505.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2597.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-647.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6645.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1603.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9984.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8752.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7575.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1858.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5026.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-290.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3586.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4446.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3155.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6606.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7856.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6395.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5768.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1506.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4828.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2552.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8404.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4647.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5356.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7155.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6209.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5867.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3164.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3604.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2460.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6001.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-800.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1675.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8466.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-58.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2167.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6933.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9994.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7136.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-215.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2849.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4673.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1354.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8900.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3693.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5530.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10094.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6162.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5351.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9010.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5527.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7079.dcm

# %%
len(list_im_nc), len(list_im_c)
# Out:
# (10192, 3616)

# %%
len(NON_COVID_IMAGE_PATH_LIST), len(COVID_IMAGE_PATH_LIST)
# Out:
# (10192, 3616)

# %%
list_im_nc[0], list_im_c[0]
# Out:
# ('./content/data/DCM/NON_COVID/Normal-9163.dcm',
#  './content/data/DCM/COVID/COVID-215.dcm')

# %%
def extract_fnames(file_list):
  temp_ll = []
  for i in file_list:
    fname = i.split("/")[-1].split(".")[0]
    temp_ll.append(fname)
    return sorted(temp_ll)

# %%
ll_dc_fname = extract_fnames(list_im_c)
ll_dnc_fname = extract_fnames(list_im_nc)
ll_pc_fname = extract_fnames(COVID_IMAGE_PATH_LIST)
ll_pnc_fname = extract_fnames(NON_COVID_IMAGE_PATH_LIST)

# %%
ll_dc_fname == ll_pc_fname
# Out:
# True

# %%
ll_dnc_fname == ll_pnc_fname
# Out:
# True

# %%
df_nc = pd.DataFrame()

# %%
df_nc['filename'] = list_im_nc

# %%
df_nc['class'] = 0

# %%
df_nc
# Out:
#                                            filename  class
# 0      ./content/data/DCM/NON_COVID/Normal-9163.dcm      0
# 1      ./content/data/DCM/NON_COVID/Normal-2617.dcm      0
# 2       ./content/data/DCM/NON_COVID/Normal-618.dcm      0
# 3      ./content/data/DCM/NON_COVID/Normal-2518.dcm      0
# 4      ./content/data/DCM/NON_COVID/Normal-8107.dcm      0
# ...                                             ...    ...
# 10187  ./content/data/DCM/NON_COVID/Normal-6162.dcm      0
# 10188  ./content/data/DCM/NON_COVID/Normal-5351.dcm      0
# 10189  ./content/data/DCM/NON_COVID/Normal-9010.dcm      0
# 10190  ./content/data/DCM/NON_COVID/Normal-5527.dcm      0
# 10191  ./content/data/DCM/NON_COVID/Normal-7079.dcm      0
#
# [10192 rows x 2 columns]

# %%
label_1 = list(np.ones(len(list_im_c), dtype=int))
len(label_1), len(list_im_c)
# Out:
# (3616, 3616)

# %%
dict_c = {'filename': list_im_c, 'class': label_1}

# %%
df_c = pd.DataFrame(data=dict_c)

# %%
df_c
# Out:
#                                      filename  class
# 0      ./content/data/DCM/COVID/COVID-215.dcm      1
# 1     ./content/data/DCM/COVID/COVID-1264.dcm      1
# 2     ./content/data/DCM/COVID/COVID-2130.dcm      1
# 3      ./content/data/DCM/COVID/COVID-861.dcm      1
# 4     ./content/data/DCM/COVID/COVID-3149.dcm      1
# ...                                       ...    ...
# 3611   ./content/data/DCM/COVID/COVID-774.dcm      1
# 3612   ./content/data/DCM/COVID/COVID-739.dcm      1
# 3613  ./content/data/DCM/COVID/COVID-1787.dcm      1
# 3614   ./content/data/DCM/COVID/COVID-888.dcm      1
# 3615  ./content/data/DCM/COVID/COVID-1247.dcm      1
#
# [3616 rows x 2 columns]

# %%
df = pd.concat([df_nc, df_c])

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns=['index'], inplace=True)

# %%
df
# Out:
#                                            filename  class
# 0      ./content/data/DCM/NON_COVID/Normal-9163.dcm      0
# 1      ./content/data/DCM/NON_COVID/Normal-2617.dcm      0
# 2       ./content/data/DCM/NON_COVID/Normal-618.dcm      0
# 3      ./content/data/DCM/NON_COVID/Normal-2518.dcm      0
# 4      ./content/data/DCM/NON_COVID/Normal-8107.dcm      0
# ...                                             ...    ...
# 13803        ./content/data/DCM/COVID/COVID-774.dcm      1
# 13804        ./content/data/DCM/COVID/COVID-739.dcm      1
# 13805       ./content/data/DCM/COVID/COVID-1787.dcm      1
# 13806        ./content/data/DCM/COVID/COVID-888.dcm      1
# 13807       ./content/data/DCM/COVID/COVID-1247.dcm      1
#
# [13808 rows x 2 columns]

# %%
df['class'].value_counts()
# Out:
# 0    10192
# 1     3616
# Name: class, dtype: int64

# %%
df.to_csv('./content/data/DCM/dcm_files_list_labels.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13808 entries, 0 to 13807
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  13808 non-null  object
#  1   class     13808 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 215.9+ KB

# %% [markdown]
# ## Milestone 1.2

# %%
df_loaddata = pd.read_csv('./content/data/DCM/dcm_files_list_labels.csv')

# %%
df_loaddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13808 entries, 0 to 13807
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  13808 non-null  object
#  1   class     13808 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 215.9+ KB

# %%
len(df_loaddata.filename.unique())
# Out:
# 13808

# %%
df_loaddata['class'].value_counts()
# Out:
# 0    10192
# 1     3616
# Name: class, dtype: int64

# %%
df_X = df_loaddata.drop(columns=['class'])
df_y = df_loaddata['class']

# %%
df_y.head(), df_X.head()
# Out:
# (0    0
#  1    0
#  2    0
#  3    0
#  4    0
#  Name: class, dtype: int64,
#                                         filename
#  0  ./content/data/DCM/NON_COVID/Normal-9163.dcm
#  1  ./content/data/DCM/NON_COVID/Normal-2617.dcm
#  2   ./content/data/DCM/NON_COVID/Normal-618.dcm
#  3  ./content/data/DCM/NON_COVID/Normal-2518.dcm
#  4  ./content/data/DCM/NON_COVID/Normal-8107.dcm)

# %%
train_df, test_df = train_test_split(df_loaddata, test_size=0.2, random_state=42, stratify=df['class'])

len(train_df), len(test_df)
# Out:
# (11046, 2762)

# %%
# we need to further reserve 20% data in training for validation
train_df, valid_df = train_test_split(train_df, test_size=0.2, random_state=42, stratify=train_df['class'])

len(train_df), len(valid_df)
# Out:
# (8836, 2210)

# %%
train_df['class'].sum(), valid_df['class'].sum(), test_df['class'].sum()
# Out:
# (2314, 579, 723)

# %%
train_df['class'].sum() + valid_df['class'].sum() + test_df['class'].sum()
# Out:
# 3616

# %%
train_aug_params = dict(
    #rescale=1./255,
    rotation_range=10,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    brightness_range = [0.8, 1.2]
)

valid_aug_params = dict(
    #rescale=1./255
    )

test_aug_params = dict(
    #rescale=1./255
)

# %%
#Creating augmenters

train_augmenter = ImageDataGenerator(**train_aug_params)
valid_augmenter = ImageDataGenerator(**valid_aug_params)
test_augmenter = ImageDataGenerator(**test_aug_params)

# %%
type(train_augmenter), type(valid_augmenter), type(test_augmenter)
# Out:
# (keras.preprocessing.image.ImageDataGenerator,
#  keras.preprocessing.image.ImageDataGenerator,
#  keras.preprocessing.image.ImageDataGenerator)

# %%
# training parameters
BATCH_SIZE = 32
COLOR_MODE = 'grayscale'
TARGET_SIZE = (224, 224)
EPOCHS = 10

train_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE,  
}

valid_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE, 
    'shuffle': False
}

test_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE,  # resize input images
    'shuffle': False
}

# %%
class DCMDataFrameIterator(DataFrameIterator):
    def __init__(self, *arg, **kwargs):
        self.white_list_formats = ('dcm')
        super(DCMDataFrameIterator, self).__init__(*arg, **kwargs)
        self.dataframe = kwargs['dataframe']
        self.x = self.dataframe[kwargs['x_col']]
        self.y = self.dataframe[kwargs['y_col']]
        self.color_mode = kwargs['color_mode']
        self.target_size = kwargs['target_size']

    def _get_batches_of_transformed_samples(self, indices_array):
        # get batch of images
        batch_x = np.array([self.read_dcm_as_array(dcm_path, self.target_size, color_mode=self.color_mode)
                            for dcm_path in self.x.iloc[indices_array]])

        batch_y = np.array(self.y.iloc[indices_array].astype(np.uint8))  # astype because y was passed as str

        # transform images
        if self.image_data_generator is not None:
            for i, (x, y) in enumerate(zip(batch_x, batch_y)):
                transform_params = self.image_data_generator.get_random_transform(x.shape)
                batch_x[i] = self.image_data_generator.apply_transform(x, transform_params)
                
                # you can change y here as well, eg: in semantic segmentation you want to transform masks as well 
                # using the same image_data_generator transformations.

        return batch_x, batch_y

    @staticmethod
    def read_dcm_as_array(dcm_path, target_size=(256, 256), color_mode='rgb'):
        image_array = pydicom.dcmread(dcm_path).pixel_array
        image = Image.fromarray(image_array) #converts from array to PIL
        #image = Image.open(image).convert('L')
        image.thumbnail((224,224)) #resize image to 224,224
        #image_array = cv2.resize(image_array, target_size, interpolation=cv2.INTER_NEAREST)  #this returns a 2d array
        image_array = np.expand_dims(image, -1)
        return image_array.astype(np.float32)

# %%
train_df['class'] = train_df['class'].astype('str')
valid_df['class'] = valid_df['class'].astype('str')
test_df['class'] = test_df['class'].astype('str')

# %%
train_df.info(), valid_df.info(),  test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8836 entries, 13528 to 8134
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  8836 non-null   object
#  1   class     8836 non-null   object
# dtypes: object(2)
# memory usage: 207.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2210 entries, 6681 to 12452
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  2210 non-null   object
#  1   class     2210 non-null   object
# dtypes: object(2)
# memory usage: 51.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2762 entries, 1939 to 8436
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  2762 non-null   object
#  1   class     2762 non-null   object
# dtypes: object(2)
# memory usage: 64.7+ KB
# (None, None, None)

# %%
train_generator = DCMDataFrameIterator(dataframe=train_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=train_augmenter,
                             **train_consts)

valid_generator = DCMDataFrameIterator(dataframe=valid_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=valid_augmenter,
                             **valid_consts)

test_generator = DCMDataFrameIterator(dataframe=test_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=test_augmenter,
                             **test_consts)
# Out:
# Found 8836 validated image filenames belonging to 2 classes.
# Found 2210 validated image filenames belonging to 2 classes.
# Found 2762 validated image filenames belonging to 2 classes.

# %%
#train_augmenter.fit(train_generator)

# %%
classes = ['NON-COVID', 'COVID']

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(train_generator))

imgs.shape, labels.shape, type(imgs), type(labels)
# Out:
# ((32, 224, 224, 1), (32,), numpy.ndarray, numpy.ndarray)

# %%
imgs[0].mean(), imgs[0].max(), imgs[0].min()
# Out:
# (111.90206, 209.0, 1.0)

# %%
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(valid_generator))
print(imgs.shape, labels.shape, type(imgs), type(labels))
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()
# Out:
# (32, 224, 224, 1) (32,) <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(test_generator))
print(imgs.shape, labels.shape, type(imgs), type(labels))
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()
# Out:
# (32, 224, 224, 1) (32,) <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
imgs[0].dtype
# Out:
# dtype('float32')

# %%
#imgs[0]

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Add, Flatten, LayerNormalization, Activation, Input
from tensorflow.keras import Sequential
try:
    from einops import rearrange, repeat
    from einops.layers.tensorflow import Rearrange
except:
    print("Einops not installed, Initiating install")
    # !pip install einops
    from einops import rearrange, repeat
    from einops.layers.tensorflow import Rearrange
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
# Out:
# Einops not installed, Initiating install
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting einops
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.6.1

# %%
basemodel = EfficientNetV2B0(weights='imagenet', include_top=False, input_tensor=Input(shape=(224,224,3)), pooling='avg')
basemodel.summary()
# Out:
# Model: "efficientnetv2-b0"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 224, 224, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 224, 224, 3)  0           ['rescaling[0][0]']
#
#  stem_conv (Conv2D)             (None, 112, 112, 32  864         ['normalization[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 112, 112, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 112, 112, 32  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 112, 112, 16  4608        ['stem_activation[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 112, 112, 16  64         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1a_project_activation (Ac  (None, 112, 112, 16  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  block2a_expand_conv (Conv2D)   (None, 56, 56, 64)   9216        ['block1a_project_activation[0][0
#                                                                  ]']
#
#  block2a_expand_bn (BatchNormal  (None, 56, 56, 64)  256         ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 56, 56, 64)  0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_project_conv (Conv2D)  (None, 56, 56, 32)   2048        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  block2a_project_bn (BatchNorma  (None, 56, 56, 32)  128         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 56, 56, 128)  36864       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 56, 56, 128)  512        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 56, 56, 128)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_project_conv (Conv2D)  (None, 56, 56, 32)   4096        ['block2b_expand_activation[0][0]
#                                                                  ']
#
#  block2b_project_bn (BatchNorma  (None, 56, 56, 32)  128         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 56, 56, 32)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 56, 56, 32)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 28, 28, 128)  36864       ['block2b_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 28, 28, 128)  512        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 28, 28, 128)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 28, 28, 48)   6144        ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 28, 28, 48)  192         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 28, 28, 192)  82944       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 28, 28, 192)  768        ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 28, 28, 192)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 28, 28, 48)   9216        ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 28, 28, 48)  192         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 28, 28, 48)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 28, 28, 48)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 28, 28, 192)  9216        ['block3b_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 28, 28, 192)  768        ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 28, 28, 192)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 14, 14, 192)  1728       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 14, 14, 192)  768        ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 14, 14, 192)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 192)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 12)     2316        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 192)    2496        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 14, 14, 192)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 14, 14, 96)   18432       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 14, 14, 96)  384         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 14, 14, 384)  36864       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 14, 14, 384)  1536       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 14, 14, 384)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 14, 14, 384)  3456       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 14, 14, 384)  1536       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 14, 14, 384)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 384)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 24)     9240        ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 384)    9600        ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 14, 14, 384)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 14, 14, 96)   36864       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 14, 14, 96)  384         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 14, 14, 96)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 14, 14, 96)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 14, 14, 384)  36864       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 14, 14, 384)  1536       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 14, 14, 384)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 14, 14, 384)  3456       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 14, 14, 384)  1536       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 14, 14, 384)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 384)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 24)     9240        ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 384)    9600        ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 14, 14, 384)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 14, 14, 96)   36864       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 14, 14, 96)  384         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 14, 14, 96)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 14, 14, 96)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 14, 14, 576)  55296       ['block4c_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 14, 14, 576)  2304       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 14, 14, 576)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv2 (DepthwiseConv  (None, 14, 14, 576)  5184       ['block5a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5a_bn (BatchNormalization  (None, 14, 14, 576)  2304       ['block5a_dwconv2[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 14, 14, 576)  0          ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 576)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, 14, 14, 576)  0           ['block5a_activation[0][0]',
#                                                                   'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, 14, 14, 112)  64512       ['block5a_se_excite[0][0]']
#
#  block5a_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5a_project_conv[0][0]']
#  lization)
#
#  block5b_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5a_project_bn[0][0]']
#
#  block5b_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block5b_expand_conv[0][0]']
#  ization)
#
#  block5b_expand_activation (Act  (None, 14, 14, 672)  0          ['block5b_expand_bn[0][0]']
#  ivation)
#
#  block5b_dwconv2 (DepthwiseConv  (None, 14, 14, 672)  6048       ['block5b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5b_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block5b_dwconv2[0][0]']
#  )
#
#  block5b_activation (Activation  (None, 14, 14, 672)  0          ['block5b_bn[0][0]']
#  )
#
#  block5b_se_squeeze (GlobalAver  (None, 672)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, 14, 14, 672)  0           ['block5b_activation[0][0]',
#                                                                   'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, 14, 14, 112)  75264       ['block5b_se_excite[0][0]']
#
#  block5b_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5b_project_conv[0][0]']
#  lization)
#
#  block5b_drop (Dropout)         (None, 14, 14, 112)  0           ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)              (None, 14, 14, 112)  0           ['block5b_drop[0][0]',
#                                                                   'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5b_add[0][0]']
#
#  block5c_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block5c_expand_conv[0][0]']
#  ization)
#
#  block5c_expand_activation (Act  (None, 14, 14, 672)  0          ['block5c_expand_bn[0][0]']
#  ivation)
#
#  block5c_dwconv2 (DepthwiseConv  (None, 14, 14, 672)  6048       ['block5c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5c_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block5c_dwconv2[0][0]']
#  )
#
#  block5c_activation (Activation  (None, 14, 14, 672)  0          ['block5c_bn[0][0]']
#  )
#
#  block5c_se_squeeze (GlobalAver  (None, 672)         0           ['block5c_activation[0][0]']
#  agePooling2D)
#
#  block5c_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5c_se_squeeze[0][0]']
#
#  block5c_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multiply)   (None, 14, 14, 672)  0           ['block5c_activation[0][0]',
#                                                                   'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv2D)  (None, 14, 14, 112)  75264       ['block5c_se_excite[0][0]']
#
#  block5c_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5c_project_conv[0][0]']
#  lization)
#
#  block5c_drop (Dropout)         (None, 14, 14, 112)  0           ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)              (None, 14, 14, 112)  0           ['block5c_drop[0][0]',
#                                                                   'block5b_add[0][0]']
#
#  block5d_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5c_add[0][0]']
#
#  block5d_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block5d_expand_conv[0][0]']
#  ization)
#
#  block5d_expand_activation (Act  (None, 14, 14, 672)  0          ['block5d_expand_bn[0][0]']
#  ivation)
#
#  block5d_dwconv2 (DepthwiseConv  (None, 14, 14, 672)  6048       ['block5d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5d_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block5d_dwconv2[0][0]']
#  )
#
#  block5d_activation (Activation  (None, 14, 14, 672)  0          ['block5d_bn[0][0]']
#  )
#
#  block5d_se_squeeze (GlobalAver  (None, 672)         0           ['block5d_activation[0][0]']
#  agePooling2D)
#
#  block5d_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5d_se_squeeze[0][0]']
#
#  block5d_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5d_se_reshape[0][0]']
#
#  block5d_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5d_se_reduce[0][0]']
#
#  block5d_se_excite (Multiply)   (None, 14, 14, 672)  0           ['block5d_activation[0][0]',
#                                                                   'block5d_se_expand[0][0]']
#
#  block5d_project_conv (Conv2D)  (None, 14, 14, 112)  75264       ['block5d_se_excite[0][0]']
#
#  block5d_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5d_project_conv[0][0]']
#  lization)
#
#  block5d_drop (Dropout)         (None, 14, 14, 112)  0           ['block5d_project_bn[0][0]']
#
#  block5d_add (Add)              (None, 14, 14, 112)  0           ['block5d_drop[0][0]',
#                                                                   'block5c_add[0][0]']
#
#  block5e_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5d_add[0][0]']
#
#  block5e_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block5e_expand_conv[0][0]']
#  ization)
#
#  block5e_expand_activation (Act  (None, 14, 14, 672)  0          ['block5e_expand_bn[0][0]']
#  ivation)
#
#  block5e_dwconv2 (DepthwiseConv  (None, 14, 14, 672)  6048       ['block5e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5e_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block5e_dwconv2[0][0]']
#  )
#
#  block5e_activation (Activation  (None, 14, 14, 672)  0          ['block5e_bn[0][0]']
#  )
#
#  block5e_se_squeeze (GlobalAver  (None, 672)         0           ['block5e_activation[0][0]']
#  agePooling2D)
#
#  block5e_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5e_se_squeeze[0][0]']
#
#  block5e_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5e_se_reshape[0][0]']
#
#  block5e_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5e_se_reduce[0][0]']
#
#  block5e_se_excite (Multiply)   (None, 14, 14, 672)  0           ['block5e_activation[0][0]',
#                                                                   'block5e_se_expand[0][0]']
#
#  block5e_project_conv (Conv2D)  (None, 14, 14, 112)  75264       ['block5e_se_excite[0][0]']
#
#  block5e_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5e_project_conv[0][0]']
#  lization)
#
#  block5e_drop (Dropout)         (None, 14, 14, 112)  0           ['block5e_project_bn[0][0]']
#
#  block5e_add (Add)              (None, 14, 14, 112)  0           ['block5e_drop[0][0]',
#                                                                   'block5d_add[0][0]']
#
#  block6a_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5e_add[0][0]']
#
#  block6a_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block6a_expand_conv[0][0]']
#  ization)
#
#  block6a_expand_activation (Act  (None, 14, 14, 672)  0          ['block6a_expand_bn[0][0]']
#  ivation)
#
#  block6a_dwconv2 (DepthwiseConv  (None, 7, 7, 672)   6048        ['block6a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6a_bn (BatchNormalization  (None, 7, 7, 672)   2688        ['block6a_dwconv2[0][0]']
#  )
#
#  block6a_activation (Activation  (None, 7, 7, 672)   0           ['block6a_bn[0][0]']
#  )
#
#  block6a_se_squeeze (GlobalAver  (None, 672)         0           ['block6a_activation[0][0]']
#  agePooling2D)
#
#  block6a_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block6a_se_squeeze[0][0]']
#
#  block6a_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block6a_se_reshape[0][0]']
#
#  block6a_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block6a_se_reduce[0][0]']
#
#  block6a_se_excite (Multiply)   (None, 7, 7, 672)    0           ['block6a_activation[0][0]',
#                                                                   'block6a_se_expand[0][0]']
#
#  block6a_project_conv (Conv2D)  (None, 7, 7, 192)    129024      ['block6a_se_excite[0][0]']
#
#  block6a_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6a_project_conv[0][0]']
#  lization)
#
#  block6b_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6a_project_bn[0][0]']
#
#  block6b_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6b_expand_conv[0][0]']
#  ization)
#
#  block6b_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6b_expand_bn[0][0]']
#  ivation)
#
#  block6b_dwconv2 (DepthwiseConv  (None, 7, 7, 1152)  10368       ['block6b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6b_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6b_dwconv2[0][0]']
#  )
#
#  block6b_activation (Activation  (None, 7, 7, 1152)  0           ['block6b_bn[0][0]']
#  )
#
#  block6b_se_squeeze (GlobalAver  (None, 1152)        0           ['block6b_activation[0][0]']
#  agePooling2D)
#
#  block6b_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6b_se_squeeze[0][0]']
#
#  block6b_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6b_se_reshape[0][0]']
#
#  block6b_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6b_se_reduce[0][0]']
#
#  block6b_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6b_activation[0][0]',
#                                                                   'block6b_se_expand[0][0]']
#
#  block6b_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6b_se_excite[0][0]']
#
#  block6b_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6b_project_conv[0][0]']
#  lization)
#
#  block6b_drop (Dropout)         (None, 7, 7, 192)    0           ['block6b_project_bn[0][0]']
#
#  block6b_add (Add)              (None, 7, 7, 192)    0           ['block6b_drop[0][0]',
#                                                                   'block6a_project_bn[0][0]']
#
#  block6c_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6b_add[0][0]']
#
#  block6c_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6c_expand_conv[0][0]']
#  ization)
#
#  block6c_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6c_expand_bn[0][0]']
#  ivation)
#
#  block6c_dwconv2 (DepthwiseConv  (None, 7, 7, 1152)  10368       ['block6c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6c_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6c_dwconv2[0][0]']
#  )
#
# ...
#
#  block6e_dwconv2 (DepthwiseConv  (None, 7, 7, 1152)  10368       ['block6e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6e_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6e_dwconv2[0][0]']
#  )
#
#  block6e_activation (Activation  (None, 7, 7, 1152)  0           ['block6e_bn[0][0]']
#  )
#
#  block6e_se_squeeze (GlobalAver  (None, 1152)        0           ['block6e_activation[0][0]']
#  agePooling2D)
#
#  block6e_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6e_se_squeeze[0][0]']
#
#  block6e_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6e_activation[0][0]',
#                                                                   'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6e_se_excite[0][0]']
#
#  block6e_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6e_project_conv[0][0]']
#  lization)
#
#  block6e_drop (Dropout)         (None, 7, 7, 192)    0           ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)              (None, 7, 7, 192)    0           ['block6e_drop[0][0]',
#                                                                   'block6d_add[0][0]']
#
#  block6f_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6e_add[0][0]']
#
#  block6f_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6f_expand_conv[0][0]']
#  ization)
#
#  block6f_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6f_expand_bn[0][0]']
#  ivation)
#
#  block6f_dwconv2 (DepthwiseConv  (None, 7, 7, 1152)  10368       ['block6f_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6f_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6f_dwconv2[0][0]']
#  )
#
#  block6f_activation (Activation  (None, 7, 7, 1152)  0           ['block6f_bn[0][0]']
#  )
#
#  block6f_se_squeeze (GlobalAver  (None, 1152)        0           ['block6f_activation[0][0]']
#  agePooling2D)
#
#  block6f_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6f_se_squeeze[0][0]']
#
#  block6f_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6f_activation[0][0]',
#                                                                   'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6f_se_excite[0][0]']
#
#  block6f_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6f_project_conv[0][0]']
#  lization)
#
#  block6f_drop (Dropout)         (None, 7, 7, 192)    0           ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)              (None, 7, 7, 192)    0           ['block6f_drop[0][0]',
#                                                                   'block6e_add[0][0]']
#
#  block6g_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6f_add[0][0]']
#
#  block6g_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6g_expand_conv[0][0]']
#  ization)
#
#  block6g_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6g_expand_bn[0][0]']
#  ivation)
#
#  block6g_dwconv2 (DepthwiseConv  (None, 7, 7, 1152)  10368       ['block6g_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6g_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6g_dwconv2[0][0]']
#  )
#
#  block6g_activation (Activation  (None, 7, 7, 1152)  0           ['block6g_bn[0][0]']
#  )
#
#  block6g_se_squeeze (GlobalAver  (None, 1152)        0           ['block6g_activation[0][0]']
#  agePooling2D)
#
#  block6g_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6g_se_squeeze[0][0]']
#
#  block6g_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6g_se_reshape[0][0]']
#
#  block6g_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6g_se_reduce[0][0]']
#
#  block6g_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6g_activation[0][0]',
#                                                                   'block6g_se_expand[0][0]']
#
#  block6g_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6g_se_excite[0][0]']
#
#  block6g_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6g_project_conv[0][0]']
#  lization)
#
#  block6g_drop (Dropout)         (None, 7, 7, 192)    0           ['block6g_project_bn[0][0]']
#
#  block6g_add (Add)              (None, 7, 7, 192)    0           ['block6g_drop[0][0]',
#                                                                   'block6f_add[0][0]']
#
#  block6h_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6g_add[0][0]']
#
#  block6h_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6h_expand_conv[0][0]']
#  ization)
#
#  block6h_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6h_expand_bn[0][0]']
#  ivation)
#
#  block6h_dwconv2 (DepthwiseConv  (None, 7, 7, 1152)  10368       ['block6h_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6h_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6h_dwconv2[0][0]']
#  )
#
#  block6h_activation (Activation  (None, 7, 7, 1152)  0           ['block6h_bn[0][0]']
#  )
#
#  block6h_se_squeeze (GlobalAver  (None, 1152)        0           ['block6h_activation[0][0]']
#  agePooling2D)
#
#  block6h_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6h_se_squeeze[0][0]']
#
#  block6h_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6h_se_reshape[0][0]']
#
#  block6h_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6h_se_reduce[0][0]']
#
#  block6h_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6h_activation[0][0]',
#                                                                   'block6h_se_expand[0][0]']
#
#  block6h_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6h_se_excite[0][0]']
#
#  block6h_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6h_project_conv[0][0]']
#  lization)
#
#  block6h_drop (Dropout)         (None, 7, 7, 192)    0           ['block6h_project_bn[0][0]']
#
#  block6h_add (Add)              (None, 7, 7, 192)    0           ['block6h_drop[0][0]',
#                                                                   'block6g_add[0][0]']
#
#  top_conv (Conv2D)              (None, 7, 7, 1280)   245760      ['block6h_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 7, 7, 1280)   5120        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 7, 7, 1280)   0           ['top_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1280)        0           ['top_activation[0][0]']
#  2D)
#
# ==================================================================================================
# Total params: 5,919,312
# Trainable params: 5,858,704
# Non-trainable params: 60,608
# __________________________________________________________________________________________________

# %%
class EfficientNetV2B0_TL(tensorflow.keras.Model):
  def __init__(self):
    super().__init__()

    self.conv_layer = Conv2D(3, (3,3), padding='same')

    self.basemodel = EfficientNetV2B0(weights='imagenet', include_top=False, input_tensor=Input(shape=(224,224,3)))
    for layer in self.basemodel.layers:
      layer.trainable=False
    self.classifier = Sequential([
        Flatten(),
        Dense(512, use_bias=False),
        BatchNormalization(),
        Activation('relu'),
        Dropout(0.1),
        Dense(128, use_bias=False),
        BatchNormalization(),
        Activation('relu'),
        Dropout(0.1),
        Dense(2)
    ])

  def call(self,x):
    #for layer in self.basemodel.layers:
     # layer.trainable=False
    x = self.conv_layer(x)
    #x = preprocess_input(x)
    x = self.basemodel(x)
    x = self.classifier(x)
    return x

# %%
model = EfficientNetV2B0_TL()

# %%
X_input = Input(shape=(224,224,1,))
out = EfficientNetV2B0_TL()(X_input)
temp_model = Model(inputs=X_input, outputs=out)
temp_model.summary(expand_nested=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 1)]     0
#
#  efficient_net_v2b0_tl_1 (Ef  (None, 2)                38100336
#  ficientNetV2B0_TL)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | conv2d_1 (Conv2D)         multiple                  30        |
# |                                                               |
# | efficientnetv2-b0 (Function  (None, 7, 7, 1280)     5919312   |
# | al)                                                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_4 (InputLayer)    [(None, 224, 224, 3)]     0         ||
# ||                                                             ||
# || rescaling_2 (Rescaling)  (None, 224, 224, 3)      0         ||
# ||                                                             ||
# || normalization_2 (Normalizat  (None, 224, 224, 3)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || stem_conv (Conv2D)      (None, 112, 112, 32)      864       ||
# ||                                                             ||
# || stem_bn (BatchNormalization  (None, 112, 112, 32)  128      ||
# || )                                                           ||
# ||                                                             ||
# || stem_activation (Activation  (None, 112, 112, 32)  0        ||
# || )                                                           ||
# ||                                                             ||
# || block1a_project_conv (Conv2  (None, 112, 112, 16)  4608     ||
# || D)                                                          ||
# ||                                                             ||
# || block1a_project_bn (BatchNo  (None, 112, 112, 16)  64       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block1a_project_activation   (None, 112, 112, 16)  0        ||
# || (Activation)                                                ||
# ||                                                             ||
# || block2a_expand_conv (Conv2D  (None, 56, 56, 64)   9216      ||
# || )                                                           ||
# ||                                                             ||
# || block2a_expand_bn (BatchNor  (None, 56, 56, 64)   256       ||
# || malization)                                                 ||
# ||                                                             ||
# || block2a_expand_activation (  (None, 56, 56, 64)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block2a_project_conv (Conv2  (None, 56, 56, 32)   2048      ||
# || D)                                                          ||
# ||                                                             ||
# || block2a_project_bn (BatchNo  (None, 56, 56, 32)   128       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block2b_expand_conv (Conv2D  (None, 56, 56, 128)  36864     ||
# || )                                                           ||
# ||                                                             ||
# || block2b_expand_bn (BatchNor  (None, 56, 56, 128)  512       ||
# || malization)                                                 ||
# ||                                                             ||
# || block2b_expand_activation (  (None, 56, 56, 128)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block2b_project_conv (Conv2  (None, 56, 56, 32)   4096      ||
# || D)                                                          ||
# ||                                                             ||
# || block2b_project_bn (BatchNo  (None, 56, 56, 32)   128       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block2b_drop (Dropout)  (None, 56, 56, 32)        0         ||
# ||                                                             ||
# || block2b_add (Add)       (None, 56, 56, 32)        0         ||
# ||                                                             ||
# || block3a_expand_conv (Conv2D  (None, 28, 28, 128)  36864     ||
# || )                                                           ||
# ||                                                             ||
# || block3a_expand_bn (BatchNor  (None, 28, 28, 128)  512       ||
# || malization)                                                 ||
# ||                                                             ||
# || block3a_expand_activation (  (None, 28, 28, 128)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block3a_project_conv (Conv2  (None, 28, 28, 48)   6144      ||
# || D)                                                          ||
# ||                                                             ||
# || block3a_project_bn (BatchNo  (None, 28, 28, 48)   192       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block3b_expand_conv (Conv2D  (None, 28, 28, 192)  82944     ||
# || )                                                           ||
# ||                                                             ||
# || block3b_expand_bn (BatchNor  (None, 28, 28, 192)  768       ||
# || malization)                                                 ||
# ||                                                             ||
# || block3b_expand_activation (  (None, 28, 28, 192)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block3b_project_conv (Conv2  (None, 28, 28, 48)   9216      ||
# || D)                                                          ||
# ||                                                             ||
# || block3b_project_bn (BatchNo  (None, 28, 28, 48)   192       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block3b_drop (Dropout)  (None, 28, 28, 48)        0         ||
# ||                                                             ||
# || block3b_add (Add)       (None, 28, 28, 48)        0         ||
# ||                                                             ||
# || block4a_expand_conv (Conv2D  (None, 28, 28, 192)  9216      ||
# || )                                                           ||
# ||                                                             ||
# || block4a_expand_bn (BatchNor  (None, 28, 28, 192)  768       ||
# || malization)                                                 ||
# ||                                                             ||
# || block4a_expand_activation (  (None, 28, 28, 192)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block4a_dwconv2 (DepthwiseC  (None, 14, 14, 192)  1728      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block4a_bn (BatchNormalizat  (None, 14, 14, 192)  768       ||
# || ion)                                                        ||
# ||                                                             ||
# || block4a_activation (Activat  (None, 14, 14, 192)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block4a_se_squeeze (GlobalA  (None, 192)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block4a_se_reshape (Reshape  (None, 1, 1, 192)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block4a_se_reduce (Conv2D)  (None, 1, 1, 12)      2316      ||
# ||                                                             ||
# || block4a_se_expand (Conv2D)  (None, 1, 1, 192)     2496      ||
# ||                                                             ||
# || block4a_se_excite (Multiply  (None, 14, 14, 192)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block4a_project_conv (Conv2  (None, 14, 14, 96)   18432     ||
# || D)                                                          ||
# ||                                                             ||
# || block4a_project_bn (BatchNo  (None, 14, 14, 96)   384       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block4b_expand_conv (Conv2D  (None, 14, 14, 384)  36864     ||
# || )                                                           ||
# ||                                                             ||
# || block4b_expand_bn (BatchNor  (None, 14, 14, 384)  1536      ||
# || malization)                                                 ||
# ||                                                             ||
# || block4b_expand_activation (  (None, 14, 14, 384)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block4b_dwconv2 (DepthwiseC  (None, 14, 14, 384)  3456      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block4b_bn (BatchNormalizat  (None, 14, 14, 384)  1536      ||
# || ion)                                                        ||
# ||                                                             ||
# || block4b_activation (Activat  (None, 14, 14, 384)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block4b_se_squeeze (GlobalA  (None, 384)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block4b_se_reshape (Reshape  (None, 1, 1, 384)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block4b_se_reduce (Conv2D)  (None, 1, 1, 24)      9240      ||
# ||                                                             ||
# || block4b_se_expand (Conv2D)  (None, 1, 1, 384)     9600      ||
# ||                                                             ||
# || block4b_se_excite (Multiply  (None, 14, 14, 384)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block4b_project_conv (Conv2  (None, 14, 14, 96)   36864     ||
# || D)                                                          ||
# ||                                                             ||
# || block4b_project_bn (BatchNo  (None, 14, 14, 96)   384       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block4b_drop (Dropout)  (None, 14, 14, 96)        0         ||
# ||                                                             ||
# || block4b_add (Add)       (None, 14, 14, 96)        0         ||
# ||                                                             ||
# || block4c_expand_conv (Conv2D  (None, 14, 14, 384)  36864     ||
# || )                                                           ||
# ||                                                             ||
# || block4c_expand_bn (BatchNor  (None, 14, 14, 384)  1536      ||
# || malization)                                                 ||
# ||                                                             ||
# || block4c_expand_activation (  (None, 14, 14, 384)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block4c_dwconv2 (DepthwiseC  (None, 14, 14, 384)  3456      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block4c_bn (BatchNormalizat  (None, 14, 14, 384)  1536      ||
# || ion)                                                        ||
# ||                                                             ||
# || block4c_activation (Activat  (None, 14, 14, 384)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block4c_se_squeeze (GlobalA  (None, 384)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block4c_se_reshape (Reshape  (None, 1, 1, 384)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block4c_se_reduce (Conv2D)  (None, 1, 1, 24)      9240      ||
# ||                                                             ||
# || block4c_se_expand (Conv2D)  (None, 1, 1, 384)     9600      ||
# ||                                                             ||
# || block4c_se_excite (Multiply  (None, 14, 14, 384)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block4c_project_conv (Conv2  (None, 14, 14, 96)   36864     ||
# || D)                                                          ||
# ||                                                             ||
# || block4c_project_bn (BatchNo  (None, 14, 14, 96)   384       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block4c_drop (Dropout)  (None, 14, 14, 96)        0         ||
# ||                                                             ||
# || block4c_add (Add)       (None, 14, 14, 96)        0         ||
# ||                                                             ||
# || block5a_expand_conv (Conv2D  (None, 14, 14, 576)  55296     ||
# || )                                                           ||
# ||                                                             ||
# || block5a_expand_bn (BatchNor  (None, 14, 14, 576)  2304      ||
# || malization)                                                 ||
# ||                                                             ||
# || block5a_expand_activation (  (None, 14, 14, 576)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block5a_dwconv2 (DepthwiseC  (None, 14, 14, 576)  5184      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block5a_bn (BatchNormalizat  (None, 14, 14, 576)  2304      ||
# || ion)                                                        ||
# ||                                                             ||
# || block5a_activation (Activat  (None, 14, 14, 576)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block5a_se_squeeze (GlobalA  (None, 576)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block5a_se_reshape (Reshape  (None, 1, 1, 576)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block5a_se_reduce (Conv2D)  (None, 1, 1, 24)      13848     ||
# ||                                                             ||
# || block5a_se_expand (Conv2D)  (None, 1, 1, 576)     14400     ||
# ||                                                             ||
# || block5a_se_excite (Multiply  (None, 14, 14, 576)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block5a_project_conv (Conv2  (None, 14, 14, 112)  64512     ||
# || D)                                                          ||
# ||                                                             ||
# || block5a_project_bn (BatchNo  (None, 14, 14, 112)  448       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block5b_expand_conv (Conv2D  (None, 14, 14, 672)  75264     ||
# || )                                                           ||
# ||                                                             ||
# || block5b_expand_bn (BatchNor  (None, 14, 14, 672)  2688      ||
# || malization)                                                 ||
# ||                                                             ||
# || block5b_expand_activation (  (None, 14, 14, 672)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block5b_dwconv2 (DepthwiseC  (None, 14, 14, 672)  6048      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block5b_bn (BatchNormalizat  (None, 14, 14, 672)  2688      ||
# || ion)                                                        ||
# ||                                                             ||
# || block5b_activation (Activat  (None, 14, 14, 672)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block5b_se_squeeze (GlobalA  (None, 672)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block5b_se_reshape (Reshape  (None, 1, 1, 672)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block5b_se_reduce (Conv2D)  (None, 1, 1, 28)      18844     ||
# ||                                                             ||
# || block5b_se_expand (Conv2D)  (None, 1, 1, 672)     19488     ||
# ||                                                             ||
# || block5b_se_excite (Multiply  (None, 14, 14, 672)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block5b_project_conv (Conv2  (None, 14, 14, 112)  75264     ||
# || D)                                                          ||
# ||                                                             ||
# || block5b_project_bn (BatchNo  (None, 14, 14, 112)  448       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block5b_drop (Dropout)  (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block5b_add (Add)       (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block5c_expand_conv (Conv2D  (None, 14, 14, 672)  75264     ||
# || )                                                           ||
# ||                                                             ||
# || block5c_expand_bn (BatchNor  (None, 14, 14, 672)  2688      ||
# || malization)                                                 ||
# ||                                                             ||
# || block5c_expand_activation (  (None, 14, 14, 672)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block5c_dwconv2 (DepthwiseC  (None, 14, 14, 672)  6048      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block5c_bn (BatchNormalizat  (None, 14, 14, 672)  2688      ||
# || ion)                                                        ||
# ||                                                             ||
# || block5c_activation (Activat  (None, 14, 14, 672)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block5c_se_squeeze (GlobalA  (None, 672)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block5c_se_reshape (Reshape  (None, 1, 1, 672)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block5c_se_reduce (Conv2D)  (None, 1, 1, 28)      18844     ||
# ||                                                             ||
# || block5c_se_expand (Conv2D)  (None, 1, 1, 672)     19488     ||
# ||                                                             ||
# || block5c_se_excite (Multiply  (None, 14, 14, 672)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block5c_project_conv (Conv2  (None, 14, 14, 112)  75264     ||
# || D)                                                          ||
# ||                                                             ||
# || block5c_project_bn (BatchNo  (None, 14, 14, 112)  448       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block5c_drop (Dropout)  (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block5c_add (Add)       (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block5d_expand_conv (Conv2D  (None, 14, 14, 672)  75264     ||
# || )                                                           ||
# ||                                                             ||
# || block5d_expand_bn (BatchNor  (None, 14, 14, 672)  2688      ||
# || malization)                                                 ||
# ||                                                             ||
# || block5d_expand_activation (  (None, 14, 14, 672)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block5d_dwconv2 (DepthwiseC  (None, 14, 14, 672)  6048      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block5d_bn (BatchNormalizat  (None, 14, 14, 672)  2688      ||
# || ion)                                                        ||
# ||                                                             ||
# || block5d_activation (Activat  (None, 14, 14, 672)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block5d_se_squeeze (GlobalA  (None, 672)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block5d_se_reshape (Reshape  (None, 1, 1, 672)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block5d_se_reduce (Conv2D)  (None, 1, 1, 28)      18844     ||
# ||                                                             ||
# || block5d_se_expand (Conv2D)  (None, 1, 1, 672)     19488     ||
# ||                                                             ||
# || block5d_se_excite (Multiply  (None, 14, 14, 672)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block5d_project_conv (Conv2  (None, 14, 14, 112)  75264     ||
# || D)                                                          ||
# ||                                                             ||
# || block5d_project_bn (BatchNo  (None, 14, 14, 112)  448       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block5d_drop (Dropout)  (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block5d_add (Add)       (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block5e_expand_conv (Conv2D  (None, 14, 14, 672)  75264     ||
# || )                                                           ||
# ||                                                             ||
# || block5e_expand_bn (BatchNor  (None, 14, 14, 672)  2688      ||
# || malization)                                                 ||
# ||                                                             ||
# || block5e_expand_activation (  (None, 14, 14, 672)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block5e_dwconv2 (DepthwiseC  (None, 14, 14, 672)  6048      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block5e_bn (BatchNormalizat  (None, 14, 14, 672)  2688      ||
# || ion)                                                        ||
# ||                                                             ||
# || block5e_activation (Activat  (None, 14, 14, 672)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block5e_se_squeeze (GlobalA  (None, 672)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block5e_se_reshape (Reshape  (None, 1, 1, 672)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block5e_se_reduce (Conv2D)  (None, 1, 1, 28)      18844     ||
# ||                                                             ||
# || block5e_se_expand (Conv2D)  (None, 1, 1, 672)     19488     ||
# ||                                                             ||
# || block5e_se_excite (Multiply  (None, 14, 14, 672)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block5e_project_conv (Conv2  (None, 14, 14, 112)  75264     ||
# || D)                                                          ||
# ||                                                             ||
# || block5e_project_bn (BatchNo  (None, 14, 14, 112)  448       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block5e_drop (Dropout)  (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block5e_add (Add)       (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block6a_expand_conv (Conv2D  (None, 14, 14, 672)  75264     ||
# || )                                                           ||
# ||                                                             ||
# || block6a_expand_bn (BatchNor  (None, 14, 14, 672)  2688      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6a_expand_activation (  (None, 14, 14, 672)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6a_dwconv2 (DepthwiseC  (None, 7, 7, 672)    6048      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6a_bn (BatchNormalizat  (None, 7, 7, 672)    2688      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6a_activation (Activat  (None, 7, 7, 672)    0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6a_se_squeeze (GlobalA  (None, 672)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6a_se_reshape (Reshape  (None, 1, 1, 672)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block6a_se_reduce (Conv2D)  (None, 1, 1, 28)      18844     ||
# ||                                                             ||
# || block6a_se_expand (Conv2D)  (None, 1, 1, 672)     19488     ||
# ||                                                             ||
# || block6a_se_excite (Multiply  (None, 7, 7, 672)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block6a_project_conv (Conv2  (None, 7, 7, 192)    129024    ||
# || D)                                                          ||
# ||                                                             ||
# || block6a_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6b_expand_conv (Conv2D  (None, 7, 7, 1152)   221184    ||
# || )                                                           ||
# ||                                                             ||
# || block6b_expand_bn (BatchNor  (None, 7, 7, 1152)   4608      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6b_expand_activation (  (None, 7, 7, 1152)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6b_dwconv2 (DepthwiseC  (None, 7, 7, 1152)   10368     ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6b_bn (BatchNormalizat  (None, 7, 7, 1152)   4608      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6b_activation (Activat  (None, 7, 7, 1152)   0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6b_se_squeeze (GlobalA  (None, 1152)         0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6b_se_reshape (Reshape  (None, 1, 1, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6b_se_reduce (Conv2D)  (None, 1, 1, 48)      55344     ||
# ||                                                             ||
# || block6b_se_expand (Conv2D)  (None, 1, 1, 1152)    56448     ||
# ||                                                             ||
# || block6b_se_excite (Multiply  (None, 7, 7, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6b_project_conv (Conv2  (None, 7, 7, 192)    221184    ||
# || D)                                                          ||
# ||                                                             ||
# || block6b_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6b_drop (Dropout)  (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6b_add (Add)       (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6c_expand_conv (Conv2D  (None, 7, 7, 1152)   221184    ||
# || )                                                           ||
# ||                                                             ||
# || block6c_expand_bn (BatchNor  (None, 7, 7, 1152)   4608      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6c_expand_activation (  (None, 7, 7, 1152)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6c_dwconv2 (DepthwiseC  (None, 7, 7, 1152)   10368     ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6c_bn (BatchNormalizat  (None, 7, 7, 1152)   4608      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6c_activation (Activat  (None, 7, 7, 1152)   0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6c_se_squeeze (GlobalA  (None, 1152)         0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6c_se_reshape (Reshape  (None, 1, 1, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6c_se_reduce (Conv2D)  (None, 1, 1, 48)      55344     ||
# ||                                                             ||
# || block6c_se_expand (Conv2D)  (None, 1, 1, 1152)    56448     ||
# ||                                                             ||
# || block6c_se_excite (Multiply  (None, 7, 7, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6c_project_conv (Conv2  (None, 7, 7, 192)    221184    ||
# || D)                                                          ||
# ||                                                             ||
# || block6c_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6c_drop (Dropout)  (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6c_add (Add)       (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6d_expand_conv (Conv2D  (None, 7, 7, 1152)   221184    ||
# || )                                                           ||
# ||                                                             ||
# || block6d_expand_bn (BatchNor  (None, 7, 7, 1152)   4608      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6d_expand_activation (  (None, 7, 7, 1152)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6d_dwconv2 (DepthwiseC  (None, 7, 7, 1152)   10368     ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6d_bn (BatchNormalizat  (None, 7, 7, 1152)   4608      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6d_activation (Activat  (None, 7, 7, 1152)   0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6d_se_squeeze (GlobalA  (None, 1152)         0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6d_se_reshape (Reshape  (None, 1, 1, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6d_se_reduce (Conv2D)  (None, 1, 1, 48)      55344     ||
# ||                                                             ||
# || block6d_se_expand (Conv2D)  (None, 1, 1, 1152)    56448     ||
# ||                                                             ||
# || block6d_se_excite (Multiply  (None, 7, 7, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6d_project_conv (Conv2  (None, 7, 7, 192)    221184    ||
# || D)                                                          ||
# ||                                                             ||
# || block6d_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6d_drop (Dropout)  (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6d_add (Add)       (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6e_expand_conv (Conv2D  (None, 7, 7, 1152)   221184    ||
# || )                                                           ||
# ||                                                             ||
# || block6e_expand_bn (BatchNor  (None, 7, 7, 1152)   4608      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6e_expand_activation (  (None, 7, 7, 1152)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6e_dwconv2 (DepthwiseC  (None, 7, 7, 1152)   10368     ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6e_bn (BatchNormalizat  (None, 7, 7, 1152)   4608      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6e_activation (Activat  (None, 7, 7, 1152)   0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6e_se_squeeze (GlobalA  (None, 1152)         0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6e_se_reshape (Reshape  (None, 1, 1, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6e_se_reduce (Conv2D)  (None, 1, 1, 48)      55344     ||
# ||                                                             ||
# || block6e_se_expand (Conv2D)  (None, 1, 1, 1152)    56448     ||
# ||                                                             ||
# || block6e_se_excite (Multiply  (None, 7, 7, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6e_project_conv (Conv2  (None, 7, 7, 192)    221184    ||
# || D)                                                          ||
# ||                                                             ||
# || block6e_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6e_drop (Dropout)  (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6e_add (Add)       (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6f_expand_conv (Conv2D  (None, 7, 7, 1152)   221184    ||
# || )                                                           ||
# ||                                                             ||
# || block6f_expand_bn (BatchNor  (None, 7, 7, 1152)   4608      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6f_expand_activation (  (None, 7, 7, 1152)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6f_dwconv2 (DepthwiseC  (None, 7, 7, 1152)   10368     ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6f_bn (BatchNormalizat  (None, 7, 7, 1152)   4608      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6f_activation (Activat  (None, 7, 7, 1152)   0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6f_se_squeeze (GlobalA  (None, 1152)         0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6f_se_reshape (Reshape  (None, 1, 1, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6f_se_reduce (Conv2D)  (None, 1, 1, 48)      55344     ||
# ||                                                             ||
# || block6f_se_expand (Conv2D)  (None, 1, 1, 1152)    56448     ||
# ||                                                             ||
# || block6f_se_excite (Multiply  (None, 7, 7, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6f_project_conv (Conv2  (None, 7, 7, 192)    221184    ||
# || D)                                                          ||
# ||                                                             ||
# || block6f_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6f_drop (Dropout)  (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6f_add (Add)       (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6g_expand_conv (Conv2D  (None, 7, 7, 1152)   221184    ||
# || )                                                           ||
# ||                                                             ||
# || block6g_expand_bn (BatchNor  (None, 7, 7, 1152)   4608      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6g_expand_activation (  (None, 7, 7, 1152)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6g_dwconv2 (DepthwiseC  (None, 7, 7, 1152)   10368     ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6g_bn (BatchNormalizat  (None, 7, 7, 1152)   4608      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6g_activation (Activat  (None, 7, 7, 1152)   0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6g_se_squeeze (GlobalA  (None, 1152)         0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6g_se_reshape (Reshape  (None, 1, 1, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6g_se_reduce (Conv2D)  (None, 1, 1, 48)      55344     ||
# ||                                                             ||
# || block6g_se_expand (Conv2D)  (None, 1, 1, 1152)    56448     ||
# ||                                                             ||
# || block6g_se_excite (Multiply  (None, 7, 7, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6g_project_conv (Conv2  (None, 7, 7, 192)    221184    ||
# || D)                                                          ||
# ||                                                             ||
# || block6g_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6g_drop (Dropout)  (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6g_add (Add)       (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6h_expand_conv (Conv2D  (None, 7, 7, 1152)   221184    ||
# || )                                                           ||
# ||                                                             ||
# || block6h_expand_bn (BatchNor  (None, 7, 7, 1152)   4608      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6h_expand_activation (  (None, 7, 7, 1152)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6h_dwconv2 (DepthwiseC  (None, 7, 7, 1152)   10368     ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6h_bn (BatchNormalizat  (None, 7, 7, 1152)   4608      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6h_activation (Activat  (None, 7, 7, 1152)   0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6h_se_squeeze (GlobalA  (None, 1152)         0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6h_se_reshape (Reshape  (None, 1, 1, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6h_se_reduce (Conv2D)  (None, 1, 1, 48)      55344     ||
# ||                                                             ||
# || block6h_se_expand (Conv2D)  (None, 1, 1, 1152)    56448     ||
# ||                                                             ||
# || block6h_se_excite (Multiply  (None, 7, 7, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6h_project_conv (Conv2  (None, 7, 7, 192)    221184    ||
# || D)                                                          ||
# ||                                                             ||
# || block6h_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6h_drop (Dropout)  (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6h_add (Add)       (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || top_conv (Conv2D)       (None, 7, 7, 1280)        245760    ||
# ||                                                             ||
# || top_bn (BatchNormalization)  (None, 7, 7, 1280)   5120      ||
# ||                                                             ||
# || top_activation (Activation)  (None, 7, 7, 1280)   0         ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_1 (Sequential)  (None, 2)                32180994  |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || flatten_1 (Flatten)     (None, 62720)             0         ||
# ||                                                             ||
# || dense_3 (Dense)         (None, 512)               32112640  ||
# ||                                                             ||
# || batch_normalization_2 (Batc  (None, 512)          2048      ||
# || hNormalization)                                             ||
# ||                                                             ||
# || activation_2 (Activation)  (None, 512)            0         ||
# ||                                                             ||
# || dropout_2 (Dropout)     (None, 512)               0         ||
# ||                                                             ||
# || dense_4 (Dense)         (None, 128)               65536     ||
# ||                                                             ||
# || batch_normalization_3 (Batc  (None, 128)          512       ||
# || hNormalization)                                             ||
# ||                                                             ||
# || activation_3 (Activation)  (None, 128)            0         ||
# ||                                                             ||
# || dropout_3 (Dropout)     (None, 128)               0         ||
# ||                                                             ||
# || dense_5 (Dense)         (None, 2)                 258       ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 38,100,336
# Trainable params: 32,179,744
# Non-trainable params: 5,920,592
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
from tensorflow import data, train, math, reduce_sum, cast, equal, argmax, \
float32, GradientTape, TensorSpec, function, int64

# %%
opt = Adam(learning_rate=0.0001)
loss_fn = tensorflow.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
train_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()
val_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()
test_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()

# %%
from sklearn.metrics import confusion_matrix

# %%
if os.path.exists('./content/data/ckpt'):
    print(f'Weight Checkpoint directory already exists')
    # !ls -ld ./content/data/ckpt
else:
    print(f'Weight Checkpooint directory doesnt exists.. Creating it now..')
    os.mkdir('./content/data/ckpt')
    print(f'Weight Checkpoint directory successfully created')
    # !ls -ld ./content/data/ckpt

    
if os.path.exists('./content/data/saved_model'):
    print(f'Protobuf Checkpoint directory already exists')
    # !ls -ld ./content/data/saved_model
else:
    print(f'Protobuf Checkpoint directory doesnt exists.. Creating it now..')
    os.mkdir('./content/data/saved_model')
    print(f'Weight Checkpoint directory successfully created')
    # !ls -ld ./content/data/saved_model
# Out:
# Weight Checkpooint directory doesnt exists.. Creating it now..
# Weight Checkpoint directory successfully created
# drwxr-xr-x 2 root root 4096 Apr 23 02:54 ./content/data/ckpt
# Protobuf Checkpoint directory doesnt exists.. Creating it now..
# Weight Checkpoint directory successfully created
# drwxr-xr-x 2 root root 4096 Apr 23 02:54 ./content/data/saved_model

# %%
class Model_Train():
  def __init__(self, model, optimizer, loss_fn, epochs, batch_size, train_gen, valid_gen, test_gen, train_acc_metric, val_acc_metric, test_acc_metric):
    super().__init__()

    self.model = model
    self.optimizer = optimizer
    self.loss_fn = loss_fn
    self.epochs = epochs
    self.batch_size = batch_size
    self.train_generator = train_gen
    self.valid_generator = valid_gen
    self.test_generator = test_gen
    self.steps_train = len(train_gen)
    self.steps_valid = len(valid_gen)
    self.steps_test = len(test_gen)
    self.train_acc_metric = train_acc_metric
    self.val_acc_metric = val_acc_metric
    self.test_acc_metric = test_acc_metric
    self.train_history = {'loss': [], 'accuracy': [], 'f1': [], 'precision': [], 'recall': []}
    self.valid_history = {'loss': [], 'accuracy': [], 'f1': [], 'precision': [], 'recall': [], 'ckpt_name': []}


   

  @tensorflow.function
  def train_step(self, train_data, train_label):
    with tensorflow.GradientTape() as tape:
      output = self.model(train_data, training=True)
      loss_value = self.loss_fn(train_label, output)
    grads = tape.gradient(loss_value, self.model.trainable_weights)
    self.optimizer.apply_gradients(zip(grads, self.model.trainable_weights))
    self.train_acc_metric.update_state(train_label, output)
    return output, loss_value

  @tensorflow.function
  def test_step(self, validation_data, validation_label):
    val_output = self.model(validation_data, training=False)
    loss_value = self.loss_fn(validation_label, val_output)
    self.val_acc_metric.update_state(validation_label, val_output)
    return val_output, loss_value

  def getloss_accuracy(self, gen, batch_size, steps_per_epoch, df, train=False, valid=False):
    loss_epoch = 0
    n=0
    for step, (x_batch, y_batch) in enumerate(gen):
      if train:
        output, loss_value = self.train_step(x_batch, y_batch)
        ###new code below
        
        pred_labls = list(np.argmax(output.numpy(), axis=1))
        temp_df = pd.DataFrame({'orig_label': list(y_batch), 'pred_label': pred_labls})
        df = pd.concat([df, temp_df])
            

        ## newcode above
        
      else:
        output, loss_value = self.test_step(x_batch, y_batch)
        pred_labls = list(np.argmax(output.numpy(), axis=1))
        temp_df = pd.DataFrame({'orig_label': list(y_batch), 'pred_label': pred_labls})
        df = pd.concat([df, temp_df])
            
      loss_epoch += loss_value*x_batch.shape[0]
      #n = n+1
      #print("Training step ", n )
      if step >= (steps_per_epoch-1):
        if train:
          avg_epoch_loss = (loss_epoch/(len(train_df))).numpy()
          accuracy = self.train_acc_metric.result().numpy()
          self.train_acc_metric.reset_states()
          gen.on_epoch_end()
        else:
          if valid:
            avg_epoch_loss = (loss_epoch/(len(valid_df))).numpy()
            accuracy = self.val_acc_metric.result().numpy()
            self.val_acc_metric.reset_states()
          else:
            avg_epoch_loss = (loss_epoch/(len(test_df))).numpy()
            accuracy = self.val_acc_metric.result().numpy()
            self.val_acc_metric.reset_states()


        return df, avg_epoch_loss, accuracy

  def train_validate_loop(self):
    for epoch in range(self.epochs):
      start_time = time.time()
      histdf_train = pd.DataFrame({'orig_label': [], 'pred_label': []})
      histdf_val   = pd.DataFrame({'orig_label': [], 'pred_label': []})  

      df_train_cm, avg_epoch_train_loss, train_accuracy = self.getloss_accuracy(self.train_generator, self.batch_size, self.steps_train, histdf_train, train=True)
      df_val_cm, avg_epoch_val_loss, val_accuracy = self.getloss_accuracy(self.valid_generator, self.batch_size, self.steps_valid, histdf_val, train=False, valid=True)

    
      f1, precision, recall             = self.calc_rec_prec_f1(df_train_cm, train=True)
      f1_val, precision_val, recall_val = self.calc_rec_prec_f1(df_val_cm, train=False)


      print(f'Epoch : {epoch}, Train Loss: {avg_epoch_train_loss}, Train Accuracy: {train_accuracy}, Validation Loss: {avg_epoch_val_loss}, Validation Accuracy: {val_accuracy}')
      
      self.train_history['loss'].append(avg_epoch_train_loss)
      self.train_history['accuracy'].append(train_accuracy)
      self.train_history['f1'].append(f1)
      self.train_history['precision'].append(precision)
      self.train_history['recall'].append(recall)

      self.valid_history['loss'].append(avg_epoch_val_loss)
      self.valid_history['accuracy'].append(val_accuracy)
      self.valid_history['f1'].append(f1_val)
      self.valid_history['precision'].append(precision_val)
      self.valid_history['recall'].append(recall_val)

      ###New Code for early stopping#####
      la = self.valid_history['accuracy']
      if (len(la) > 4):
        if (((la[-1] <= la[-2]) and (la[-2] <= la[-3])) and ((la[-3] <= la[-4]) and (la[-4] <= la[-5]))):
          print("Validation accuracy has not improved over last 4 epochs, hence invoking early stopping and exiting training process")
          if len(self.valid_history['ckpt_name']) > 0:
            print('Loading Best weights..')
            self.model.load_weights(self.valid_history['ckpt_name'][-1])
            break
          else:
            print("Ouch !! seems like you dont have any checkpoints saved matching criteria specified in logic. Please excuse !")
            break
                        
      if ((la[-1] > 0.9) and (len(la) > 1)):
        if(la[-1] > max(la[0:-1])):
          self.save_checkpoint(la[-1])
      elif ((la[-1] > 0.9) and (len(la) == 1)):
        self.save_checkpoint(la[-1])





      #####New Cod for early stopping


    
      print(f'Time taken: {np.round((time.time() - start_time), 4)}')
    print(f'Training completed successfully. Loading best checkpoint weights ...')
    if len(self.valid_history['ckpt_name']) > 0:
      self.model.load_weights(self.valid_history['ckpt_name'][-1])
      print(f'Best checkpoint weights loaded : {self.valid_history["ckpt_name"][-1]}')
    else:
      print("Ouch !! seems like you dont have any checkpoints saved matching criteria specified in logic. Please excuse !")

      #draw graph depicting train and validation losses and accuracy + recall, f1
    return self.train_history, self.valid_history

  def save_checkpoint(self, acc):
    ckpt_name = './content/data/ckpt/' + 'ckpt' + '_' + str(acc) + '_acc.pt'
    #pb_name = './content/data/saved_model/' + 'ckpt' + '_' + str(acc) + '_acc'
    self.model.save_weights(ckpt_name)
    self.valid_history['ckpt_name'].append(ckpt_name)
    print(f'Saved Checkpoint : {ckpt_name}')
    #self.model.save(pb_name)
    #print(f'Saved model in protobuf format : {pb_name}')


  def get_test_accuracy(self):
    df = pd.DataFrame({'orig_label': [], 'pred_label': []})
    df_test, avg_test_loss, test_accuracy = self.getloss_accuracy(self.test_generator, self.batch_size, self.steps_test, df)
    return df_test, avg_test_loss, test_accuracy

  def calc_rec_prec_f1(self, df, train):
    print_string = "Training Confusion Matrix" if train else "Validation Confusion Matrix"
    print(print_string, "\n", confusion_matrix(df['orig_label'], df['pred_label']))
    tn, fp, fn, tp = confusion_matrix(df['orig_label'], df['pred_label']).ravel()
    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    f1 = 2*precision*recall/(precision+recall)
    return f1, precision, recall

  def predict_single(self,dcm_path, target_size=(224,224)):
    image_array = pydicom.dcmread(dcm_path).pixel_array
    image = Image.fromarray(image_array) #converts from array to PIL
    #image.thumbnail((224,224)) #resize image to 224,224
    image = image.resize((224,224))
    image_array = np.expand_dims(image, 0)
    image_array = image_array.astype(np.float32) # * (1.0/255.0)
    image_array = np.expand_dims(image_array, -1)
    output = self.model(image_array, training=False)
    pred_label = np.argmax(output.numpy())
    print(f'Predicted label for image supplied is : {classes[pred_label]}')
    return classes[pred_label]
    
  def pred_image_show(self,image_list):
    fig, subs = plt.subplots(3,3, figsize=(14,12))
    for i, sub in enumerate(subs.flatten()):
      print(f'Image path is {image_list[i][0]} and Original label is {classes[int(image_list[i][1])]}')
      pred_class = self.predict_single(image_list[i][0])
      image_array = pydicom.dcmread(image_list[i][0]).pixel_array
      sub.imshow(image_array, cmap='gray')
      sub.set_title(f'{pred_class}(Pred) : {classes[int(image_list[i][1])]}(Orig)')
            
  def plot_metrics(self):
    list = ['accuracy', 'loss', 'f1', 'recall', 'precision']
    for metrics in list:
      x = [i for i in range(len(self.train_history[metrics]))]
      y1 = self.train_history[metrics]
      y2 = self.valid_history[metrics]
      fig, ax = plt.subplots()
      ax.plot(x, y1, label="train_"+metrics)
      ax.plot(x, y2, label="valid_"+metrics)
      plt.suptitle(f'Plot showing {metrics} for Different Epoch Runs')
      ax.legend()
      plt.show()
## Save weights
## if current accuracy > 90 and current accuracy > max(list_accuracy) then create checkpoint and save weights. Also do a protobuf saved model
## store the saved checkpoint name in a list. This will make sure than checkpoints are stored in asecnding order.
## at the end of training , take the last element in checkpoint list and load and restore it. test accuracy should be checked using this chkpoint.

# %%
EPOCHS = 20
train_object = Model_Train(model, opt, loss_fn, EPOCHS, BATCH_SIZE, train_generator, valid_generator, test_generator,
             train_acc_metric, val_acc_metric, test_acc_metric
             )

# %%
train_object.__dict__
# Out:
# {'model': <__main__.EfficientNetV2B0_TL at 0x7f33fc0fb9d0>,
#  'optimizer': <keras.optimizers.adam.Adam at 0x7f33723cf5b0>,
#  'loss_fn': <keras.losses.SparseCategoricalCrossentropy at 0x7f33723cf100>,
#  'epochs': 20,
#  'batch_size': 32,
#  'train_generator': <__main__.DCMDataFrameIterator at 0x7f3499805a30>,
#  'valid_generator': <__main__.DCMDataFrameIterator at 0x7f3499805e20>,
#  'test_generator': <__main__.DCMDataFrameIterator at 0x7f349985a9a0>,
#  'steps_train': 277,
#  'steps_valid': 70,
#  'steps_test': 87,
#  'train_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7f33723dc9a0>,
#  'val_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7f33723818b0>,
#  'test_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7f3372381a00>,
#  'train_history': {'loss': [],
#   'accuracy': [],
#   'f1': [],
#   'precision': [],
#   'recall': []},
#  'valid_history': {'loss': [],
#   'accuracy': [],
#   'f1': [],
#   'precision': [],
#   'recall': [],
#   'ckpt_name': []}}

# %%
train_dict, val_dict = train_object.train_validate_loop()
# Out:
# Training Confusion Matrix
#  [[6136  385]
#  [ 508 1807]]
# Validation Confusion Matrix
#  [[1526  105]
#  [  53  526]]
# Epoch : 0, Train Loss: 0.25028195977211, Train Accuracy: 0.8989361524581909, Validation Loss: 0.17739136517047882, Validation Accuracy: 0.9285067915916443
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9285068_acc.pt
# Time taken: 144.6612
# Training Confusion Matrix
#  [[6246  284]
#  [ 354 1952]]
# Validation Confusion Matrix
#  [[1610   21]
#  [  80  499]]
# Epoch : 1, Train Loss: 0.17899028956890106, Train Accuracy: 0.92779541015625, Validation Loss: 0.12795276939868927, Validation Accuracy: 0.9542986154556274
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9542986_acc.pt
# Time taken: 102.2683
# Training Confusion Matrix
#  [[6312  209]
#  [ 294 2021]]
# Validation Confusion Matrix
#  [[1621   10]
#  [  73  506]]
# Epoch : 2, Train Loss: 0.14615777134895325, Train Accuracy: 0.9430738091468811, Validation Loss: 0.11451656371355057, Validation Accuracy: 0.9624434113502502
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9624434_acc.pt
# Time taken: 97.958
# Training Confusion Matrix
#  [[6338  177]
#  [ 246 2075]]
# Validation Confusion Matrix
#  [[1603   28]
#  [  42  537]]
# Epoch : 3, Train Loss: 0.126524418592453, Train Accuracy: 0.9521276354789734, Validation Loss: 0.0886133462190628, Validation Accuracy: 0.9683257937431335
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9683258_acc.pt
# Time taken: 98.3563
# Training Confusion Matrix
#  [[6372  153]
#  [ 222 2089]]
# Validation Confusion Matrix
#  [[1610   21]
#  [  46  533]]
# Epoch : 4, Train Loss: 0.11113293468952179, Train Accuracy: 0.9575600028038025, Validation Loss: 0.08393140882253647, Validation Accuracy: 0.9696832299232483
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.96968323_acc.pt
# Time taken: 97.4155
# Training Confusion Matrix
#  [[6367  158]
#  [ 192 2119]]
# Validation Confusion Matrix
#  [[1606   25]
#  [  50  529]]
# Epoch : 5, Train Loss: 0.1056436225771904, Train Accuracy: 0.9603893160820007, Validation Loss: 0.10368596762418747, Validation Accuracy: 0.9660633206367493
# Time taken: 96.8097
# Training Confusion Matrix
#  [[6385  135]
#  [ 194 2122]]
# Validation Confusion Matrix
#  [[1620   11]
#  [  41  538]]
# Epoch : 6, Train Loss: 0.0999491736292839, Train Accuracy: 0.9627659320831299, Validation Loss: 0.07987082004547119, Validation Accuracy: 0.9764705896377563
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9764706_acc.pt
# Time taken: 97.7117
# Training Confusion Matrix
#  [[6407  123]
#  [ 170 2136]]
# Validation Confusion Matrix
#  [[1624    7]
#  [  58  521]]
# Epoch : 7, Train Loss: 0.08969300240278244, Train Accuracy: 0.9668402075767517, Validation Loss: 0.10070677101612091, Validation Accuracy: 0.970588207244873
# Time taken: 96.2088
# Training Confusion Matrix
#  [[6385  133]
#  [ 164 2154]]
# Validation Confusion Matrix
#  [[1622    9]
#  [  57  522]]
# Epoch : 8, Train Loss: 0.08858622610569, Train Accuracy: 0.9663875102996826, Validation Loss: 0.09074798971414566, Validation Accuracy: 0.9701357483863831
# Time taken: 96.0933
# Training Confusion Matrix
#  [[6383  135]
#  [ 173 2145]]
# Validation Confusion Matrix
#  [[1623    8]
#  [  53  526]]
# Epoch : 9, Train Loss: 0.08750758320093155, Train Accuracy: 0.9651426076889038, Validation Loss: 0.09427563101053238, Validation Accuracy: 0.9723981618881226
# Time taken: 96.2627
# Training Confusion Matrix
#  [[6412  103]
#  [ 142 2179]]
# Validation Confusion Matrix
#  [[1612   19]
#  [  33  546]]
# Epoch : 10, Train Loss: 0.07667423039674759, Train Accuracy: 0.972272515296936, Validation Loss: 0.07452887296676636, Validation Accuracy: 0.9764705896377563
# Time taken: 96.1152
# Training Confusion Matrix
#  [[6407  119]
#  [ 138 2172]]
# Validation Confusion Matrix
#  [[1591   40]
#  [  22  557]]
# Epoch : 11, Train Loss: 0.07698285579681396, Train Accuracy: 0.9709144234657288, Validation Loss: 0.08679163455963135, Validation Accuracy: 0.9719457030296326
# Time taken: 95.8513
# Training Confusion Matrix
#  [[6426   92]
#  [ 133 2185]]
# Validation Confusion Matrix
#  [[1625    6]
#  [  54  525]]
# Epoch : 12, Train Loss: 0.06977520138025284, Train Accuracy: 0.9745360016822815, Validation Loss: 0.09585807472467422, Validation Accuracy: 0.9728506803512573
# Time taken: 96.2516
# Training Confusion Matrix
#  [[6434   95]
#  [ 133 2174]]
# Validation Confusion Matrix
#  [[1619   12]
#  [  38  541]]
# Epoch : 13, Train Loss: 0.06896186619997025, Train Accuracy: 0.9741964936256409, Validation Loss: 0.06889350712299347, Validation Accuracy: 0.9773755669593811
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.97737557_acc.pt
# Time taken: 97.2723
# Training Confusion Matrix
#  [[6411  111]
#  [ 112 2202]]
# Validation Confusion Matrix
#  [[1618   13]
#  [  33  546]]
# Epoch : 14, Train Loss: 0.06829319894313812, Train Accuracy: 0.9747623205184937, Validation Loss: 0.06691896915435791, Validation Accuracy: 0.9791855216026306
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9791855_acc.pt
# Time taken: 97.2615
# Training Confusion Matrix
#  [[6424  104]
#  [ 124 2184]]
# Validation Confusion Matrix
#  [[1618   13]
#  [  38  541]]
# Epoch : 15, Train Loss: 0.0660087838768959, Train Accuracy: 0.9741964936256409, Validation Loss: 0.07959411293268204, Validation Accuracy: 0.9769230484962463
# Time taken: 96.3543
# Training Confusion Matrix
#  [[6427   93]
#  [ 119 2197]]
# Validation Confusion Matrix
#  [[1622    9]
#  [  40  539]]
# Epoch : 16, Train Loss: 0.06351751834154129, Train Accuracy: 0.9760072231292725, Validation Loss: 0.08253103494644165, Validation Accuracy: 0.9778280258178711
# Time taken: 96.1402
# Training Confusion Matrix
#  [[6420  104]
#  [ 113 2199]]
# Validation Confusion Matrix
#  [[1606   25]
#  [  28  551]]
# Epoch : 17, Train Loss: 0.0652502104640007, Train Accuracy: 0.9754413962364197, Validation Loss: 0.06664395332336426, Validation Accuracy: 0.9760180711746216
# Time taken: 95.9018
# Training Confusion Matrix
#  [[6447   75]
#  [ 107 2207]]
# Validation Confusion Matrix
#  [[1621   10]
#  [  32  547]]
# Epoch : 18, Train Loss: 0.060509782284498215, Train Accuracy: 0.9794024229049683, Validation Loss: 0.06448464095592499, Validation Accuracy: 0.9809954762458801
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9809955_acc.pt
# Time taken: 96.9514
# Training Confusion Matrix
#  [[6440   77]
#  [  90 2229]]
# Validation Confusion Matrix
#  [[1625    6]
#  [  41  538]]
# Epoch : 19, Train Loss: 0.05330180004239082, Train Accuracy: 0.9811000227928162, Validation Loss: 0.08104588091373444, Validation Accuracy: 0.9787330031394958
# Time taken: 95.9501
# Training completed successfully. Loading best checkpoint weights ...
# Best checkpoint weights loaded : ./content/data/ckpt/ckpt_0.9809955_acc.pt

# %%
df, loss, accuracy = train_object.get_test_accuracy() #from df returned by function you can check which image has lables incorrectly predicted

# %%
accuracy
# Out:
# 0.9822592

# %%
confusion_matrix(df['orig_label'], df['pred_label'])
# Out:
# array([[2026,   13],
#        [  36,  687]])

# %%
687/(687+36)
# Out:
# 0.950207468879668

# %%
train_object.predict_single(test_df.iloc[-2,0])
# Out:
# Predicted label for image supplied is : COVID
# 'COVID'

# %%
train_object.model.save_weights('./content/data/ckpt/model_best_weights')

# %%
with zipfile.ZipFile('./XRAY_resnet50_model_best_weights.zip', 'w') as myzip:
    myzip.write('./content/data/ckpt/checkpoint')
    myzip.write('./content/data/ckpt/model_best_weights.data-00000-of-00001')
    #myzip.write('./content/data/ckpt/model_best_weights.data-00001-of-00002')
    myzip.write('./content/data/ckpt/model_best_weights.index')

# %%
random_9_test = random.sample(list(test_df.values), 9)
random_9_test, len(random_9_test)
# Out:
# ([array(['./content/data/DCM/COVID/COVID-2867.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-2826.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-3185.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-347.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-1384.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-1863.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-6039.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-8405.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-8034.dcm', '0'], dtype=object)],
#  9)

# %%
random_9_test[0][0], random_9_test[0][1]
# Out:
# ('./content/data/DCM/COVID/COVID-2867.dcm', '1')

# %%
train_object.pred_image_show(random_9_test)
# Out:
# Image path is ./content/data/DCM/COVID/COVID-2867.dcm and Original label is COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/COVID/COVID-2826.dcm and Original label is COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-3185.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/COVID/COVID-347.dcm and Original label is COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/COVID/COVID-1384.dcm and Original label is COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-1863.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-6039.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-8405.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-8034.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID

# %%
train_object.plot_metrics()

# %%
#!cp ./*model_best_weights.zip ./gdrive/MyDrive/Manning_Projects/
