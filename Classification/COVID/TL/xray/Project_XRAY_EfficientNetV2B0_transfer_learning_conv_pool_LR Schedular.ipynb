# %% [markdown]
# ## Milestone 1.1

# %%
# !nvidia-smi
# Out:
# /bin/bash: nvidia-smi: command not found

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
# Out:
# Your runtime has 27.3 gigabytes of available RAM

# %%
import requests
import pickle
import zipfile
import time
import os
#from google.colab import drive
import random
import glob
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy import asarray
from PIL.ImageStat import Stat
# !pip install pydicom
import pydicom
# Package for converting PNG Files to DICOM(.dcm ) format
# !pip install simpleitk
import SimpleITK as sitk
from sklearn.model_selection import train_test_split
from PIL import Image
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import DataFrameIterator
#from keras_preprocessing.image.dataframe_iterator import DataFrameIterator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Conv2D, AveragePooling2D, Flatten, Dense, Activation, MaxPool2D, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.applications import EfficientNetV2B0
#tf.keras.applications.efficientnet.EfficientNetB4
#tf.keras.applications.efficientnet.preprocess_input (not required for efficientnets)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydicom
#   Downloading pydicom-2.3.1-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 20.0 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-2.3.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting simpleitk
#   Downloading SimpleITK-2.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 MB 27.2 MB/s eta 0:00:00
# Installing collected packages: simpleitk
# Successfully installed simpleitk-2.2.1

# %%
data_path = './content'
archive_path = data_path + '/data/'
if os.path.exists(archive_path):
  print(f"{archive_path} directory exists.")
else:
  print(f"Did not find {archive_path} directory, creating one...")
  os.mkdir('./content')

  os.mkdir(archive_path)
  if os.path.exists(archive_path):
    print(f'{archive_path} created successfully')
# Out:
# Did not find ./content/data/ directory, creating one...
# ./content/data/ created successfully

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#!mv /content/gdrive/MyDrive/Manning_Projects/archive\ \(2\).zip /content/gdrive/MyDrive/Manning_Projects/covid_data.zip
# !ls /content/gdrive/MyDrive/Manning_Projects/
# Out:
# 'Best Project_XRAY_EfficientnetB0_transfer_learning_conv.ipynb'
#  Best_Project_XRAY_EfficientNetV2B0_transfer_learning_conv.ipynb
#  Best_Project_XRAY_VGG16_transfer_learning_conv.ipynb
# 'Copy of Project_XRAY_Resnet50_fc_removed.ipynb'
#  covid_data.zip
#  model_best_weights.zip
#  Project_CTSCAN_EfficientNetB0_Transfer_transfer.ipynb
#  Project_CTSCAN_ViT_Transfer_transfer_all_outs_conv.ipynb
#  Project_XRAY_EfficientnetB0_transfer_learning_conv.ipynb
#  Project_XRAY_EfficientNetV2B0_transfer_learning_conv_pool_0.0003LR.ipynb
# 'Project_XRAY_EfficientNetV2B0_transfer_learning_conv_pool_LR Schedular.ipynb'
#  Project_XRAY_Resnet18.ipynb
#  Project_XRAY_Resnet50.ipynb
#  Project_XRAY_RESNET50_transfer_learning_conv.ipynb
#  Project_XRAY_VGG16_Transfer_Learning_3D.ipynb
#  Project_XRAY_VGG16_transfer_learning_conv.ipynb
#  Project_XRAY_VGG16_Transfer_Learning.ipynb
#  Project_XRAY_ViT_1.ipynb
#  Project_XRAY_ViT.ipynb
#  Project_XRAY_ViT_transfer_learning_conv.ipynb
#  XRAY_NFC_resnet50_model_best_weights.zip
#  XRAY_resnet50_model_best_weights.zip

# %%
DRIVE_PATH = '/content/gdrive/MyDrive/Manning_Projects/'
ARCHIVE_ZIP_FILE = DRIVE_PATH + 'covid_data.zip'
ARCHIVE_ZIP_FILE
# Out:
# '/content/gdrive/MyDrive/Manning_Projects/covid_data.zip'

# %%
# !cp {ARCHIVE_ZIP_FILE} ./content/data/

# %%
archive_file =  archive_path + 'covid_data.zip'

size = os.path.getsize(archive_file)
  
print(f'Size of the file is {size/1024} MegaBytes.')
# Out:
# Size of the file is 796903.357421875 MegaBytes.

# %%
with zipfile.ZipFile(archive_file, "r") as zip_ref:
  print("Unzipping archive") 
  zip_ref.extractall(archive_path)
# Out:
# Unzipping archive

# %%
# !rm -rf ./content/data/COVID-19_Radiography_Dataset/Lung_Opacity

# %%
# !rm -rf ./content/data/COVID-19_Radiography_Dataset/Viral\ Pneumonia

# %%
COVID_IMAGE_PATH = './content/data/COVID-19_Radiography_Dataset/COVID/images'
NON_COVID_IMAGE_PATH = './content/data/COVID-19_Radiography_Dataset/Normal/images'

# %%
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
walk_through_dir(COVID_IMAGE_PATH)
# Out:
# There are 0 directories and 3616 images in './content/data/COVID-19_Radiography_Dataset/COVID/images'.

# %%
walk_through_dir(NON_COVID_IMAGE_PATH)
# Out:
# There are 0 directories and 10192 images in './content/data/COVID-19_Radiography_Dataset/Normal/images'.

# %%
random.seed(42)

COVID_IMAGE_PATH_LIST = glob.glob(COVID_IMAGE_PATH + "/*.png")
len(COVID_IMAGE_PATH_LIST), type(COVID_IMAGE_PATH_LIST)
# Out:
# (3616, list)

# %%
NON_COVID_IMAGE_PATH_LIST = glob.glob(NON_COVID_IMAGE_PATH + "/*.png")
len(NON_COVID_IMAGE_PATH_LIST), type(NON_COVID_IMAGE_PATH_LIST)
# Out:
# (10192, list)

# %%
random_image_cov = random.choice(COVID_IMAGE_PATH_LIST)
cov_pic = Image.open(random_image_cov).convert('L')
cov_pic.show()
# Out:
# <PIL.Image.Image image mode=L size=299x299 at 0x7FDDF83BA040>

# %%
random_image_ncov = random.choice(NON_COVID_IMAGE_PATH_LIST)
ncov_pic = Image.open(random_image_ncov).convert('L')
ncov_pic.show()
type(ncov_pic)
# Out:
# <PIL.Image.Image image mode=L size=299x299 at 0x7FDD5C3C7820>
# PIL.Image.Image

# %%
def image_show(image_list, label):
  fig, subs = plt.subplots(3,3, figsize=(16,12))
  for i, sub in enumerate(subs.flatten()):
    #image_path = os.path.normpath(image[i])
    print(f'Image path is {image_list[i]} and label is {label}')
    img = Image.open(image_list[i])
    img.thumbnail((224,224))
    sub.imshow(img, cmap='gray')
    #sub.axis("off")
    print(f'Size of displayed image is {img.size}')
    sub.set_title(label)

# %%
random.seed(3)
ll_d_c =  []
for i in range(9):
  im = random.choice(COVID_IMAGE_PATH_LIST)
  ll_d_c.append(im)
print(ll_d_c, len(ll_d_c))

ll_d_nc = []
for i in range(9):
  im = random.choice(NON_COVID_IMAGE_PATH_LIST)
  ll_d_nc.append(im)

print(ll_d_nc, len(ll_d_nc))
# Out:
# ['./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1186.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2603.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2134.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1237.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-16.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2113.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2662.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2363.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-23.png'] 9
# ['./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2227.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-448.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-4057.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5028.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-7686.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-58.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2073.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6809.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2491.png'] 9

# %%
image_show(ll_d_c, 'COVID')
# Out:
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1186.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2603.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2134.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1237.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-16.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2113.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2662.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2363.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-23.png and label is COVID
# Size of displayed image is (224, 224)

# %%
image_show(ll_d_nc, 'NON-COVID')
# Out:
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2227.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-448.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-4057.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5028.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-7686.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-58.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2073.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6809.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2491.png and label is NON-COVID
# Size of displayed image is (224, 224)

# %%
random_image = random.choice(COVID_IMAGE_PATH_LIST)
random_image_gs = Image.open(random_image).convert('L')
shape= random_image_gs.size
img= np.reshape(random_image_gs, (-1, *shape, 1))
img.shape
# Out:
# (1, 299, 299, 1)

# %%
#def img_resize_save(img_path_list):
#  for i in range(len(img_path_list)):
#    temp_img = Image.open(img_path_list[i])
#    temp_img.thumbnail((224,224))
#    temp_img.save(img_path_list[i])
#  print('All images in supplied list resized to (224,224)')

#Originally I was under impression that all files have to be resized to 224,224 and then saved to disk. This is mentioned as a separate task.
#Hence, the logical deduction

# %%
df = pd.DataFrame({'Class': [len(NON_COVID_IMAGE_PATH_LIST), len(COVID_IMAGE_PATH_LIST)]})

# %%
total_class = df.Class.sum()
total_class
# Out:
# 13808

# %%
df['per_distr'] = df['Class'].apply(lambda x: x/total_class)
df.index = ['Non_Covid', 'Covid']

# %%
df.Class.plot(kind="bar", figsize=(8,6))
plt.ylabel("Number of Images")
plt.xlabel("Image Class")
plt.title("Distribution of Covid/Non-Covid Images")
plt.show()

# %%
list_arr = []
for pic in COVID_IMAGE_PATH_LIST:
  pic_np = np.array(Image.open(pic).convert('L'))
  pic_np = pic_np.reshape(299,299,1)
  list_arr.append(pic_np)

# %%
len(list_arr)
# Out:
# 3616

# %%
covid_arr = np.array(list_arr)

# %%
covid_arr.shape
# Out:
# (3616, 299, 299, 1)

# %%
np.mean(covid_arr), np.min(covid_arr), np.max(covid_arr), np.std(covid_arr)
# Out:
# (139.52120961679765, 0, 255, 61.90712697550046)

# %%
# Flatten the image data into a 1D array
pixel_values = covid_arr.flatten()

pixel_values.shape
# Out:
# (323274016,)

# %%
# Plot a histogram of the pixel values
plt.hist(pixel_values, bins=50)
plt.suptitle("Distribution of pixel values for Covid Image Data")
plt.show()

# %%
list_arr_nc = []
for pic in NON_COVID_IMAGE_PATH_LIST:
  pic_np_nc = np.array(Image.open(pic).convert('L'))
  pic_np_nc = pic_np_nc.reshape(299,299,1)
  list_arr_nc.append(pic_np_nc)
len(list_arr_nc)
# Out:
# 10192

# %%
covid_arr_nc = np.array(list_arr_nc)
covid_arr_nc.shape
# Out:
# (10192, 299, 299, 1)

# %%
np.mean(covid_arr_nc), np.max(covid_arr_nc), np.mean(covid_arr_nc), np.std(covid_arr_nc)
# Out:
# (129.38979982014257, 255, 129.38979982014257, 66.21686464627396)

# %%
# Flatten the image data into a 1D array
pixel_values_nc = covid_arr_nc.flatten()
pixel_values_nc.shape
# Out:
# (911174992,)

# %%
# Plot a histogram of the pixel values
fig, subs = plt.subplots(1,2, figsize=(24,6))
for i, sub in enumerate(subs.flatten()):
  if i==0:
    sub.hist(pixel_values_nc, bins=50)
    sub.set_title("Distribution of pixel values for Non-Covid Image Data")
  else:
    sub.hist(pixel_values, bins=50)
    sub.set_title("Distribution of pixel values for Covid Image Data")

# %% [markdown]
# ## Observation
#
# It can be seen from above two histograms that pixel intensity for covid data is more peaked(kurtosis is high) than for non-covid images.
#
# This confirms with fact that X-Ray images for covid infected patients show white patches in chest X-Ray Images.

# %%
#Lets do simple check on whether the pixel data that we get from converted .dcm files is same what we get from original png image
image = COVID_IMAGE_PATH_LIST[0]
im1 = Image.open(image).convert('L')
im1= np.array(im1)
img= sitk.GetImageFromArray(im1)
sitk.WriteImage(img,'template.dcm')

# %%
fig, subs = plt.subplots(1,2, figsize=(12,6))
for i, sub in enumerate(subs.flatten()):
  if i==0:
    #ds = pydicom.dcmread('template.dcm')
    # Load the DICOM file
    ds = pydicom.dcmread('template.dcm')
    # Access the image data
    image_d = ds.pixel_array
    print(type(image_d))
    sub.imshow(image_d, cmap='gray')
    sub.set_title("Image data from .dcm file")
  else:
    sub.imshow(im1, cmap='gray')
    sub.set_title("Image data from original png file")
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## It does looks like the data from both sources are one and same.
# ## STATUS : VERIFIED

# %% [markdown]
# ## Convert all the PNG Files to DICOM (.dcm) Format

# %%
DCM_FILE_PATH = './content/data/DCM/'
COVID_DCM_FILE_PATH = './content/data/DCM/COVID/'
NON_COVID_DCM_FILE_PATH = './content/data/DCM/NON_COVID/'
if os.path.exists(DCM_FILE_PATH):
  print(f"{DCM_FILE_PATH} directory exists.")
  if os.path.exists(COVID_DCM_FILE_PATH):
    print(f'{COVID_DCM_FILE_PATH} directory exists')
  else:
    print(f'Ok... looks like {COVID_DCM_FILE_PATH} does not exists. Let us make one')
    os.mkdir(COVID_DCM_FILE_PATH)
    print(f'{COVID_DCM_FILE_PATH} directory created successfully')
  if os.path.exists(NON_COVID_DCM_FILE_PATH):
    print(f'{NON_COVID_DCM_FILE_PATH} directory exists')
  else:
    print(f'Ok... looks like {NON_COVID_DCM_FILE_PATH} does not exists. Let us make one')
    os.mkdir(NON_COVID_DCM_FILE_PATH)
    print(f'{NON_COVID_DCM_FILE_PATH} directory created successfully')
else:
  print(f'Looks like there is no directory structure below /content/data.. Lets create required directory structures')
  print(f'Creating {DCM_FILE_PATH} directory path first')
  os.mkdir(DCM_FILE_PATH)
  print(f'{DCM_FILE_PATH} directory created successfully')

  print(f'Creating {COVID_DCM_FILE_PATH} directory path')
  os.mkdir(COVID_DCM_FILE_PATH)
  print(f'{COVID_DCM_FILE_PATH} directory created successfully')

  print(f'Creating {NON_COVID_DCM_FILE_PATH} directory path')
  os.mkdir(NON_COVID_DCM_FILE_PATH)
  print(f'{NON_COVID_DCM_FILE_PATH} directory created successfully')
# Out:
# Looks like there is no directory structure below /content/data.. Lets create required directory structures
# Creating ./content/data/DCM/ directory path first
# ./content/data/DCM/ directory created successfully
# Creating ./content/data/DCM/COVID/ directory path
# ./content/data/DCM/COVID/ directory created successfully
# Creating ./content/data/DCM/NON_COVID/ directory path
# ./content/data/DCM/NON_COVID/ directory created successfully

# %%
def pngtodcm(image_list, COVID, l_i):
  print(f'COVID variable is set to {COVID}')
  list_im = []
  list_im = l_i

  for png_image in image_list:
    png_im_arr = np.array(Image.open(png_image).convert('L'))
    dcm_im_arr = sitk.GetImageFromArray(png_im_arr)
    if COVID:
      SAVE_PATH = COVID_DCM_FILE_PATH
      list_im = list_im_c
    else:
      SAVE_PATH = NON_COVID_DCM_FILE_PATH
      list_im = list_im_nc
    FILENAME = png_image.split("/")[-1].split(".")[0]
    DCM_FILENAME = SAVE_PATH + FILENAME + '.dcm'
    sitk.WriteImage(dcm_im_arr, DCM_FILENAME)
    print(f'Successfully converted and saved {DCM_FILENAME}')
    list_im.append(DCM_FILENAME)

# %%
list_im_c = []
pngtodcm(COVID_IMAGE_PATH_LIST, True, list_im_c)
# Out:
# COVID variable is set to True
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3064.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1603.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2986.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2143.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1543.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2955.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2753.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-415.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-202.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3245.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2237.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2730.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-688.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3031.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2691.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3138.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2171.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2052.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-208.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1439.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1821.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1697.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2511.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-9.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1661.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3311.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3094.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-770.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1565.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1971.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3452.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3095.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2932.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2498.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1448.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2818.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2048.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1385.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-932.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-905.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1763.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-844.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2467.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1400.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2816.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3022.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1744.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1992.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1939.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2016.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3065.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3137.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3484.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1825.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3223.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2833.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1054.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2657.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-807.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2762.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2492.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3151.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1632.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-820.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3373.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-431.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3126.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2717.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-559.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1196.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-776.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-199.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-800.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2085.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1966.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3556.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1964.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1968.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1529.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3416.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-195.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3052.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-160.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2836.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-534.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2700.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-263.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-230.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1487.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3305.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-884.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3243.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-976.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1478.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-490.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3107.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1126.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-767.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3241.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3115.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2334.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-366.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2485.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-705.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1232.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-788.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2694.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-421.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-350.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3129.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2880.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1962.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1963.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2636.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2882.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1869.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2514.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1691.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2638.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2522.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-173.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1736.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1835.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1183.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1181.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2602.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1935.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1781.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-558.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2504.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2423.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1222.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2055.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1420.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2306.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-824.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1303.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1266.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2759.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1453.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3613.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3076.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3483.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2273.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2731.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1011.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1814.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2023.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2164.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-802.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3567.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-900.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3464.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2894.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1418.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-974.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3249.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1094.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3395.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-407.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-44.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1132.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1240.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2061.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2053.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1803.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3082.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1602.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2925.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1205.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2776.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2540.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-967.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2117.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2267.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2922.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-906.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2853.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-585.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3216.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2773.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-401.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2626.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-855.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-795.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2595.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1597.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2400.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-785.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2324.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-34.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3047.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-372.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1559.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1922.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3447.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3303.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-266.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-177.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1517.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3301.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2340.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2944.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3477.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-853.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-608.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2698.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-289.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-414.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-233.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1938.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2174.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1542.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2317.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2725.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1142.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2927.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1558.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2106.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1376.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2455.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3429.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2505.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1306.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3074.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1335.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-955.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1997.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-683.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3532.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-755.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-424.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-606.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2519.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-978.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-228.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3179.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1662.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2585.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3271.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-637.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2281.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-581.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-340.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-861.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3608.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1188.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1889.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2160.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1553.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3542.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1053.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-500.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1685.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3434.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1340.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3194.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1169.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-215.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1465.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-363.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2127.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2617.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3267.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1471.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1201.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3178.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1141.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3025.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2298.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1348.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1284.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-880.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-627.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2757.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1199.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1618.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3144.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2722.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3171.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1472.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3256.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2918.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2778.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1461.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3467.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-568.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-428.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2901.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3035.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-72.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2708.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1382.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3083.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-530.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1218.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1764.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-676.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1849.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1467.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1203.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2598.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2763.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1512.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1663.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-237.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2092.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-786.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1271.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2344.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3489.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3486.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-392.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1246.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-916.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1878.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3340.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-685.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2426.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1450.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-808.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3316.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3153.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-58.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1536.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2465.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2596.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-115.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1287.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3013.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1973.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-744.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2291.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1226.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1650.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-641.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-640.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3026.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2231.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-829.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-531.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-330.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1324.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3402.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1454.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2242.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1871.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2409.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2726.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1991.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1391.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2914.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2180.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3559.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-327.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3106.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2974.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1550.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3276.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2014.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1269.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2676.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2166.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-873.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2811.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3441.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3616.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-255.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2090.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2711.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2709.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2376.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-952.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-859.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-59.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2477.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-778.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1874.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2829.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3599.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3565.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-753.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2988.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1998.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-703.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2251.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1277.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-201.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2825.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-928.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-479.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-717.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2383.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-863.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2116.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-569.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2949.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-537.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3531.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-249.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-245.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2300.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3363.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-271.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3561.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3187.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-546.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1989.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-376.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-319.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1958.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3470.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-293.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1381.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3596.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1006.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3042.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1272.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3371.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3283.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2727.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1262.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2822.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-374.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3088.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1515.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2820.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1633.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2309.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2260.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-39.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3517.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-240.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-386.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2946.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1395.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-890.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-728.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1566.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2038.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1866.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3554.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-161.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-724.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2351.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1831.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2832.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3408.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-487.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-295.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2664.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-355.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3428.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3536.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-353.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2241.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-63.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1028.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2530.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1429.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2572.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-291.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2212.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2436.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3131.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1223.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2862.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-989.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3401.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1614.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2788.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-762.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1502.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2313.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1087.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1872.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-314.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2548.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2509.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-870.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-869.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1275.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-181.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-875.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3468.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-609.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1636.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2919.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-55.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2852.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-860.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1440.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1776.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2496.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2508.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2834.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2764.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1667.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-723.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-168.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1611.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1351.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1490.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2077.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1828.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1423.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-648.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2622.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3461.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-118.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1613.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1162.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2348.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1347.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1156.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-646.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3344.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-670.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2515.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-632.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2285.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-486.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1372.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-712.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-270.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-468.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2755.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-167.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1635.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1706.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2845.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1654.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1591.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1782.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1237.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3018.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1634.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2297.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3117.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2433.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1217.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2323.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-260.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1106.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2453.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-742.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2737.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-190.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3320.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1534.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2148.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2272.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3017.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3011.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-865.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1338.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3530.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3292.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1647.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-66.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3160.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1123.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-499.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2529.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-451.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1653.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2889.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-671.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1837.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2729.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1904.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2417.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-107.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3048.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3228.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3103.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1307.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2168.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1594.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-351.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-140.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-901.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3583.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2075.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-969.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-588.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1528.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1030.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2398.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2738.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3147.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3312.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2683.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2674.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1380.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-25.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3520.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1793.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1040.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-318.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1089.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-370.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3564.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2118.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1805.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-15.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-836.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2819.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3443.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2775.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3297.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-292.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-772.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1238.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2957.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2169.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2424.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-469.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-692.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3578.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2223.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2591.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1944.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2202.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-672.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1308.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1979.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-950.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-132.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3072.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1913.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3537.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2750.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2560.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1466.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2520.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2444.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-50.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2536.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2073.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2896.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1757.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2716.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1843.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1227.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2196.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3563.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1513.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-562.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-211.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3244.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-603.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3317.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1248.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-252.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1546.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-507.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1260.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2482.dcm
# ...
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2102.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-799.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2881.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1085.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2004.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-761.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3248.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2813.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2130.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-963.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1144.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-470.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2282.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-384.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2321.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-232.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1923.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1412.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1150.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3051.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2633.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1716.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-964.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1652.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-57.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1564.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3404.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2799.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3089.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3380.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-284.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1273.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1579.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2119.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1576.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3234.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1311.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-134.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-200.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1129.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3545.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2096.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3497.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3321.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2350.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2384.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2902.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2158.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2921.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3514.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2469.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-871.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-992.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2890.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2979.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1314.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2109.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2712.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2604.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-385.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3071.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-104.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2154.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2752.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-580.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1305.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1670.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2387.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-405.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1135.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2589.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-218.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-951.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2341.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-197.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3150.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2857.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1854.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1942.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-777.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2663.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3250.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1498.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3087.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2177.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2042.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3258.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-443.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2665.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3516.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1914.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-621.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2299.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3571.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2301.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1741.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-152.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2703.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-968.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2254.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-56.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2549.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1719.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2214.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1401.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3329.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-8.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1720.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2575.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2233.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1544.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2807.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2978.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2630.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1645.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-262.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2368.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1495.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3085.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-503.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3413.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2688.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1925.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1751.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-395.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1170.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-496.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-560.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1254.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-966.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3358.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-272.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2379.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-491.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-182.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3098.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1354.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3396.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3005.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1434.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-573.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1211.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2124.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2335.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2559.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1164.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2558.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1313.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1726.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3299.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1190.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-805.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-28.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-929.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1243.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2025.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-347.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2195.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3479.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3383.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-294.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-622.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-334.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-782.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1452.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-878.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2013.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2421.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-64.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-912.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2000.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1621.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-226.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-914.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2462.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1102.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1948.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-121.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2397.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-583.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-452.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-783.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1350.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1934.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2422.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3309.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1917.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3453.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-593.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1575.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1475.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2984.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2354.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1469.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2728.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-651.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-947.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2916.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2650.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2791.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2378.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2046.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1777.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3524.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1919.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2933.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1364.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2137.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-738.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1046.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1285.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2749.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-482.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-149.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-290.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-847.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-830.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-214.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2031.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2183.dcm

# %%
len(list_im_c)
# Out:
# 3616

# %%
list_im_nc = []
pngtodcm(NON_COVID_IMAGE_PATH_LIST, False, list_im_nc)
# Out:
# Streaming output truncated to the last 5000 lines.
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2902.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-329.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3501.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4721.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5146.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6462.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9057.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-759.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9913.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10148.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2705.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-36.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3168.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-418.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7196.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8125.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-622.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4941.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5763.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8942.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1041.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2003.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4661.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9822.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1950.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7145.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7567.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7481.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4221.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4416.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8843.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5266.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5022.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1792.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5471.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3182.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2128.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9220.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-777.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2704.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1208.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2468.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5407.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-561.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8189.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4750.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2604.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5396.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7041.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9572.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3716.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4369.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9155.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8745.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3829.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7453.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3951.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9749.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4042.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1758.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1797.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6650.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5019.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7592.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3507.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9755.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2206.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7154.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-262.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2022.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4465.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3846.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6800.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8972.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8014.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8012.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2298.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1209.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6088.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1828.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7889.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4924.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5370.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5811.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-717.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4640.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8278.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4858.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1330.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4190.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2531.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5391.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-954.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5377.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9770.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1527.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10061.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7774.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2745.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-407.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8885.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-906.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4403.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9973.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3843.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3948.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4317.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8724.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-753.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8080.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3287.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8824.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5016.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2991.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2729.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6224.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6676.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1979.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6426.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1617.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9558.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9516.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2568.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2798.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2706.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7309.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6787.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5210.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2536.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2056.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2555.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2628.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7608.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7678.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9861.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9893.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2894.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-197.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3427.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4881.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2459.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6223.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3834.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-552.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9517.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7363.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4357.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-66.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2945.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6518.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9802.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3838.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6259.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5408.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7708.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2487.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5316.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7029.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-551.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1917.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1155.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3461.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2344.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9204.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2047.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3205.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4175.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5281.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2709.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-412.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3386.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6122.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1446.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6842.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8996.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4255.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1352.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-341.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4299.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7489.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2687.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4383.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4660.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6294.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4814.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8715.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5840.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3845.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8051.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7859.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5406.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9702.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7508.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7781.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3446.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2309.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-989.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3285.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5217.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1942.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8968.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1746.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4868.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8239.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2180.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1086.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7970.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1154.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-243.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5476.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8802.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-999.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4492.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5573.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10008.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7208.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4330.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1246.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7284.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9503.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9256.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-129.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3817.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1038.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2172.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2549.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4588.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-658.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4510.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9079.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8984.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4261.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4469.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4276.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-185.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1281.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5900.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2226.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9804.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10064.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5224.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-446.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9753.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5030.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6101.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4980.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7353.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8991.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7311.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3946.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6250.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10151.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5877.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9436.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3824.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3703.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4935.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-908.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7901.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8066.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5489.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1162.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8765.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9598.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3032.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6832.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8390.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3304.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-685.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6167.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9122.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-337.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8653.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-334.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4197.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2972.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6912.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7502.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5643.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-789.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7855.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3065.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-968.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6000.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1864.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8503.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8477.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5082.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5910.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4895.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5127.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-118.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6682.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7766.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6784.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1336.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10059.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4827.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9982.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6417.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2701.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9695.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2454.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4323.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-128.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3368.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2028.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6888.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7335.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9597.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6519.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4016.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2975.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5267.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7777.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4009.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8210.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6135.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7443.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-276.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1703.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3475.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7420.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7817.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3453.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3147.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9507.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2944.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9853.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4260.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5896.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5511.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9165.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4951.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2430.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8674.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2998.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1779.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6256.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9584.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8381.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1831.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3445.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5163.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5751.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1629.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5994.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9909.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2896.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9595.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3877.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3802.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7784.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4333.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3056.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8074.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3894.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-825.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9185.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7116.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10191.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4027.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5255.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6325.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-202.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3232.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9912.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6621.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7536.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-769.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7426.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4296.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3327.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3599.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-644.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5392.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2637.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7026.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9634.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-837.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-800.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9377.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6428.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-191.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2088.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6815.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1259.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6828.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1098.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6491.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9405.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1296.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6994.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8622.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7840.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4000.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5228.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6957.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10048.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3758.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-884.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4077.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-315.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-153.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1603.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2220.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1303.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5007.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5083.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8747.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7880.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7211.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9430.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1844.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8330.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7087.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1625.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1267.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1971.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4877.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2941.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5572.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9911.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2166.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9342.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1056.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-940.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1595.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6632.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4600.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2159.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2607.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-351.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2827.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9508.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2380.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6763.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5202.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5800.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2370.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9072.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7241.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3967.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6134.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6433.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3407.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-586.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2907.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5200.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-719.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9324.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1465.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8111.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7173.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5219.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6510.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3165.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2883.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2191.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3353.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6463.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1255.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5997.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3404.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7876.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3053.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6320.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-672.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9537.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8379.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1299.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5436.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8098.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-116.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4405.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-921.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1012.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1298.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3598.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-459.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6656.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2878.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2029.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8440.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3600.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3773.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2851.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10105.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7851.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4912.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5614.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2524.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8759.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-470.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3539.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10119.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6936.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7857.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3280.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6984.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5325.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6059.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9958.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9043.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-890.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8155.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3511.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9071.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4963.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-445.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7083.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7896.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6925.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2364.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4647.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3848.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8375.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8110.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5945.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-220.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5662.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9322.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5745.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3721.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-976.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4499.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5728.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6410.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2266.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6335.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8419.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4086.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6375.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-447.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8734.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7267.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3990.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7428.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5636.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7436.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7815.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2719.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5426.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5052.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-788.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7004.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-296.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5171.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1796.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3937.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8100.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7364.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8946.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5592.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9988.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7588.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7234.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9506.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4534.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5261.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9769.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8062.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2381.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9945.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7862.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1286.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5568.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4377.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8470.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-708.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6803.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8283.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3969.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5253.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5344.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6291.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4459.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5372.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8332.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6530.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9560.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6907.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7298.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8649.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7624.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6614.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8455.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4237.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9824.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6163.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9123.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7448.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3321.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4613.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1775.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8928.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9076.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-847.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8940.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-70.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3823.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6807.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5954.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2283.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1624.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10010.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-634.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9140.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6457.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9808.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4541.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4335.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1300.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1711.dcm
# ...
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8401.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5722.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5493.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2084.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9954.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4322.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5072.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8119.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-630.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8195.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3864.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8945.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9484.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3392.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8151.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1152.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1167.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8365.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1111.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4957.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2614.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-56.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3163.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8493.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4470.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9124.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-705.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1818.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6831.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2700.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5001.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9777.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8456.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6269.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7024.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1529.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4071.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4291.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1114.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6733.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7658.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2070.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2315.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9331.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3016.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4125.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4545.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3945.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1943.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1869.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9427.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8244.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4756.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7221.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-714.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1248.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-735.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7940.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7275.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1143.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6989.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8179.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6690.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2076.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3350.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9876.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2414.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7531.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-598.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2497.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6274.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1852.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9561.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8684.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2319.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8725.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-327.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9689.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7571.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7570.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6727.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6644.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4861.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-813.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6758.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6097.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7954.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7177.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4468.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6004.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2617.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-83.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6185.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8060.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1572.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6487.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3669.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-227.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8976.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3772.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5455.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8548.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10107.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-553.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7018.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7821.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-939.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-23.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2051.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5172.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8711.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8811.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4045.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5290.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9929.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1455.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7747.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5508.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3757.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9919.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-833.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4289.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4095.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7932.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3950.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-507.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8384.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2154.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2477.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5732.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3105.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5005.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1824.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5197.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4293.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8771.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7964.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8391.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7340.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1952.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3013.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3563.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6470.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9985.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-26.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6072.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5852.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3122.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6371.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1478.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7758.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2325.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7631.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3292.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1332.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5821.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1118.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3665.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8101.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5057.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-399.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6248.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9526.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5991.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8845.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5847.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9424.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6010.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5641.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6438.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8624.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10041.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1798.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6018.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-922.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3825.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1899.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2856.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9181.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3390.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2158.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9932.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2400.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-33.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1727.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8055.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3219.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5191.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5543.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6660.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1551.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4332.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-102.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6093.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7148.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7984.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-649.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2728.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3305.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1064.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9631.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3020.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8163.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2936.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-174.dcm

# %%
len(list_im_nc), len(list_im_c)
# Out:
# (10192, 3616)

# %%
len(NON_COVID_IMAGE_PATH_LIST), len(COVID_IMAGE_PATH_LIST)
# Out:
# (10192, 3616)

# %%
list_im_nc[0], list_im_c[0]
# Out:
# ('./content/data/DCM/NON_COVID/Normal-2376.dcm',
#  './content/data/DCM/COVID/COVID-3064.dcm')

# %%
def extract_fnames(file_list):
  temp_ll = []
  for i in file_list:
    fname = i.split("/")[-1].split(".")[0]
    temp_ll.append(fname)
    return sorted(temp_ll)

# %%
ll_dc_fname = extract_fnames(list_im_c)
ll_dnc_fname = extract_fnames(list_im_nc)
ll_pc_fname = extract_fnames(COVID_IMAGE_PATH_LIST)
ll_pnc_fname = extract_fnames(NON_COVID_IMAGE_PATH_LIST)

# %%
ll_dc_fname == ll_pc_fname
# Out:
# True

# %%
ll_dnc_fname == ll_pnc_fname
# Out:
# True

# %%
df_nc = pd.DataFrame()

# %%
df_nc['filename'] = list_im_nc

# %%
df_nc['class'] = 0

# %%
df_nc
# Out:
#                                            filename  class
# 0      ./content/data/DCM/NON_COVID/Normal-2376.dcm      0
# 1       ./content/data/DCM/NON_COVID/Normal-603.dcm      0
# 2      ./content/data/DCM/NON_COVID/Normal-9621.dcm      0
# 3      ./content/data/DCM/NON_COVID/Normal-6085.dcm      0
# 4      ./content/data/DCM/NON_COVID/Normal-7822.dcm      0
# ...                                             ...    ...
# 10187  ./content/data/DCM/NON_COVID/Normal-9631.dcm      0
# 10188  ./content/data/DCM/NON_COVID/Normal-3020.dcm      0
# 10189  ./content/data/DCM/NON_COVID/Normal-8163.dcm      0
# 10190  ./content/data/DCM/NON_COVID/Normal-2936.dcm      0
# 10191   ./content/data/DCM/NON_COVID/Normal-174.dcm      0
#
# [10192 rows x 2 columns]

# %%
label_1 = list(np.ones(len(list_im_c), dtype=int))
len(label_1), len(list_im_c)
# Out:
# (3616, 3616)

# %%
dict_c = {'filename': list_im_c, 'class': label_1}

# %%
df_c = pd.DataFrame(data=dict_c)

# %%
df_c
# Out:
#                                      filename  class
# 0     ./content/data/DCM/COVID/COVID-3064.dcm      1
# 1     ./content/data/DCM/COVID/COVID-1603.dcm      1
# 2     ./content/data/DCM/COVID/COVID-2986.dcm      1
# 3     ./content/data/DCM/COVID/COVID-2143.dcm      1
# 4     ./content/data/DCM/COVID/COVID-1543.dcm      1
# ...                                       ...    ...
# 3611   ./content/data/DCM/COVID/COVID-847.dcm      1
# 3612   ./content/data/DCM/COVID/COVID-830.dcm      1
# 3613   ./content/data/DCM/COVID/COVID-214.dcm      1
# 3614  ./content/data/DCM/COVID/COVID-2031.dcm      1
# 3615  ./content/data/DCM/COVID/COVID-2183.dcm      1
#
# [3616 rows x 2 columns]

# %%
df = pd.concat([df_nc, df_c])

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns=['index'], inplace=True)

# %%
df
# Out:
#                                            filename  class
# 0      ./content/data/DCM/NON_COVID/Normal-2376.dcm      0
# 1       ./content/data/DCM/NON_COVID/Normal-603.dcm      0
# 2      ./content/data/DCM/NON_COVID/Normal-9621.dcm      0
# 3      ./content/data/DCM/NON_COVID/Normal-6085.dcm      0
# 4      ./content/data/DCM/NON_COVID/Normal-7822.dcm      0
# ...                                             ...    ...
# 13803        ./content/data/DCM/COVID/COVID-847.dcm      1
# 13804        ./content/data/DCM/COVID/COVID-830.dcm      1
# 13805        ./content/data/DCM/COVID/COVID-214.dcm      1
# 13806       ./content/data/DCM/COVID/COVID-2031.dcm      1
# 13807       ./content/data/DCM/COVID/COVID-2183.dcm      1
#
# [13808 rows x 2 columns]

# %%
df['class'].value_counts()
# Out:
# 0    10192
# 1     3616
# Name: class, dtype: int64

# %%
df.to_csv('./content/data/DCM/dcm_files_list_labels.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13808 entries, 0 to 13807
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  13808 non-null  object
#  1   class     13808 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 215.9+ KB

# %% [markdown]
# ## Milestone 1.2

# %%
df_loaddata = pd.read_csv('./content/data/DCM/dcm_files_list_labels.csv')

# %%
df_loaddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13808 entries, 0 to 13807
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  13808 non-null  object
#  1   class     13808 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 215.9+ KB

# %%
len(df_loaddata.filename.unique())
# Out:
# 13808

# %%
df_loaddata['class'].value_counts()
# Out:
# 0    10192
# 1     3616
# Name: class, dtype: int64

# %%
df_X = df_loaddata.drop(columns=['class'])
df_y = df_loaddata['class']

# %%
df_y.head(), df_X.head()
# Out:
# (0    0
#  1    0
#  2    0
#  3    0
#  4    0
#  Name: class, dtype: int64,
#                                         filename
#  0  ./content/data/DCM/NON_COVID/Normal-2376.dcm
#  1   ./content/data/DCM/NON_COVID/Normal-603.dcm
#  2  ./content/data/DCM/NON_COVID/Normal-9621.dcm
#  3  ./content/data/DCM/NON_COVID/Normal-6085.dcm
#  4  ./content/data/DCM/NON_COVID/Normal-7822.dcm)

# %%
train_df, test_df = train_test_split(df_loaddata, test_size=0.2, random_state=42, stratify=df['class'])

len(train_df), len(test_df)
# Out:
# (11046, 2762)

# %%
# we need to further reserve 20% data in training for validation
train_df, valid_df = train_test_split(train_df, test_size=0.2, random_state=42, stratify=train_df['class'])

len(train_df), len(valid_df)
# Out:
# (8836, 2210)

# %%
train_df['class'].sum(), valid_df['class'].sum(), test_df['class'].sum()
# Out:
# (2314, 579, 723)

# %%
train_df['class'].sum() + valid_df['class'].sum() + test_df['class'].sum()
# Out:
# 3616

# %%
train_aug_params = dict(
    #rescale=1./255,
    rotation_range=10,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    brightness_range = [0.8, 1.2]
)

valid_aug_params = dict(
    #rescale=1./255
    )

test_aug_params = dict(
    #rescale=1./255
)

# %%
#Creating augmenters

train_augmenter = ImageDataGenerator(**train_aug_params)
valid_augmenter = ImageDataGenerator(**valid_aug_params)
test_augmenter = ImageDataGenerator(**test_aug_params)

# %%
type(train_augmenter), type(valid_augmenter), type(test_augmenter)
# Out:
# (keras.preprocessing.image.ImageDataGenerator,
#  keras.preprocessing.image.ImageDataGenerator,
#  keras.preprocessing.image.ImageDataGenerator)

# %%
# training parameters
BATCH_SIZE = 32
COLOR_MODE = 'grayscale'
TARGET_SIZE = (224, 224)
EPOCHS = 10

train_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE,  
}

valid_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE, 
    'shuffle': False
}

test_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE,  # resize input images
    'shuffle': False
}

# %%
class DCMDataFrameIterator(DataFrameIterator):
    def __init__(self, *arg, **kwargs):
        self.white_list_formats = ('dcm')
        super(DCMDataFrameIterator, self).__init__(*arg, **kwargs)
        self.dataframe = kwargs['dataframe']
        self.x = self.dataframe[kwargs['x_col']]
        self.y = self.dataframe[kwargs['y_col']]
        self.color_mode = kwargs['color_mode']
        self.target_size = kwargs['target_size']

    def _get_batches_of_transformed_samples(self, indices_array):
        # get batch of images
        batch_x = np.array([self.read_dcm_as_array(dcm_path, self.target_size, color_mode=self.color_mode)
                            for dcm_path in self.x.iloc[indices_array]])

        batch_y = np.array(self.y.iloc[indices_array].astype(np.uint8))  # astype because y was passed as str

        # transform images
        if self.image_data_generator is not None:
            for i, (x, y) in enumerate(zip(batch_x, batch_y)):
                transform_params = self.image_data_generator.get_random_transform(x.shape)
                batch_x[i] = self.image_data_generator.apply_transform(x, transform_params)
                
                # you can change y here as well, eg: in semantic segmentation you want to transform masks as well 
                # using the same image_data_generator transformations.

        return batch_x, batch_y

    @staticmethod
    def read_dcm_as_array(dcm_path, target_size=(256, 256), color_mode='rgb'):
        image_array = pydicom.dcmread(dcm_path).pixel_array
        image = Image.fromarray(image_array) #converts from array to PIL
        #image = Image.open(image).convert('L')
        image.thumbnail((224,224)) #resize image to 224,224
        #image_array = cv2.resize(image_array, target_size, interpolation=cv2.INTER_NEAREST)  #this returns a 2d array
        image_array = np.expand_dims(image, -1)
        return image_array.astype(np.float32)

# %%
train_df['class'] = train_df['class'].astype('str')
valid_df['class'] = valid_df['class'].astype('str')
test_df['class'] = test_df['class'].astype('str')

# %%
train_df.info(), valid_df.info(),  test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8836 entries, 13528 to 8134
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  8836 non-null   object
#  1   class     8836 non-null   object
# dtypes: object(2)
# memory usage: 207.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2210 entries, 6681 to 12452
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  2210 non-null   object
#  1   class     2210 non-null   object
# dtypes: object(2)
# memory usage: 51.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2762 entries, 1939 to 8436
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  2762 non-null   object
#  1   class     2762 non-null   object
# dtypes: object(2)
# memory usage: 64.7+ KB
# (None, None, None)

# %%
train_generator = DCMDataFrameIterator(dataframe=train_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=train_augmenter,
                             **train_consts)

valid_generator = DCMDataFrameIterator(dataframe=valid_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=valid_augmenter,
                             **valid_consts)

test_generator = DCMDataFrameIterator(dataframe=test_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=test_augmenter,
                             **test_consts)
# Out:
# Found 8836 validated image filenames belonging to 2 classes.
# Found 2210 validated image filenames belonging to 2 classes.
# Found 2762 validated image filenames belonging to 2 classes.

# %%
#train_augmenter.fit(train_generator)

# %%
classes = ['NON-COVID', 'COVID']

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(train_generator))

imgs.shape, labels.shape, type(imgs), type(labels)
# Out:
# ((32, 224, 224, 1), (32,), numpy.ndarray, numpy.ndarray)

# %%
imgs[0].mean(), imgs[0].max(), imgs[0].min()
# Out:
# (143.57153, 213.0, 0.0)

# %%
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(valid_generator))
print(imgs.shape, labels.shape, type(imgs), type(labels))
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()
# Out:
# (32, 224, 224, 1) (32,) <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(test_generator))
print(imgs.shape, labels.shape, type(imgs), type(labels))
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()
# Out:
# (32, 224, 224, 1) (32,) <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
imgs[0].dtype
# Out:
# dtype('float32')

# %%
#imgs[0]

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Add, Flatten, LayerNormalization, Activation, Input
from tensorflow.keras import Sequential
try:
    from einops import rearrange, repeat
    from einops.layers.tensorflow import Rearrange
except:
    print("Einops not installed, Initiating install")
    # !pip install einops
    from einops import rearrange, repeat
    from einops.layers.tensorflow import Rearrange
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
# Out:
# Einops not installed, Initiating install
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting einops
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.6.1

# %%
basemodel = EfficientNetV2B0(weights='imagenet', include_top=False, input_tensor=Input(shape=(224,224,3)), pooling='avg')
basemodel.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 [==============================] - 0s 0us/step
# Model: "efficientnetv2-b0"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 224, 224, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 224, 224, 3)  0           ['rescaling[0][0]']
#
#  stem_conv (Conv2D)             (None, 112, 112, 32  864         ['normalization[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 112, 112, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 112, 112, 32  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 112, 112, 16  4608        ['stem_activation[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 112, 112, 16  64         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1a_project_activation (Ac  (None, 112, 112, 16  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  block2a_expand_conv (Conv2D)   (None, 56, 56, 64)   9216        ['block1a_project_activation[0][0
#                                                                  ]']
#
#  block2a_expand_bn (BatchNormal  (None, 56, 56, 64)  256         ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 56, 56, 64)  0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_project_conv (Conv2D)  (None, 56, 56, 32)   2048        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  block2a_project_bn (BatchNorma  (None, 56, 56, 32)  128         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 56, 56, 128)  36864       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 56, 56, 128)  512        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 56, 56, 128)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_project_conv (Conv2D)  (None, 56, 56, 32)   4096        ['block2b_expand_activation[0][0]
#                                                                  ']
#
#  block2b_project_bn (BatchNorma  (None, 56, 56, 32)  128         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 56, 56, 32)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 56, 56, 32)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 28, 28, 128)  36864       ['block2b_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 28, 28, 128)  512        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 28, 28, 128)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 28, 28, 48)   6144        ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 28, 28, 48)  192         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 28, 28, 192)  82944       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 28, 28, 192)  768        ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 28, 28, 192)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 28, 28, 48)   9216        ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 28, 28, 48)  192         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 28, 28, 48)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 28, 28, 48)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 28, 28, 192)  9216        ['block3b_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 28, 28, 192)  768        ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 28, 28, 192)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 14, 14, 192)  1728       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 14, 14, 192)  768        ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 14, 14, 192)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 192)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 12)     2316        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 192)    2496        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 14, 14, 192)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 14, 14, 96)   18432       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 14, 14, 96)  384         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 14, 14, 384)  36864       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 14, 14, 384)  1536       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 14, 14, 384)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 14, 14, 384)  3456       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 14, 14, 384)  1536       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 14, 14, 384)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 384)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 24)     9240        ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 384)    9600        ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 14, 14, 384)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 14, 14, 96)   36864       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 14, 14, 96)  384         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 14, 14, 96)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 14, 14, 96)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 14, 14, 384)  36864       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 14, 14, 384)  1536       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 14, 14, 384)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 14, 14, 384)  3456       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 14, 14, 384)  1536       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 14, 14, 384)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 384)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 24)     9240        ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 384)    9600        ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 14, 14, 384)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 14, 14, 96)   36864       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 14, 14, 96)  384         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 14, 14, 96)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 14, 14, 96)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 14, 14, 576)  55296       ['block4c_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 14, 14, 576)  2304       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 14, 14, 576)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv2 (DepthwiseConv  (None, 14, 14, 576)  5184       ['block5a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5a_bn (BatchNormalization  (None, 14, 14, 576)  2304       ['block5a_dwconv2[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 14, 14, 576)  0          ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 576)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 576)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 24)     13848       ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 576)    14400       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, 14, 14, 576)  0           ['block5a_activation[0][0]',
#                                                                   'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, 14, 14, 112)  64512       ['block5a_se_excite[0][0]']
#
#  block5a_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5a_project_conv[0][0]']
#  lization)
#
#  block5b_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5a_project_bn[0][0]']
#
#  block5b_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block5b_expand_conv[0][0]']
#  ization)
#
#  block5b_expand_activation (Act  (None, 14, 14, 672)  0          ['block5b_expand_bn[0][0]']
#  ivation)
#
#  block5b_dwconv2 (DepthwiseConv  (None, 14, 14, 672)  6048       ['block5b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5b_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block5b_dwconv2[0][0]']
#  )
#
#  block5b_activation (Activation  (None, 14, 14, 672)  0          ['block5b_bn[0][0]']
#  )
#
#  block5b_se_squeeze (GlobalAver  (None, 672)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, 14, 14, 672)  0           ['block5b_activation[0][0]',
#                                                                   'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, 14, 14, 112)  75264       ['block5b_se_excite[0][0]']
#
#  block5b_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5b_project_conv[0][0]']
#  lization)
#
#  block5b_drop (Dropout)         (None, 14, 14, 112)  0           ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)              (None, 14, 14, 112)  0           ['block5b_drop[0][0]',
#                                                                   'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5b_add[0][0]']
#
#  block5c_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block5c_expand_conv[0][0]']
#  ization)
#
#  block5c_expand_activation (Act  (None, 14, 14, 672)  0          ['block5c_expand_bn[0][0]']
#  ivation)
#
#  block5c_dwconv2 (DepthwiseConv  (None, 14, 14, 672)  6048       ['block5c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5c_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block5c_dwconv2[0][0]']
#  )
#
#  block5c_activation (Activation  (None, 14, 14, 672)  0          ['block5c_bn[0][0]']
#  )
#
#  block5c_se_squeeze (GlobalAver  (None, 672)         0           ['block5c_activation[0][0]']
#  agePooling2D)
#
#  block5c_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5c_se_squeeze[0][0]']
#
#  block5c_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multiply)   (None, 14, 14, 672)  0           ['block5c_activation[0][0]',
#                                                                   'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv2D)  (None, 14, 14, 112)  75264       ['block5c_se_excite[0][0]']
#
#  block5c_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5c_project_conv[0][0]']
#  lization)
#
#  block5c_drop (Dropout)         (None, 14, 14, 112)  0           ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)              (None, 14, 14, 112)  0           ['block5c_drop[0][0]',
#                                                                   'block5b_add[0][0]']
#
#  block5d_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5c_add[0][0]']
#
#  block5d_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block5d_expand_conv[0][0]']
#  ization)
#
#  block5d_expand_activation (Act  (None, 14, 14, 672)  0          ['block5d_expand_bn[0][0]']
#  ivation)
#
#  block5d_dwconv2 (DepthwiseConv  (None, 14, 14, 672)  6048       ['block5d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5d_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block5d_dwconv2[0][0]']
#  )
#
#  block5d_activation (Activation  (None, 14, 14, 672)  0          ['block5d_bn[0][0]']
#  )
#
#  block5d_se_squeeze (GlobalAver  (None, 672)         0           ['block5d_activation[0][0]']
#  agePooling2D)
#
#  block5d_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5d_se_squeeze[0][0]']
#
#  block5d_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5d_se_reshape[0][0]']
#
#  block5d_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5d_se_reduce[0][0]']
#
#  block5d_se_excite (Multiply)   (None, 14, 14, 672)  0           ['block5d_activation[0][0]',
#                                                                   'block5d_se_expand[0][0]']
#
#  block5d_project_conv (Conv2D)  (None, 14, 14, 112)  75264       ['block5d_se_excite[0][0]']
#
#  block5d_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5d_project_conv[0][0]']
#  lization)
#
#  block5d_drop (Dropout)         (None, 14, 14, 112)  0           ['block5d_project_bn[0][0]']
#
#  block5d_add (Add)              (None, 14, 14, 112)  0           ['block5d_drop[0][0]',
#                                                                   'block5c_add[0][0]']
#
#  block5e_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5d_add[0][0]']
#
#  block5e_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block5e_expand_conv[0][0]']
#  ization)
#
#  block5e_expand_activation (Act  (None, 14, 14, 672)  0          ['block5e_expand_bn[0][0]']
#  ivation)
#
#  block5e_dwconv2 (DepthwiseConv  (None, 14, 14, 672)  6048       ['block5e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5e_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block5e_dwconv2[0][0]']
#  )
#
#  block5e_activation (Activation  (None, 14, 14, 672)  0          ['block5e_bn[0][0]']
#  )
#
#  block5e_se_squeeze (GlobalAver  (None, 672)         0           ['block5e_activation[0][0]']
#  agePooling2D)
#
#  block5e_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5e_se_squeeze[0][0]']
#
#  block5e_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5e_se_reshape[0][0]']
#
#  block5e_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5e_se_reduce[0][0]']
#
#  block5e_se_excite (Multiply)   (None, 14, 14, 672)  0           ['block5e_activation[0][0]',
#                                                                   'block5e_se_expand[0][0]']
#
#  block5e_project_conv (Conv2D)  (None, 14, 14, 112)  75264       ['block5e_se_excite[0][0]']
#
#  block5e_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block5e_project_conv[0][0]']
#  lization)
#
#  block5e_drop (Dropout)         (None, 14, 14, 112)  0           ['block5e_project_bn[0][0]']
#
#  block5e_add (Add)              (None, 14, 14, 112)  0           ['block5e_drop[0][0]',
#                                                                   'block5d_add[0][0]']
#
#  block6a_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block5e_add[0][0]']
#
#  block6a_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block6a_expand_conv[0][0]']
#  ization)
#
#  block6a_expand_activation (Act  (None, 14, 14, 672)  0          ['block6a_expand_bn[0][0]']
#  ivation)
#
#  block6a_dwconv2 (DepthwiseConv  (None, 7, 7, 672)   6048        ['block6a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6a_bn (BatchNormalization  (None, 7, 7, 672)   2688        ['block6a_dwconv2[0][0]']
#  )
#
#  block6a_activation (Activation  (None, 7, 7, 672)   0           ['block6a_bn[0][0]']
#  )
#
#  block6a_se_squeeze (GlobalAver  (None, 672)         0           ['block6a_activation[0][0]']
#  agePooling2D)
#
#  block6a_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block6a_se_squeeze[0][0]']
#
#  block6a_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block6a_se_reshape[0][0]']
#
#  block6a_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block6a_se_reduce[0][0]']
#
#  block6a_se_excite (Multiply)   (None, 7, 7, 672)    0           ['block6a_activation[0][0]',
#                                                                   'block6a_se_expand[0][0]']
#
#  block6a_project_conv (Conv2D)  (None, 7, 7, 192)    129024      ['block6a_se_excite[0][0]']
#
#  block6a_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6a_project_conv[0][0]']
#  lization)
#
#  block6b_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6a_project_bn[0][0]']
#
#  block6b_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6b_expand_conv[0][0]']
#  ization)
#
#  block6b_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6b_expand_bn[0][0]']
#  ivation)
#
#  block6b_dwconv2 (DepthwiseConv  (None, 7, 7, 1152)  10368       ['block6b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6b_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6b_dwconv2[0][0]']
#  )
#
#  block6b_activation (Activation  (None, 7, 7, 1152)  0           ['block6b_bn[0][0]']
#  )
#
#  block6b_se_squeeze (GlobalAver  (None, 1152)        0           ['block6b_activation[0][0]']
#  agePooling2D)
#
#  block6b_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6b_se_squeeze[0][0]']
#
#  block6b_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6b_se_reshape[0][0]']
#
#  block6b_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6b_se_reduce[0][0]']
#
#  block6b_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6b_activation[0][0]',
#                                                                   'block6b_se_expand[0][0]']
#
#  block6b_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6b_se_excite[0][0]']
#
#  block6b_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6b_project_conv[0][0]']
#  lization)
#
#  block6b_drop (Dropout)         (None, 7, 7, 192)    0           ['block6b_project_bn[0][0]']
#
#  block6b_add (Add)              (None, 7, 7, 192)    0           ['block6b_drop[0][0]',
#                                                                   'block6a_project_bn[0][0]']
#
#  block6c_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6b_add[0][0]']
#
#  block6c_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6c_expand_conv[0][0]']
#  ization)
#
#  block6c_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6c_expand_bn[0][0]']
#  ivation)
#
#  block6c_dwconv2 (DepthwiseConv  (None, 7, 7, 1152)  10368       ['block6c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6c_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6c_dwconv2[0][0]']
# ...
#
#  block6e_dwconv2 (DepthwiseConv  (None, 7, 7, 1152)  10368       ['block6e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6e_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6e_dwconv2[0][0]']
#  )
#
#  block6e_activation (Activation  (None, 7, 7, 1152)  0           ['block6e_bn[0][0]']
#  )
#
#  block6e_se_squeeze (GlobalAver  (None, 1152)        0           ['block6e_activation[0][0]']
#  agePooling2D)
#
#  block6e_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6e_se_squeeze[0][0]']
#
#  block6e_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6e_activation[0][0]',
#                                                                   'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6e_se_excite[0][0]']
#
#  block6e_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6e_project_conv[0][0]']
#  lization)
#
#  block6e_drop (Dropout)         (None, 7, 7, 192)    0           ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)              (None, 7, 7, 192)    0           ['block6e_drop[0][0]',
#                                                                   'block6d_add[0][0]']
#
#  block6f_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6e_add[0][0]']
#
#  block6f_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6f_expand_conv[0][0]']
#  ization)
#
#  block6f_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6f_expand_bn[0][0]']
#  ivation)
#
#  block6f_dwconv2 (DepthwiseConv  (None, 7, 7, 1152)  10368       ['block6f_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6f_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6f_dwconv2[0][0]']
#  )
#
#  block6f_activation (Activation  (None, 7, 7, 1152)  0           ['block6f_bn[0][0]']
#  )
#
#  block6f_se_squeeze (GlobalAver  (None, 1152)        0           ['block6f_activation[0][0]']
#  agePooling2D)
#
#  block6f_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6f_se_squeeze[0][0]']
#
#  block6f_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6f_activation[0][0]',
#                                                                   'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6f_se_excite[0][0]']
#
#  block6f_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6f_project_conv[0][0]']
#  lization)
#
#  block6f_drop (Dropout)         (None, 7, 7, 192)    0           ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)              (None, 7, 7, 192)    0           ['block6f_drop[0][0]',
#                                                                   'block6e_add[0][0]']
#
#  block6g_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6f_add[0][0]']
#
#  block6g_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6g_expand_conv[0][0]']
#  ization)
#
#  block6g_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6g_expand_bn[0][0]']
#  ivation)
#
#  block6g_dwconv2 (DepthwiseConv  (None, 7, 7, 1152)  10368       ['block6g_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6g_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6g_dwconv2[0][0]']
#  )
#
#  block6g_activation (Activation  (None, 7, 7, 1152)  0           ['block6g_bn[0][0]']
#  )
#
#  block6g_se_squeeze (GlobalAver  (None, 1152)        0           ['block6g_activation[0][0]']
#  agePooling2D)
#
#  block6g_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6g_se_squeeze[0][0]']
#
#  block6g_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6g_se_reshape[0][0]']
#
#  block6g_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6g_se_reduce[0][0]']
#
#  block6g_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6g_activation[0][0]',
#                                                                   'block6g_se_expand[0][0]']
#
#  block6g_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6g_se_excite[0][0]']
#
#  block6g_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6g_project_conv[0][0]']
#  lization)
#
#  block6g_drop (Dropout)         (None, 7, 7, 192)    0           ['block6g_project_bn[0][0]']
#
#  block6g_add (Add)              (None, 7, 7, 192)    0           ['block6g_drop[0][0]',
#                                                                   'block6f_add[0][0]']
#
#  block6h_expand_conv (Conv2D)   (None, 7, 7, 1152)   221184      ['block6g_add[0][0]']
#
#  block6h_expand_bn (BatchNormal  (None, 7, 7, 1152)  4608        ['block6h_expand_conv[0][0]']
#  ization)
#
#  block6h_expand_activation (Act  (None, 7, 7, 1152)  0           ['block6h_expand_bn[0][0]']
#  ivation)
#
#  block6h_dwconv2 (DepthwiseConv  (None, 7, 7, 1152)  10368       ['block6h_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6h_bn (BatchNormalization  (None, 7, 7, 1152)  4608        ['block6h_dwconv2[0][0]']
#  )
#
#  block6h_activation (Activation  (None, 7, 7, 1152)  0           ['block6h_bn[0][0]']
#  )
#
#  block6h_se_squeeze (GlobalAver  (None, 1152)        0           ['block6h_activation[0][0]']
#  agePooling2D)
#
#  block6h_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6h_se_squeeze[0][0]']
#
#  block6h_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6h_se_reshape[0][0]']
#
#  block6h_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6h_se_reduce[0][0]']
#
#  block6h_se_excite (Multiply)   (None, 7, 7, 1152)   0           ['block6h_activation[0][0]',
#                                                                   'block6h_se_expand[0][0]']
#
#  block6h_project_conv (Conv2D)  (None, 7, 7, 192)    221184      ['block6h_se_excite[0][0]']
#
#  block6h_project_bn (BatchNorma  (None, 7, 7, 192)   768         ['block6h_project_conv[0][0]']
#  lization)
#
#  block6h_drop (Dropout)         (None, 7, 7, 192)    0           ['block6h_project_bn[0][0]']
#
#  block6h_add (Add)              (None, 7, 7, 192)    0           ['block6h_drop[0][0]',
#                                                                   'block6g_add[0][0]']
#
#  top_conv (Conv2D)              (None, 7, 7, 1280)   245760      ['block6h_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 7, 7, 1280)   5120        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 7, 7, 1280)   0           ['top_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1280)        0           ['top_activation[0][0]']
#  2D)
#
# ==================================================================================================
# Total params: 5,919,312
# Trainable params: 5,858,704
# Non-trainable params: 60,608
# __________________________________________________________________________________________________

# %%
class EfficientNetV2B0_TL(tensorflow.keras.Model):
  def __init__(self):
    super().__init__()

    self.conv_layer = Conv2D(3, (3,3), padding='same')

    self.basemodel = EfficientNetV2B0(weights='imagenet', include_top=False, input_tensor=Input(shape=(224,224,3)))
    for layer in self.basemodel.layers:
      layer.trainable=False
    self.classifier = Sequential([
        AveragePooling2D((7,7)),
        Flatten(),
      
        #Dense(512, use_bias=False),
        #BatchNormalization(),
        #Activation('relu'),
        #Dropout(0.1),
        #Dense(128, use_bias=False),
        #BatchNormalization(),
        #Activation('relu'),
        #Dropout(0.1),
        Dense(2)
    ])

  def call(self,x):
    #for layer in self.basemodel.layers:
     # layer.trainable=False
    x = self.conv_layer(x)
    #x = preprocess_input(x)
    x = self.basemodel(x)
    x = self.classifier(x)
    return x

# %%
model = EfficientNetV2B0_TL()

# %%
X_input = Input(shape=(224,224,1,))
out = EfficientNetV2B0_TL()(X_input)
temp_model = Model(inputs=X_input, outputs=out)
temp_model.summary(expand_nested=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 1)]     0
#
#  efficient_net_v2b0_tl_1 (Ef  (None, 2)                5921904
#  ficientNetV2B0_TL)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | conv2d_1 (Conv2D)         multiple                  30        |
# |                                                               |
# | efficientnetv2-b0 (Function  (None, 7, 7, 1280)     5919312   |
# | al)                                                           |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || input_4 (InputLayer)    [(None, 224, 224, 3)]     0         ||
# ||                                                             ||
# || rescaling_2 (Rescaling)  (None, 224, 224, 3)      0         ||
# ||                                                             ||
# || normalization_2 (Normalizat  (None, 224, 224, 3)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || stem_conv (Conv2D)      (None, 112, 112, 32)      864       ||
# ||                                                             ||
# || stem_bn (BatchNormalization  (None, 112, 112, 32)  128      ||
# || )                                                           ||
# ||                                                             ||
# || stem_activation (Activation  (None, 112, 112, 32)  0        ||
# || )                                                           ||
# ||                                                             ||
# || block1a_project_conv (Conv2  (None, 112, 112, 16)  4608     ||
# || D)                                                          ||
# ||                                                             ||
# || block1a_project_bn (BatchNo  (None, 112, 112, 16)  64       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block1a_project_activation   (None, 112, 112, 16)  0        ||
# || (Activation)                                                ||
# ||                                                             ||
# || block2a_expand_conv (Conv2D  (None, 56, 56, 64)   9216      ||
# || )                                                           ||
# ||                                                             ||
# || block2a_expand_bn (BatchNor  (None, 56, 56, 64)   256       ||
# || malization)                                                 ||
# ||                                                             ||
# || block2a_expand_activation (  (None, 56, 56, 64)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block2a_project_conv (Conv2  (None, 56, 56, 32)   2048      ||
# || D)                                                          ||
# ||                                                             ||
# || block2a_project_bn (BatchNo  (None, 56, 56, 32)   128       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block2b_expand_conv (Conv2D  (None, 56, 56, 128)  36864     ||
# || )                                                           ||
# ||                                                             ||
# || block2b_expand_bn (BatchNor  (None, 56, 56, 128)  512       ||
# || malization)                                                 ||
# ||                                                             ||
# || block2b_expand_activation (  (None, 56, 56, 128)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block2b_project_conv (Conv2  (None, 56, 56, 32)   4096      ||
# || D)                                                          ||
# ||                                                             ||
# || block2b_project_bn (BatchNo  (None, 56, 56, 32)   128       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block2b_drop (Dropout)  (None, 56, 56, 32)        0         ||
# ||                                                             ||
# || block2b_add (Add)       (None, 56, 56, 32)        0         ||
# ||                                                             ||
# || block3a_expand_conv (Conv2D  (None, 28, 28, 128)  36864     ||
# || )                                                           ||
# ||                                                             ||
# || block3a_expand_bn (BatchNor  (None, 28, 28, 128)  512       ||
# || malization)                                                 ||
# ||                                                             ||
# || block3a_expand_activation (  (None, 28, 28, 128)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block3a_project_conv (Conv2  (None, 28, 28, 48)   6144      ||
# || D)                                                          ||
# ||                                                             ||
# || block3a_project_bn (BatchNo  (None, 28, 28, 48)   192       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block3b_expand_conv (Conv2D  (None, 28, 28, 192)  82944     ||
# || )                                                           ||
# ||                                                             ||
# || block3b_expand_bn (BatchNor  (None, 28, 28, 192)  768       ||
# || malization)                                                 ||
# ||                                                             ||
# || block3b_expand_activation (  (None, 28, 28, 192)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block3b_project_conv (Conv2  (None, 28, 28, 48)   9216      ||
# || D)                                                          ||
# ||                                                             ||
# || block3b_project_bn (BatchNo  (None, 28, 28, 48)   192       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block3b_drop (Dropout)  (None, 28, 28, 48)        0         ||
# ||                                                             ||
# || block3b_add (Add)       (None, 28, 28, 48)        0         ||
# ||                                                             ||
# || block4a_expand_conv (Conv2D  (None, 28, 28, 192)  9216      ||
# || )                                                           ||
# ||                                                             ||
# || block4a_expand_bn (BatchNor  (None, 28, 28, 192)  768       ||
# || malization)                                                 ||
# ||                                                             ||
# || block4a_expand_activation (  (None, 28, 28, 192)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block4a_dwconv2 (DepthwiseC  (None, 14, 14, 192)  1728      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block4a_bn (BatchNormalizat  (None, 14, 14, 192)  768       ||
# || ion)                                                        ||
# ||                                                             ||
# || block4a_activation (Activat  (None, 14, 14, 192)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block4a_se_squeeze (GlobalA  (None, 192)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block4a_se_reshape (Reshape  (None, 1, 1, 192)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block4a_se_reduce (Conv2D)  (None, 1, 1, 12)      2316      ||
# ||                                                             ||
# || block4a_se_expand (Conv2D)  (None, 1, 1, 192)     2496      ||
# ||                                                             ||
# || block4a_se_excite (Multiply  (None, 14, 14, 192)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block4a_project_conv (Conv2  (None, 14, 14, 96)   18432     ||
# || D)                                                          ||
# ||                                                             ||
# || block4a_project_bn (BatchNo  (None, 14, 14, 96)   384       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block4b_expand_conv (Conv2D  (None, 14, 14, 384)  36864     ||
# || )                                                           ||
# ||                                                             ||
# || block4b_expand_bn (BatchNor  (None, 14, 14, 384)  1536      ||
# || malization)                                                 ||
# ||                                                             ||
# || block4b_expand_activation (  (None, 14, 14, 384)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block4b_dwconv2 (DepthwiseC  (None, 14, 14, 384)  3456      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block4b_bn (BatchNormalizat  (None, 14, 14, 384)  1536      ||
# || ion)                                                        ||
# ||                                                             ||
# || block4b_activation (Activat  (None, 14, 14, 384)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block4b_se_squeeze (GlobalA  (None, 384)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block4b_se_reshape (Reshape  (None, 1, 1, 384)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block4b_se_reduce (Conv2D)  (None, 1, 1, 24)      9240      ||
# ||                                                             ||
# || block4b_se_expand (Conv2D)  (None, 1, 1, 384)     9600      ||
# ||                                                             ||
# || block4b_se_excite (Multiply  (None, 14, 14, 384)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block4b_project_conv (Conv2  (None, 14, 14, 96)   36864     ||
# || D)                                                          ||
# ||                                                             ||
# || block4b_project_bn (BatchNo  (None, 14, 14, 96)   384       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block4b_drop (Dropout)  (None, 14, 14, 96)        0         ||
# ||                                                             ||
# || block4b_add (Add)       (None, 14, 14, 96)        0         ||
# ||                                                             ||
# || block4c_expand_conv (Conv2D  (None, 14, 14, 384)  36864     ||
# || )                                                           ||
# ||                                                             ||
# || block4c_expand_bn (BatchNor  (None, 14, 14, 384)  1536      ||
# || malization)                                                 ||
# ||                                                             ||
# || block4c_expand_activation (  (None, 14, 14, 384)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block4c_dwconv2 (DepthwiseC  (None, 14, 14, 384)  3456      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block4c_bn (BatchNormalizat  (None, 14, 14, 384)  1536      ||
# || ion)                                                        ||
# ||                                                             ||
# || block4c_activation (Activat  (None, 14, 14, 384)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block4c_se_squeeze (GlobalA  (None, 384)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block4c_se_reshape (Reshape  (None, 1, 1, 384)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block4c_se_reduce (Conv2D)  (None, 1, 1, 24)      9240      ||
# ||                                                             ||
# || block4c_se_expand (Conv2D)  (None, 1, 1, 384)     9600      ||
# ||                                                             ||
# || block4c_se_excite (Multiply  (None, 14, 14, 384)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block4c_project_conv (Conv2  (None, 14, 14, 96)   36864     ||
# || D)                                                          ||
# ||                                                             ||
# || block4c_project_bn (BatchNo  (None, 14, 14, 96)   384       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block4c_drop (Dropout)  (None, 14, 14, 96)        0         ||
# ||                                                             ||
# || block4c_add (Add)       (None, 14, 14, 96)        0         ||
# ||                                                             ||
# || block5a_expand_conv (Conv2D  (None, 14, 14, 576)  55296     ||
# || )                                                           ||
# ||                                                             ||
# || block5a_expand_bn (BatchNor  (None, 14, 14, 576)  2304      ||
# || malization)                                                 ||
# ||                                                             ||
# || block5a_expand_activation (  (None, 14, 14, 576)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block5a_dwconv2 (DepthwiseC  (None, 14, 14, 576)  5184      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block5a_bn (BatchNormalizat  (None, 14, 14, 576)  2304      ||
# || ion)                                                        ||
# ||                                                             ||
# || block5a_activation (Activat  (None, 14, 14, 576)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block5a_se_squeeze (GlobalA  (None, 576)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block5a_se_reshape (Reshape  (None, 1, 1, 576)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block5a_se_reduce (Conv2D)  (None, 1, 1, 24)      13848     ||
# ||                                                             ||
# || block5a_se_expand (Conv2D)  (None, 1, 1, 576)     14400     ||
# ||                                                             ||
# || block5a_se_excite (Multiply  (None, 14, 14, 576)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block5a_project_conv (Conv2  (None, 14, 14, 112)  64512     ||
# || D)                                                          ||
# ||                                                             ||
# || block5a_project_bn (BatchNo  (None, 14, 14, 112)  448       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block5b_expand_conv (Conv2D  (None, 14, 14, 672)  75264     ||
# || )                                                           ||
# ||                                                             ||
# || block5b_expand_bn (BatchNor  (None, 14, 14, 672)  2688      ||
# || malization)                                                 ||
# ||                                                             ||
# || block5b_expand_activation (  (None, 14, 14, 672)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block5b_dwconv2 (DepthwiseC  (None, 14, 14, 672)  6048      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block5b_bn (BatchNormalizat  (None, 14, 14, 672)  2688      ||
# || ion)                                                        ||
# ||                                                             ||
# || block5b_activation (Activat  (None, 14, 14, 672)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block5b_se_squeeze (GlobalA  (None, 672)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block5b_se_reshape (Reshape  (None, 1, 1, 672)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block5b_se_reduce (Conv2D)  (None, 1, 1, 28)      18844     ||
# ||                                                             ||
# || block5b_se_expand (Conv2D)  (None, 1, 1, 672)     19488     ||
# ||                                                             ||
# || block5b_se_excite (Multiply  (None, 14, 14, 672)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block5b_project_conv (Conv2  (None, 14, 14, 112)  75264     ||
# || D)                                                          ||
# ||                                                             ||
# || block5b_project_bn (BatchNo  (None, 14, 14, 112)  448       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block5b_drop (Dropout)  (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block5b_add (Add)       (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block5c_expand_conv (Conv2D  (None, 14, 14, 672)  75264     ||
# || )                                                           ||
# ||                                                             ||
# || block5c_expand_bn (BatchNor  (None, 14, 14, 672)  2688      ||
# || malization)                                                 ||
# ||                                                             ||
# || block5c_expand_activation (  (None, 14, 14, 672)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block5c_dwconv2 (DepthwiseC  (None, 14, 14, 672)  6048      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block5c_bn (BatchNormalizat  (None, 14, 14, 672)  2688      ||
# || ion)                                                        ||
# ||                                                             ||
# || block5c_activation (Activat  (None, 14, 14, 672)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block5c_se_squeeze (GlobalA  (None, 672)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block5c_se_reshape (Reshape  (None, 1, 1, 672)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block5c_se_reduce (Conv2D)  (None, 1, 1, 28)      18844     ||
# ||                                                             ||
# || block5c_se_expand (Conv2D)  (None, 1, 1, 672)     19488     ||
# ||                                                             ||
# || block5c_se_excite (Multiply  (None, 14, 14, 672)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block5c_project_conv (Conv2  (None, 14, 14, 112)  75264     ||
# || D)                                                          ||
# ||                                                             ||
# || block5c_project_bn (BatchNo  (None, 14, 14, 112)  448       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block5c_drop (Dropout)  (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block5c_add (Add)       (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block5d_expand_conv (Conv2D  (None, 14, 14, 672)  75264     ||
# || )                                                           ||
# ||                                                             ||
# || block5d_expand_bn (BatchNor  (None, 14, 14, 672)  2688      ||
# || malization)                                                 ||
# ||                                                             ||
# || block5d_expand_activation (  (None, 14, 14, 672)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block5d_dwconv2 (DepthwiseC  (None, 14, 14, 672)  6048      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block5d_bn (BatchNormalizat  (None, 14, 14, 672)  2688      ||
# || ion)                                                        ||
# ||                                                             ||
# || block5d_activation (Activat  (None, 14, 14, 672)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block5d_se_squeeze (GlobalA  (None, 672)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block5d_se_reshape (Reshape  (None, 1, 1, 672)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block5d_se_reduce (Conv2D)  (None, 1, 1, 28)      18844     ||
# ||                                                             ||
# || block5d_se_expand (Conv2D)  (None, 1, 1, 672)     19488     ||
# ||                                                             ||
# || block5d_se_excite (Multiply  (None, 14, 14, 672)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block5d_project_conv (Conv2  (None, 14, 14, 112)  75264     ||
# || D)                                                          ||
# ||                                                             ||
# || block5d_project_bn (BatchNo  (None, 14, 14, 112)  448       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block5d_drop (Dropout)  (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block5d_add (Add)       (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block5e_expand_conv (Conv2D  (None, 14, 14, 672)  75264     ||
# || )                                                           ||
# ||                                                             ||
# || block5e_expand_bn (BatchNor  (None, 14, 14, 672)  2688      ||
# || malization)                                                 ||
# ||                                                             ||
# || block5e_expand_activation (  (None, 14, 14, 672)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block5e_dwconv2 (DepthwiseC  (None, 14, 14, 672)  6048      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block5e_bn (BatchNormalizat  (None, 14, 14, 672)  2688      ||
# || ion)                                                        ||
# ||                                                             ||
# || block5e_activation (Activat  (None, 14, 14, 672)  0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block5e_se_squeeze (GlobalA  (None, 672)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block5e_se_reshape (Reshape  (None, 1, 1, 672)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block5e_se_reduce (Conv2D)  (None, 1, 1, 28)      18844     ||
# ||                                                             ||
# || block5e_se_expand (Conv2D)  (None, 1, 1, 672)     19488     ||
# ||                                                             ||
# || block5e_se_excite (Multiply  (None, 14, 14, 672)  0         ||
# || )                                                           ||
# ||                                                             ||
# || block5e_project_conv (Conv2  (None, 14, 14, 112)  75264     ||
# || D)                                                          ||
# ||                                                             ||
# || block5e_project_bn (BatchNo  (None, 14, 14, 112)  448       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block5e_drop (Dropout)  (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block5e_add (Add)       (None, 14, 14, 112)       0         ||
# ||                                                             ||
# || block6a_expand_conv (Conv2D  (None, 14, 14, 672)  75264     ||
# || )                                                           ||
# ||                                                             ||
# || block6a_expand_bn (BatchNor  (None, 14, 14, 672)  2688      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6a_expand_activation (  (None, 14, 14, 672)  0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6a_dwconv2 (DepthwiseC  (None, 7, 7, 672)    6048      ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6a_bn (BatchNormalizat  (None, 7, 7, 672)    2688      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6a_activation (Activat  (None, 7, 7, 672)    0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6a_se_squeeze (GlobalA  (None, 672)          0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6a_se_reshape (Reshape  (None, 1, 1, 672)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block6a_se_reduce (Conv2D)  (None, 1, 1, 28)      18844     ||
# ||                                                             ||
# || block6a_se_expand (Conv2D)  (None, 1, 1, 672)     19488     ||
# ||                                                             ||
# || block6a_se_excite (Multiply  (None, 7, 7, 672)    0         ||
# || )                                                           ||
# ||                                                             ||
# || block6a_project_conv (Conv2  (None, 7, 7, 192)    129024    ||
# || D)                                                          ||
# ||                                                             ||
# || block6a_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6b_expand_conv (Conv2D  (None, 7, 7, 1152)   221184    ||
# || )                                                           ||
# ||                                                             ||
# || block6b_expand_bn (BatchNor  (None, 7, 7, 1152)   4608      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6b_expand_activation (  (None, 7, 7, 1152)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6b_dwconv2 (DepthwiseC  (None, 7, 7, 1152)   10368     ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6b_bn (BatchNormalizat  (None, 7, 7, 1152)   4608      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6b_activation (Activat  (None, 7, 7, 1152)   0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6b_se_squeeze (GlobalA  (None, 1152)         0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6b_se_reshape (Reshape  (None, 1, 1, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6b_se_reduce (Conv2D)  (None, 1, 1, 48)      55344     ||
# ||                                                             ||
# || block6b_se_expand (Conv2D)  (None, 1, 1, 1152)    56448     ||
# ||                                                             ||
# || block6b_se_excite (Multiply  (None, 7, 7, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6b_project_conv (Conv2  (None, 7, 7, 192)    221184    ||
# || D)                                                          ||
# ||                                                             ||
# || block6b_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6b_drop (Dropout)  (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6b_add (Add)       (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6c_expand_conv (Conv2D  (None, 7, 7, 1152)   221184    ||
# || )                                                           ||
# ||                                                             ||
# || block6c_expand_bn (BatchNor  (None, 7, 7, 1152)   4608      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6c_expand_activation (  (None, 7, 7, 1152)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6c_dwconv2 (DepthwiseC  (None, 7, 7, 1152)   10368     ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6c_bn (BatchNormalizat  (None, 7, 7, 1152)   4608      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6c_activation (Activat  (None, 7, 7, 1152)   0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6c_se_squeeze (GlobalA  (None, 1152)         0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6c_se_reshape (Reshape  (None, 1, 1, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6c_se_reduce (Conv2D)  (None, 1, 1, 48)      55344     ||
# ||                                                             ||
# || block6c_se_expand (Conv2D)  (None, 1, 1, 1152)    56448     ||
# ||                                                             ||
# || block6c_se_excite (Multiply  (None, 7, 7, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6c_project_conv (Conv2  (None, 7, 7, 192)    221184    ||
# || D)                                                          ||
# ||                                                             ||
# || block6c_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6c_drop (Dropout)  (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6c_add (Add)       (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6d_expand_conv (Conv2D  (None, 7, 7, 1152)   221184    ||
# || )                                                           ||
# ||                                                             ||
# || block6d_expand_bn (BatchNor  (None, 7, 7, 1152)   4608      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6d_expand_activation (  (None, 7, 7, 1152)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6d_dwconv2 (DepthwiseC  (None, 7, 7, 1152)   10368     ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6d_bn (BatchNormalizat  (None, 7, 7, 1152)   4608      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6d_activation (Activat  (None, 7, 7, 1152)   0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6d_se_squeeze (GlobalA  (None, 1152)         0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6d_se_reshape (Reshape  (None, 1, 1, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6d_se_reduce (Conv2D)  (None, 1, 1, 48)      55344     ||
# ||                                                             ||
# || block6d_se_expand (Conv2D)  (None, 1, 1, 1152)    56448     ||
# ||                                                             ||
# || block6d_se_excite (Multiply  (None, 7, 7, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6d_project_conv (Conv2  (None, 7, 7, 192)    221184    ||
# || D)                                                          ||
# ||                                                             ||
# || block6d_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6d_drop (Dropout)  (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6d_add (Add)       (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6e_expand_conv (Conv2D  (None, 7, 7, 1152)   221184    ||
# || )                                                           ||
# ||                                                             ||
# || block6e_expand_bn (BatchNor  (None, 7, 7, 1152)   4608      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6e_expand_activation (  (None, 7, 7, 1152)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6e_dwconv2 (DepthwiseC  (None, 7, 7, 1152)   10368     ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6e_bn (BatchNormalizat  (None, 7, 7, 1152)   4608      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6e_activation (Activat  (None, 7, 7, 1152)   0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6e_se_squeeze (GlobalA  (None, 1152)         0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6e_se_reshape (Reshape  (None, 1, 1, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6e_se_reduce (Conv2D)  (None, 1, 1, 48)      55344     ||
# ||                                                             ||
# || block6e_se_expand (Conv2D)  (None, 1, 1, 1152)    56448     ||
# ||                                                             ||
# || block6e_se_excite (Multiply  (None, 7, 7, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6e_project_conv (Conv2  (None, 7, 7, 192)    221184    ||
# || D)                                                          ||
# ||                                                             ||
# || block6e_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6e_drop (Dropout)  (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6e_add (Add)       (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6f_expand_conv (Conv2D  (None, 7, 7, 1152)   221184    ||
# || )                                                           ||
# ||                                                             ||
# || block6f_expand_bn (BatchNor  (None, 7, 7, 1152)   4608      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6f_expand_activation (  (None, 7, 7, 1152)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6f_dwconv2 (DepthwiseC  (None, 7, 7, 1152)   10368     ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6f_bn (BatchNormalizat  (None, 7, 7, 1152)   4608      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6f_activation (Activat  (None, 7, 7, 1152)   0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6f_se_squeeze (GlobalA  (None, 1152)         0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6f_se_reshape (Reshape  (None, 1, 1, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6f_se_reduce (Conv2D)  (None, 1, 1, 48)      55344     ||
# ||                                                             ||
# || block6f_se_expand (Conv2D)  (None, 1, 1, 1152)    56448     ||
# ||                                                             ||
# || block6f_se_excite (Multiply  (None, 7, 7, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6f_project_conv (Conv2  (None, 7, 7, 192)    221184    ||
# || D)                                                          ||
# ||                                                             ||
# || block6f_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6f_drop (Dropout)  (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6f_add (Add)       (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6g_expand_conv (Conv2D  (None, 7, 7, 1152)   221184    ||
# || )                                                           ||
# ||                                                             ||
# || block6g_expand_bn (BatchNor  (None, 7, 7, 1152)   4608      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6g_expand_activation (  (None, 7, 7, 1152)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6g_dwconv2 (DepthwiseC  (None, 7, 7, 1152)   10368     ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6g_bn (BatchNormalizat  (None, 7, 7, 1152)   4608      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6g_activation (Activat  (None, 7, 7, 1152)   0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6g_se_squeeze (GlobalA  (None, 1152)         0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6g_se_reshape (Reshape  (None, 1, 1, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6g_se_reduce (Conv2D)  (None, 1, 1, 48)      55344     ||
# ||                                                             ||
# || block6g_se_expand (Conv2D)  (None, 1, 1, 1152)    56448     ||
# ||                                                             ||
# || block6g_se_excite (Multiply  (None, 7, 7, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6g_project_conv (Conv2  (None, 7, 7, 192)    221184    ||
# || D)                                                          ||
# ||                                                             ||
# || block6g_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6g_drop (Dropout)  (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6g_add (Add)       (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6h_expand_conv (Conv2D  (None, 7, 7, 1152)   221184    ||
# || )                                                           ||
# ||                                                             ||
# || block6h_expand_bn (BatchNor  (None, 7, 7, 1152)   4608      ||
# || malization)                                                 ||
# ||                                                             ||
# || block6h_expand_activation (  (None, 7, 7, 1152)   0         ||
# || Activation)                                                 ||
# ||                                                             ||
# || block6h_dwconv2 (DepthwiseC  (None, 7, 7, 1152)   10368     ||
# || onv2D)                                                      ||
# ||                                                             ||
# || block6h_bn (BatchNormalizat  (None, 7, 7, 1152)   4608      ||
# || ion)                                                        ||
# ||                                                             ||
# || block6h_activation (Activat  (None, 7, 7, 1152)   0         ||
# || ion)                                                        ||
# ||                                                             ||
# || block6h_se_squeeze (GlobalA  (None, 1152)         0         ||
# || veragePooling2D)                                            ||
# ||                                                             ||
# || block6h_se_reshape (Reshape  (None, 1, 1, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6h_se_reduce (Conv2D)  (None, 1, 1, 48)      55344     ||
# ||                                                             ||
# || block6h_se_expand (Conv2D)  (None, 1, 1, 1152)    56448     ||
# ||                                                             ||
# || block6h_se_excite (Multiply  (None, 7, 7, 1152)   0         ||
# || )                                                           ||
# ||                                                             ||
# || block6h_project_conv (Conv2  (None, 7, 7, 192)    221184    ||
# || D)                                                          ||
# ||                                                             ||
# || block6h_project_bn (BatchNo  (None, 7, 7, 192)    768       ||
# || rmalization)                                                ||
# ||                                                             ||
# || block6h_drop (Dropout)  (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || block6h_add (Add)       (None, 7, 7, 192)         0         ||
# ||                                                             ||
# || top_conv (Conv2D)       (None, 7, 7, 1280)        245760    ||
# ||                                                             ||
# || top_bn (BatchNormalization)  (None, 7, 7, 1280)   5120      ||
# ||                                                             ||
# || top_activation (Activation)  (None, 7, 7, 1280)   0         ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_1 (Sequential)  (None, 2)                2562      |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || average_pooling2d_1 (Averag  (None, 1, 1, 1280)   0         ||
# || ePooling2D)                                                 ||
# ||                                                             ||
# || flatten_1 (Flatten)     (None, 1280)              0         ||
# ||                                                             ||
# || dense_1 (Dense)         (None, 2)                 2562      ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 5,921,904
# Trainable params: 2,592
# Non-trainable params: 5,919,312
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
from tensorflow import data, train, math, reduce_sum, cast, equal, argmax, \
float32, GradientTape, TensorSpec, function, int64

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
  def __init__(self, d_model, warmup_steps=277):
    super().__init__()
    self.initial_learning_rate = 0.00002

    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps

  def __call__(self, step):
    step = tf.cast(step, dtype=tf.float32)
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)

    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
#opt = Adam(LRScheduler(768))
#opt = Adam(learning_rate=0.001)
learning_rate = CustomSchedule(2)
opt = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.999,
                                     epsilon=1e-9)
loss_fn = tensorflow.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
plt.plot(learning_rate(tf.range(2770*2, dtype=tf.float32)))
plt.ylabel('Learning Rate')
plt.xlabel('Train Step')
# Out:
# Text(0.5, 0, 'Train Step')

# %%
#opt = Adam(learning_rate=0.0003)
#loss_fn = tensorflow.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
train_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()
val_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()
test_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()

# %%
from sklearn.metrics import confusion_matrix

# %%
if os.path.exists('./content/data/ckpt'):
    print(f'Weight Checkpoint directory already exists')
    # !ls -ld ./content/data/ckpt
else:
    print(f'Weight Checkpooint directory doesnt exists.. Creating it now..')
    os.mkdir('./content/data/ckpt')
    print(f'Weight Checkpoint directory successfully created')
    # !ls -ld ./content/data/ckpt

    
if os.path.exists('./content/data/saved_model'):
    print(f'Protobuf Checkpoint directory already exists')
    # !ls -ld ./content/data/saved_model
else:
    print(f'Protobuf Checkpoint directory doesnt exists.. Creating it now..')
    os.mkdir('./content/data/saved_model')
    print(f'Weight Checkpoint directory successfully created')
    # !ls -ld ./content/data/saved_model
# Out:
# Weight Checkpoint directory already exists
# drwxr-xr-x 2 root root 4096 Apr 23 04:17 ./content/data/ckpt
# Protobuf Checkpoint directory already exists
# drwxr-xr-x 2 root root 4096 Apr 23 03:42 ./content/data/saved_model

# %%
class Model_Train():
  def __init__(self, model, optimizer, loss_fn, epochs, batch_size, train_gen, valid_gen, test_gen, train_acc_metric, val_acc_metric, test_acc_metric):
    super().__init__()

    self.model = model
    self.optimizer = optimizer
    self.loss_fn = loss_fn
    self.epochs = epochs
    self.batch_size = batch_size
    self.train_generator = train_gen
    self.valid_generator = valid_gen
    self.test_generator = test_gen
    self.steps_train = len(train_gen)
    self.steps_valid = len(valid_gen)
    self.steps_test = len(test_gen)
    self.train_acc_metric = train_acc_metric
    self.val_acc_metric = val_acc_metric
    self.test_acc_metric = test_acc_metric
    self.train_history = {'loss': [], 'accuracy': [], 'f1': [], 'precision': [], 'recall': []}
    self.valid_history = {'loss': [], 'accuracy': [], 'f1': [], 'precision': [], 'recall': [], 'ckpt_name': []}


   

  @tensorflow.function
  def train_step(self, train_data, train_label):
    with tensorflow.GradientTape() as tape:
      output = self.model(train_data, training=True)
      loss_value = self.loss_fn(train_label, output)
    grads = tape.gradient(loss_value, self.model.trainable_weights)
    self.optimizer.apply_gradients(zip(grads, self.model.trainable_weights))
    self.train_acc_metric.update_state(train_label, output)
    return output, loss_value

  @tensorflow.function
  def test_step(self, validation_data, validation_label):
    val_output = self.model(validation_data, training=False)
    loss_value = self.loss_fn(validation_label, val_output)
    self.val_acc_metric.update_state(validation_label, val_output)
    return val_output, loss_value

  def getloss_accuracy(self, gen, batch_size, steps_per_epoch, df, train=False, valid=False):
    loss_epoch = 0
    n=0
    for step, (x_batch, y_batch) in enumerate(gen):
      if train:
        output, loss_value = self.train_step(x_batch, y_batch)
        ###new code below
        
        pred_labls = list(np.argmax(output.numpy(), axis=1))
        temp_df = pd.DataFrame({'orig_label': list(y_batch), 'pred_label': pred_labls})
        df = pd.concat([df, temp_df])
            

        ## newcode above
        
      else:
        output, loss_value = self.test_step(x_batch, y_batch)
        pred_labls = list(np.argmax(output.numpy(), axis=1))
        temp_df = pd.DataFrame({'orig_label': list(y_batch), 'pred_label': pred_labls})
        df = pd.concat([df, temp_df])
            
      loss_epoch += loss_value*x_batch.shape[0]
      #n = n+1
      #print("Training step ", n )
      if step >= (steps_per_epoch-1):
        if train:
          avg_epoch_loss = (loss_epoch/(len(train_df))).numpy()
          accuracy = self.train_acc_metric.result().numpy()
          self.train_acc_metric.reset_states()
          gen.on_epoch_end()
        else:
          if valid:
            avg_epoch_loss = (loss_epoch/(len(valid_df))).numpy()
            accuracy = self.val_acc_metric.result().numpy()
            self.val_acc_metric.reset_states()
          else:
            avg_epoch_loss = (loss_epoch/(len(test_df))).numpy()
            accuracy = self.val_acc_metric.result().numpy()
            self.val_acc_metric.reset_states()


        return df, avg_epoch_loss, accuracy

  def train_validate_loop(self):
    for epoch in range(self.epochs):
      start_time = time.time()
      histdf_train = pd.DataFrame({'orig_label': [], 'pred_label': []})
      histdf_val   = pd.DataFrame({'orig_label': [], 'pred_label': []})  

      df_train_cm, avg_epoch_train_loss, train_accuracy = self.getloss_accuracy(self.train_generator, self.batch_size, self.steps_train, histdf_train, train=True)
      df_val_cm, avg_epoch_val_loss, val_accuracy = self.getloss_accuracy(self.valid_generator, self.batch_size, self.steps_valid, histdf_val, train=False, valid=True)

    
      f1, precision, recall             = self.calc_rec_prec_f1(df_train_cm, train=True)
      f1_val, precision_val, recall_val = self.calc_rec_prec_f1(df_val_cm, train=False)


      print(f'Epoch : {epoch}, Train Loss: {avg_epoch_train_loss}, Train Accuracy: {train_accuracy}, Validation Loss: {avg_epoch_val_loss}, Validation Accuracy: {val_accuracy}')
      
      self.train_history['loss'].append(avg_epoch_train_loss)
      self.train_history['accuracy'].append(train_accuracy)
      self.train_history['f1'].append(f1)
      self.train_history['precision'].append(precision)
      self.train_history['recall'].append(recall)

      self.valid_history['loss'].append(avg_epoch_val_loss)
      self.valid_history['accuracy'].append(val_accuracy)
      self.valid_history['f1'].append(f1_val)
      self.valid_history['precision'].append(precision_val)
      self.valid_history['recall'].append(recall_val)

      ###New Code for early stopping#####
      la = self.valid_history['accuracy']
      if (len(la) > 4):
        if (((la[-1] <= la[-2]) and (la[-2] <= la[-3])) and ((la[-3] <= la[-4]) and (la[-4] <= la[-5]))):
          print("Validation accuracy has not improved over last 4 epochs, hence invoking early stopping and exiting training process")
          if len(self.valid_history['ckpt_name']) > 0:
            print('Loading Best weights..')
            self.model.load_weights(self.valid_history['ckpt_name'][-1])
            break
          else:
            print("Ouch !! seems like you dont have any checkpoints saved matching criteria specified in logic. Please excuse !")
            break
                        
      if ((la[-1] > 0.9) and (len(la) > 1)):
        if(la[-1] > max(la[0:-1])):
          self.save_checkpoint(la[-1])
      elif ((la[-1] > 0.9) and (len(la) == 1)):
        self.save_checkpoint(la[-1])





      #####New Cod for early stopping


    
      print(f'Time taken: {np.round((time.time() - start_time), 4)}')
    print(f'Training completed successfully. Loading best checkpoint weights ...')
    if len(self.valid_history['ckpt_name']) > 0:
      self.model.load_weights(self.valid_history['ckpt_name'][-1])
      print(f'Best checkpoint weights loaded : {self.valid_history["ckpt_name"][-1]}')
    else:
      print("Ouch !! seems like you dont have any checkpoints saved matching criteria specified in logic. Please excuse !")

      #draw graph depicting train and validation losses and accuracy + recall, f1
    return self.train_history, self.valid_history

  def save_checkpoint(self, acc):
    ckpt_name = './content/data/ckpt/' + 'ckpt' + '_' + str(acc) + '_acc.pt'
    #pb_name = './content/data/saved_model/' + 'ckpt' + '_' + str(acc) + '_acc'
    self.model.save_weights(ckpt_name)
    self.valid_history['ckpt_name'].append(ckpt_name)
    print(f'Saved Checkpoint : {ckpt_name}')
    #self.model.save(pb_name)
    #print(f'Saved model in protobuf format : {pb_name}')


  def get_test_accuracy(self):
    df = pd.DataFrame({'orig_label': [], 'pred_label': []})
    df_test, avg_test_loss, test_accuracy = self.getloss_accuracy(self.test_generator, self.batch_size, self.steps_test, df)
    return df_test, avg_test_loss, test_accuracy

  def calc_rec_prec_f1(self, df, train):
    print_string = "Training Confusion Matrix" if train else "Validation Confusion Matrix"
    print(print_string, "\n", confusion_matrix(df['orig_label'], df['pred_label']))
    tn, fp, fn, tp = confusion_matrix(df['orig_label'], df['pred_label']).ravel()
    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    f1 = 2*precision*recall/(precision+recall)
    return f1, precision, recall

  def predict_single(self,dcm_path, target_size=(224,224)):
    image_array = pydicom.dcmread(dcm_path).pixel_array
    image = Image.fromarray(image_array) #converts from array to PIL
    #image.thumbnail((224,224)) #resize image to 224,224
    image = image.resize((224,224))
    image_array = np.expand_dims(image, 0)
    image_array = image_array.astype(np.float32) # * (1.0/255.0)
    image_array = np.expand_dims(image_array, -1)
    output = self.model(image_array, training=False)
    pred_label = np.argmax(output.numpy())
    print(f'Predicted label for image supplied is : {classes[pred_label]}')
    return classes[pred_label]
    
  def pred_image_show(self,image_list):
    fig, subs = plt.subplots(3,3, figsize=(14,12))
    for i, sub in enumerate(subs.flatten()):
      print(f'Image path is {image_list[i][0]} and Original label is {classes[int(image_list[i][1])]}')
      pred_class = self.predict_single(image_list[i][0])
      image_array = pydicom.dcmread(image_list[i][0]).pixel_array
      sub.imshow(image_array, cmap='gray')
      sub.set_title(f'{pred_class}(Pred) : {classes[int(image_list[i][1])]}(Orig)')
            
  def plot_metrics(self):
    list = ['accuracy', 'loss', 'f1', 'recall', 'precision']
    for metrics in list:
      x = [i for i in range(len(self.train_history[metrics]))]
      y1 = self.train_history[metrics]
      y2 = self.valid_history[metrics]
      fig, ax = plt.subplots()
      ax.plot(x, y1, label="train_"+metrics)
      ax.plot(x, y2, label="valid_"+metrics)
      plt.suptitle(f'Plot showing {metrics} for Different Epoch Runs')
      ax.legend()
      plt.show()
## Save weights
## if current accuracy > 90 and current accuracy > max(list_accuracy) then create checkpoint and save weights. Also do a protobuf saved model
## store the saved checkpoint name in a list. This will make sure than checkpoints are stored in asecnding order.
## at the end of training , take the last element in checkpoint list and load and restore it. test accuracy should be checked using this chkpoint.

# %%
EPOCHS = 20
train_object = Model_Train(model, opt, loss_fn, EPOCHS, BATCH_SIZE, train_generator, valid_generator, test_generator,
             train_acc_metric, val_acc_metric, test_acc_metric
             )

# %%
train_object.__dict__
# Out:
# {'model': <__main__.EfficientNetV2B0_TL at 0x7f72a02708b0>,
#  'optimizer': <keras.optimizers.adam.Adam at 0x7f7228d4e760>,
#  'loss_fn': <keras.losses.SparseCategoricalCrossentropy at 0x7f7229195340>,
#  'epochs': 20,
#  'batch_size': 32,
#  'train_generator': <__main__.DCMDataFrameIterator at 0x7f7351d6d880>,
#  'valid_generator': <__main__.DCMDataFrameIterator at 0x7f7351d6d100>,
#  'test_generator': <__main__.DCMDataFrameIterator at 0x7f7351d6d0a0>,
#  'steps_train': 277,
#  'steps_valid': 70,
#  'steps_test': 87,
#  'train_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7f7229171e20>,
#  'val_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7f7228d4ec40>,
#  'test_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7f7228d48c10>,
#  'train_history': {'loss': [],
#   'accuracy': [],
#   'f1': [],
#   'precision': [],
#   'recall': []},
#  'valid_history': {'loss': [],
#   'accuracy': [],
#   'f1': [],
#   'precision': [],
#   'recall': [],
#   'ckpt_name': []}}

# %%
train_dict, val_dict = train_object.train_validate_loop()
# Out:
# Training Confusion Matrix
#  [[6203  319]
#  [1319  995]]
# Validation Confusion Matrix
#  [[1567   64]
#  [ 180  399]]
# Epoch : 0, Train Loss: 0.418716162443161, Train Accuracy: 0.8146219849586487, Validation Loss: 0.31751829385757446, Validation Accuracy: 0.8895927667617798
# Time taken: 140.292
# Training Confusion Matrix
#  [[6271  251]
#  [ 762 1552]]
# Validation Confusion Matrix
#  [[1586   45]
#  [ 168  411]]
# Epoch : 1, Train Loss: 0.306458979845047, Train Accuracy: 0.8853553533554077, Validation Loss: 0.27035287022590637, Validation Accuracy: 0.9036198854446411
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9036199_acc.pt
# Time taken: 105.9763
# Training Confusion Matrix
#  [[6277  248]
#  [ 649 1662]]
# Validation Confusion Matrix
#  [[1613   18]
#  [ 183  396]]
# Epoch : 2, Train Loss: 0.26809266209602356, Train Accuracy: 0.8984834551811218, Validation Loss: 0.24989502131938934, Validation Accuracy: 0.9090497493743896
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.90904975_acc.pt
# Time taken: 102.3693
# Training Confusion Matrix
#  [[6299  219]
#  [ 615 1703]]
# Validation Confusion Matrix
#  [[1597   34]
#  [ 135  444]]
# Epoch : 3, Train Loss: 0.2490881234407425, Train Accuracy: 0.9056134223937988, Validation Loss: 0.22222521901130676, Validation Accuracy: 0.9235293865203857
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9235294_acc.pt
# Time taken: 103.3343
# Training Confusion Matrix
#  [[6295  225]
#  [ 563 1753]]
# Validation Confusion Matrix
#  [[1615   16]
#  [ 167  412]]
# Epoch : 4, Train Loss: 0.23214316368103027, Train Accuracy: 0.9108193516731262, Validation Loss: 0.22118151187896729, Validation Accuracy: 0.9171945452690125
# Time taken: 101.6681
# Training Confusion Matrix
#  [[6326  196]
#  [ 534 1780]]
# Validation Confusion Matrix
#  [[1614   17]
#  [ 154  425]]
# Epoch : 5, Train Loss: 0.21897369623184204, Train Accuracy: 0.9173834323883057, Validation Loss: 0.21037708222866058, Validation Accuracy: 0.922624409198761
# Time taken: 100.7204
# Training Confusion Matrix
#  [[6315  211]
#  [ 493 1817]]
# Validation Confusion Matrix
#  [[1620   11]
#  [ 158  421]]
# Epoch : 6, Train Loss: 0.2080962359905243, Train Accuracy: 0.9203259348869324, Validation Loss: 0.20803651213645935, Validation Accuracy: 0.9235293865203857
# Time taken: 101.6552
# Training Confusion Matrix
#  [[6335  189]
#  [ 472 1840]]
# Validation Confusion Matrix
#  [[1619   12]
#  [ 141  438]]
# Epoch : 7, Train Loss: 0.19973404705524445, Train Accuracy: 0.9251924157142639, Validation Loss: 0.1982409507036209, Validation Accuracy: 0.9307692050933838
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9307692_acc.pt
# Time taken: 103.0423
# Training Confusion Matrix
#  [[6328  196]
#  [ 478 1834]]
# Validation Confusion Matrix
#  [[1615   16]
#  [ 129  450]]
# Epoch : 8, Train Loss: 0.2000480592250824, Train Accuracy: 0.9237211346626282, Validation Loss: 0.1857590675354004, Validation Accuracy: 0.9343891143798828
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9343891_acc.pt
# Time taken: 102.6742
# Training Confusion Matrix
#  [[6344  182]
#  [ 466 1844]]
# Validation Confusion Matrix
#  [[1613   18]
#  [ 122  457]]
# Epoch : 9, Train Loss: 0.1935037076473236, Train Accuracy: 0.9266636371612549, Validation Loss: 0.18017475306987762, Validation Accuracy: 0.9366515874862671
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9366516_acc.pt
# Time taken: 101.8816
# Training Confusion Matrix
#  [[6316  207]
#  [ 434 1879]]
# Validation Confusion Matrix
#  [[1618   13]
#  [ 122  457]]
# Epoch : 10, Train Loss: 0.18473047018051147, Train Accuracy: 0.9274558424949646, Validation Loss: 0.17671748995780945, Validation Accuracy: 0.9389140009880066
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.938914_acc.pt
# Time taken: 102.8583
# Training Confusion Matrix
#  [[6336  186]
#  [ 427 1887]]
# Validation Confusion Matrix
#  [[1619   12]
#  [ 133  446]]
# Epoch : 11, Train Loss: 0.18504440784454346, Train Accuracy: 0.9306247234344482, Validation Loss: 0.18054145574569702, Validation Accuracy: 0.9343891143798828
# Time taken: 101.4046
# Training Confusion Matrix
#  [[6340  178]
#  [ 417 1901]]
# Validation Confusion Matrix
#  [[1620   11]
#  [ 130  449]]
# Epoch : 12, Train Loss: 0.17814227938652039, Train Accuracy: 0.9326618313789368, Validation Loss: 0.1794576197862625, Validation Accuracy: 0.9361990690231323
# Time taken: 100.8763
# Training Confusion Matrix
#  [[6344  182]
#  [ 416 1894]]
# Validation Confusion Matrix
#  [[1616   15]
#  [ 114  465]]
# Epoch : 13, Train Loss: 0.1755724549293518, Train Accuracy: 0.9323223233222961, Validation Loss: 0.17187240719795227, Validation Accuracy: 0.9416289329528809
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.94162893_acc.pt
# Time taken: 102.0421
# Training Confusion Matrix
#  [[6339  179]
#  [ 409 1909]]
# Validation Confusion Matrix
#  [[1612   19]
#  [ 108  471]]
# Epoch : 14, Train Loss: 0.17855635285377502, Train Accuracy: 0.9334540367126465, Validation Loss: 0.16598480939865112, Validation Accuracy: 0.9425339102745056
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9425339_acc.pt
# Time taken: 101.8194
# Training Confusion Matrix
#  [[6345  172]
#  [ 396 1923]]
# Validation Confusion Matrix
#  [[1620   11]
#  [ 132  447]]
# Epoch : 15, Train Loss: 0.17349860072135925, Train Accuracy: 0.9357175230979919, Validation Loss: 0.180269256234169, Validation Accuracy: 0.9352940917015076
# Time taken: 101.3995
# Training Confusion Matrix
#  [[6341  179]
#  [ 385 1931]]
# Validation Confusion Matrix
#  [[1612   19]
#  [  98  481]]
# Epoch : 16, Train Loss: 0.1691853106021881, Train Accuracy: 0.936170220375061, Validation Loss: 0.16100944578647614, Validation Accuracy: 0.9470587968826294
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9470588_acc.pt
# Time taken: 102.9829
# Training Confusion Matrix
#  [[6358  162]
#  [ 370 1946]]
# Validation Confusion Matrix
#  [[1618   13]
#  [ 118  461]]
# Epoch : 17, Train Loss: 0.16447842121124268, Train Accuracy: 0.939791738986969, Validation Loss: 0.17151086032390594, Validation Accuracy: 0.9407239556312561
# Time taken: 101.9512
# Training Confusion Matrix
#  [[6361  170]
#  [ 379 1926]]
# Validation Confusion Matrix
#  [[1613   18]
#  [ 106  473]]
# Epoch : 18, Train Loss: 0.16237179934978485, Train Accuracy: 0.9378678202629089, Validation Loss: 0.16072571277618408, Validation Accuracy: 0.9438914060592651
# Time taken: 102.5409
# Training Confusion Matrix
#  [[6339  172]
#  [ 373 1952]]
# Validation Confusion Matrix
#  [[1617   14]
#  [ 117  462]]
# Epoch : 19, Train Loss: 0.16195915639400482, Train Accuracy: 0.938320517539978, Validation Loss: 0.16963903605937958, Validation Accuracy: 0.9407239556312561
# Time taken: 101.4016
# Training completed successfully. Loading best checkpoint weights ...
# Best checkpoint weights loaded : ./content/data/ckpt/ckpt_0.9470588_acc.pt

# %%
df, loss, accuracy = train_object.get_test_accuracy() #from df returned by function you can check which image has lables incorrectly predicted

# %%
accuracy
# Out:
# 0.94750184

# %%
confusion_matrix(df['orig_label'], df['pred_label'])
# Out:
# array([[2018,   21],
#        [ 124,  599]])

# %%
687/(687+36)
# Out:
# 0.950207468879668

# %%
train_object.predict_single(test_df.iloc[-2,0])
# Out:
# Predicted label for image supplied is : COVID
# 'COVID'

# %%
train_object.model.save_weights('./content/data/ckpt/model_best_weights')

# %%
with zipfile.ZipFile('./XRAY_resnet50_model_best_weights.zip', 'w') as myzip:
    myzip.write('./content/data/ckpt/checkpoint')
    myzip.write('./content/data/ckpt/model_best_weights.data-00000-of-00001')
    #myzip.write('./content/data/ckpt/model_best_weights.data-00001-of-00002')
    myzip.write('./content/data/ckpt/model_best_weights.index')

# %%
random_9_test = random.sample(list(test_df.values), 9)
random_9_test, len(random_9_test)
# Out:
# ([array(['./content/data/DCM/NON_COVID/Normal-5172.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-1083.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-1205.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-2867.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-2826.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-3185.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-347.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-1384.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-1863.dcm', '0'], dtype=object)],
#  9)

# %%
random_9_test[0][0], random_9_test[0][1]
# Out:
# ('./content/data/DCM/NON_COVID/Normal-5172.dcm', '0')

# %%
train_object.pred_image_show(random_9_test)
# Out:
# Image path is ./content/data/DCM/NON_COVID/Normal-5172.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/COVID/COVID-1083.dcm and Original label is COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/COVID/COVID-1205.dcm and Original label is COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/COVID/COVID-2867.dcm and Original label is COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/COVID/COVID-2826.dcm and Original label is COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-3185.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/COVID/COVID-347.dcm and Original label is COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/COVID/COVID-1384.dcm and Original label is COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-1863.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID

# %%
train_object.plot_metrics()

# %%
#!cp ./*model_best_weights.zip ./gdrive/MyDrive/Manning_Projects/
