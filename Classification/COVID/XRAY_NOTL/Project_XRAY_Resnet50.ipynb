# %% [markdown]
# ## Milestone 1.1

# %%
# !nvidia-smi
# Out:
# Mon Apr 10 04:16:23 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
# Out:
# Your runtime has 13.6 gigabytes of available RAM

# %%
import requests
import pickle
import zipfile
import time
import os
#from google.colab import drive
import random
import glob
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy import asarray
from PIL.ImageStat import Stat
# !pip install pydicom
import pydicom
# Package for converting PNG Files to DICOM(.dcm ) format
# !pip install simpleitk
import SimpleITK as sitk
from sklearn.model_selection import train_test_split
from PIL import Image
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import DataFrameIterator
#from keras_preprocessing.image.dataframe_iterator import DataFrameIterator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Conv2D, AveragePooling2D, Flatten, Dense, Activation, MaxPool2D, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import sparse_categorical_crossentropy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydicom
#   Downloading pydicom-2.3.1-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 49.1 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-2.3.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting simpleitk
#   Downloading SimpleITK-2.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 MB 15.3 MB/s eta 0:00:00
# Installing collected packages: simpleitk
# Successfully installed simpleitk-2.2.1

# %%
data_path = './content'
archive_path = data_path + '/data/'
if os.path.exists(archive_path):
  print(f"{archive_path} directory exists.")
else:
  print(f"Did not find {archive_path} directory, creating one...")
  os.mkdir('./content')

  os.mkdir(archive_path)
  if os.path.exists(archive_path):
    print(f'{archive_path} created successfully')
# Out:
# Did not find ./content/data/ directory, creating one...
# ./content/data/ created successfully

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !mv /content/gdrive/MyDrive/Manning_Projects/archive\ \(2\).zip /content/gdrive/MyDrive/Manning_Projects/covid_data.zip
# !ls /content/gdrive/MyDrive/Manning_Projects/
# Out:
# mv: cannot stat '/content/gdrive/MyDrive/Manning_Projects/archive (2).zip': No such file or directory
# covid_data.zip		Project_XRAY_Resnet18.ipynb
# model_best_weights.zip	Project_XRAY_Resnet50.ipynb

# %%
DRIVE_PATH = '/content/gdrive/MyDrive/Manning_Projects/'
ARCHIVE_ZIP_FILE = DRIVE_PATH + 'covid_data.zip'
ARCHIVE_ZIP_FILE
# Out:
# '/content/gdrive/MyDrive/Manning_Projects/covid_data.zip'

# %%
# !cp {ARCHIVE_ZIP_FILE} ./content/data/

# %%
archive_file =  archive_path + 'covid_data.zip'

size = os.path.getsize(archive_file)
  
print(f'Size of the file is {size/1024} MegaBytes.')
# Out:
# Size of the file is 796903.357421875 MegaBytes.

# %%
with zipfile.ZipFile(archive_file, "r") as zip_ref:
  print("Unzipping archive") 
  zip_ref.extractall(archive_path)
# Out:
# Unzipping archive

# %%
# !rm -rf ./content/data/COVID-19_Radiography_Dataset/Lung_Opacity

# %%
# !rm -rf ./content/data/COVID-19_Radiography_Dataset/Viral\ Pneumonia

# %%
COVID_IMAGE_PATH = './content/data/COVID-19_Radiography_Dataset/COVID/images'
NON_COVID_IMAGE_PATH = './content/data/COVID-19_Radiography_Dataset/Normal/images'

# %%
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
walk_through_dir(COVID_IMAGE_PATH)
# Out:
# There are 0 directories and 3616 images in './content/data/COVID-19_Radiography_Dataset/COVID/images'.

# %%
walk_through_dir(NON_COVID_IMAGE_PATH)
# Out:
# There are 0 directories and 10192 images in './content/data/COVID-19_Radiography_Dataset/Normal/images'.

# %%
random.seed(42)

COVID_IMAGE_PATH_LIST = glob.glob(COVID_IMAGE_PATH + "/*.png")
len(COVID_IMAGE_PATH_LIST), type(COVID_IMAGE_PATH_LIST)
# Out:
# (3616, list)

# %%
NON_COVID_IMAGE_PATH_LIST = glob.glob(NON_COVID_IMAGE_PATH + "/*.png")
len(NON_COVID_IMAGE_PATH_LIST), type(NON_COVID_IMAGE_PATH_LIST)
# Out:
# (10192, list)

# %%
random_image_cov = random.choice(COVID_IMAGE_PATH_LIST)
cov_pic = Image.open(random_image_cov).convert('L')
cov_pic.show()
# Out:
# <PIL.Image.Image image mode=L size=299x299 at 0x7FC5C2B1FD00>

# %%
random_image_ncov = random.choice(NON_COVID_IMAGE_PATH_LIST)
ncov_pic = Image.open(random_image_ncov).convert('L')
ncov_pic.show()
type(ncov_pic)
# Out:
# <PIL.Image.Image image mode=L size=299x299 at 0x7FC6588C6640>
# PIL.Image.Image

# %%
def image_show(image_list, label):
  fig, subs = plt.subplots(3,3, figsize=(16,12))
  for i, sub in enumerate(subs.flatten()):
    #image_path = os.path.normpath(image[i])
    print(f'Image path is {image_list[i]} and label is {label}')
    img = Image.open(image_list[i])
    img.thumbnail((224,224))
    sub.imshow(img, cmap='gray')
    #sub.axis("off")
    print(f'Size of displayed image is {img.size}')
    sub.set_title(label)

# %%
random.seed(3)
ll_d_c =  []
for i in range(9):
  im = random.choice(COVID_IMAGE_PATH_LIST)
  ll_d_c.append(im)
print(ll_d_c, len(ll_d_c))

ll_d_nc = []
for i in range(9):
  im = random.choice(NON_COVID_IMAGE_PATH_LIST)
  ll_d_nc.append(im)

print(ll_d_nc, len(ll_d_nc))
# Out:
# ['./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1428.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-388.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1689.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2569.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1543.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2453.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2346.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2091.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2684.png'] 9
# ['./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-7549.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2936.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2779.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6907.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-9631.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5098.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-4226.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-1847.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5501.png'] 9

# %%
image_show(ll_d_c, 'COVID')
# Out:
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1428.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-388.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1689.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2569.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-1543.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2453.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2346.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2091.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2684.png and label is COVID
# Size of displayed image is (224, 224)

# %%
image_show(ll_d_nc, 'NON-COVID')
# Out:
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-7549.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2936.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2779.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6907.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-9631.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5098.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-4226.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-1847.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-5501.png and label is NON-COVID
# Size of displayed image is (224, 224)

# %%
random_image = random.choice(COVID_IMAGE_PATH_LIST)
random_image_gs = Image.open(random_image).convert('L')
shape= random_image_gs.size
img= np.reshape(random_image_gs, (-1, *shape, 1))
img.shape
# Out:
# (1, 299, 299, 1)

# %%
#def img_resize_save(img_path_list):
#  for i in range(len(img_path_list)):
#    temp_img = Image.open(img_path_list[i])
#    temp_img.thumbnail((224,224))
#    temp_img.save(img_path_list[i])
#  print('All images in supplied list resized to (224,224)')

#Originally I was under impression that all files have to be resized to 224,224 and then saved to disk. This is mentioned as a separate task.
#Hence, the logical deduction

# %%
df = pd.DataFrame({'Class': [len(NON_COVID_IMAGE_PATH_LIST), len(COVID_IMAGE_PATH_LIST)]})

# %%
total_class = df.Class.sum()
total_class
# Out:
# 13808

# %%
df['per_distr'] = df['Class'].apply(lambda x: x/total_class)
df.index = ['Non_Covid', 'Covid']

# %%
df.Class.plot(kind="bar", figsize=(8,6))
plt.ylabel("Number of Images")
plt.xlabel("Image Class")
plt.title("Distribution of Covid/Non-Covid Images")
plt.show()

# %%
list_arr = []
for pic in COVID_IMAGE_PATH_LIST:
  pic_np = np.array(Image.open(pic).convert('L'))
  pic_np = pic_np.reshape(299,299,1)
  list_arr.append(pic_np)

# %%
len(list_arr)
# Out:
# 3616

# %%
covid_arr = np.array(list_arr)

# %%
covid_arr.shape
# Out:
# (3616, 299, 299, 1)

# %%
np.mean(covid_arr), np.min(covid_arr), np.max(covid_arr), np.std(covid_arr)
# Out:
# (139.52120961679765, 0, 255, 61.90712697550049)

# %%
# Flatten the image data into a 1D array
pixel_values = covid_arr.flatten()

pixel_values.shape
# Out:
# (323274016,)

# %%
# Plot a histogram of the pixel values
plt.hist(pixel_values, bins=50)
plt.suptitle("Distribution of pixel values for Covid Image Data")
plt.show()

# %%
list_arr_nc = []
for pic in NON_COVID_IMAGE_PATH_LIST:
  pic_np_nc = np.array(Image.open(pic).convert('L'))
  pic_np_nc = pic_np_nc.reshape(299,299,1)
  list_arr_nc.append(pic_np_nc)
len(list_arr_nc)
# Out:
# 10192

# %%
covid_arr_nc = np.array(list_arr_nc)
covid_arr_nc.shape
# Out:
# (10192, 299, 299, 1)

# %%
np.mean(covid_arr_nc), np.max(covid_arr_nc), np.mean(covid_arr_nc), np.std(covid_arr_nc)
# Out:
# (129.38979982014257, 255, 129.38979982014257, 66.21686464627359)

# %%
# Flatten the image data into a 1D array
pixel_values_nc = covid_arr_nc.flatten()
pixel_values_nc.shape
# Out:
# (911174992,)

# %%
# Plot a histogram of the pixel values
fig, subs = plt.subplots(1,2, figsize=(24,6))
for i, sub in enumerate(subs.flatten()):
  if i==0:
    sub.hist(pixel_values_nc, bins=50)
    sub.set_title("Distribution of pixel values for Non-Covid Image Data")
  else:
    sub.hist(pixel_values, bins=50)
    sub.set_title("Distribution of pixel values for Covid Image Data")

# %% [markdown]
# ## Observation
#
# It can be seen from above two histograms that pixel intensity for covid data is more peaked(kurtosis is high) than for non-covid images.
#
# This confirms with fact that X-Ray images for covid infected patients show white patches in chest X-Ray Images.

# %%
#Lets do simple check on whether the pixel data that we get from converted .dcm files is same what we get from original png image
image = COVID_IMAGE_PATH_LIST[0]
im1 = Image.open(image).convert('L')
im1= np.array(im1)
img= sitk.GetImageFromArray(im1)
sitk.WriteImage(img,'template.dcm')

# %%
fig, subs = plt.subplots(1,2, figsize=(12,6))
for i, sub in enumerate(subs.flatten()):
  if i==0:
    #ds = pydicom.dcmread('template.dcm')
    # Load the DICOM file
    ds = pydicom.dcmread('template.dcm')
    # Access the image data
    image_d = ds.pixel_array
    print(type(image_d))
    sub.imshow(image_d, cmap='gray')
    sub.set_title("Image data from .dcm file")
  else:
    sub.imshow(im1, cmap='gray')
    sub.set_title("Image data from original png file")
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## It does looks like the data from both sources are one and same.
# ## STATUS : VERIFIED

# %% [markdown]
# ## Convert all the PNG Files to DICOM (.dcm) Format

# %%
DCM_FILE_PATH = './content/data/DCM/'
COVID_DCM_FILE_PATH = './content/data/DCM/COVID/'
NON_COVID_DCM_FILE_PATH = './content/data/DCM/NON_COVID/'
if os.path.exists(DCM_FILE_PATH):
  print(f"{DCM_FILE_PATH} directory exists.")
  if os.path.exists(COVID_DCM_FILE_PATH):
    print(f'{COVID_DCM_FILE_PATH} directory exists')
  else:
    print(f'Ok... looks like {COVID_DCM_FILE_PATH} does not exists. Let us make one')
    os.mkdir(COVID_DCM_FILE_PATH)
    print(f'{COVID_DCM_FILE_PATH} directory created successfully')
  if os.path.exists(NON_COVID_DCM_FILE_PATH):
    print(f'{NON_COVID_DCM_FILE_PATH} directory exists')
  else:
    print(f'Ok... looks like {NON_COVID_DCM_FILE_PATH} does not exists. Let us make one')
    os.mkdir(NON_COVID_DCM_FILE_PATH)
    print(f'{NON_COVID_DCM_FILE_PATH} directory created successfully')
else:
  print(f'Looks like there is no directory structure below /content/data.. Lets create required directory structures')
  print(f'Creating {DCM_FILE_PATH} directory path first')
  os.mkdir(DCM_FILE_PATH)
  print(f'{DCM_FILE_PATH} directory created successfully')

  print(f'Creating {COVID_DCM_FILE_PATH} directory path')
  os.mkdir(COVID_DCM_FILE_PATH)
  print(f'{COVID_DCM_FILE_PATH} directory created successfully')

  print(f'Creating {NON_COVID_DCM_FILE_PATH} directory path')
  os.mkdir(NON_COVID_DCM_FILE_PATH)
  print(f'{NON_COVID_DCM_FILE_PATH} directory created successfully')
# Out:
# Looks like there is no directory structure below /content/data.. Lets create required directory structures
# Creating ./content/data/DCM/ directory path first
# ./content/data/DCM/ directory created successfully
# Creating ./content/data/DCM/COVID/ directory path
# ./content/data/DCM/COVID/ directory created successfully
# Creating ./content/data/DCM/NON_COVID/ directory path
# ./content/data/DCM/NON_COVID/ directory created successfully

# %%
def pngtodcm(image_list, COVID, l_i):
  print(f'COVID variable is set to {COVID}')
  list_im = []
  list_im = l_i

  for png_image in image_list:
    png_im_arr = np.array(Image.open(png_image).convert('L'))
    dcm_im_arr = sitk.GetImageFromArray(png_im_arr)
    if COVID:
      SAVE_PATH = COVID_DCM_FILE_PATH
      list_im = list_im_c
    else:
      SAVE_PATH = NON_COVID_DCM_FILE_PATH
      list_im = list_im_nc
    FILENAME = png_image.split("/")[-1].split(".")[0]
    DCM_FILENAME = SAVE_PATH + FILENAME + '.dcm'
    sitk.WriteImage(dcm_im_arr, DCM_FILENAME)
    print(f'Successfully converted and saved {DCM_FILENAME}')
    list_im.append(DCM_FILENAME)

# %%
list_im_c = []
pngtodcm(COVID_IMAGE_PATH_LIST, True, list_im_c)
# Out:
# COVID variable is set to True
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1198.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-701.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2686.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1802.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-587.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2109.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2541.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1811.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-800.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2316.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-14.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1545.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2254.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3051.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1977.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-143.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-351.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-137.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3227.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1875.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2036.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3394.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-948.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2405.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1640.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2958.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2578.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-236.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-199.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3031.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-13.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3096.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3489.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2713.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-23.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2596.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-239.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-722.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2313.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-36.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2894.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1131.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1798.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2172.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3591.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-745.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-767.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2040.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2663.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-278.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-35.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3099.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2158.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2727.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1402.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2415.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1230.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-363.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3161.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-588.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2106.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3156.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2883.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1300.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3495.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1808.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1858.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-41.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1412.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2335.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2935.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-651.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2735.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2218.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3446.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1529.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3560.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2634.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-510.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3308.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2753.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-237.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-775.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-169.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1126.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1904.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1019.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-179.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1964.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1514.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1075.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1290.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2740.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2359.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2671.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2198.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1925.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1753.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-381.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2154.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2319.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1659.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-544.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-911.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1128.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2508.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1162.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-193.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2844.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2144.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-274.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1989.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1507.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2877.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2034.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1085.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2051.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1042.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-791.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1734.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3228.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3200.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1478.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2353.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2829.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1138.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1600.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1577.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-667.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3480.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-34.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-223.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-624.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-819.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2373.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1031.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3466.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2437.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2690.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-739.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-750.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3108.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3373.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-534.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1036.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1002.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3236.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1806.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-117.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-481.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-610.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3539.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1116.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1061.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1179.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2676.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-413.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1676.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2377.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-11.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-509.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-31.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-264.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1236.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1007.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1764.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2558.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-688.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3573.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3268.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-467.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2646.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1313.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2776.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1285.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1338.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-560.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2732.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1383.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1793.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-420.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-400.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2669.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-607.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2210.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-427.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1501.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3193.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2650.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2114.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1498.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3554.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-893.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-446.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2527.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3362.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3280.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2863.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-452.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-884.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1275.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3533.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2293.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2853.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1911.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1915.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1890.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-10.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2251.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2195.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3301.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1903.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2110.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2607.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3291.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-773.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2730.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-256.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-284.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3175.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1489.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-375.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-154.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3081.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1044.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1536.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1599.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2217.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3163.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-73.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2831.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2107.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2879.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3072.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-794.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2839.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-754.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3552.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1930.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1326.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2643.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2038.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1865.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-597.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2309.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2252.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2687.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1123.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1748.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1845.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3075.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3020.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1474.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3142.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-572.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3581.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-825.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1513.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3247.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1605.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-105.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-63.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3067.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3418.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3014.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3337.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2827.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-967.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2910.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1367.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3603.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-631.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-211.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2013.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2443.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3350.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2115.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1619.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2236.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2681.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-708.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-938.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-582.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1742.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3170.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1098.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-337.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1122.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-165.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1953.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-424.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1398.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1548.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3091.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1408.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1636.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-68.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3585.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1586.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1638.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3207.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1050.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3222.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-235.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2171.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1542.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2502.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-27.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1288.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2141.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2982.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-686.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2666.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1975.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2922.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-639.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-331.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-330.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2033.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2630.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1328.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1951.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1089.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3154.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3323.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-881.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2928.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-329.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2623.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2550.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1510.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3532.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-724.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-428.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3284.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1114.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1273.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-577.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1744.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1003.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1418.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1615.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1736.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-867.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1363.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1084.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2365.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1672.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1278.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1816.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1441.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2908.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1015.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2702.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3493.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3347.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1341.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2893.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1301.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1022.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1848.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-732.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1504.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-539.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-606.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2267.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3015.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-662.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3098.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2315.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2757.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2823.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1271.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-475.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1780.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1626.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2847.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2544.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2797.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1492.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-550.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3376.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2436.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-352.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2400.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-302.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3348.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1099.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-565.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-523.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3104.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2973.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-482.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3039.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-965.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1387.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2533.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3106.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-751.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3485.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2068.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2017.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2125.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-749.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2843.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2764.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2500.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-897.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3306.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1682.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3027.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-914.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2487.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3608.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2160.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-930.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1460.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2450.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-301.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-707.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3557.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-632.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3148.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1353.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1818.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2917.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2728.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2434.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-575.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-125.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1430.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-206.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2817.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1317.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2332.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1070.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-716.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3482.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1662.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2718.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3084.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-283.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2096.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2413.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1047.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2147.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1695.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1310.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-681.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3569.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1078.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-637.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-989.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-18.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-793.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2204.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2911.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3276.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3264.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2419.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1303.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1602.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2341.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2874.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-230.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2570.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3265.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2100.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-487.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3413.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-384.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1870.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2256.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2018.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1164.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-640.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-216.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3519.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1691.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1234.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2778.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1721.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-759.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-634.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1170.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3380.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3488.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3204.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2378.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1016.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2136.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3548.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-998.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2156.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3076.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1074.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1745.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3085.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2227.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2403.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1534.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2350.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2399.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2984.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2870.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1643.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3287.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2019.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2027.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3116.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3071.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2265.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3496.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3279.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2008.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2187.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-191.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-525.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-22.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1733.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2546.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1503.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1454.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3537.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1551.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-709.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1727.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-659.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3052.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1524.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3567.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-80.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-766.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2199.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2569.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1538.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1293.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2064.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2226.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-642.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1201.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2584.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2372.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1900.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1465.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1601.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2593.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-260.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1101.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-356.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-958.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2302.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3057.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1243.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-613.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2577.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-332.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-842.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-815.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-173.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-457.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-827.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2127.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3179.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1080.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-40.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2986.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3321.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2901.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1787.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2134.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2284.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-661.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3216.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1697.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1397.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-48.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2804.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3145.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-353.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-345.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-212.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-387.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1205.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2716.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2512.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1941.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3443.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-618.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1488.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-502.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1021.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2963.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3258.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2211.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-285.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1730.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-671.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-399.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-423.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1621.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2899.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1587.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-641.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-810.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-180.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-324.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2447.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3529.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2699.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-976.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2723.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-872.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2056.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1584.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1755.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2903.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1789.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1229.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-440.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-24.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-769.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-882.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-900.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-188.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1706.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1451.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2744.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-830.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-787.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3235.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1604.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2393.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1644.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2345.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-802.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2807.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1323.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1281.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1137.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-828.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-7.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-316.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-845.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1805.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2833.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3144.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2907.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2482.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1307.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2760.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1121.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-574.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2765.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1526.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2228.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3439.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1087.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2813.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3.dcm
# ...
# Successfully converted and saved ./content/data/DCM/COVID/COVID-5.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1360.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1373.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3283.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3421.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2679.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1013.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3398.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1486.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2456.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-207.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-15.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3183.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1817.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2358.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-238.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-566.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2808.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2242.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3352.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-728.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1724.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3357.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3388.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1950.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2446.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-626.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2182.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1140.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2376.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3221.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1982.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3190.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-51.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2396.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2601.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1927.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-109.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-325.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2143.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1648.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2483.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-546.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2773.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3125.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3097.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3292.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2766.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1009.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1609.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1563.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3367.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2580.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2012.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2709.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2323.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3499.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1779.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2582.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3614.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1887.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-511.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1090.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-864.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1382.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3320.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1663.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1983.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2216.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2206.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2974.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1467.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2991.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-25.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1958.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2801.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1421.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1228.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-476.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1350.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3048.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1335.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-556.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-776.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-132.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2140.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-144.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2979.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1506.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1193.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1426.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3002.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-862.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2953.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-848.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-135.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2193.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-839.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-856.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3094.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2840.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3504.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1109.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-184.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1557.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2049.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3087.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1523.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-167.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1836.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-445.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1399.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3592.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3393.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2146.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2526.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3251.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-547.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1803.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1245.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1647.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2479.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1856.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2555.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-112.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-385.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1134.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2331.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2867.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1246.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3274.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3056.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2587.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1045.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-226.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-90.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2086.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-552.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3342.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3334.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1567.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2135.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-789.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1308.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2045.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1420.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3012.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-298.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-689.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-504.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-333.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-581.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2639.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-9.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-853.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1533.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3477.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3238.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2599.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1561.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1986.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1948.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-449.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1522.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1041.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1048.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-140.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1196.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-493.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2837.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1726.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-370.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2799.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2940.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2113.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3214.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2458.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2865.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-992.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-847.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1711.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1280.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2411.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3580.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1102.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-619.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3540.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3064.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-221.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2463.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2662.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3435.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-141.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-145.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1079.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1106.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1238.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3101.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1596.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1345.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2192.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-444.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3042.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1992.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3598.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2571.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-970.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2221.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1842.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3111.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-674.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2448.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-282.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2791.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3167.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-240.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-241.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-746.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-61.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2902.dcm

# %%
len(list_im_c)
# Out:
# 3616

# %%
list_im_nc = []
pngtodcm(NON_COVID_IMAGE_PATH_LIST, False, list_im_nc)
# Out:
# Streaming output truncated to the last 5000 lines.
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6691.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1626.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3743.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8981.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1243.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4177.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-235.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4989.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2164.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9146.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7263.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6705.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7127.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5585.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-449.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6537.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7186.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5842.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1001.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-702.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8052.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9533.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4112.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8102.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5995.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9931.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1663.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1660.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7656.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-395.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-794.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2071.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4337.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8036.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3847.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3629.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4820.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4575.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6834.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1790.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6342.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7006.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-887.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1313.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3147.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5322.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1248.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-786.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1043.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9724.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1131.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2371.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-742.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5683.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8308.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4758.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7793.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8107.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-648.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4813.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-186.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1480.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6771.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2622.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2943.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2992.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6036.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5143.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-135.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7560.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6386.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4427.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7113.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7626.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7509.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6712.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1658.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9726.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3985.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9444.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9952.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-661.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9657.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9175.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7429.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2144.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4081.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8176.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-511.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-179.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9907.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6353.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7361.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3077.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5991.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9467.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5278.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6267.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8493.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6096.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8242.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2548.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-401.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6930.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9574.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-318.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8429.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9717.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-937.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9134.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3567.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8443.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1503.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1098.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4845.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1603.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7069.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-904.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4944.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8383.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8164.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1985.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2367.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4339.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2034.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4616.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8416.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4014.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9440.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2131.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7408.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9025.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5155.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9417.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9060.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2028.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3175.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6231.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7884.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3951.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7642.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7762.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8699.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6662.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3607.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-243.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7650.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2891.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-864.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2026.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8599.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4456.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6806.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-520.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8811.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9830.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3677.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5740.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4645.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4080.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-63.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-230.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6134.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6383.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8619.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4998.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9057.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7207.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3760.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3484.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2946.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2690.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4412.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3199.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6364.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3154.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2195.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9947.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8418.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-429.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8328.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8059.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9664.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3166.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5226.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1312.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7569.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7253.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6845.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4088.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-373.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1943.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-560.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9865.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1022.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3700.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4141.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10144.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9402.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1785.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-847.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7116.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5261.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4003.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7811.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4465.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5397.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-78.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3611.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2656.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3020.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5790.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5970.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8994.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2306.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-167.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9995.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6698.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5198.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9520.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6951.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8395.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3300.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7739.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3523.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4731.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2019.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9300.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3269.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8675.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1450.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5883.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7460.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9058.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9683.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-147.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4255.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5444.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2838.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5724.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8859.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7938.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-316.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5545.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5856.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10035.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3577.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7264.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10021.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8113.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2369.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8905.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8777.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9416.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9529.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6927.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7615.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2781.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6188.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7059.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9757.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5153.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8657.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3145.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-359.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7588.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1211.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9374.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9442.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4805.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5791.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5930.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7976.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1895.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2041.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1291.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9741.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4911.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6374.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6198.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-614.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2146.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4789.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7837.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1511.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3133.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3755.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5263.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1956.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8402.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6120.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10093.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1941.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5414.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7566.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6653.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1057.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7071.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6699.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4381.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5424.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1024.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8128.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6512.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7990.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5024.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2083.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8400.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3036.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7518.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3328.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9233.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-29.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9922.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8211.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4194.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7980.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9336.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4919.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5487.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2676.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8771.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9687.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-877.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1912.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2604.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2350.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8474.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8706.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3599.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2180.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4612.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7779.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4489.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4925.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9367.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7744.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2995.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3375.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5341.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6101.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8928.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-834.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4342.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1070.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3277.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3204.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2846.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5821.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5505.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6022.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7218.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8105.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2698.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4823.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2794.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1543.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1372.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10158.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7323.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1795.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7530.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5538.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1558.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8284.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7395.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4587.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8241.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3969.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-354.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3447.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1485.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-191.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2227.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6105.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8710.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4994.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6989.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3319.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2831.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7133.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9477.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2633.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1564.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3473.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4004.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3660.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-364.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3614.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8807.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9141.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9231.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1172.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3778.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9837.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8399.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8751.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6968.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8277.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1210.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9074.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9974.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-728.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1195.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4245.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6128.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4466.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3239.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5784.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5689.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1201.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8332.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9191.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-304.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8368.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4875.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5549.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5405.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4408.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1763.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9036.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10159.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9534.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6700.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5594.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3842.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5547.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4523.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5361.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1508.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5779.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3257.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6207.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1599.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-867.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8904.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1584.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8725.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5551.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6515.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1876.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8559.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9488.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3928.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4821.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2201.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7832.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5344.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7342.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-660.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9241.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7986.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-526.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4761.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6097.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8591.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2784.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2625.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-596.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5910.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7103.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9260.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3819.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1952.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9301.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9285.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5813.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7192.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4360.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1555.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-853.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7147.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4871.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7746.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6963.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7510.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9779.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4294.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7475.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-642.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3376.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4932.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7233.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8398.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1873.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7369.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2932.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5519.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9613.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5757.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6567.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7300.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4317.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7175.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6504.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9764.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9150.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5649.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1492.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4257.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6092.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5946.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1412.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-490.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2977.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2475.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6606.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6139.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2845.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4890.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6664.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-173.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2711.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7695.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-924.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2956.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3717.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2878.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-592.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7748.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10109.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4026.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3134.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5314.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8669.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3213.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4745.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5269.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2172.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6500.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5923.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3295.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2626.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7306.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8041.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6319.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4281.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-883.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9441.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1661.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4937.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2574.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2349.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8737.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1532.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-54.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5406.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-982.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-365.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1692.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2426.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5070.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-509.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5037.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5490.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-351.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1461.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5776.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3130.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9864.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3090.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8979.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7322.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6954.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3332.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5434.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-785.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2571.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2009.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7765.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5684.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4092.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9429.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5157.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7328.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1157.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3866.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5907.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1783.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1495.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1787.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5331.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7449.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9017.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6345.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5465.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1893.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2589.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-723.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6111.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7721.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2115.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9957.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10076.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5761.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2837.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4441.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1681.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3196.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6578.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9148.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9582.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-966.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8801.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6799.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-327.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8756.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8055.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5112.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-881.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3919.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1770.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4058.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9854.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9318.dcm
# ...
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6116.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4636.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2417.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2591.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5524.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2509.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6518.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9975.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-82.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6942.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-830.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7280.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5522.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-888.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7316.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1800.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8433.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5309.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1811.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7261.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7198.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2665.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-371.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2291.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4733.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2670.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5142.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5731.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2976.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2152.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2714.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-100.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5695.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8717.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3433.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4643.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4854.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9306.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1735.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2985.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9713.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-71.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9157.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1540.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8228.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3911.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3659.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9888.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6308.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3955.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9759.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1881.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6014.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7693.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5254.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3107.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2542.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7896.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6793.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2605.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7419.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5935.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6078.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-672.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6281.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9201.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7646.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8822.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7091.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9590.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1005.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8709.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5963.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8446.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9733.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7601.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-885.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9804.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3556.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4453.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5171.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1471.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4660.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1650.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4027.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5838.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9012.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7459.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3998.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8907.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2419.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-291.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9584.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7229.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3878.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7767.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-976.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7713.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9434.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2446.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5818.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-857.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8877.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1574.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8831.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8769.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4158.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10131.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1437.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3275.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3150.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6776.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3016.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9276.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8227.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5617.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2206.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2211.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5619.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9881.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9956.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2055.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6486.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6637.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3008.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4145.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3381.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9284.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4996.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1457.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10161.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8780.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5264.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6730.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3797.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-169.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9408.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-740.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7809.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6688.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1944.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6309.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-522.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1325.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9858.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6754.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8047.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6513.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-422.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6660.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8043.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8380.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9903.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6814.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-763.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10115.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7354.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9941.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1747.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1423.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-267.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8434.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6981.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6273.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3585.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6330.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7371.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3699.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5557.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6490.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-590.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8348.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-682.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4142.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10010.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9209.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4443.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9330.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6499.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1824.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5534.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-10046.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1087.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8335.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3907.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7260.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7718.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-1529.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-2199.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8436.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3712.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7951.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9308.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-876.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-8306.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-5692.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7930.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7146.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-7526.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-228.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-9228.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4491.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-4510.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-3710.dcm
# Successfully converted and saved ./content/data/DCM/NON_COVID/Normal-6442.dcm

# %%
len(list_im_nc), len(list_im_c)
# Out:
# (10192, 3616)

# %%
len(NON_COVID_IMAGE_PATH_LIST), len(COVID_IMAGE_PATH_LIST)
# Out:
# (10192, 3616)

# %%
list_im_nc[0], list_im_c[0]
# Out:
# ('./content/data/DCM/NON_COVID/Normal-6824.dcm',
#  './content/data/DCM/COVID/COVID-1198.dcm')

# %%
def extract_fnames(file_list):
  temp_ll = []
  for i in file_list:
    fname = i.split("/")[-1].split(".")[0]
    temp_ll.append(fname)
    return sorted(temp_ll)

# %%
ll_dc_fname = extract_fnames(list_im_c)
ll_dnc_fname = extract_fnames(list_im_nc)
ll_pc_fname = extract_fnames(COVID_IMAGE_PATH_LIST)
ll_pnc_fname = extract_fnames(NON_COVID_IMAGE_PATH_LIST)

# %%
ll_dc_fname == ll_pc_fname
# Out:
# True

# %%
ll_dnc_fname == ll_pnc_fname
# Out:
# True

# %%
df_nc = pd.DataFrame()

# %%
df_nc['filename'] = list_im_nc

# %%
df_nc['class'] = 0

# %%
df_nc
# Out:
#                                            filename  class
# 0      ./content/data/DCM/NON_COVID/Normal-6824.dcm      0
# 1      ./content/data/DCM/NON_COVID/Normal-3457.dcm      0
# 2      ./content/data/DCM/NON_COVID/Normal-6414.dcm      0
# 3      ./content/data/DCM/NON_COVID/Normal-5253.dcm      0
# 4      ./content/data/DCM/NON_COVID/Normal-7911.dcm      0
# ...                                             ...    ...
# 10187  ./content/data/DCM/NON_COVID/Normal-9228.dcm      0
# 10188  ./content/data/DCM/NON_COVID/Normal-4491.dcm      0
# 10189  ./content/data/DCM/NON_COVID/Normal-4510.dcm      0
# 10190  ./content/data/DCM/NON_COVID/Normal-3710.dcm      0
# 10191  ./content/data/DCM/NON_COVID/Normal-6442.dcm      0
#
# [10192 rows x 2 columns]

# %%
label_1 = list(np.ones(len(list_im_c), dtype=int))
len(label_1), len(list_im_c)
# Out:
# (3616, 3616)

# %%
dict_c = {'filename': list_im_c, 'class': label_1}

# %%
df_c = pd.DataFrame(data=dict_c)

# %%
df_c
# Out:
#                                      filename  class
# 0     ./content/data/DCM/COVID/COVID-1198.dcm      1
# 1      ./content/data/DCM/COVID/COVID-701.dcm      1
# 2     ./content/data/DCM/COVID/COVID-2686.dcm      1
# 3     ./content/data/DCM/COVID/COVID-1802.dcm      1
# 4      ./content/data/DCM/COVID/COVID-587.dcm      1
# ...                                       ...    ...
# 3611   ./content/data/DCM/COVID/COVID-240.dcm      1
# 3612   ./content/data/DCM/COVID/COVID-241.dcm      1
# 3613   ./content/data/DCM/COVID/COVID-746.dcm      1
# 3614    ./content/data/DCM/COVID/COVID-61.dcm      1
# 3615  ./content/data/DCM/COVID/COVID-2902.dcm      1
#
# [3616 rows x 2 columns]

# %%
df = pd.concat([df_nc, df_c])

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns=['index'], inplace=True)

# %%
df
# Out:
#                                            filename  class
# 0      ./content/data/DCM/NON_COVID/Normal-6824.dcm      0
# 1      ./content/data/DCM/NON_COVID/Normal-3457.dcm      0
# 2      ./content/data/DCM/NON_COVID/Normal-6414.dcm      0
# 3      ./content/data/DCM/NON_COVID/Normal-5253.dcm      0
# 4      ./content/data/DCM/NON_COVID/Normal-7911.dcm      0
# ...                                             ...    ...
# 13803        ./content/data/DCM/COVID/COVID-240.dcm      1
# 13804        ./content/data/DCM/COVID/COVID-241.dcm      1
# 13805        ./content/data/DCM/COVID/COVID-746.dcm      1
# 13806         ./content/data/DCM/COVID/COVID-61.dcm      1
# 13807       ./content/data/DCM/COVID/COVID-2902.dcm      1
#
# [13808 rows x 2 columns]

# %%
df['class'].value_counts()
# Out:
# 0    10192
# 1     3616
# Name: class, dtype: int64

# %%
df.to_csv('./content/data/DCM/dcm_files_list_labels.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13808 entries, 0 to 13807
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  13808 non-null  object
#  1   class     13808 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 215.9+ KB

# %% [markdown]
# ## Milestone 1.2

# %%
df_loaddata = pd.read_csv('./content/data/DCM/dcm_files_list_labels.csv')

# %%
df_loaddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13808 entries, 0 to 13807
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  13808 non-null  object
#  1   class     13808 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 215.9+ KB

# %%
len(df_loaddata.filename.unique())
# Out:
# 13808

# %%
df_loaddata['class'].value_counts()
# Out:
# 0    10192
# 1     3616
# Name: class, dtype: int64

# %%
df_X = df_loaddata.drop(columns=['class'])
df_y = df_loaddata['class']

# %%
df_y.head(), df_X.head()
# Out:
# (0    0
#  1    0
#  2    0
#  3    0
#  4    0
#  Name: class, dtype: int64,
#                                         filename
#  0  ./content/data/DCM/NON_COVID/Normal-6824.dcm
#  1  ./content/data/DCM/NON_COVID/Normal-3457.dcm
#  2  ./content/data/DCM/NON_COVID/Normal-6414.dcm
#  3  ./content/data/DCM/NON_COVID/Normal-5253.dcm
#  4  ./content/data/DCM/NON_COVID/Normal-7911.dcm)

# %%
train_df, test_df = train_test_split(df_loaddata, test_size=0.2, random_state=42, stratify=df['class'])

len(train_df), len(test_df)
# Out:
# (11046, 2762)

# %%
# we need to further reserve 20% data in training for validation
train_df, valid_df = train_test_split(train_df, test_size=0.2, random_state=42, stratify=train_df['class'])

len(train_df), len(valid_df)
# Out:
# (8836, 2210)

# %%
train_df['class'].sum(), valid_df['class'].sum(), test_df['class'].sum()
# Out:
# (2314, 579, 723)

# %%
train_df['class'].sum() + valid_df['class'].sum() + test_df['class'].sum()
# Out:
# 3616

# %%
train_aug_params = dict(
    rescale=1./255,
    rotation_range=10,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    brightness_range = [0.8, 1.2]
)

valid_aug_params = dict(
    rescale=1./255
    )

test_aug_params = dict(
    rescale=1./255
)

# %%
#Creating augmenters

train_augmenter = ImageDataGenerator(**train_aug_params)
valid_augmenter = ImageDataGenerator(**valid_aug_params)
test_augmenter = ImageDataGenerator(**test_aug_params)

# %%
type(train_augmenter), type(valid_augmenter), type(test_augmenter)
# Out:
# (keras.preprocessing.image.ImageDataGenerator,
#  keras.preprocessing.image.ImageDataGenerator,
#  keras.preprocessing.image.ImageDataGenerator)

# %%
# training parameters
BATCH_SIZE = 32
COLOR_MODE = 'grayscale'
TARGET_SIZE = (224, 224)
EPOCHS = 10

train_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE,  
}

valid_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE, 
    'shuffle': False
}

test_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE,  # resize input images
    'shuffle': False
}

# %%
class DCMDataFrameIterator(DataFrameIterator):
    def __init__(self, *arg, **kwargs):
        self.white_list_formats = ('dcm')
        super(DCMDataFrameIterator, self).__init__(*arg, **kwargs)
        self.dataframe = kwargs['dataframe']
        self.x = self.dataframe[kwargs['x_col']]
        self.y = self.dataframe[kwargs['y_col']]
        self.color_mode = kwargs['color_mode']
        self.target_size = kwargs['target_size']

    def _get_batches_of_transformed_samples(self, indices_array):
        # get batch of images
        batch_x = np.array([self.read_dcm_as_array(dcm_path, self.target_size, color_mode=self.color_mode)
                            for dcm_path in self.x.iloc[indices_array]])

        batch_y = np.array(self.y.iloc[indices_array].astype(np.uint8))  # astype because y was passed as str

        # transform images
        if self.image_data_generator is not None:
            for i, (x, y) in enumerate(zip(batch_x, batch_y)):
                transform_params = self.image_data_generator.get_random_transform(x.shape)
                batch_x[i] = self.image_data_generator.apply_transform(x, transform_params)
                
                # you can change y here as well, eg: in semantic segmentation you want to transform masks as well 
                # using the same image_data_generator transformations.

        return batch_x, batch_y

    @staticmethod
    def read_dcm_as_array(dcm_path, target_size=(256, 256), color_mode='rgb'):
        image_array = pydicom.dcmread(dcm_path).pixel_array
        image = Image.fromarray(image_array) #converts from array to PIL
        #image = Image.open(image).convert('L')
        image.thumbnail((224,224)) #resize image to 224,224
        #image_array = cv2.resize(image_array, target_size, interpolation=cv2.INTER_NEAREST)  #this returns a 2d array
        image_array = np.expand_dims(image, -1)
        return image_array.astype(np.float32)

# %%
train_df['class'] = train_df['class'].astype('str')
valid_df['class'] = valid_df['class'].astype('str')
test_df['class'] = test_df['class'].astype('str')

# %%
train_df.info(), valid_df.info(),  test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8836 entries, 13528 to 8134
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  8836 non-null   object
#  1   class     8836 non-null   object
# dtypes: object(2)
# memory usage: 207.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2210 entries, 6681 to 12452
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  2210 non-null   object
#  1   class     2210 non-null   object
# dtypes: object(2)
# memory usage: 51.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2762 entries, 1939 to 8436
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  2762 non-null   object
#  1   class     2762 non-null   object
# dtypes: object(2)
# memory usage: 64.7+ KB
# (None, None, None)

# %%
train_generator = DCMDataFrameIterator(dataframe=train_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=train_augmenter,
                             **train_consts)

valid_generator = DCMDataFrameIterator(dataframe=valid_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=valid_augmenter,
                             **valid_consts)

test_generator = DCMDataFrameIterator(dataframe=test_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=test_augmenter,
                             **test_consts)
# Out:
# Found 8836 validated image filenames belonging to 2 classes.
# Found 2210 validated image filenames belonging to 2 classes.
# Found 2762 validated image filenames belonging to 2 classes.

# %%
#train_augmenter.fit(train_generator)

# %%
classes = ['NON-COVID', 'COVID']

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(train_generator))

imgs.shape, labels.shape, type(imgs), type(labels)
# Out:
# ((32, 224, 224, 1), (32,), numpy.ndarray, numpy.ndarray)

# %%
imgs[0].mean(), imgs[0].max(), imgs[0].min()
# Out:
# (144.28824, 255.0, 0.0)

# %%
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(valid_generator))
print(imgs.shape, labels.shape, type(imgs), type(labels))
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()
# Out:
# (32, 224, 224, 1) (32,) <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(test_generator))
print(imgs.shape, labels.shape, type(imgs), type(labels))
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()
# Out:
# (32, 224, 224, 1) (32,) <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
imgs[0].dtype
# Out:
# dtype('float32')

# %%
#imgs[0]

# %%
#help(train_generator)

# %%
import tensorflow
from tensorflow.keras.layers import ZeroPadding2D, Add
from tensorflow.keras.regularizers import l2
l2_reg = l2(0.001)

# %%
class Resnet50(tensorflow.keras.Model):
    def __init__(self, input_dim, num_classes):
        super(Resnet50, self).__init__()
        
        self.init_pad = ZeroPadding2D(padding=(3,3))
        self.conv_block_0 = Sequential([
            Conv2D(64, (7,7), use_bias=False), ## 112
            BatchNormalization(),
            Activation('relu'),
            ZeroPadding2D(padding=(1,1)),
            MaxPool2D((3,3), strides=(2,2)) ##56
        ])
        
        ### Residual Block 1 (3x3) - No reduction required
        self.shortcut_1 = Sequential([
            Conv2D(256, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_1_0 = Sequential([
            Conv2D(64, (1,1), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(64, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(256, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_1_1 = Sequential([
            Conv2D(64, (1,1), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(64, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(256, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_1_2 = Sequential([
            Conv2D(64, (1,1), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(64, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(256, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        ###Residual Block 2 (4x3) Reduction required in first Conv2D in first block component
        
        self.shortcut_4 = Sequential([
            Conv2D(512, (1,1), strides=(2,2), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_2_0 = Sequential([
            Conv2D(128, (1,1), strides=(2,2), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(128, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(512, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_2_1 = Sequential([
            Conv2D(128, (1,1), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(128, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(512, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_2_2 = Sequential([
            Conv2D(128, (1,1), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(128, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(512, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_2_3 = Sequential([
            Conv2D(128, (1,1), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(128, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(512, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        ###Residual Block 3 (6x3) Reduction required in first Conv2D in first block component
        
        self.shortcut_8 = Sequential([
            Conv2D(1024, (1,1), strides=(2,2), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_3_0 = Sequential([
            Conv2D(256, (1,1), strides=(2,2), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(256, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(1024, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_3_1 = Sequential([
            Conv2D(256, (1,1), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(256, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(1024, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_3_2 = Sequential([
            Conv2D(256, (1,1), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(256, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(1024, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_3_3 = Sequential([
            Conv2D(256, (1,1), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(256, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(1024, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_3_4 = Sequential([
            Conv2D(256, (1,1), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(256, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(1024, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_3_5 = Sequential([
            Conv2D(256, (1,1), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(256, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(1024, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        ##Residual Block 4 Reduction required in first Conv2D in first block component
        self.shortcut_14 = Sequential([
            Conv2D(2048, (1,1), strides=(2,2), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_4_0 = Sequential([
            Conv2D(512, (1,1), strides=(2,2), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(512, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(2048, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_4_1 = Sequential([
            Conv2D(512, (1,1), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(512, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(2048, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        self.residual_block_4_2 = Sequential([
            Conv2D(512, (1,1), use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(512, (3,3), padding='same', use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Conv2D(2048, (1,1), use_bias=False),
            BatchNormalization()
        ])
        
        self.aggregate = AveragePooling2D((1,1))
        
        self.classifier = Sequential([
            Flatten(),
            Dense(128, use_bias=False),
            BatchNormalization(),
            Activation('relu'),
            Dropout(0.4),
            Dense(num_classes)
            #Activation('softmax')
        ])
        
        

    def call(self, input_dim):
        x = self.init_pad(input_dim)
        x = self.conv_block_0(x)
        ##Res Block_1
        x_shortcut_1 = self.shortcut_1(x)
        x = self.residual_block_1_0(x)
        x = Add()([x, x_shortcut_1])
        #x = x + x_s_1
        x = Activation('relu')(x)
        #x is next shortcut and input to next residual block
        x_shortcut_2 = x
        x = self.residual_block_1_1(x)
        x = Add()([x, x_shortcut_2])
        x = Activation('relu')(x)
        
        x_shortcut_3 = x
        x = self.residual_block_1_2(x)
        x = Add()([x, x_shortcut_3])
        x = Activation('relu')(x)
        
        ######Res Block_1 complete
        ##Start of Res Block 2
        x_shortcut_4 = self.shortcut_4(x)
        x = self.residual_block_2_0(x)
        x = Add()([x, x_shortcut_4])
        x = Activation('relu')(x)
        ##
        x_shortcut_5 = x
        x = self.residual_block_2_1(x)
        x = Add()([x, x_shortcut_5])
        x = Activation('relu')(x)
        ##
        x_shortcut_6 = x
        x = self.residual_block_2_2(x)
        x = Add()([x, x_shortcut_6])
        x = Activation('relu')(x)
        ##
        x_shortcut_7 = x
        x = self.residual_block_2_3(x)
        x = Add()([x, x_shortcut_7])
        x = Activation('relu')(x)
        ######Res Block_2 complete
        ## Res Block 3 start
        x_shortcut_8 = self.shortcut_8(x)
        x = self.residual_block_3_0(x)
        x = Add()([x, x_shortcut_8])
        x = Activation('relu')(x)
        
        x_shortcut_9 = x
        x = self.residual_block_3_1(x)
        x = Add()([x, x_shortcut_9])
        x = Activation('relu')(x)
        
        x_shortcut_10 = x
        x = self.residual_block_3_2(x)
        x = Add()([x, x_shortcut_10])
        x = Activation('relu')(x)
        
        x_shortcut_11 = x
        x = self.residual_block_3_3(x)
        x = Add()([x, x_shortcut_11])
        x = Activation('relu')(x)
        
        x_shortcut_12 = x
        x = self.residual_block_3_4(x)
        x = Add()([x, x_shortcut_12])
        x = Activation('relu')(x)
        
        x_shortcut_13 = x
        x = self.residual_block_3_5(x)
        x = Add()([x, x_shortcut_13])
        x = Activation('relu')(x)
        
        #### Residual Block 3 End
        ### REsidual Block 4 Start
        x_shortcut_14 = self.shortcut_14(x)
        x = self.residual_block_4_0(x)
        x = Add()([x, x_shortcut_14])
        x = Activation('relu')(x)
        
        x_shortcut_15 = x
        x = self.residual_block_4_1(x)
        x = Add()([x, x_shortcut_15])
        x = Activation('relu')(x)
        
        x_shortcut_16 = x
        x = self.residual_block_4_2(x)
        x = Add()([x, x_shortcut_16])
        x = Activation('relu')(x)
        
        x = self.aggregate(x)
        x = self.classifier(x)
        
        
        return x

# %%
#VGG16_custom(224).build([None, 224,244,1,])
X_input = Input(shape=(224,224,1,))
out = Resnet50(224,2)(X_input)
temp_model = Model(inputs=X_input, outputs=out)
temp_model.summary(expand_nested=True)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 1)]     0
#
#  resnet50_5 (Resnet50)       (None, 2)                 74935874
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | zero_padding2d_10 (ZeroPadd  multiple               0         |
# | ing2D)                                                        |
# |                                                               |
# | sequential_110 (Sequential)  (None, 112, 112, 64)   3392      |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_265 (Conv2D)     (None, 224, 224, 64)      3136      ||
# ||                                                             ||
# || batch_normalization_265 (Ba  (None, 224, 224, 64)  256      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_165 (Activation)  (None, 224, 224, 64)  0        ||
# ||                                                             ||
# || zero_padding2d_11 (ZeroPadd  (None, 226, 226, 64)  0        ||
# || ing2D)                                                      ||
# ||                                                             ||
# || max_pooling2d_5 (MaxPooling  (None, 112, 112, 64)  0        ||
# || 2D)                                                         ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_111 (Sequential)  (None, 112, 112, 256)  17408     |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_266 (Conv2D)     (None, 112, 112, 256)     16384     ||
# ||                                                             ||
# || batch_normalization_266 (Ba  (None, 112, 112, 256)  1024    ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_112 (Sequential)  (None, 112, 112, 256)  58880     |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_267 (Conv2D)     (None, 112, 112, 64)      4096      ||
# ||                                                             ||
# || batch_normalization_267 (Ba  (None, 112, 112, 64)  256      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_166 (Activation)  (None, 112, 112, 64)  0        ||
# ||                                                             ||
# || conv2d_268 (Conv2D)     (None, 112, 112, 64)      36864     ||
# ||                                                             ||
# || batch_normalization_268 (Ba  (None, 112, 112, 64)  256      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_167 (Activation)  (None, 112, 112, 64)  0        ||
# ||                                                             ||
# || conv2d_269 (Conv2D)     (None, 112, 112, 256)     16384     ||
# ||                                                             ||
# || batch_normalization_269 (Ba  (None, 112, 112, 256)  1024    ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_113 (Sequential)  (None, 112, 112, 256)  71168     |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_270 (Conv2D)     (None, 112, 112, 64)      16384     ||
# ||                                                             ||
# || batch_normalization_270 (Ba  (None, 112, 112, 64)  256      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_168 (Activation)  (None, 112, 112, 64)  0        ||
# ||                                                             ||
# || conv2d_271 (Conv2D)     (None, 112, 112, 64)      36864     ||
# ||                                                             ||
# || batch_normalization_271 (Ba  (None, 112, 112, 64)  256      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_169 (Activation)  (None, 112, 112, 64)  0        ||
# ||                                                             ||
# || conv2d_272 (Conv2D)     (None, 112, 112, 256)     16384     ||
# ||                                                             ||
# || batch_normalization_272 (Ba  (None, 112, 112, 256)  1024    ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_114 (Sequential)  (None, 112, 112, 256)  71168     |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_273 (Conv2D)     (None, 112, 112, 64)      16384     ||
# ||                                                             ||
# || batch_normalization_273 (Ba  (None, 112, 112, 64)  256      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_170 (Activation)  (None, 112, 112, 64)  0        ||
# ||                                                             ||
# || conv2d_274 (Conv2D)     (None, 112, 112, 64)      36864     ||
# ||                                                             ||
# || batch_normalization_274 (Ba  (None, 112, 112, 64)  256      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_171 (Activation)  (None, 112, 112, 64)  0        ||
# ||                                                             ||
# || conv2d_275 (Conv2D)     (None, 112, 112, 256)     16384     ||
# ||                                                             ||
# || batch_normalization_275 (Ba  (None, 112, 112, 256)  1024    ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_115 (Sequential)  (None, 56, 56, 512)    133120    |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_276 (Conv2D)     (None, 56, 56, 512)       131072    ||
# ||                                                             ||
# || batch_normalization_276 (Ba  (None, 56, 56, 512)  2048      ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_116 (Sequential)  (None, 56, 56, 512)    248832    |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_277 (Conv2D)     (None, 56, 56, 128)       32768     ||
# ||                                                             ||
# || batch_normalization_277 (Ba  (None, 56, 56, 128)  512       ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_172 (Activation)  (None, 56, 56, 128)  0         ||
# ||                                                             ||
# || conv2d_278 (Conv2D)     (None, 56, 56, 128)       147456    ||
# ||                                                             ||
# || batch_normalization_278 (Ba  (None, 56, 56, 128)  512       ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_173 (Activation)  (None, 56, 56, 128)  0         ||
# ||                                                             ||
# || conv2d_279 (Conv2D)     (None, 56, 56, 512)       65536     ||
# ||                                                             ||
# || batch_normalization_279 (Ba  (None, 56, 56, 512)  2048      ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_117 (Sequential)  (None, 56, 56, 512)    281600    |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_280 (Conv2D)     (None, 56, 56, 128)       65536     ||
# ||                                                             ||
# || batch_normalization_280 (Ba  (None, 56, 56, 128)  512       ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_174 (Activation)  (None, 56, 56, 128)  0         ||
# ||                                                             ||
# || conv2d_281 (Conv2D)     (None, 56, 56, 128)       147456    ||
# ||                                                             ||
# || batch_normalization_281 (Ba  (None, 56, 56, 128)  512       ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_175 (Activation)  (None, 56, 56, 128)  0         ||
# ||                                                             ||
# || conv2d_282 (Conv2D)     (None, 56, 56, 512)       65536     ||
# ||                                                             ||
# || batch_normalization_282 (Ba  (None, 56, 56, 512)  2048      ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_118 (Sequential)  (None, 56, 56, 512)    281600    |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_283 (Conv2D)     (None, 56, 56, 128)       65536     ||
# ||                                                             ||
# || batch_normalization_283 (Ba  (None, 56, 56, 128)  512       ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_176 (Activation)  (None, 56, 56, 128)  0         ||
# ||                                                             ||
# || conv2d_284 (Conv2D)     (None, 56, 56, 128)       147456    ||
# ||                                                             ||
# || batch_normalization_284 (Ba  (None, 56, 56, 128)  512       ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_177 (Activation)  (None, 56, 56, 128)  0         ||
# ||                                                             ||
# || conv2d_285 (Conv2D)     (None, 56, 56, 512)       65536     ||
# ||                                                             ||
# || batch_normalization_285 (Ba  (None, 56, 56, 512)  2048      ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_119 (Sequential)  (None, 56, 56, 512)    281600    |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_286 (Conv2D)     (None, 56, 56, 128)       65536     ||
# ||                                                             ||
# || batch_normalization_286 (Ba  (None, 56, 56, 128)  512       ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_178 (Activation)  (None, 56, 56, 128)  0         ||
# ||                                                             ||
# || conv2d_287 (Conv2D)     (None, 56, 56, 128)       147456    ||
# ||                                                             ||
# || batch_normalization_287 (Ba  (None, 56, 56, 128)  512       ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_179 (Activation)  (None, 56, 56, 128)  0         ||
# ||                                                             ||
# || conv2d_288 (Conv2D)     (None, 56, 56, 512)       65536     ||
# ||                                                             ||
# || batch_normalization_288 (Ba  (None, 56, 56, 512)  2048      ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_120 (Sequential)  (None, 28, 28, 1024)   528384    |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_289 (Conv2D)     (None, 28, 28, 1024)      524288    ||
# ||                                                             ||
# || batch_normalization_289 (Ba  (None, 28, 28, 1024)  4096     ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_121 (Sequential)  (None, 28, 28, 1024)   989184    |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_290 (Conv2D)     (None, 28, 28, 256)       131072    ||
# ||                                                             ||
# || batch_normalization_290 (Ba  (None, 28, 28, 256)  1024      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_180 (Activation)  (None, 28, 28, 256)  0         ||
# ||                                                             ||
# || conv2d_291 (Conv2D)     (None, 28, 28, 256)       589824    ||
# ||                                                             ||
# || batch_normalization_291 (Ba  (None, 28, 28, 256)  1024      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_181 (Activation)  (None, 28, 28, 256)  0         ||
# ||                                                             ||
# || conv2d_292 (Conv2D)     (None, 28, 28, 1024)      262144    ||
# ||                                                             ||
# || batch_normalization_292 (Ba  (None, 28, 28, 1024)  4096     ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_122 (Sequential)  (None, 28, 28, 1024)   1120256   |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_293 (Conv2D)     (None, 28, 28, 256)       262144    ||
# ||                                                             ||
# || batch_normalization_293 (Ba  (None, 28, 28, 256)  1024      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_182 (Activation)  (None, 28, 28, 256)  0         ||
# ||                                                             ||
# || conv2d_294 (Conv2D)     (None, 28, 28, 256)       589824    ||
# ||                                                             ||
# || batch_normalization_294 (Ba  (None, 28, 28, 256)  1024      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_183 (Activation)  (None, 28, 28, 256)  0         ||
# ||                                                             ||
# || conv2d_295 (Conv2D)     (None, 28, 28, 1024)      262144    ||
# ||                                                             ||
# || batch_normalization_295 (Ba  (None, 28, 28, 1024)  4096     ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_123 (Sequential)  (None, 28, 28, 1024)   1120256   |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_296 (Conv2D)     (None, 28, 28, 256)       262144    ||
# ||                                                             ||
# || batch_normalization_296 (Ba  (None, 28, 28, 256)  1024      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_184 (Activation)  (None, 28, 28, 256)  0         ||
# ||                                                             ||
# || conv2d_297 (Conv2D)     (None, 28, 28, 256)       589824    ||
# ||                                                             ||
# || batch_normalization_297 (Ba  (None, 28, 28, 256)  1024      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_185 (Activation)  (None, 28, 28, 256)  0         ||
# ||                                                             ||
# || conv2d_298 (Conv2D)     (None, 28, 28, 1024)      262144    ||
# ||                                                             ||
# || batch_normalization_298 (Ba  (None, 28, 28, 1024)  4096     ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_124 (Sequential)  (None, 28, 28, 1024)   1120256   |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_299 (Conv2D)     (None, 28, 28, 256)       262144    ||
# ||                                                             ||
# || batch_normalization_299 (Ba  (None, 28, 28, 256)  1024      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_186 (Activation)  (None, 28, 28, 256)  0         ||
# ||                                                             ||
# || conv2d_300 (Conv2D)     (None, 28, 28, 256)       589824    ||
# ||                                                             ||
# || batch_normalization_300 (Ba  (None, 28, 28, 256)  1024      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_187 (Activation)  (None, 28, 28, 256)  0         ||
# ||                                                             ||
# || conv2d_301 (Conv2D)     (None, 28, 28, 1024)      262144    ||
# ||                                                             ||
# || batch_normalization_301 (Ba  (None, 28, 28, 1024)  4096     ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_125 (Sequential)  (None, 28, 28, 1024)   1120256   |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_302 (Conv2D)     (None, 28, 28, 256)       262144    ||
# ||                                                             ||
# || batch_normalization_302 (Ba  (None, 28, 28, 256)  1024      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_188 (Activation)  (None, 28, 28, 256)  0         ||
# ||                                                             ||
# || conv2d_303 (Conv2D)     (None, 28, 28, 256)       589824    ||
# ||                                                             ||
# || batch_normalization_303 (Ba  (None, 28, 28, 256)  1024      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_189 (Activation)  (None, 28, 28, 256)  0         ||
# ||                                                             ||
# || conv2d_304 (Conv2D)     (None, 28, 28, 1024)      262144    ||
# ||                                                             ||
# || batch_normalization_304 (Ba  (None, 28, 28, 1024)  4096     ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_126 (Sequential)  (None, 28, 28, 1024)   1120256   |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_305 (Conv2D)     (None, 28, 28, 256)       262144    ||
# ||                                                             ||
# || batch_normalization_305 (Ba  (None, 28, 28, 256)  1024      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_190 (Activation)  (None, 28, 28, 256)  0         ||
# ||                                                             ||
# || conv2d_306 (Conv2D)     (None, 28, 28, 256)       589824    ||
# ||                                                             ||
# || batch_normalization_306 (Ba  (None, 28, 28, 256)  1024      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_191 (Activation)  (None, 28, 28, 256)  0         ||
# ||                                                             ||
# || conv2d_307 (Conv2D)     (None, 28, 28, 1024)      262144    ||
# ||                                                             ||
# || batch_normalization_307 (Ba  (None, 28, 28, 1024)  4096     ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_127 (Sequential)  (None, 14, 14, 2048)   2105344   |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_308 (Conv2D)     (None, 14, 14, 2048)      2097152   ||
# ||                                                             ||
# || batch_normalization_308 (Ba  (None, 14, 14, 2048)  8192     ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_128 (Sequential)  (None, 14, 14, 2048)   3944448   |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_309 (Conv2D)     (None, 14, 14, 512)       524288    ||
# ||                                                             ||
# || batch_normalization_309 (Ba  (None, 14, 14, 512)  2048      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_192 (Activation)  (None, 14, 14, 512)  0         ||
# ||                                                             ||
# || conv2d_310 (Conv2D)     (None, 14, 14, 512)       2359296   ||
# ||                                                             ||
# || batch_normalization_310 (Ba  (None, 14, 14, 512)  2048      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_193 (Activation)  (None, 14, 14, 512)  0         ||
# ||                                                             ||
# || conv2d_311 (Conv2D)     (None, 14, 14, 2048)      1048576   ||
# ||                                                             ||
# || batch_normalization_311 (Ba  (None, 14, 14, 2048)  8192     ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_129 (Sequential)  (None, 14, 14, 2048)   4468736   |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_312 (Conv2D)     (None, 14, 14, 512)       1048576   ||
# ||                                                             ||
# || batch_normalization_312 (Ba  (None, 14, 14, 512)  2048      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_194 (Activation)  (None, 14, 14, 512)  0         ||
# ||                                                             ||
# || conv2d_313 (Conv2D)     (None, 14, 14, 512)       2359296   ||
# ||                                                             ||
# || batch_normalization_313 (Ba  (None, 14, 14, 512)  2048      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_195 (Activation)  (None, 14, 14, 512)  0         ||
# ||                                                             ||
# || conv2d_314 (Conv2D)     (None, 14, 14, 2048)      1048576   ||
# ||                                                             ||
# || batch_normalization_314 (Ba  (None, 14, 14, 2048)  8192     ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_130 (Sequential)  (None, 14, 14, 2048)   4468736   |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_315 (Conv2D)     (None, 14, 14, 512)       1048576   ||
# ||                                                             ||
# || batch_normalization_315 (Ba  (None, 14, 14, 512)  2048      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_196 (Activation)  (None, 14, 14, 512)  0         ||
# ||                                                             ||
# || conv2d_316 (Conv2D)     (None, 14, 14, 512)       2359296   ||
# ||                                                             ||
# || batch_normalization_316 (Ba  (None, 14, 14, 512)  2048      ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_197 (Activation)  (None, 14, 14, 512)  0         ||
# ||                                                             ||
# || conv2d_317 (Conv2D)     (None, 14, 14, 2048)      1048576   ||
# ||                                                             ||
# || batch_normalization_317 (Ba  (None, 14, 14, 2048)  8192     ||
# || tchNormalization)                                           ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | average_pooling2d_5 (Averag  multiple               0         |
# | ePooling2D)                                                   |
# |                                                               |
# | sequential_131 (Sequential)  (None, 2)              51380994  |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || flatten_5 (Flatten)     (None, 401408)            0         ||
# ||                                                             ||
# || dense_5 (Dense)         (None, 128)               51380224  ||
# ||                                                             ||
# || batch_normalization_318 (Ba  (None, 128)          512       ||
# || tchNormalization)                                           ||
# ||                                                             ||
# || activation_198 (Activation)  (None, 128)          0         ||
# ||                                                             ||
# || dropout (Dropout)       (None, 128)               0         ||
# ||                                                             ||
# || dense_6 (Dense)         (None, 2)                 258       ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 74,935,874
# Trainable params: 74,882,498
# Non-trainable params: 53,376
# _________________________________________________________________

# %%
model_resnet50 = Resnet50(224, 2)

# %%
#help(tensorflow.python.keras.layers.convolutional.Conv2D)

# %%
opt = Adam(learning_rate=0.0001)
loss_fn = tensorflow.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
train_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()
val_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()
test_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()

# %%
from sklearn.metrics import confusion_matrix

# %%
if os.path.exists('./content/data/ckpt'):
    print(f'Weight Checkpoint directory already exists')
    # !ls -ld ./content/data/ckpt
else:
    print(f'Weight Checkpooint directory doesnt exists.. Creating it now..')
    os.mkdir('./content/data/ckpt')
    print(f'Weight Checkpoint directory successfully created')
    # !ls -ld ./content/data/ckpt

    
if os.path.exists('./content/data/saved_model'):
    print(f'Protobuf Checkpoint directory already exists')
    # !ls -ld ./content/data/saved_model
else:
    print(f'Protobuf Checkpoint directory doesnt exists.. Creating it now..')
    os.mkdir('./content/data/saved_model')
    print(f'Weight Checkpoint directory successfully created')
    # !ls -ld ./content/data/saved_model
# Out:
# Weight Checkpoint directory already exists
# drwxr-xr-x 2 root root 4096 Apr 10 04:29 ./content/data/ckpt
# Protobuf Checkpoint directory already exists
# drwxr-xr-x 2 root root 4096 Apr 10 04:29 ./content/data/saved_model

# %%
class Model_Train():
    def __init__(self, model, optimizer, loss_fn, epochs, batch_size, train_gen, valid_gen, test_gen, train_acc_metric, val_acc_metric, test_acc_metric):
        super().__init__()

        self.model = model
        self.optimizer = optimizer
        self.loss_fn = loss_fn
        self.epochs = epochs
        self.batch_size = batch_size
        self.train_generator = train_gen
        self.valid_generator = valid_gen
        self.test_generator = test_gen
        self.steps_train = len(train_gen)
        self.steps_valid = len(valid_gen)
        self.steps_test = len(test_gen)
        self.train_acc_metric = train_acc_metric
        self.val_acc_metric = val_acc_metric
        self.test_acc_metric = test_acc_metric
        self.train_history = {'loss': [], 'accuracy': [], 'f1': [], 'precision': [], 'recall': []}
        self.valid_history = {'loss': [], 'accuracy': [], 'f1': [], 'precision': [], 'recall': [], 'ckpt_name': []}


   

    @tensorflow.function
    def train_step(self, train_data, train_label):
        with tensorflow.GradientTape() as tape:
            output = self.model(train_data, training=True)
            loss_value = self.loss_fn(train_label, output)
        grads = tape.gradient(loss_value, self.model.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_weights))
        self.train_acc_metric.update_state(train_label, output)
        return output, loss_value

    @tensorflow.function
    def test_step(self, validation_data, validation_label):
        val_output = self.model(validation_data, training=False)
        loss_value = self.loss_fn(validation_label, val_output)
        self.val_acc_metric.update_state(validation_label, val_output)
        return val_output, loss_value

    def getloss_accuracy(self, gen, batch_size, steps_per_epoch, df, train=False, valid=False):
        loss_epoch = 0
        for step, (x_batch, y_batch) in enumerate(gen):
            if train:
                output, loss_value = self.train_step(x_batch, y_batch)
        ###new code below
        
                pred_labls = list(np.argmax(output.numpy(), axis=1))
                temp_df = pd.DataFrame({'orig_label': list(y_batch), 'pred_label': pred_labls})
                df = pd.concat([df, temp_df])
            

        ## newcode above
        
            else:
                output, loss_value = self.test_step(x_batch, y_batch)
                pred_labls = list(np.argmax(output.numpy(), axis=1))
                temp_df = pd.DataFrame({'orig_label': list(y_batch), 'pred_label': pred_labls})
                df = pd.concat([df, temp_df])
            
            loss_epoch += loss_value*x_batch.shape[0]
            if step >= (steps_per_epoch-1):
                
                if train:
                    avg_epoch_loss = (loss_epoch/(len(train_df))).numpy()
                    accuracy = self.train_acc_metric.result().numpy()
                    self.train_acc_metric.reset_states()
                    gen.on_epoch_end()
                else:
                    if valid:
                        avg_epoch_loss = (loss_epoch/(len(valid_df))).numpy()
                        accuracy = self.val_acc_metric.result().numpy()
                        self.val_acc_metric.reset_states()
                    else:
                        avg_epoch_loss = (loss_epoch/(len(test_df))).numpy()
                        accuracy = self.val_acc_metric.result().numpy()
                        self.val_acc_metric.reset_states()


                return df, avg_epoch_loss, accuracy

    def train_validate_loop(self):
        for epoch in range(self.epochs):
            start_time = time.time()
            histdf_train = pd.DataFrame({'orig_label': [], 'pred_label': []})
            histdf_val   = pd.DataFrame({'orig_label': [], 'pred_label': []})  

            df_train_cm, avg_epoch_train_loss, train_accuracy = self.getloss_accuracy(self.train_generator, self.batch_size, self.steps_train, histdf_train, train=True)
            df_val_cm, avg_epoch_val_loss, val_accuracy = self.getloss_accuracy(self.valid_generator, self.batch_size, self.steps_valid, histdf_val, train=False, valid=True)

    
            f1, precision, recall             = self.calc_rec_prec_f1(df_train_cm, train=True)
            f1_val, precision_val, recall_val = self.calc_rec_prec_f1(df_val_cm, train=False)


            print(f'Epoch : {epoch}, Train Loss: {avg_epoch_train_loss}, Train Accuracy: {train_accuracy}, Validation Loss: {avg_epoch_val_loss}, Validation Accuracy: {val_accuracy}')
      
            self.train_history['loss'].append(avg_epoch_train_loss)
            self.train_history['accuracy'].append(train_accuracy)
            self.train_history['f1'].append(f1)
            self.train_history['precision'].append(precision)
            self.train_history['recall'].append(recall)

            self.valid_history['loss'].append(avg_epoch_val_loss)
            self.valid_history['accuracy'].append(val_accuracy)
            self.valid_history['f1'].append(f1_val)
            self.valid_history['precision'].append(precision_val)
            self.valid_history['recall'].append(recall_val)

      ###New Code for early stopping#####
            la = self.valid_history['accuracy']
            if (len(la) > 4):
                if (((la[-1] <= la[-2]) and (la[-2] <= la[-3])) and ((la[-3] <= la[-4]) and (la[-4] <= la[-5]))):
                    print("Validation accuracy has not improved over last 4 epochs, hence invoking early stopping and exiting training process")
                    if len(self.valid_history['ckpt_name']) > 0:
                        print('Loading Best weights..')
                        self.model.load_weights(self.valid_history['ckpt_name'][-1])
                        break
                    else:
                        print("Ouch !! seems like you dont have any checkpoints saved matching criteria specified in logic. Please excuse !")
                        break
                        
                    
            if ((la[-1] > 0.9) and (la[-1] > max(la[0:-1]))):
                ckpt_name = './content/data/ckpt/' + 'ckpt' + '_' + str(la[-1]) + '_acc.pt'
                pb_name = './content/data/saved_model/' + 'ckpt' + '_' + str(la[-1]) + '_acc'
                self.model.save_weights(ckpt_name)
                self.valid_history['ckpt_name'].append(ckpt_name)
                print(f'Saved Checkpoint : {ckpt_name}')
                self.model.save(pb_name)
                print(f'Saved model in protobuf format : {pb_name}')




      #####New Cod for early stopping


    
            print(f'Time taken: {np.round((time.time() - start_time), 4)}')
        print(f'Training completed successfully. Loading best checkpoint weights ...')
        if len(self.valid_history['ckpt_name']) > 0:
            self.model.load_weights(self.valid_history['ckpt_name'][-1])
            print(f'Best checkpoint weights loaded : {self.valid_history["ckpt_name"][-1]}')
        else:
            print("Ouch !! seems like you dont have any checkpoints saved matching criteria specified in logic. Please excuse !")

      #draw graph depicting train and validation losses and accuracy + recall, f1
        return self.train_history, self.valid_history

    def get_test_accuracy(self):
        df = pd.DataFrame({'orig_label': [], 'pred_label': []})
        df_test, avg_test_loss, test_accuracy = self.getloss_accuracy(self.test_generator, self.batch_size, self.steps_test, df)
        return df_test, avg_test_loss, test_accuracy

    def calc_rec_prec_f1(self, df, train):
        print_string = "Training Confusion Matrix" if train else "Validation Confusion Matrix"
        print(print_string, "\n", confusion_matrix(df['orig_label'], df['pred_label']))
        tn, fp, fn, tp = confusion_matrix(df['orig_label'], df['pred_label']).ravel()
        precision = tp/(tp+fp)
        recall = tp/(tp+fn)
        f1 = 2*precision*recall/(precision+recall)
        return f1, precision, recall

    def predict_single(self,dcm_path, target_size=(224,224)):
        image_array = pydicom.dcmread(dcm_path).pixel_array
        image = Image.fromarray(image_array) #converts from array to PIL
        #image.thumbnail((224,224)) #resize image to 224,224
        image = image.resize((224,224))
        image_array = np.expand_dims(image, -1)
        image_array = image_array.astype(np.float32) # * (1.0/255.0)
        image_array = np.expand_dims(image_array, 0)
        output = self.model(image_array, training=False)
        pred_label = np.argmax(output.numpy())
        print(f'Predicted label for image supplied is : {classes[pred_label]}')
        return classes[pred_label]
    
    def pred_image_show(self,image_list):
        fig, subs = plt.subplots(3,3, figsize=(14,12))
        for i, sub in enumerate(subs.flatten()):
            print(f'Image path is {image_list[i][0]} and Original label is {classes[int(image_list[i][1])]}')
            pred_class = self.predict_single(image_list[i][0])
            image_array = pydicom.dcmread(image_list[i][0]).pixel_array
            sub.imshow(image_array, cmap='gray')
            sub.set_title(f'{pred_class}(Pred) : {classes[int(image_list[i][1])]}(Orig)')
            
    def plot_metrics(self):
        list = ['accuracy', 'loss', 'f1', 'recall', 'precision']
        for metrics in list:
            x = [i for i in range(len(self.train_history[metrics]))]
            y1 = self.train_history[metrics]
            y2 = self.valid_history[metrics]
            fig, ax = plt.subplots()
            ax.plot(x, y1, label="train_"+metrics)
            ax.plot(x, y2, label="valid_"+metrics)
            plt.suptitle(f'Plot showing {metrics} for Different Epoch Runs')
            ax.legend()
            plt.show()
## Save weights
## if current accuracy > 90 and current accuracy > max(list_accuracy) then create checkpoint and save weights. Also do a protobuf saved model
## store the saved checkpoint name in a list. This will make sure than checkpoints are stored in asecnding order.
## at the end of training , take the last element in checkpoint list and load and restore it. test accuracy should be checked using this chkpoint.

# %%
EPOCHS = 10
train_object = Model_Train(model_resnet50, opt, loss_fn, EPOCHS, BATCH_SIZE, train_generator, valid_generator, test_generator,
             train_acc_metric, val_acc_metric, test_acc_metric
             )

# %%
train_object.__dict__
# Out:
# {'model': <__main__.Resnet50 at 0x7fc47cad2790>,
#  'optimizer': <keras.optimizers.adam.Adam at 0x7fc47842c130>,
#  'loss_fn': <keras.losses.SparseCategoricalCrossentropy at 0x7fc47cca5490>,
#  'epochs': 10,
#  'batch_size': 32,
#  'train_generator': <__main__.DCMDataFrameIterator at 0x7fc5c2a9eee0>,
#  'valid_generator': <__main__.DCMDataFrameIterator at 0x7fc5c07268e0>,
#  'test_generator': <__main__.DCMDataFrameIterator at 0x7fc5c2b20790>,
#  'steps_train': 277,
#  'steps_valid': 70,
#  'steps_test': 87,
#  'train_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7fc47842c6d0>,
#  'val_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7fc47cafb7f0>,
#  'test_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7fc478400550>,
#  'train_history': {'loss': [],
#   'accuracy': [],
#   'f1': [],
#   'precision': [],
#   'recall': []},
#  'valid_history': {'loss': [],
#   'accuracy': [],
#   'f1': [],
#   'precision': [],
#   'recall': [],
#   'ckpt_name': []}}

# %%
train_dict, val_dict = train_object.train_validate_loop()
# Out:
# Training Confusion Matrix
#  [[5061 1461]
#  [1056 1258]]
# Validation Confusion Matrix
#  [[   0 1631]
#  [   1  578]]
# Epoch : 0, Train Loss: 0.5899409651756287, Train Accuracy: 0.7151426076889038, Validation Loss: 1.7373543977737427, Validation Accuracy: 0.26153847575187683
# Time taken: 411.8733
# Training Confusion Matrix
#  [[5707  816]
#  [ 882 1431]]
# Validation Confusion Matrix
#  [[1491  140]
#  [ 342  237]]
# Epoch : 1, Train Loss: 0.42848241329193115, Train Accuracy: 0.8078315854072571, Validation Loss: 0.4622393846511841, Validation Accuracy: 0.7819004654884338
# Time taken: 387.1917
# Training Confusion Matrix
#  [[5875  643]
#  [ 748 1570]]
# Validation Confusion Matrix
#  [[1513  118]
#  [ 205  374]]
# Epoch : 2, Train Loss: 0.36566391587257385, Train Accuracy: 0.8425758481025696, Validation Loss: 0.34147435426712036, Validation Accuracy: 0.8538461327552795
# Time taken: 388.7803
# Training Confusion Matrix
#  [[5963  558]
#  [ 632 1683]]
# Validation Confusion Matrix
#  [[1511  120]
#  [ 205  374]]
# Epoch : 3, Train Loss: 0.3133307695388794, Train Accuracy: 0.8653236627578735, Validation Loss: 0.3289714455604553, Validation Accuracy: 0.8529411554336548
# Time taken: 389.6623
# Training Confusion Matrix
#  [[6046  477]
#  [ 560 1753]]
# Validation Confusion Matrix
#  [[1036  595]
#  [  20  559]]
# Epoch : 4, Train Loss: 0.2862111032009125, Train Accuracy: 0.8826392292976379, Validation Loss: 0.5830817222595215, Validation Accuracy: 0.7217194437980652
# Time taken: 388.4023
# Training Confusion Matrix
#  [[6117  406]
#  [ 500 1813]]
# Validation Confusion Matrix
#  [[1534   97]
#  [ 104  475]]
# Epoch : 5, Train Loss: 0.2500138282775879, Train Accuracy: 0.8974649310112, Validation Loss: 0.22455516457557678, Validation Accuracy: 0.9090497493743896
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.90904975_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.90904975_acc
# Time taken: 412.8742
# Training Confusion Matrix
#  [[6136  391]
#  [ 463 1846]]
# Validation Confusion Matrix
#  [[1431  200]
#  [  37  542]]
# Epoch : 6, Train Loss: 0.24116399884223938, Train Accuracy: 0.9033499360084534, Validation Loss: 0.25601792335510254, Validation Accuracy: 0.892760157585144
# Time taken: 387.5718
# Training Confusion Matrix
#  [[6169  356]
#  [ 438 1873]]
# Validation Confusion Matrix
#  [[1493  138]
#  [  52  527]]
# Epoch : 7, Train Loss: 0.2238905280828476, Train Accuracy: 0.910140335559845, Validation Loss: 0.21505053341388702, Validation Accuracy: 0.9140271544456482
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.91402715_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.91402715_acc
# Time taken: 412.1008
# Training Confusion Matrix
#  [[6177  344]
#  [ 421 1894]]
# Validation Confusion Matrix
#  [[1586   45]
#  [ 161  418]]
# Epoch : 8, Train Loss: 0.2183370143175125, Train Accuracy: 0.9134223461151123, Validation Loss: 0.27667921781539917, Validation Accuracy: 0.9067873358726501
# Time taken: 384.0731
# Training Confusion Matrix
#  [[6188  336]
#  [ 427 1885]]
# Validation Confusion Matrix
#  [[856 775]
#  [ 16 563]]
# Epoch : 9, Train Loss: 0.20391972362995148, Train Accuracy: 0.9136487245559692, Validation Loss: 0.8346248269081116, Validation Accuracy: 0.6420814394950867
# Time taken: 385.2905
# Training completed successfully. Loading best checkpoint weights ...
# Best checkpoint weights loaded : ./content/data/ckpt/ckpt_0.91402715_acc.pt

# %%
df, loss, accuracy = train_object.get_test_accuracy() #from df returned by function you can check which image has lables incorrectly predicted

# %%
accuracy
# Out:
# 0.9181752

# %%
confusion_matrix(df['orig_label'], df['pred_label'])
# Out:
# array([[1877,  162],
#        [  64,  659]])

# %%
train_object.predict_single(test_df.iloc[-2,0])
# Out:
# Predicted label for image supplied is : COVID
# 'COVID'

# %%
train_object.model.save_weights('./content/data/ckpt/model_best_weights')

# %%
with zipfile.ZipFile('./XRAY_resnet50_model_best_weights.zip', 'w') as myzip:
    myzip.write('./content/data/ckpt/checkpoint')
    myzip.write('./content/data/ckpt/model_best_weights.data-00000-of-00001')
    #myzip.write('./content/data/ckpt/model_best_weights.data-00001-of-00002')
    myzip.write('./content/data/ckpt/model_best_weights.index')

# %%
random_9_test = random.sample(list(test_df.values), 9)
random_9_test, len(random_9_test)
# Out:
# ([array(['./content/data/DCM/NON_COVID/Normal-8525.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-2213.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-284.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-4708.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-3482.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-8838.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-423.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-2774.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-3107.dcm', '0'], dtype=object)],
#  9)

# %%
random_9_test[0][0], random_9_test[0][1]
# Out:
# ('./content/data/DCM/NON_COVID/Normal-8525.dcm', '0')

# %%
train_object.pred_image_show(random_9_test)
# Out:
# Image path is ./content/data/DCM/NON_COVID/Normal-8525.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-2213.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-284.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-4708.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/COVID/COVID-3482.dcm and Original label is COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-8838.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/COVID/COVID-423.dcm and Original label is COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/COVID/COVID-2774.dcm and Original label is COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-3107.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID

# %%
train_object.plot_metrics()

# %%
# !cp ./*model_best_weights.zip ./gdrive/MyDrive/Manning_Projects/
