# %% [markdown]
# ## Milestone 1.1

# %%
# !nvidia-smi
# Out:
# Thu Apr 20 02:59:01 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
# Out:
# Your runtime has 13.6 gigabytes of available RAM

# %%
import requests
import pickle
import zipfile
import time
import os
#from google.colab import drive
import random
import glob
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy import asarray
from PIL.ImageStat import Stat
# !pip install pydicom
import pydicom
# Package for converting PNG Files to DICOM(.dcm ) format
# !pip install simpleitk
import SimpleITK as sitk
from sklearn.model_selection import train_test_split
from PIL import Image
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import DataFrameIterator
#from keras_preprocessing.image.dataframe_iterator import DataFrameIterator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Conv2D, AveragePooling2D, Flatten, Dense, Activation, MaxPool2D, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import sparse_categorical_crossentropy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydicom in /usr/local/lib/python3.9/dist-packages (2.3.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: simpleitk in /usr/local/lib/python3.9/dist-packages (2.2.1)

# %%
data_path = './content'
archive_path = data_path + '/data/'
if os.path.exists(archive_path):
  print(f"{archive_path} directory exists.")
else:
  print(f"Did not find {archive_path} directory, creating one...")
  os.mkdir('./content')

  os.mkdir(archive_path)
  if os.path.exists(archive_path):
    print(f'{archive_path} created successfully')
# Out:
# ./content/data/ directory exists.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !mv /content/gdrive/MyDrive/Manning_Projects/archive\ \(2\).zip /content/gdrive/MyDrive/Manning_Projects/covid_data.zip
# !ls /content/gdrive/MyDrive/Manning_Projects/
# Out:
# mv: cannot stat '/content/gdrive/MyDrive/Manning_Projects/archive (2).zip': No such file or directory
#  Best_Project_XRAY_VGG16_transfer_learning_conv.ipynb
# 'Copy of Project_XRAY_Resnet50_fc_removed.ipynb'
#  covid_data.zip
#  model_best_weights.zip
#  Project_CTSCAN_ViT_Transfer_transfer_all_outs_conv.ipynb
#  Project_XRAY_Resnet18.ipynb
#  Project_XRAY_Resnet50.ipynb
#  Project_XRAY_RESNET50_transfer_learning_conv.ipynb
#  Project_XRAY_VGG16_Transfer_Learning_3D.ipynb
#  Project_XRAY_VGG16_transfer_learning_conv.ipynb
#  Project_XRAY_VGG16_Transfer_Learning.ipynb
#  Project_XRAY_ViT_1.ipynb
#  Project_XRAY_ViT.ipynb
#  Project_XRAY_ViT_transfer_learning_conv.ipynb
#  XRAY_NFC_resnet50_model_best_weights.zip
#  XRAY_resnet50_model_best_weights.zip

# %%
DRIVE_PATH = '/content/gdrive/MyDrive/Manning_Projects/'
ARCHIVE_ZIP_FILE = DRIVE_PATH + 'covid_data.zip'
ARCHIVE_ZIP_FILE
# Out:
# '/content/gdrive/MyDrive/Manning_Projects/covid_data.zip'

# %%
# !cp {ARCHIVE_ZIP_FILE} ./content/data/

# %%
archive_file =  archive_path + 'covid_data.zip'

size = os.path.getsize(archive_file)
  
print(f'Size of the file is {size/1024} MegaBytes.')
# Out:
# Size of the file is 796903.357421875 MegaBytes.

# %%
with zipfile.ZipFile(archive_file, "r") as zip_ref:
  print("Unzipping archive") 
  zip_ref.extractall(archive_path)
# Out:
# Unzipping archive

# %%
# !rm -rf ./content/data/COVID-19_Radiography_Dataset/Lung_Opacity

# %%
# !rm -rf ./content/data/COVID-19_Radiography_Dataset/Viral\ Pneumonia

# %%
COVID_IMAGE_PATH = './content/data/COVID-19_Radiography_Dataset/COVID/images'
NON_COVID_IMAGE_PATH = './content/data/COVID-19_Radiography_Dataset/Normal/images'

# %%
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
walk_through_dir(COVID_IMAGE_PATH)
# Out:
# There are 0 directories and 3616 images in './content/data/COVID-19_Radiography_Dataset/COVID/images'.

# %%
walk_through_dir(NON_COVID_IMAGE_PATH)
# Out:
# There are 0 directories and 10192 images in './content/data/COVID-19_Radiography_Dataset/Normal/images'.

# %%
random.seed(42)

COVID_IMAGE_PATH_LIST = glob.glob(COVID_IMAGE_PATH + "/*.png")
len(COVID_IMAGE_PATH_LIST), type(COVID_IMAGE_PATH_LIST)
# Out:
# (3616, list)

# %%
NON_COVID_IMAGE_PATH_LIST = glob.glob(NON_COVID_IMAGE_PATH + "/*.png")
len(NON_COVID_IMAGE_PATH_LIST), type(NON_COVID_IMAGE_PATH_LIST)
# Out:
# (10192, list)

# %%
random_image_cov = random.choice(COVID_IMAGE_PATH_LIST)
cov_pic = Image.open(random_image_cov).convert('L')
cov_pic.show()
# Out:
# <PIL.Image.Image image mode=L size=299x299 at 0x7FF4D9043640>

# %%
random_image_ncov = random.choice(NON_COVID_IMAGE_PATH_LIST)
ncov_pic = Image.open(random_image_ncov).convert('L')
ncov_pic.show()
type(ncov_pic)
# Out:
# <PIL.Image.Image image mode=L size=299x299 at 0x7FF4D9059BE0>
# PIL.Image.Image

# %%
def image_show(image_list, label):
  fig, subs = plt.subplots(3,3, figsize=(16,12))
  for i, sub in enumerate(subs.flatten()):
    #image_path = os.path.normpath(image[i])
    print(f'Image path is {image_list[i]} and label is {label}')
    img = Image.open(image_list[i])
    img.thumbnail((224,224))
    sub.imshow(img, cmap='gray')
    #sub.axis("off")
    print(f'Size of displayed image is {img.size}')
    sub.set_title(label)

# %%
random.seed(3)
ll_d_c =  []
for i in range(9):
  im = random.choice(COVID_IMAGE_PATH_LIST)
  ll_d_c.append(im)
print(ll_d_c, len(ll_d_c))

ll_d_nc = []
for i in range(9):
  im = random.choice(NON_COVID_IMAGE_PATH_LIST)
  ll_d_nc.append(im)

print(ll_d_nc, len(ll_d_nc))
# Out:
# ['./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-86.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-375.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-464.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2050.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-631.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-304.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-335.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2360.png', './content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-921.png'] 9
# ['./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6790.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-8666.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6894.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6602.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-9602.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-1181.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-8633.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-7706.png', './content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2197.png'] 9

# %%
image_show(ll_d_c, 'COVID')
# Out:
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-86.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-375.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-464.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2050.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-631.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-304.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-335.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-2360.png and label is COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/COVID/images/COVID-921.png and label is COVID
# Size of displayed image is (224, 224)

# %%
image_show(ll_d_nc, 'NON-COVID')
# Out:
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6790.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-8666.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6894.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-6602.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-9602.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-1181.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-8633.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-7706.png and label is NON-COVID
# Size of displayed image is (224, 224)
# Image path is ./content/data/COVID-19_Radiography_Dataset/Normal/images/Normal-2197.png and label is NON-COVID
# Size of displayed image is (224, 224)

# %%
random_image = random.choice(COVID_IMAGE_PATH_LIST)
random_image_gs = Image.open(random_image).convert('L')
shape= random_image_gs.size
img= np.reshape(random_image_gs, (-1, *shape, 1))
img.shape
# Out:
# (1, 299, 299, 1)

# %%
#def img_resize_save(img_path_list):
#  for i in range(len(img_path_list)):
#    temp_img = Image.open(img_path_list[i])
#    temp_img.thumbnail((224,224))
#    temp_img.save(img_path_list[i])
#  print('All images in supplied list resized to (224,224)')

#Originally I was under impression that all files have to be resized to 224,224 and then saved to disk. This is mentioned as a separate task.
#Hence, the logical deduction

# %%
df = pd.DataFrame({'Class': [len(NON_COVID_IMAGE_PATH_LIST), len(COVID_IMAGE_PATH_LIST)]})

# %%
total_class = df.Class.sum()
total_class
# Out:
# 13808

# %%
df['per_distr'] = df['Class'].apply(lambda x: x/total_class)
df.index = ['Non_Covid', 'Covid']

# %%
df.Class.plot(kind="bar", figsize=(8,6))
plt.ylabel("Number of Images")
plt.xlabel("Image Class")
plt.title("Distribution of Covid/Non-Covid Images")
plt.show()

# %%
list_arr = []
for pic in COVID_IMAGE_PATH_LIST:
  pic_np = np.array(Image.open(pic).convert('L'))
  pic_np = pic_np.reshape(299,299,1)
  list_arr.append(pic_np)

# %%
len(list_arr)
# Out:
# 3616

# %%
covid_arr = np.array(list_arr)

# %%
covid_arr.shape
# Out:
# (3616, 299, 299, 1)

# %%
np.mean(covid_arr), np.min(covid_arr), np.max(covid_arr), np.std(covid_arr)
# Out:
# (139.52120961679765, 0, 255, 61.90712697550075)

# %%
# Flatten the image data into a 1D array
pixel_values = covid_arr.flatten()

pixel_values.shape
# Out:
# (323274016,)

# %%
# Plot a histogram of the pixel values
plt.hist(pixel_values, bins=50)
plt.suptitle("Distribution of pixel values for Covid Image Data")
plt.show()

# %%
list_arr_nc = []
for pic in NON_COVID_IMAGE_PATH_LIST:
  pic_np_nc = np.array(Image.open(pic).convert('L'))
  pic_np_nc = pic_np_nc.reshape(299,299,1)
  list_arr_nc.append(pic_np_nc)
len(list_arr_nc)
# Out:
# 10192

# %%
covid_arr_nc = np.array(list_arr_nc)
covid_arr_nc.shape
# Out:
# (10192, 299, 299, 1)

# %%
np.mean(covid_arr_nc), np.max(covid_arr_nc), np.mean(covid_arr_nc), np.std(covid_arr_nc)
# Out:
# (129.38979982014257, 255, 129.38979982014257, 66.21686464627378)

# %%
# Flatten the image data into a 1D array
pixel_values_nc = covid_arr_nc.flatten()
pixel_values_nc.shape
# Out:
# (911174992,)

# %%
# Plot a histogram of the pixel values
fig, subs = plt.subplots(1,2, figsize=(24,6))
for i, sub in enumerate(subs.flatten()):
  if i==0:
    sub.hist(pixel_values_nc, bins=50)
    sub.set_title("Distribution of pixel values for Non-Covid Image Data")
  else:
    sub.hist(pixel_values, bins=50)
    sub.set_title("Distribution of pixel values for Covid Image Data")

# %% [markdown]
# ## Observation
#
# It can be seen from above two histograms that pixel intensity for covid data is more peaked(kurtosis is high) than for non-covid images.
#
# This confirms with fact that X-Ray images for covid infected patients show white patches in chest X-Ray Images.

# %%
#Lets do simple check on whether the pixel data that we get from converted .dcm files is same what we get from original png image
image = COVID_IMAGE_PATH_LIST[0]
im1 = Image.open(image).convert('L')
im1= np.array(im1)
img= sitk.GetImageFromArray(im1)
sitk.WriteImage(img,'template.dcm')

# %%
fig, subs = plt.subplots(1,2, figsize=(12,6))
for i, sub in enumerate(subs.flatten()):
  if i==0:
    #ds = pydicom.dcmread('template.dcm')
    # Load the DICOM file
    ds = pydicom.dcmread('template.dcm')
    # Access the image data
    image_d = ds.pixel_array
    print(type(image_d))
    sub.imshow(image_d, cmap='gray')
    sub.set_title("Image data from .dcm file")
  else:
    sub.imshow(im1, cmap='gray')
    sub.set_title("Image data from original png file")
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## It does looks like the data from both sources are one and same.
# ## STATUS : VERIFIED

# %% [markdown]
# ## Convert all the PNG Files to DICOM (.dcm) Format

# %%
DCM_FILE_PATH = './content/data/DCM/'
COVID_DCM_FILE_PATH = './content/data/DCM/COVID/'
NON_COVID_DCM_FILE_PATH = './content/data/DCM/NON_COVID/'
if os.path.exists(DCM_FILE_PATH):
  print(f"{DCM_FILE_PATH} directory exists.")
  if os.path.exists(COVID_DCM_FILE_PATH):
    print(f'{COVID_DCM_FILE_PATH} directory exists')
  else:
    print(f'Ok... looks like {COVID_DCM_FILE_PATH} does not exists. Let us make one')
    os.mkdir(COVID_DCM_FILE_PATH)
    print(f'{COVID_DCM_FILE_PATH} directory created successfully')
  if os.path.exists(NON_COVID_DCM_FILE_PATH):
    print(f'{NON_COVID_DCM_FILE_PATH} directory exists')
  else:
    print(f'Ok... looks like {NON_COVID_DCM_FILE_PATH} does not exists. Let us make one')
    os.mkdir(NON_COVID_DCM_FILE_PATH)
    print(f'{NON_COVID_DCM_FILE_PATH} directory created successfully')
else:
  print(f'Looks like there is no directory structure below /content/data.. Lets create required directory structures')
  print(f'Creating {DCM_FILE_PATH} directory path first')
  os.mkdir(DCM_FILE_PATH)
  print(f'{DCM_FILE_PATH} directory created successfully')

  print(f'Creating {COVID_DCM_FILE_PATH} directory path')
  os.mkdir(COVID_DCM_FILE_PATH)
  print(f'{COVID_DCM_FILE_PATH} directory created successfully')

  print(f'Creating {NON_COVID_DCM_FILE_PATH} directory path')
  os.mkdir(NON_COVID_DCM_FILE_PATH)
  print(f'{NON_COVID_DCM_FILE_PATH} directory created successfully')
# Out:
# ./content/data/DCM/ directory exists.
# ./content/data/DCM/COVID/ directory exists
# ./content/data/DCM/NON_COVID/ directory exists

# %%
def pngtodcm(image_list, COVID, l_i):
  print(f'COVID variable is set to {COVID}')
  list_im = []
  list_im = l_i

  for png_image in image_list:
    png_im_arr = np.array(Image.open(png_image).convert('L'))
    dcm_im_arr = sitk.GetImageFromArray(png_im_arr)
    if COVID:
      SAVE_PATH = COVID_DCM_FILE_PATH
      list_im = list_im_c
    else:
      SAVE_PATH = NON_COVID_DCM_FILE_PATH
      list_im = list_im_nc
    FILENAME = png_image.split("/")[-1].split(".")[0]
    DCM_FILENAME = SAVE_PATH + FILENAME + '.dcm'
    sitk.WriteImage(dcm_im_arr, DCM_FILENAME)
    print(f'Successfully converted and saved {DCM_FILENAME}')
    list_im.append(DCM_FILENAME)

# %%
list_im_c = []
pngtodcm(COVID_IMAGE_PATH_LIST, True, list_im_c)
# Out:
# COVID variable is set to True
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1010.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2529.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3577.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1230.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1113.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1200.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1601.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2392.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3307.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-619.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1853.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-824.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3214.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3054.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3558.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1008.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-9.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2100.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3440.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3350.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-991.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-446.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1293.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-372.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2319.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1420.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1505.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-871.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2710.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-795.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1213.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1324.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1151.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2103.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3441.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1376.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2528.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2920.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1393.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2310.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2632.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1414.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1683.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2738.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-707.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-630.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3291.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-443.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3035.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2124.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2488.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2372.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2435.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-435.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-337.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2140.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-164.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2464.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-888.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-854.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2324.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1620.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2759.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2388.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1861.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1947.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1517.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-561.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-475.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1494.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1089.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-3590.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-1528.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2937.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-2014.dcm
# Successfully converted and saved ./content/data/DCM/COVID/COVID-

# Out:
# ('./content/data/DCM/NON_COVID/Normal-9179.dcm',
#  './content/data/DCM/COVID/COVID-1010.dcm')

# %%
def extract_fnames(file_list):
  temp_ll = []
  for i in file_list:
    fname = i.split("/")[-1].split(".")[0]
    temp_ll.append(fname)
    return sorted(temp_ll)

# %%
ll_dc_fname = extract_fnames(list_im_c)
ll_dnc_fname = extract_fnames(list_im_nc)
ll_pc_fname = extract_fnames(COVID_IMAGE_PATH_LIST)
ll_pnc_fname = extract_fnames(NON_COVID_IMAGE_PATH_LIST)

# %%
ll_dc_fname == ll_pc_fname
# Out:
# True

# %%
ll_dnc_fname == ll_pnc_fname
# Out:
# True

# %%
df_nc = pd.DataFrame()

# %%
df_nc['filename'] = list_im_nc

# %%
df_nc['class'] = 0

# %%
df_nc
# Out:
#                                            filename  class
# 0      ./content/data/DCM/NON_COVID/Normal-9179.dcm      0
# 1      ./content/data/DCM/NON_COVID/Normal-7818.dcm      0
# 2      ./content/data/DCM/NON_COVID/Normal-4910.dcm      0
# 3      ./content/data/DCM/NON_COVID/Normal-9262.dcm      0
# 4      ./content/data/DCM/NON_COVID/Normal-8994.dcm      0
# ...                                             ...    ...
# 10187  ./content/data/DCM/NON_COVID/Normal-5480.dcm      0
# 10188  ./content/data/DCM/NON_COVID/Normal-8950.dcm      0
# 10189  ./content/data/DCM/NON_COVID/Normal-7232.dcm      0
# 10190  ./content/data/DCM/NON_COVID/Normal-1186.dcm      0
# 10191  ./content/data/DCM/NON_COVID/Normal-8343.dcm      0
#
# [10192 rows x 2 columns]

# %%
label_1 = list(np.ones(len(list_im_c), dtype=int))
len(label_1), len(list_im_c)
# Out:
# (3616, 3616)

# %%
dict_c = {'filename': list_im_c, 'class': label_1}

# %%
df_c = pd.DataFrame(data=dict_c)

# %%
df_c
# Out:
#                                      filename  class
# 0     ./content/data/DCM/COVID/COVID-1010.dcm      1
# 1     ./content/data/DCM/COVID/COVID-2529.dcm      1
# 2     ./content/data/DCM/COVID/COVID-3577.dcm      1
# 3     ./content/data/DCM/COVID/COVID-1230.dcm      1
# 4     ./content/data/DCM/COVID/COVID-1113.dcm      1
# ...                                       ...    ...
# 3611   ./content/data/DCM/COVID/COVID-470.dcm      1
# 3612  ./content/data/DCM/COVID/COVID-3402.dcm      1
# 3613   ./content/data/DCM/COVID/COVID-787.dcm      1
# 3614  ./content/data/DCM/COVID/COVID-1686.dcm      1
# 3615  ./content/data/DCM/COVID/COVID-2465.dcm      1
#
# [3616 rows x 2 columns]

# %%
df = pd.concat([df_nc, df_c])

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns=['index'], inplace=True)

# %%
df
# Out:
#                                            filename  class
# 0      ./content/data/DCM/NON_COVID/Normal-9179.dcm      0
# 1      ./content/data/DCM/NON_COVID/Normal-7818.dcm      0
# 2      ./content/data/DCM/NON_COVID/Normal-4910.dcm      0
# 3      ./content/data/DCM/NON_COVID/Normal-9262.dcm      0
# 4      ./content/data/DCM/NON_COVID/Normal-8994.dcm      0
# ...                                             ...    ...
# 13803        ./content/data/DCM/COVID/COVID-470.dcm      1
# 13804       ./content/data/DCM/COVID/COVID-3402.dcm      1
# 13805        ./content/data/DCM/COVID/COVID-787.dcm      1
# 13806       ./content/data/DCM/COVID/COVID-1686.dcm      1
# 13807       ./content/data/DCM/COVID/COVID-2465.dcm      1
#
# [13808 rows x 2 columns]

# %%
df['class'].value_counts()
# Out:
# 0    10192
# 1     3616
# Name: class, dtype: int64

# %%
df.to_csv('./content/data/DCM/dcm_files_list_labels.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13808 entries, 0 to 13807
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  13808 non-null  object
#  1   class     13808 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 215.9+ KB

# %% [markdown]
# ## Milestone 1.2

# %%
df_loaddata = pd.read_csv('./content/data/DCM/dcm_files_list_labels.csv')

# %%
df_loaddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13808 entries, 0 to 13807
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  13808 non-null  object
#  1   class     13808 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 215.9+ KB

# %%
len(df_loaddata.filename.unique())
# Out:
# 13808

# %%
df_loaddata['class'].value_counts()
# Out:
# 0    10192
# 1     3616
# Name: class, dtype: int64

# %%
df_X = df_loaddata.drop(columns=['class'])
df_y = df_loaddata['class']

# %%
df_y.head(), df_X.head()
# Out:
# (0    0
#  1    0
#  2    0
#  3    0
#  4    0
#  Name: class, dtype: int64,
#                                         filename
#  0  ./content/data/DCM/NON_COVID/Normal-9179.dcm
#  1  ./content/data/DCM/NON_COVID/Normal-7818.dcm
#  2  ./content/data/DCM/NON_COVID/Normal-4910.dcm
#  3  ./content/data/DCM/NON_COVID/Normal-9262.dcm
#  4  ./content/data/DCM/NON_COVID/Normal-8994.dcm)

# %%
train_df, test_df = train_test_split(df_loaddata, test_size=0.2, random_state=42, stratify=df['class'])

len(train_df), len(test_df)
# Out:
# (11046, 2762)

# %%
# we need to further reserve 20% data in training for validation
train_df, valid_df = train_test_split(train_df, test_size=0.2, random_state=42, stratify=train_df['class'])

len(train_df), len(valid_df)
# Out:
# (8836, 2210)

# %%
train_df['class'].sum(), valid_df['class'].sum(), test_df['class'].sum()
# Out:
# (2314, 579, 723)

# %%
train_df['class'].sum() + valid_df['class'].sum() + test_df['class'].sum()
# Out:
# 3616

# %%
train_aug_params = dict(
    rescale=1./255,
    rotation_range=10,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    brightness_range = [0.8, 1.2]
)

valid_aug_params = dict(
    rescale=1./255
    )

test_aug_params = dict(
    rescale=1./255
)

# %%
#Creating augmenters

train_augmenter = ImageDataGenerator(**train_aug_params)
valid_augmenter = ImageDataGenerator(**valid_aug_params)
test_augmenter = ImageDataGenerator(**test_aug_params)

# %%
type(train_augmenter), type(valid_augmenter), type(test_augmenter)
# Out:
# (keras.preprocessing.image.ImageDataGenerator,
#  keras.preprocessing.image.ImageDataGenerator,
#  keras.preprocessing.image.ImageDataGenerator)

# %%
# training parameters
BATCH_SIZE = 32
COLOR_MODE = 'grayscale'
TARGET_SIZE = (224, 224)
EPOCHS = 10

train_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE,  
}

valid_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE, 
    'shuffle': False
}

test_consts = {
    'batch_size': BATCH_SIZE,
    'color_mode': COLOR_MODE,
    'target_size': TARGET_SIZE,  # resize input images
    'shuffle': False
}

# %%
class DCMDataFrameIterator(DataFrameIterator):
    def __init__(self, *arg, **kwargs):
        self.white_list_formats = ('dcm')
        super(DCMDataFrameIterator, self).__init__(*arg, **kwargs)
        self.dataframe = kwargs['dataframe']
        self.x = self.dataframe[kwargs['x_col']]
        self.y = self.dataframe[kwargs['y_col']]
        self.color_mode = kwargs['color_mode']
        self.target_size = kwargs['target_size']

    def _get_batches_of_transformed_samples(self, indices_array):
        # get batch of images
        batch_x = np.array([self.read_dcm_as_array(dcm_path, self.target_size, color_mode=self.color_mode)
                            for dcm_path in self.x.iloc[indices_array]])

        batch_y = np.array(self.y.iloc[indices_array].astype(np.uint8))  # astype because y was passed as str

        # transform images
        if self.image_data_generator is not None:
            for i, (x, y) in enumerate(zip(batch_x, batch_y)):
                transform_params = self.image_data_generator.get_random_transform(x.shape)
                batch_x[i] = self.image_data_generator.apply_transform(x, transform_params)
                
                # you can change y here as well, eg: in semantic segmentation you want to transform masks as well 
                # using the same image_data_generator transformations.

        return batch_x, batch_y

    @staticmethod
    def read_dcm_as_array(dcm_path, target_size=(256, 256), color_mode='rgb'):
        image_array = pydicom.dcmread(dcm_path).pixel_array
        image = Image.fromarray(image_array) #converts from array to PIL
        #image = Image.open(image).convert('L')
        image.thumbnail((224,224)) #resize image to 224,224
        #image_array = cv2.resize(image_array, target_size, interpolation=cv2.INTER_NEAREST)  #this returns a 2d array
        image_array = np.expand_dims(image, -1)
        return image_array.astype(np.float32)

# %%
train_df['class'] = train_df['class'].astype('str')
valid_df['class'] = valid_df['class'].astype('str')
test_df['class'] = test_df['class'].astype('str')

# %%
train_df.info(), valid_df.info(),  test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8836 entries, 13528 to 8134
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  8836 non-null   object
#  1   class     8836 non-null   object
# dtypes: object(2)
# memory usage: 207.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2210 entries, 6681 to 12452
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  2210 non-null   object
#  1   class     2210 non-null   object
# dtypes: object(2)
# memory usage: 51.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2762 entries, 1939 to 8436
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  2762 non-null   object
#  1   class     2762 non-null   object
# dtypes: object(2)
# memory usage: 64.7+ KB
# (None, None, None)

# %%
train_generator = DCMDataFrameIterator(dataframe=train_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=train_augmenter,
                             **train_consts)

valid_generator = DCMDataFrameIterator(dataframe=valid_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=valid_augmenter,
                             **valid_consts)

test_generator = DCMDataFrameIterator(dataframe=test_df,
                             x_col='filename',
                             y_col='class',
                             image_data_generator=test_augmenter,
                             **test_consts)
# Out:
# Found 8836 validated image filenames belonging to 2 classes.
# Found 2210 validated image filenames belonging to 2 classes.
# Found 2762 validated image filenames belonging to 2 classes.

# %%
#train_augmenter.fit(train_generator)

# %%
classes = ['NON-COVID', 'COVID']

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(train_generator))

imgs.shape, labels.shape, type(imgs), type(labels)
# Out:
# ((32, 224, 224, 1), (32,), numpy.ndarray, numpy.ndarray)

# %%
imgs[0].mean(), imgs[0].max(), imgs[0].min()
# Out:
# (89.96429, 212.0, 0.0)

# %%
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(valid_generator))
print(imgs.shape, labels.shape, type(imgs), type(labels))
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()
# Out:
# (32, 224, 224, 1) (32,) <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
#Lets fetch some images from generator to ensure it is working good
imgs, labels = next(iter(test_generator))
print(imgs.shape, labels.shape, type(imgs), type(labels))
plt.imshow(imgs[0], cmap='gray')
plt.title(classes[labels[0]])
plt.show()
# Out:
# (32, 224, 224, 1) (32,) <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
imgs[0].dtype
# Out:
# dtype('float32')

# %%
#imgs[0]

# %%
#help(train_generator)

# %%
#help(tensorflow.python.keras.layers.convolutional.Conv2D)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Dense, Dropout, Add, Flatten, LayerNormalization, Activation, Input
from tensorflow.keras import Sequential
try:
    from einops import rearrange, repeat
    from einops.layers.tensorflow import Rearrange
except:
    print("Einops not installed, Initiating install")
    # !pip install einops
    from einops import rearrange, repeat
    from einops.layers.tensorflow import Rearrange
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
from tensorflow.keras.layers import Resizing, Rescaling, Normalization

# %%
class Image_Embedding(tf.keras.Model):
    def __init__(self):
        super().__init__()
        #self.conv_3D = Conv2D(3, (3,3), padding='same')
        #self.preprocess_input = Sequential([
        #    Rescaling(0.00392156862745098),
        #    Normalization(mean=0.5, variance=0.5)
        #    ])
        self.conv_split_image = Conv2D(768, (16,16), strides=(16,16))
        self.cls_token = tf.Variable(initial_value=tf.random.normal([1, 1, 768]))
        self.pos_embedding = tf.Variable(initial_value=tf.random.normal([1, 197, 768]))
        self.drop = Dropout(0.1)
        #self.training=True
        
    def call(self, x):    # , training=True)
        #x = self.conv_3D(x)
        #x = self.preprocess_input(x)
        x = self.conv_split_image(x)
        if x.shape[0] == None:
            x = tf.reshape(x, (1, -1, 768))
        else:
            x = tf.reshape(x, (x.shape[0], -1, 768)) #original
        b,n,d = x.shape
        
        cls_tokens = repeat(self.cls_token, '() n d -> b n d', b=b)
        x = tf.concat([cls_tokens, x], axis =1)
        x += self.pos_embedding
        x = self.drop(x) #, training=training)
        
        return x

# %%
input = tf.Variable(initial_value=tf.random.normal([1,224,224,1]))
input.shape
# Out:
# TensorShape([1, 224, 224, 1])

# %%
patch_embed = Image_Embedding()
type(patch_embed)
# Out:
# __main__.Image_Embedding

# %%
out = patch_embed(input)
out.shape
# Out:
# TensorShape([1, 197, 768])

# %%
class Attention_0_0(tf.keras.Model):
    def __init__(self, num_heads, out_dims):
        super().__init__()
        self.embed_dim = out_dims/num_heads
        self.Qw = Dense(self.embed_dim)
        self.Kw = Dense(self.embed_dim)
        self.Vw = Dense(self.embed_dim)
        
    
    def call(self, x):
        Q = self.Qw(x)
        K = self.Kw(x)
        V = self.Vw(x)
        KT = tf.transpose(K, perm=[0,2,1])
        ScaledDotProductAttention_0 = tf.matmul(Q, KT)
        ScaledDotProductAttention_1 = ScaledDotProductAttention_0/tf.math.sqrt(float(self.embed_dim))
        ScaledDotProductAttention_2 = tf.nn.softmax(ScaledDotProductAttention_1, axis=-1)
        ScaledDotProductAttention_3 = tf.matmul(ScaledDotProductAttention_2, V)
        scp = tf.transpose(ScaledDotProductAttention_3, perm=[0,2,1])
        return scp

# %%
class Full_Single_Attention_Block(tf.keras.Model):
    def __init__(self, num_heads, out_dims):
        super().__init__()
        self.layer_norm = LayerNormalization()
        self.num_heads = num_heads
        self.out_dims = out_dims
        self.attention_heads = self.get_attention_heads()
    
    def get_attention_heads(self):
        list_attention_heads = []
        for i in range(self.num_heads):
            att_head = Attention_0_0(self.num_heads, self.out_dims)
            list_attention_heads.append(att_head)
        return list_attention_heads
    
    def call(self, x):
        pre_norm = x
        x = self.layer_norm(x)
        list_attention_heads_out = []
        for heads in self.attention_heads:
            x_i = heads(x)
            list_attention_heads_out.append(x_i)
        x = tf.concat(list_attention_heads_out, axis=1)
        x = tf.transpose(x, perm=[0,2,1])
        x += pre_norm 
        
        return x

# %%
class Encoder(tf.keras.Model):
    def __init__(self, num_heads, out_dims):
        super().__init__()
        
       
        self.multiheadedattention = Full_Single_Attention_Block(num_heads, out_dims)
        self.pre_mlp_layer_norm = LayerNormalization()
        self.intermediate = Sequential([
            Dense(3072),
            Activation('gelu'), #tf.nn.gelu(),
            Dropout(0.1)
        ])
        
        self.out = Sequential([
            Dense(768),
            Dropout(0.1)
        ])
        
        
    def call(self, x):
        x = self.multiheadedattention(x)
        pre_mlp_norm = x
        x = self.pre_mlp_layer_norm(x)
        x = self.intermediate(x)
        x = self.out(x)
        x += pre_mlp_norm
        return x

# %%
class VisionTransformer(tf.keras.Model):
    def __init__(self, num_heads, num_encoders, num_classes, out_dims):
        super().__init__()
        
        self.num_heads = num_heads
        self.num_encoders = num_encoders
        self.num_classes = num_classes
        #new
        self.out_dims = out_dims #768
        
        self.image_embed = Image_Embedding()
        self.encoders = Sequential(self.get_encoders())
        self.classifier = Sequential([
            Flatten(),
            Dense(512, use_bias=False),
            BatchNormalization(),
            Activation('gelu'),
            Dropout(0.1),
            Dense(128, use_bias=False),
            BatchNormalization(),
            Activation('gelu'),
            Dropout(0.1),
            Dense(2)
        ])
        
    def get_encoders(self):
        list_encoder = []
        for i in range(self.num_encoders):
            enc = Encoder(self.num_heads, self.out_dims)
            list_encoder.append(enc)
            
        return list_encoder
    
    def call(self, x):
        x = self.image_embed(x)
        x = self.encoders(x)
        #x = self.classifier(x[:, 0])
        x = self.classifier(x)
        return x

# %%
#VisionTransformer(num_heads, num_encoders, num_classes, out_dims)
#self.embed_dim = out_dims/num_heads
model = VisionTransformer(6, 12, 2, 768)

# %%
X_input = Input(shape=(224,224,1,))
out = VisionTransformer(6, 12, 2, 768)(X_input)
temp_model = tf.keras.Model(inputs=X_input, outputs=out)
temp_model.summary(expand_nested=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 1)]     0
#
#  vision_transformer_1 (Visio  (1, 2)                   155848706
#  nTransformer)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | image__embedding_2 (Image_E  multiple               349440    |
# | mbedding)                                                     |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || conv2d_2 (Conv2D)       multiple                  197376    ||
# ||                                                             ||
# || dropout_28 (Dropout)    multiple                  0         ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_50 (Sequential)  (1, 197, 768)           77967360  |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || encoder_12 (Encoder)    (1, 197, 768)             6497280   ||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| full__single__attention__bl  multiple           1773312   |||
# ||| ock_12 (Full_Single_Attenti                               |||
# ||| on_Block)                                                 |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| layer_normalization_24 (Lay  multiple         1536      ||||
# |||| erNormalization)                                        ||||
# ||||                                                         ||||
# |||| attention_0_0_72 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_243 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_244 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_245 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_73 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_246 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_247 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_248 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_74 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_249 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_250 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_251 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_75 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_252 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_253 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_254 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_76 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_255 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_256 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_257 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_77 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_258 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_259 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_260 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| layer_normalization_25 (Lay  multiple           1536      |||
# ||| erNormalization)                                          |||
# |||                                                           |||
# ||| sequential_26 (Sequential)  (1, 197, 3072)      2362368   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_261 (Dense)   (1, 197, 3072)            2362368   ||||
# ||||                                                         ||||
# |||| activation_14 (Activation)  (1, 197, 3072)    0         ||||
# ||||                                                         ||||
# |||| dropout_29 (Dropout)  (1, 197, 3072)          0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| sequential_27 (Sequential)  (1, 197, 768)       2360064   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_262 (Dense)   (1, 197, 768)             2360064   ||||
# ||||                                                         ||||
# |||| dropout_30 (Dropout)  (1, 197, 768)           0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || encoder_13 (Encoder)    (1, 197, 768)             6497280   ||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| full__single__attention__bl  multiple           1773312   |||
# ||| ock_13 (Full_Single_Attenti                               |||
# ||| on_Block)                                                 |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| layer_normalization_26 (Lay  multiple         1536      ||||
# |||| erNormalization)                                        ||||
# ||||                                                         ||||
# |||| attention_0_0_78 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_263 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_264 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_265 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_79 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_266 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_267 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_268 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_80 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_269 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_270 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_271 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_81 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_272 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_273 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_274 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_82 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_275 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_276 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_277 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_83 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_278 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_279 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_280 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| layer_normalization_27 (Lay  multiple           1536      |||
# ||| erNormalization)                                          |||
# |||                                                           |||
# ||| sequential_28 (Sequential)  (1, 197, 3072)      2362368   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_281 (Dense)   (1, 197, 3072)            2362368   ||||
# ||||                                                         ||||
# |||| activation_15 (Activation)  (1, 197, 3072)    0         ||||
# ||||                                                         ||||
# |||| dropout_31 (Dropout)  (1, 197, 3072)          0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| sequential_29 (Sequential)  (1, 197, 768)       2360064   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_282 (Dense)   (1, 197, 768)             2360064   ||||
# ||||                                                         ||||
# |||| dropout_32 (Dropout)  (1, 197, 768)           0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || encoder_14 (Encoder)    (1, 197, 768)             6497280   ||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| full__single__attention__bl  multiple           1773312   |||
# ||| ock_14 (Full_Single_Attenti                               |||
# ||| on_Block)                                                 |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| layer_normalization_28 (Lay  multiple         1536      ||||
# |||| erNormalization)                                        ||||
# ||||                                                         ||||
# |||| attention_0_0_84 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_283 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_284 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_285 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_85 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_286 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_287 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_288 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_86 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_289 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_290 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_291 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_87 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_292 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_293 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_294 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_88 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_295 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_296 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_297 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_89 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_298 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_299 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_300 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| layer_normalization_29 (Lay  multiple           1536      |||
# ||| erNormalization)                                          |||
# |||                                                           |||
# ||| sequential_30 (Sequential)  (1, 197, 3072)      2362368   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_301 (Dense)   (1, 197, 3072)            2362368   ||||
# ||||                                                         ||||
# |||| activation_16 (Activation)  (1, 197, 3072)    0         ||||
# ||||                                                         ||||
# |||| dropout_33 (Dropout)  (1, 197, 3072)          0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| sequential_31 (Sequential)  (1, 197, 768)       2360064   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_302 (Dense)   (1, 197, 768)             2360064   ||||
# ||||                                                         ||||
# |||| dropout_34 (Dropout)  (1, 197, 768)           0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || encoder_15 (Encoder)    (1, 197, 768)             6497280   ||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| full__single__attention__bl  multiple           1773312   |||
# ||| ock_15 (Full_Single_Attenti                               |||
# ||| on_Block)                                                 |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| layer_normalization_30 (Lay  multiple         1536      ||||
# |||| erNormalization)                                        ||||
# ||||                                                         ||||
# |||| attention_0_0_90 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_303 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_304 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_305 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_91 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_306 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_307 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_308 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_92 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_309 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_310 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_311 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_93 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_312 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_313 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_314 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_94 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_315 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_316 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_317 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_95 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_318 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_319 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_320 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| layer_normalization_31 (Lay  multiple           1536      |||
# ||| erNormalization)                                          |||
# |||                                                           |||
# ||| sequential_32 (Sequential)  (1, 197, 3072)      2362368   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_321 (Dense)   (1, 197, 3072)            2362368   ||||
# ||||                                                         ||||
# |||| activation_17 (Activation)  (1, 197, 3072)    0         ||||
# ||||                                                         ||||
# |||| dropout_35 (Dropout)  (1, 197, 3072)          0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| sequential_33 (Sequential)  (1, 197, 768)       2360064   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_322 (Dense)   (1, 197, 768)             2360064   ||||
# ||||                                                         ||||
# |||| dropout_36 (Dropout)  (1, 197, 768)           0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || encoder_16 (Encoder)    (1, 197, 768)             6497280   ||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| full__single__attention__bl  multiple           1773312   |||
# ||| ock_16 (Full_Single_Attenti                               |||
# ||| on_Block)                                                 |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| layer_normalization_32 (Lay  multiple         1536      ||||
# |||| erNormalization)                                        ||||
# ||||                                                         ||||
# |||| attention_0_0_96 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_323 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_324 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_325 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_97 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_326 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_327 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_328 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_98 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_329 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_330 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_331 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_99 (Attention  multiple         295296    ||||
# |||| _0_0)                                                   ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_332 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_333 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_334 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_100 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_335 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_336 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_337 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_101 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_338 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_339 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_340 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| layer_normalization_33 (Lay  multiple           1536      |||
# ||| erNormalization)                                          |||
# |||                                                           |||
# ||| sequential_34 (Sequential)  (1, 197, 3072)      2362368   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_341 (Dense)   (1, 197, 3072)            2362368   ||||
# ||||                                                         ||||
# |||| activation_18 (Activation)  (1, 197, 3072)    0         ||||
# ||||                                                         ||||
# |||| dropout_37 (Dropout)  (1, 197, 3072)          0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| sequential_35 (Sequential)  (1, 197, 768)       2360064   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_342 (Dense)   (1, 197, 768)             2360064   ||||
# ||||                                                         ||||
# |||| dropout_38 (Dropout)  (1, 197, 768)           0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || encoder_17 (Encoder)    (1, 197, 768)             6497280   ||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| full__single__attention__bl  multiple           1773312   |||
# ||| ock_17 (Full_Single_Attenti                               |||
# ||| on_Block)                                                 |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| layer_normalization_34 (Lay  multiple         1536      ||||
# |||| erNormalization)                                        ||||
# ||||                                                         ||||
# |||| attention_0_0_102 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_343 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_344 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_345 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_103 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_346 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_347 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_348 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_104 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_349 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_350 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_351 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_105 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_352 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_353 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_354 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_106 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_355 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_356 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_357 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_107 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_358 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_359 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_360 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| layer_normalization_35 (Lay  multiple           1536      |||
# ||| erNormalization)                                          |||
# |||                                                           |||
# ||| sequential_36 (Sequential)  (1, 197, 3072)      2362368   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_361 (Dense)   (1, 197, 3072)            2362368   ||||
# ||||                                                         ||||
# |||| activation_19 (Activation)  (1, 197, 3072)    0         ||||
# ||||                                                         ||||
# |||| dropout_39 (Dropout)  (1, 197, 3072)          0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| sequential_37 (Sequential)  (1, 197, 768)       2360064   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_362 (Dense)   (1, 197, 768)             2360064   ||||
# ||||                                                         ||||
# |||| dropout_40 (Dropout)  (1, 197, 768)           0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || encoder_18 (Encoder)    (1, 197, 768)             6497280   ||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| full__single__attention__bl  multiple           1773312   |||
# ||| ock_18 (Full_Single_Attenti                               |||
# ||| on_Block)                                                 |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| layer_normalization_36 (Lay  multiple         1536      ||||
# |||| erNormalization)                                        ||||
# ||||                                                         ||||
# |||| attention_0_0_108 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_363 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_364 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_365 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_109 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_366 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_367 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_368 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_110 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_369 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_370 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_371 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_111 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_372 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_373 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_374 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_112 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_375 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_376 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_377 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_113 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_378 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_379 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_380 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| layer_normalization_37 (Lay  multiple           1536      |||
# ||| erNormalization)                                          |||
# |||                                                           |||
# ||| sequential_38 (Sequential)  (1, 197, 3072)      2362368   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_381 (Dense)   (1, 197, 3072)            2362368   ||||
# ||||                                                         ||||
# |||| activation_20 (Activation)  (1, 197, 3072)    0         ||||
# ||||                                                         ||||
# |||| dropout_41 (Dropout)  (1, 197, 3072)          0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| sequential_39 (Sequential)  (1, 197, 768)       2360064   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_382 (Dense)   (1, 197, 768)             2360064   ||||
# ||||                                                         ||||
# |||| dropout_42 (Dropout)  (1, 197, 768)           0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || encoder_19 (Encoder)    (1, 197, 768)             6497280   ||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| full__single__attention__bl  multiple           1773312   |||
# ||| ock_19 (Full_Single_Attenti                               |||
# ||| on_Block)                                                 |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| layer_normalization_38 (Lay  multiple         1536      ||||
# |||| erNormalization)                                        ||||
# ||||                                                         ||||
# |||| attention_0_0_114 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_383 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_384 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_385 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_115 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_386 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_387 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_388 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_116 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_389 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_390 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_391 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_117 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_392 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_393 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_394 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_118 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_395 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_396 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_397 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_119 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_398 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_399 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_400 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| layer_normalization_39 (Lay  multiple           1536      |||
# ||| erNormalization)                                          |||
# |||                                                           |||
# ||| sequential_40 (Sequential)  (1, 197, 3072)      2362368   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_401 (Dense)   (1, 197, 3072)            2362368   ||||
# ||||                                                         ||||
# |||| activation_21 (Activation)  (1, 197, 3072)    0         ||||
# ||||                                                         ||||
# |||| dropout_43 (Dropout)  (1, 197, 3072)          0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| sequential_41 (Sequential)  (1, 197, 768)       2360064   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_402 (Dense)   (1, 197, 768)             2360064   ||||
# ||||                                                         ||||
# |||| dropout_44 (Dropout)  (1, 197, 768)           0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || encoder_20 (Encoder)    (1, 197, 768)             6497280   ||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| full__single__attention__bl  multiple           1773312   |||
# ||| ock_20 (Full_Single_Attenti                               |||
# ||| on_Block)                                                 |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| layer_normalization_40 (Lay  multiple         1536      ||||
# |||| erNormalization)                                        ||||
# ||||                                                         ||||
# |||| attention_0_0_120 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_403 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_404 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_405 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_121 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_406 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_407 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_408 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_122 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_409 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_410 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_411 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_123 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_412 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_413 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_414 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_124 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_415 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_416 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_417 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# ...
# |||||                                                       |||||
# ||||| dense_431 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_129 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_432 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_433 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_434 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_130 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_435 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_436 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_437 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_131 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_438 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_439 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_440 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| layer_normalization_43 (Lay  multiple           1536      |||
# ||| erNormalization)                                          |||
# |||                                                           |||
# ||| sequential_44 (Sequential)  (1, 197, 3072)      2362368   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_441 (Dense)   (1, 197, 3072)            2362368   ||||
# ||||                                                         ||||
# |||| activation_23 (Activation)  (1, 197, 3072)    0         ||||
# ||||                                                         ||||
# |||| dropout_47 (Dropout)  (1, 197, 3072)          0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| sequential_45 (Sequential)  (1, 197, 768)       2360064   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_442 (Dense)   (1, 197, 768)             2360064   ||||
# ||||                                                         ||||
# |||| dropout_48 (Dropout)  (1, 197, 768)           0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || encoder_22 (Encoder)    (1, 197, 768)             6497280   ||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| full__single__attention__bl  multiple           1773312   |||
# ||| ock_22 (Full_Single_Attenti                               |||
# ||| on_Block)                                                 |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| layer_normalization_44 (Lay  multiple         1536      ||||
# |||| erNormalization)                                        ||||
# ||||                                                         ||||
# |||| attention_0_0_132 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_443 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_444 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_445 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_133 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_446 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_447 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_448 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_134 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_449 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_450 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_451 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_135 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_452 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_453 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_454 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_136 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_455 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_456 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_457 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_137 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_458 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_459 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_460 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| layer_normalization_45 (Lay  multiple           1536      |||
# ||| erNormalization)                                          |||
# |||                                                           |||
# ||| sequential_46 (Sequential)  (1, 197, 3072)      2362368   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_461 (Dense)   (1, 197, 3072)            2362368   ||||
# ||||                                                         ||||
# |||| activation_24 (Activation)  (1, 197, 3072)    0         ||||
# ||||                                                         ||||
# |||| dropout_49 (Dropout)  (1, 197, 3072)          0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| sequential_47 (Sequential)  (1, 197, 768)       2360064   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_462 (Dense)   (1, 197, 768)             2360064   ||||
# ||||                                                         ||||
# |||| dropout_50 (Dropout)  (1, 197, 768)           0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || encoder_23 (Encoder)    (1, 197, 768)             6497280   ||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| full__single__attention__bl  multiple           1773312   |||
# ||| ock_23 (Full_Single_Attenti                               |||
# ||| on_Block)                                                 |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| layer_normalization_46 (Lay  multiple         1536      ||||
# |||| erNormalization)                                        ||||
# ||||                                                         ||||
# |||| attention_0_0_138 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_463 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_464 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_465 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_139 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_466 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_467 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_468 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_140 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_469 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_470 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_471 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_141 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_472 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_473 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_474 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_142 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_475 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_476 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_477 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| attention_0_0_143 (Attentio  multiple         295296    ||||
# |||| n_0_0)                                                  ||||
# |||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||||
# ||||| dense_478 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_479 (Dense)  multiple                 98432     |||||
# |||||                                                       |||||
# ||||| dense_480 (Dense)  multiple                 98432     |||||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| layer_normalization_47 (Lay  multiple           1536      |||
# ||| erNormalization)                                          |||
# |||                                                           |||
# ||| sequential_48 (Sequential)  (1, 197, 3072)      2362368   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_481 (Dense)   (1, 197, 3072)            2362368   ||||
# ||||                                                         ||||
# |||| activation_25 (Activation)  (1, 197, 3072)    0         ||||
# ||||                                                         ||||
# |||| dropout_51 (Dropout)  (1, 197, 3072)          0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||| sequential_49 (Sequential)  (1, 197, 768)       2360064   |||
# ||||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||||
# |||| dense_482 (Dense)   (1, 197, 768)             2360064   ||||
# ||||                                                         ||||
# |||| dropout_52 (Dropout)  (1, 197, 768)           0         ||||
# |||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|||
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | sequential_51 (Sequential)  (1, 2)                  77531906  |
# ||¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯||
# || flatten_1 (Flatten)     (1, 151296)               0         ||
# ||                                                             ||
# || dense_483 (Dense)       (1, 512)                  77463552  ||
# ||                                                             ||
# || batch_normalization_2 (Batc  (1, 512)             2048      ||
# || hNormalization)                                             ||
# ||                                                             ||
# || activation_26 (Activation)  (1, 512)              0         ||
# ||                                                             ||
# || dropout_53 (Dropout)    (1, 512)                  0         ||
# ||                                                             ||
# || dense_484 (Dense)       (1, 128)                  65536     ||
# ||                                                             ||
# || batch_normalization_3 (Batc  (1, 128)             512       ||
# || hNormalization)                                             ||
# ||                                                             ||
# || activation_27 (Activation)  (1, 128)              0         ||
# ||                                                             ||
# || dropout_54 (Dropout)    (1, 128)                  0         ||
# ||                                                             ||
# || dense_485 (Dense)       (1, 2)                    258       ||
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 155,848,706
# Trainable params: 155,847,426
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
from tensorflow import data, train, math, reduce_sum, cast, equal, argmax, \
float32, GradientTape, TensorSpec, function, int64

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
  def __init__(self, d_model, warmup_steps=277*2):
    super().__init__()
    self.initial_learning_rate = 0.0001

    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps

  def __call__(self, step):
    step = tf.cast(step, dtype=tf.float32)
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)

    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
#opt = Adam(LRScheduler(768))
opt = Adam(learning_rate=0.0002)
#learning_rate = CustomSchedule(768)
#opt = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.999,epsilon=1e-9)
loss_fn = tensorflow.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
plt.plot(learning_rate(tf.range(2760*2, dtype=tf.float32)))
plt.ylabel('Learning Rate')
plt.xlabel('Train Step')
# Out:
# Text(0.5, 0, 'Train Step')

# %%
train_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()
val_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()
test_acc_metric = tensorflow.keras.metrics.SparseCategoricalAccuracy()

# %%
from sklearn.metrics import confusion_matrix

# %%
if os.path.exists('./content/data/ckpt'):
    print(f'Weight Checkpoint directory already exists')
    # !ls -ld ./content/data/ckpt
else:
    print(f'Weight Checkpooint directory doesnt exists.. Creating it now..')
    os.mkdir('./content/data/ckpt')
    print(f'Weight Checkpoint directory successfully created')
    # !ls -ld ./content/data/ckpt

    
if os.path.exists('./content/data/saved_model'):
    print(f'Protobuf Checkpoint directory already exists')
    # !ls -ld ./content/data/saved_model
else:
    print(f'Protobuf Checkpoint directory doesnt exists.. Creating it now..')
    os.mkdir('./content/data/saved_model')
    print(f'Weight Checkpoint directory successfully created')
    # !ls -ld ./content/data/saved_model
# Out:
# Weight Checkpoint directory already exists
# drwxr-xr-x 2 root root 4096 Apr 19 23:57 ./content/data/ckpt
# Protobuf Checkpoint directory already exists
# drwxr-xr-x 2 root root 4096 Apr 19 23:57 ./content/data/saved_model

# %%
class Model_Train():
    def __init__(self, model, optimizer, loss_fn, epochs, batch_size, train_gen, valid_gen, test_gen, train_acc_metric, val_acc_metric, test_acc_metric):
        super().__init__()

        self.model = model
        self.optimizer = optimizer
        self.loss_fn = loss_fn
        self.epochs = epochs
        self.batch_size = batch_size
        self.train_generator = train_gen
        self.valid_generator = valid_gen
        self.test_generator = test_gen
        self.steps_train = len(train_gen)
        self.steps_valid = len(valid_gen)
        self.steps_test = len(test_gen)
        self.train_acc_metric = train_acc_metric
        self.val_acc_metric = val_acc_metric
        self.test_acc_metric = test_acc_metric
        self.train_history = {'loss': [], 'accuracy': [], 'f1': [], 'precision': [], 'recall': []}
        self.valid_history = {'loss': [], 'accuracy': [], 'f1': [], 'precision': [], 'recall': [], 'ckpt_name': []}


   

    @tensorflow.function
    def train_step(self, train_data, train_label):
        with tensorflow.GradientTape() as tape:
            output = self.model(train_data, training=True)
            loss_value = self.loss_fn(train_label, output)
        grads = tape.gradient(loss_value, self.model.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_weights))
        self.train_acc_metric.update_state(train_label, output)
        return output, loss_value

    @tensorflow.function
    def test_step(self, validation_data, validation_label):
        val_output = self.model(validation_data, training=False)
        loss_value = self.loss_fn(validation_label, val_output)
        self.val_acc_metric.update_state(validation_label, val_output)
        return val_output, loss_value

    def getloss_accuracy(self, gen, batch_size, steps_per_epoch, df, train=False, valid=False):
        loss_epoch = 0
        for step, (x_batch, y_batch) in enumerate(gen):
            if train:
                output, loss_value = self.train_step(x_batch, y_batch)
        ###new code below
        
                pred_labls = list(np.argmax(output.numpy(), axis=1))
                temp_df = pd.DataFrame({'orig_label': list(y_batch), 'pred_label': pred_labls})
                df = pd.concat([df, temp_df])
            

        ## newcode above
        
            else:
                output, loss_value = self.test_step(x_batch, y_batch)
                pred_labls = list(np.argmax(output.numpy(), axis=1))
                temp_df = pd.DataFrame({'orig_label': list(y_batch), 'pred_label': pred_labls})
                df = pd.concat([df, temp_df])
            
            loss_epoch += loss_value*x_batch.shape[0]
            if step >= (steps_per_epoch-1):
                
                if train:
                    avg_epoch_loss = (loss_epoch/(len(train_df))).numpy()
                    accuracy = self.train_acc_metric.result().numpy()
                    self.train_acc_metric.reset_states()
                    gen.on_epoch_end()
                else:
                    if valid:
                        avg_epoch_loss = (loss_epoch/(len(valid_df))).numpy()
                        accuracy = self.val_acc_metric.result().numpy()
                        self.val_acc_metric.reset_states()
                    else:
                        avg_epoch_loss = (loss_epoch/(len(test_df))).numpy()
                        accuracy = self.val_acc_metric.result().numpy()
                        self.val_acc_metric.reset_states()


                return df, avg_epoch_loss, accuracy

    def train_validate_loop(self):
        for epoch in range(self.epochs):
            start_time = time.time()
            histdf_train = pd.DataFrame({'orig_label': [], 'pred_label': []})
            histdf_val   = pd.DataFrame({'orig_label': [], 'pred_label': []})  

            df_train_cm, avg_epoch_train_loss, train_accuracy = self.getloss_accuracy(self.train_generator, self.batch_size, self.steps_train, histdf_train, train=True)
            df_val_cm, avg_epoch_val_loss, val_accuracy = self.getloss_accuracy(self.valid_generator, self.batch_size, self.steps_valid, histdf_val, train=False, valid=True)

    
            f1, precision, recall             = self.calc_rec_prec_f1(df_train_cm, train=True)
            f1_val, precision_val, recall_val = self.calc_rec_prec_f1(df_val_cm, train=False)


            print(f'Epoch : {epoch}, Train Loss: {avg_epoch_train_loss}, Train Accuracy: {train_accuracy}, Validation Loss: {avg_epoch_val_loss}, Validation Accuracy: {val_accuracy}')
      
            self.train_history['loss'].append(avg_epoch_train_loss)
            self.train_history['accuracy'].append(train_accuracy)
            self.train_history['f1'].append(f1)
            self.train_history['precision'].append(precision)
            self.train_history['recall'].append(recall)

            self.valid_history['loss'].append(avg_epoch_val_loss)
            self.valid_history['accuracy'].append(val_accuracy)
            self.valid_history['f1'].append(f1_val)
            self.valid_history['precision'].append(precision_val)
            self.valid_history['recall'].append(recall_val)

      ###New Code for early stopping#####
            la = self.valid_history['accuracy']
            if (len(la) > 4):
                if (((la[-1] <= la[-2]) and (la[-2] <= la[-3])) and ((la[-3] <= la[-4]) and (la[-4] <= la[-5]))):
                    print("Validation accuracy has not improved over last 4 epochs, hence invoking early stopping and exiting training process")
                    if len(self.valid_history['ckpt_name']) > 0:
                        print('Loading Best weights..')
                        self.model.load_weights(self.valid_history['ckpt_name'][-1])
                        break
                    else:
                        print("Ouch !! seems like you dont have any checkpoints saved matching criteria specified in logic. Please excuse !")
                        break
                        
                    
            if ((la[-1] > 0.9) and (la[-1] > max(la[0:-1]))):
                ckpt_name = './content/data/ckpt/' + 'ckpt' + '_' + str(la[-1]) + '_acc.pt'
                #pb_name = './content/data/saved_model/' + 'ckpt' + '_' + str(la[-1]) + '_acc'
                self.model.save_weights(ckpt_name)
                self.valid_history['ckpt_name'].append(ckpt_name)
                print(f'Saved Checkpoint : {ckpt_name}')
                #self.model.save(pb_name)
                #print(f'Saved model in protobuf format : {pb_name}')




      #####New Cod for early stopping


    
            print(f'Time taken: {np.round((time.time() - start_time), 4)}')
        print(f'Training completed successfully. Loading best checkpoint weights ...')
        if len(self.valid_history['ckpt_name']) > 0:
            self.model.load_weights(self.valid_history['ckpt_name'][-1])
            print(f'Best checkpoint weights loaded : {self.valid_history["ckpt_name"][-1]}')
        else:
            print("Ouch !! seems like you dont have any checkpoints saved matching criteria specified in logic. Please excuse !")

      #draw graph depicting train and validation losses and accuracy + recall, f1
        return self.train_history, self.valid_history

    def get_test_accuracy(self):
        df = pd.DataFrame({'orig_label': [], 'pred_label': []})
        df_test, avg_test_loss, test_accuracy = self.getloss_accuracy(self.test_generator, self.batch_size, self.steps_test, df)
        return df_test, avg_test_loss, test_accuracy

    def calc_rec_prec_f1(self, df, train):
        print_string = "Training Confusion Matrix" if train else "Validation Confusion Matrix"
        print(print_string, "\n", confusion_matrix(df['orig_label'], df['pred_label']))
        tn, fp, fn, tp = confusion_matrix(df['orig_label'], df['pred_label']).ravel()
        precision = tp/(tp+fp)
        recall = tp/(tp+fn)
        f1 = 2*precision*recall/(precision+recall)
        return f1, precision, recall

    def predict_single(self,dcm_path, target_size=(224,224)):
        image_array = pydicom.dcmread(dcm_path).pixel_array
        image = Image.fromarray(image_array) #converts from array to PIL
        #image.thumbnail((224,224)) #resize image to 224,224
        image = image.resize((224,224))
        image_array = np.expand_dims(image, -1)
        image_array = image_array.astype(np.float32) # * (1.0/255.0)
        image_array = np.expand_dims(image_array, 0)
        output = self.model(image_array, training=False)
        pred_label = np.argmax(output.numpy())
        print(f'Predicted label for image supplied is : {classes[pred_label]}')
        return classes[pred_label]
    
    def pred_image_show(self,image_list):
        fig, subs = plt.subplots(3,3, figsize=(14,12))
        for i, sub in enumerate(subs.flatten()):
            print(f'Image path is {image_list[i][0]} and Original label is {classes[int(image_list[i][1])]}')
            pred_class = self.predict_single(image_list[i][0])
            image_array = pydicom.dcmread(image_list[i][0]).pixel_array
            sub.imshow(image_array, cmap='gray')
            sub.set_title(f'{pred_class}(Pred) : {classes[int(image_list[i][1])]}(Orig)')
            
    def plot_metrics(self):
        list = ['accuracy', 'loss', 'f1', 'recall', 'precision']
        for metrics in list:
            x = [i for i in range(len(self.train_history[metrics]))]
            y1 = self.train_history[metrics]
            y2 = self.valid_history[metrics]
            fig, ax = plt.subplots()
            ax.plot(x, y1, label="train_"+metrics)
            ax.plot(x, y2, label="valid_"+metrics)
            plt.suptitle(f'Plot showing {metrics} for Different Epoch Runs')
            ax.legend()
            plt.show()
## Save weights
## if current accuracy > 90 and current accuracy > max(list_accuracy) then create checkpoint and save weights. Also do a protobuf saved model
## store the saved checkpoint name in a list. This will make sure than checkpoints are stored in asecnding order.
## at the end of training , take the last element in checkpoint list and load and restore it. test accuracy should be checked using this chkpoint.

# %%
#VisionTransformer(num_heads, num_encoders, num_classes, out_dims)
#self.embed_dim = out_dims/num_heads
EPOCHS = 20
model_VIT = VisionTransformer(6, 12, 2, 768)
train_object = Model_Train(model_VIT, opt, loss_fn, EPOCHS, BATCH_SIZE, train_generator, valid_generator, test_generator,
             train_acc_metric, val_acc_metric, test_acc_metric
             )

# %%
train_object.__dict__
# Out:
# {'model': <__main__.VisionTransformer at 0x7ff318053700>,
#  'optimizer': <keras.optimizers.adam.Adam at 0x7ff321065fa0>,
#  'loss_fn': <keras.losses.SparseCategoricalCrossentropy at 0x7ff321065ac0>,
#  'epochs': 20,
#  'batch_size': 32,
#  'train_generator': <__main__.DCMDataFrameIterator at 0x7ff43e7374f0>,
#  'valid_generator': <__main__.DCMDataFrameIterator at 0x7ff43e737760>,
#  'test_generator': <__main__.DCMDataFrameIterator at 0x7ff43e737670>,
#  'steps_train': 277,
#  'steps_valid': 70,
#  'steps_test': 87,
#  'train_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7ff321072760>,
#  'val_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7ff443092160>,
#  'test_acc_metric': <keras.metrics.accuracy_metrics.SparseCategoricalAccuracy at 0x7ff318066850>,
#  'train_history': {'loss': [],
#   'accuracy': [],
#   'f1': [],
#   'precision': [],
#   'recall': []},
#  'valid_history': {'loss': [],
#   'accuracy': [],
#   'f1': [],
#   'precision': [],
#   'recall': [],
#   'ckpt_name': []}}

# %%
#current
train_dict, val_dict = train_object.train_validate_loop()

# %%
train_dict, val_dict = train_object.train_validate_loop()
# Out:
# Training Confusion Matrix
#  [[5574  948]
#  [1027 1287]]
# Validation Confusion Matrix
#  [[1570   61]
#  [ 353  226]]
# Epoch : 0, Train Loss: 0.4749818444252014, Train Accuracy: 0.7764825820922852, Validation Loss: 0.42662513256073, Validation Accuracy: 0.8126696944236755
# Time taken: 590.6687
# Training Confusion Matrix
#  [[5943  582]
#  [1023 1288]]
# Validation Confusion Matrix
#  [[1573   58]
#  [ 296  283]]
# Epoch : 1, Train Loss: 0.3900955617427826, Train Accuracy: 0.8183566927909851, Validation Loss: 0.3227634131908417, Validation Accuracy: 0.8398190140724182
# Time taken: 426.1253
# Training Confusion Matrix
#  [[5984  532]
#  [ 913 1407]]
# Validation Confusion Matrix
#  [[1594   37]
#  [ 306  273]]
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.92579186_acc.pt
# Time taken: 414.9129

# %%
train_dict, val_dict = train_object.train_validate_loop()
# Out:
# Training Confusion Matrix
#  [[5038 1481]
#  [ 971 1346]]
# Validation Confusion Matrix
#  [[1623    8]
#  [ 557   22]]
# Epoch : 0, Train Loss: 0.5821279287338257, Train Accuracy: 0.722498893737793, Validation Loss: 1.1327683925628662, Validation Accuracy: 0.7443438768386841
# Time taken: 373.4182
# Training Confusion Matrix
#  [[5886  632]
#  [1124 1194]]
# Validation Confusion Matrix
#  [[1560   71]
#  [ 323  256]]
# Epoch : 1, Train Loss: 0.4278671145439148, Train Accuracy: 0.8012675642967224, Validation Loss: 0.385795921087265, Validation Accuracy: 0.8217194676399231
# Time taken: 290.8776
# Training Confusion Matrix
#  [[5974  550]
#  [ 977 1335]]
# Validation Confusion Matrix
#  [[1391  240]
#  [ 192  387]]
# Epoch : 2, Train Loss: 0.37574467062950134, Train Accuracy: 0.82718425989151, Validation Loss: 0.3834238648414612, Validation Accuracy: 0.8045248985290527
# Time taken: 284.8651
# Training Confusion Matrix
#  [[5991  527]
#  [ 905 1413]]
# Validation Confusion Matrix
#  [[1522  109]
#  [ 260  319]]
# Epoch : 3, Train Loss: 0.35501402616500854, Train Accuracy: 0.837935745716095, Validation Loss: 0.4236184358596802, Validation Accuracy: 0.8330316543579102
# Time taken: 284.1161
# Training Confusion Matrix
#  [[5988  536]
#  [ 913 1399]]
# Validation Confusion Matrix
#  [[1496  135]
#  [ 111  468]]
# Epoch : 4, Train Loss: 0.3547888696193695, Train Accuracy: 0.8360117673873901, Validation Loss: 0.2712751030921936, Validation Accuracy: 0.888687789440155
# Time taken: 284.0659
# Training Confusion Matrix
#  [[6052  475]
#  [ 770 1539]]
# Validation Confusion Matrix
#  [[1599   32]
#  [ 293  286]]
# Epoch : 5, Train Loss: 0.32290157675743103, Train Accuracy: 0.8590991497039795, Validation Loss: 0.34899404644966125, Validation Accuracy: 0.8529411554336548
# Time taken: 284.2132
# Training Confusion Matrix
#  [[6052  474]
#  [ 770 1540]]
# Validation Confusion Matrix
#  [[1550   81]
#  [ 194  385]]
# Epoch : 6, Train Loss: 0.317038357257843, Train Accuracy: 0.859212338924408, Validation Loss: 0.30073392391204834, Validation Accuracy: 0.8755655884742737
# Time taken: 283.9508
# Training Confusion Matrix
#  [[6057  464]
#  [ 702 1613]]
# Validation Confusion Matrix
#  [[1569   62]
#  [ 205  374]]
# Epoch : 7, Train Loss: 0.3016325533390045, Train Accuracy: 0.8680398464202881, Validation Loss: 0.2721937596797943, Validation Accuracy: 0.8791854977607727
# Time taken: 283.6787
# Training Confusion Matrix
#  [[6078  445]
#  [ 700 1613]]
# Validation Confusion Matrix
#  [[1575   56]
#  [ 167  412]]
# Epoch : 8, Train Loss: 0.295804500579834, Train Accuracy: 0.8704164624214172, Validation Loss: 0.25423067808151245, Validation Accuracy: 0.8990949988365173
# Time taken: 283.1686
# Training Confusion Matrix
#  [[6082  433]
#  [ 629 1692]]
# Validation Confusion Matrix
#  [[1348  283]
#  [ 119  460]]
# Epoch : 9, Train Loss: 0.27623915672302246, Train Accuracy: 0.8798098564147949, Validation Loss: 0.3939583897590637, Validation Accuracy: 0.8180995583534241
# Time taken: 283.1197
# Training Confusion Matrix
#  [[6088  438]
#  [ 638 1672]]
# Validation Confusion Matrix
#  [[1544   87]
#  [ 103  476]]
# Epoch : 10, Train Loss: 0.2777123749256134, Train Accuracy: 0.8782254457473755, Validation Loss: 0.22305665910243988, Validation Accuracy: 0.9140271544456482
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.91402715_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.91402715_acc
# Time taken: 346.5822
# Training Confusion Matrix
#  [[6098  423]
#  [ 607 1708]]
# Validation Confusion Matrix
#  [[1437  194]
#  [  93  486]]
# Epoch : 11, Train Loss: 0.27143338322639465, Train Accuracy: 0.8834314346313477, Validation Loss: 0.29906904697418213, Validation Accuracy: 0.8701357245445251
# Time taken: 302.0345
# Training Confusion Matrix
#  [[6096  429]
#  [ 591 1720]]
# Validation Confusion Matrix
#  [[1512  119]
#  [ 167  412]]
# Epoch : 12, Train Loss: 0.27544280886650085, Train Accuracy: 0.884563148021698, Validation Loss: 0.2875808775424957, Validation Accuracy: 0.8705882430076599
# Time taken: 297.7686
# Training Confusion Matrix
#  [[6110  413]
#  [ 611 1702]]
# Validation Confusion Matrix
#  [[1592   39]
#  [ 220  359]]
# Epoch : 13, Train Loss: 0.2758413553237915, Train Accuracy: 0.8841104507446289, Validation Loss: 0.2809098958969116, Validation Accuracy: 0.8828054070472717
# Time taken: 292.4741
# Training Confusion Matrix
#  [[6121  402]
#  [ 541 1772]]
# Validation Confusion Matrix
#  [[1513  118]
#  [ 116  463]]
# Epoch : 14, Train Loss: 0.2539863586425781, Train Accuracy: 0.8932775259017944, Validation Loss: 0.25308865308761597, Validation Accuracy: 0.8941176533699036
# Time taken: 284.9027
# Training Confusion Matrix
#  [[6134  386]
#  [ 564 1752]]
# Validation Confusion Matrix
#  [[1569   62]
#  [ 172  407]]
# Epoch : 15, Train Loss: 0.2551552653312683, Train Accuracy: 0.8924852609634399, Validation Loss: 0.24938207864761353, Validation Accuracy: 0.8941176533699036
# Time taken: 284.3782
# Training Confusion Matrix
#  [[6138  394]
#  [ 554 1750]]
# Validation Confusion Matrix
#  [[1500  131]
#  [  60  519]]
# Epoch : 16, Train Loss: 0.24839645624160767, Train Accuracy: 0.8927116394042969, Validation Loss: 0.21134254336357117, Validation Accuracy: 0.9135746359825134
# Time taken: 284.4225
# Training Confusion Matrix
#  [[6161  362]
#  [ 542 1771]]
# Validation Confusion Matrix
#  [[1598   33]
#  [ 203  376]]
# Epoch : 17, Train Loss: 0.24427708983421326, Train Accuracy: 0.8976912498474121, Validation Loss: 0.2504817545413971, Validation Accuracy: 0.8932126760482788
# Time taken: 284.1929
# Training Confusion Matrix
#  [[6145  374]
#  [ 540 1777]]
# Validation Confusion Matrix
#  [[1514  117]
#  [  70  509]]
# Epoch : 18, Train Loss: 0.2465342879295349, Train Accuracy: 0.8965595364570618, Validation Loss: 0.21212606132030487, Validation Accuracy: 0.9153845906257629
# Saved Checkpoint : ./content/data/ckpt/ckpt_0.9153846_acc.pt
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Saved model in protobuf format : ./content/data/saved_model/ckpt_0.9153846_acc
# Time taken: 363.082
# Training Confusion Matrix
#  [[6167  357]
#  [ 468 1844]]
# Validation Confusion Matrix
#  [[1599   32]
#  [ 173  406]]
# Epoch : 19, Train Loss: 0.22818391025066376, Train Accuracy: 0.9066319465637207, Validation Loss: 0.22122301161289215, Validation Accuracy: 0.9072397947311401
# Time taken: 302.8299
# Training completed successfully. Loading best checkpoint weights ...
# Best checkpoint weights loaded : ./content/data/ckpt/ckpt_0.9153846_acc.pt

# %%
df, loss, accuracy = train_object.get_test_accuracy() #from df returned by function you can check which image has lables incorrectly predicted

# %%
accuracy
# Out:
# 0.9058653

# %%
confusion_matrix(df['orig_label'], df['pred_label'])
# Out:
# array([[1870,  169],
#        [  91,  632]])

# %%
train_object.predict_single(test_df.iloc[-2,0])
# Out:
# Predicted label for image supplied is : COVID
# 'COVID'

# %%
train_object.model.save_weights('./content/data/ckpt/model_best_weights')

# %%
with zipfile.ZipFile('./XRAY_resnet50_model_best_weights.zip', 'w') as myzip:
    myzip.write('./content/data/ckpt/checkpoint')
    myzip.write('./content/data/ckpt/model_best_weights.data-00000-of-00001')
    #myzip.write('./content/data/ckpt/model_best_weights.data-00001-of-00002')
    myzip.write('./content/data/ckpt/model_best_weights.index')

# %%
random_9_test = random.sample(list(test_df.values), 9)
random_9_test, len(random_9_test)
# Out:
# ([array(['./content/data/DCM/NON_COVID/Normal-4305.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-5705.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-8613.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-2406.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-5554.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-6031.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-6620.dcm', '0'], dtype=object),
#   array(['./content/data/DCM/COVID/COVID-1089.dcm', '1'], dtype=object),
#   array(['./content/data/DCM/NON_COVID/Normal-4960.dcm', '0'], dtype=object)],
#  9)

# %%
random_9_test[0][0], random_9_test[0][1]
# Out:
# ('./content/data/DCM/NON_COVID/Normal-4305.dcm', '0')

# %%
train_object.pred_image_show(random_9_test)
# Out:
# Image path is ./content/data/DCM/NON_COVID/Normal-4305.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-5705.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-8613.dcm and Original label is NON-COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-2406.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-5554.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-6031.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-6620.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID
# Image path is ./content/data/DCM/COVID/COVID-1089.dcm and Original label is COVID
# Predicted label for image supplied is : COVID
# Image path is ./content/data/DCM/NON_COVID/Normal-4960.dcm and Original label is NON-COVID
# Predicted label for image supplied is : NON-COVID

# %%
train_object.plot_metrics()

# %%
# !cp ./*model_best_weights.zip ./gdrive/MyDrive/Manning_Projects/
# Out:
# cp: cannot create regular file './gdrive/MyDrive/Manning_Projects/XRAY_resnet50_model_best_weights.zip': Input/output error
